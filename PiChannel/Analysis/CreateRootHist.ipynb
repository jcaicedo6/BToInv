# %%
import ROOT
import numpy as np
import pandas as pd
import random

import matplotlib.pyplot as plt
import time
import math, copy
# Out:
# Welcome to JupyROOT 6.26/06

# %%
df_HadronicTag_m00 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_m00_wc.csv')
df_HadronicTag_m05 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_m05_wc.csv')
df_HadronicTag_m10 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_m10_wc.csv')
df_HadronicTag_m15 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_m15_wc.csv')
df_HadronicTag_m20 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_m20_wc.csv')
df_HadronicTag_m25 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_m25_wc.csv')
df_HadronicTag_m30 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_m30_wc.csv')
df_HadronicTag_m35 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_m35_wc.csv')
df_HadronicTag_m40 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_m40_wc.csv')
df_HadronicTag_m45 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_m45_wc.csv')
df_HadronicTag_m50 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_m50_wc.csv')

df_HadronicTag_Dstar_gamma_m00 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m00_wc.csv')
df_HadronicTag_Dstar_gamma_m05 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m05_wc.csv')
df_HadronicTag_Dstar_gamma_m10 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m10_wc.csv')
df_HadronicTag_Dstar_gamma_m15 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m15_wc.csv')
df_HadronicTag_Dstar_gamma_m20 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m20_wc.csv')
df_HadronicTag_Dstar_gamma_m25 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m25_wc.csv')
df_HadronicTag_Dstar_gamma_m30 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m30_wc.csv')
df_HadronicTag_Dstar_gamma_m35 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m35_wc.csv')
df_HadronicTag_Dstar_gamma_m40 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m40_wc.csv')
df_HadronicTag_Dstar_gamma_m45 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m45_wc.csv')
df_HadronicTag_Dstar_gamma_m50 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m50_wc.csv')

df_HadronicTag_Dstar_pi0_m00 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m00_wc.csv')
df_HadronicTag_Dstar_pi0_m05 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m05_wc.csv')
df_HadronicTag_Dstar_pi0_m10 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m10_wc.csv')
df_HadronicTag_Dstar_pi0_m15 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m15_wc.csv')
df_HadronicTag_Dstar_pi0_m20 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m20_wc.csv')
df_HadronicTag_Dstar_pi0_m25 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m25_wc.csv')
df_HadronicTag_Dstar_pi0_m30 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m30_wc.csv')
df_HadronicTag_Dstar_pi0_m35 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m35_wc.csv')
df_HadronicTag_Dstar_pi0_m40 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m40_wc.csv')
df_HadronicTag_Dstar_pi0_m45 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m45_wc.csv')
df_HadronicTag_Dstar_pi0_m50 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m50_wc.csv')

df_SemilepTag_m00 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_m00_wc.csv')
df_SemilepTag_m05 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_m05_wc.csv')
df_SemilepTag_m10 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_m10_wc.csv')
df_SemilepTag_m15 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_m15_wc.csv')
df_SemilepTag_m20 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_m20_wc.csv')
df_SemilepTag_m25 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_m25_wc.csv')
df_SemilepTag_m30 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_m30_wc.csv')
df_SemilepTag_m35 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_m35_wc.csv')
df_SemilepTag_m40 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_m40_wc.csv')
df_SemilepTag_m45 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_m45_wc.csv')
df_SemilepTag_m50 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_m50_wc.csv')

df_SemilepTag_Dstar_gamma_m00 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m00_wc.csv')
df_SemilepTag_Dstar_gamma_m05 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m05_wc.csv')
df_SemilepTag_Dstar_gamma_m10 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m10_wc.csv')
df_SemilepTag_Dstar_gamma_m15 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m15_wc.csv')
df_SemilepTag_Dstar_gamma_m20 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m20_wc.csv')
df_SemilepTag_Dstar_gamma_m25 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m25_wc.csv')
df_SemilepTag_Dstar_gamma_m30 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m30_wc.csv')
df_SemilepTag_Dstar_gamma_m35 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m35_wc.csv')
df_SemilepTag_Dstar_gamma_m40 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m40_wc.csv')
df_SemilepTag_Dstar_gamma_m45 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m45_wc.csv')
df_SemilepTag_Dstar_gamma_m50 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m50_wc.csv')

df_SemilepTag_Dstar_pi0_m00 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_pi0_m00_wc.csv')
df_SemilepTag_Dstar_pi0_m05 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_pi0_m05_wc.csv')
df_SemilepTag_Dstar_pi0_m10 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_pi0_m10_wc.csv')
df_SemilepTag_Dstar_pi0_m15 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_pi0_m15_wc.csv')
df_SemilepTag_Dstar_pi0_m20 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_pi0_m20_wc.csv')
df_SemilepTag_Dstar_pi0_m25 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_pi0_m25_wc.csv')
df_SemilepTag_Dstar_pi0_m30 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_pi0_m30_wc.csv')
df_SemilepTag_Dstar_pi0_m35 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_pi0_m35_wc.csv')
df_SemilepTag_Dstar_pi0_m40 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_pi0_m40_wc.csv')
df_SemilepTag_Dstar_pi0_m45 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_pi0_m45_wc.csv')
df_SemilepTag_Dstar_pi0_m50 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_pi0_m50_wc.csv')

df_BkgHtag_D = pd.read_csv('../Analysis/Files/CSV_Files/BkgHtag_D_wc.csv')
df_BkgHtag_Dstar_gamma = pd.read_csv('../Analysis/Files/CSV_Files/BkgHtag_Dstar_gamma_wc.csv')
df_BkgHtag_Dstar_pi0 = pd.read_csv('../Analysis/Files/CSV_Files/BkgHtag_Dstar_pi0_wc.csv')

df_BkgStag_D = pd.read_csv('../Analysis/Files/CSV_Files/BkgStag_D_wc.csv')
df_BkgStag_Dstar_gamma = pd.read_csv('../Analysis/Files/CSV_Files/BkgStag_Dstar_gamma_wc.csv')
df_BkgStag_Dstar_pi0 = pd.read_csv('../Analysis/Files/CSV_Files/BkgStag_Dstar_pi0_wc.csv')

# %%
print(len(df_SemilepTag_Dstar_gamma_m00))
# Out:
# 33735

# %%
df_BkgStag_D
# Out:
#        Unnamed: 0  nEta  nEtaPrime  nTracks_  track_sig_genMotherPDG  \
# 0           33804   0.0        0.0       6.0                  -521.0
# 1           11256   0.0        0.0       4.0                   -15.0
# 2           33534   0.0        0.0       6.0                  -521.0
# 3           23461   0.0        0.0       6.0                  -521.0
# 4           11581   0.0        0.0       6.0                  -323.0
# ...           ...   ...        ...       ...                     ...
# 44566       59590   0.0        0.0       6.0                -10411.0
# 44567       42454   0.0        0.0       6.0                 10411.0
# 44568       55319   0.0        0.0       6.0                 10411.0
# 44569       46849   0.0        0.0       6.0                -10411.0
# 44570       58480   0.0        0.0       6.0                 10411.0
#
#        track_tag_genMotherPDG  pi_tag_genMotherPDG  D_tag_M   B_tag_M  \
# ...

# %%
df_BkgStag_Dstar_gamma
# Out:
#        Unnamed: 0  nEta  nEtaPrime  nTracks_  track_sig_genMotherPDG  \
# 0            4639   0.0        0.0       4.0                    15.0
# 1           18630   0.0        0.0       6.0                   521.0
# 2            6423   0.0        0.0       4.0                   -15.0
# 3            3539   0.0        0.0       6.0                  -323.0
# 4           19783   0.0        0.0       6.0                   323.0
# ...           ...   ...        ...       ...                     ...
# 13086        1924   0.0        0.0       6.0                -20413.0
# 13087       49528   0.0        0.0       6.0                -20413.0
# 13088        2344   0.0        0.0       6.0                -20413.0
# 13089       21122   0.0        0.0       6.0                -20413.0
# 13090       21961   0.0        0.0       6.0                -20413.0
#
#        track_tag_genMotherPDG  pi_tag_genMotherPDG   D_tag_M   B_tag_M  \
# ...

# %%
df_BkgStag_Dstar_pi0
# Out:
#        Unnamed: 0  nEta  nEtaPrime  nTracks_  track_sig_genMotherPDG  \
# 0            9270   0.0        0.0       6.0                   -15.0
# 1            2861   0.0        0.0       4.0                   -15.0
# 2           27693   0.0        0.0       6.0                   521.0
# 3           31404   0.0        0.0       6.0                  -521.0
# 4           16871   0.0        0.0       6.0                  -521.0
# ...           ...   ...        ...       ...                     ...
# 42790        2918   0.0        0.0       6.0                 20413.0
# 42791       49556   0.0        0.0       6.0                 20413.0
# 42792       14988   0.0        0.0       6.0                -20413.0
# 42793       50050   0.0        0.0       6.0                 20413.0
# 42794       34513   0.0        0.0       6.0                -20413.0
#
#        track_tag_genMotherPDG  pi_tag_genMotherPDG   D_tag_M   B_tag_M  \
# ...

# %%
def PandasToRD(df, flag):
    # Extract the leafs from pandas df
    #leafs = df.columns.values.tolist()
    if flag == 1:
        leafs = ['Xps', 'q2']
    else: leafs = ['Mmin2', 'Mmax2', 'Xps', 'q2']
    # Read the pandas dataframe in form of dictionary
    df_dic = {key: df[key].values for key in leafs}
    # write the dictionary with numpy arrays to a RDataframe
    RD_df = ROOT.RDF.MakeNumpyDataFrame(df_dic)
    #RD_df = ROOT.RDF.FromCSV("myfile.csv")
    return RD_df

# %%
sig_HadTag_D_m00_df = PandasToRD(df_HadronicTag_m00, flag=1)
sig_HadTag_D_m05_df = PandasToRD(df_HadronicTag_m05, flag=1)
sig_HadTag_D_m10_df = PandasToRD(df_HadronicTag_m10, flag=1)
sig_HadTag_D_m15_df = PandasToRD(df_HadronicTag_m15, flag=1)
sig_HadTag_D_m20_df = PandasToRD(df_HadronicTag_m20, flag=1)
sig_HadTag_D_m25_df = PandasToRD(df_HadronicTag_m25, flag=1)
sig_HadTag_D_m30_df = PandasToRD(df_HadronicTag_m30, flag=1)
sig_HadTag_D_m35_df = PandasToRD(df_HadronicTag_m35, flag=1)
sig_HadTag_D_m40_df = PandasToRD(df_HadronicTag_m40, flag=1)
sig_HadTag_D_m45_df = PandasToRD(df_HadronicTag_m45, flag=1)
sig_HadTag_D_m50_df = PandasToRD(df_HadronicTag_m50, flag=1)

sig_HadTag_Dstar_gamma_m00_df = PandasToRD(df_HadronicTag_Dstar_gamma_m00, flag=1)
sig_HadTag_Dstar_gamma_m05_df = PandasToRD(df_HadronicTag_Dstar_gamma_m05, flag=1)
sig_HadTag_Dstar_gamma_m10_df = PandasToRD(df_HadronicTag_Dstar_gamma_m10, flag=1)
sig_HadTag_Dstar_gamma_m15_df = PandasToRD(df_HadronicTag_Dstar_gamma_m15, flag=1)
sig_HadTag_Dstar_gamma_m20_df = PandasToRD(df_HadronicTag_Dstar_gamma_m20, flag=1)
sig_HadTag_Dstar_gamma_m25_df = PandasToRD(df_HadronicTag_Dstar_gamma_m25, flag=1)
sig_HadTag_Dstar_gamma_m30_df = PandasToRD(df_HadronicTag_Dstar_gamma_m30, flag=1)
sig_HadTag_Dstar_gamma_m35_df = PandasToRD(df_HadronicTag_Dstar_gamma_m35, flag=1)
sig_HadTag_Dstar_gamma_m40_df = PandasToRD(df_HadronicTag_Dstar_gamma_m40, flag=1)
sig_HadTag_Dstar_gamma_m45_df = PandasToRD(df_HadronicTag_Dstar_gamma_m45, flag=1)
sig_HadTag_Dstar_gamma_m50_df = PandasToRD(df_HadronicTag_Dstar_gamma_m50, flag=1)

sig_HadTag_Dstar_pi0_m00_df = PandasToRD(df_HadronicTag_Dstar_pi0_m00, flag=1)
sig_HadTag_Dstar_pi0_m05_df = PandasToRD(df_HadronicTag_Dstar_pi0_m05, flag=1)
sig_HadTag_Dstar_pi0_m10_df = PandasToRD(df_HadronicTag_Dstar_pi0_m10, flag=1)
sig_HadTag_Dstar_pi0_m15_df = PandasToRD(df_HadronicTag_Dstar_pi0_m15, flag=1)
sig_HadTag_Dstar_pi0_m20_df = PandasToRD(df_HadronicTag_Dstar_pi0_m20, flag=1)
sig_HadTag_Dstar_pi0_m25_df = PandasToRD(df_HadronicTag_Dstar_pi0_m25, flag=1)
sig_HadTag_Dstar_pi0_m30_df = PandasToRD(df_HadronicTag_Dstar_pi0_m30, flag=1)
sig_HadTag_Dstar_pi0_m35_df = PandasToRD(df_HadronicTag_Dstar_pi0_m35, flag=1)
sig_HadTag_Dstar_pi0_m40_df = PandasToRD(df_HadronicTag_Dstar_pi0_m40, flag=1)
sig_HadTag_Dstar_pi0_m45_df = PandasToRD(df_HadronicTag_Dstar_pi0_m45, flag=1)
sig_HadTag_Dstar_pi0_m50_df = PandasToRD(df_HadronicTag_Dstar_pi0_m50, flag=1)

sig_SemiTag_D_m00_df = PandasToRD(df_SemilepTag_m00, flag=2)
sig_SemiTag_D_m05_df = PandasToRD(df_SemilepTag_m05, flag=2)
sig_SemiTag_D_m10_df = PandasToRD(df_SemilepTag_m10, flag=2)
sig_SemiTag_D_m15_df = PandasToRD(df_SemilepTag_m15, flag=2)
sig_SemiTag_D_m20_df = PandasToRD(df_SemilepTag_m20, flag=2)
sig_SemiTag_D_m25_df = PandasToRD(df_SemilepTag_m25, flag=2)
sig_SemiTag_D_m30_df = PandasToRD(df_SemilepTag_m30, flag=2)
sig_SemiTag_D_m35_df = PandasToRD(df_SemilepTag_m35, flag=2)
sig_SemiTag_D_m40_df = PandasToRD(df_SemilepTag_m40, flag=2)
sig_SemiTag_D_m45_df = PandasToRD(df_SemilepTag_m45, flag=2)
sig_SemiTag_D_m50_df = PandasToRD(df_SemilepTag_m50, flag=2)

sig_SemiTag_Dstar_gamma_m00_df = PandasToRD(df_SemilepTag_Dstar_gamma_m00, flag=2)
sig_SemiTag_Dstar_gamma_m05_df = PandasToRD(df_SemilepTag_Dstar_gamma_m05, flag=2)
sig_SemiTag_Dstar_gamma_m10_df = PandasToRD(df_SemilepTag_Dstar_gamma_m10, flag=2)
sig_SemiTag_Dstar_gamma_m15_df = PandasToRD(df_SemilepTag_Dstar_gamma_m15, flag=2)
sig_SemiTag_Dstar_gamma_m20_df = PandasToRD(df_SemilepTag_Dstar_gamma_m20, flag=2)
sig_SemiTag_Dstar_gamma_m25_df = PandasToRD(df_SemilepTag_Dstar_gamma_m25, flag=2)
sig_SemiTag_Dstar_gamma_m30_df = PandasToRD(df_SemilepTag_Dstar_gamma_m30, flag=2)
sig_SemiTag_Dstar_gamma_m35_df = PandasToRD(df_SemilepTag_Dstar_gamma_m35, flag=2)
sig_SemiTag_Dstar_gamma_m40_df = PandasToRD(df_SemilepTag_Dstar_gamma_m40, flag=2)
sig_SemiTag_Dstar_gamma_m45_df = PandasToRD(df_SemilepTag_Dstar_gamma_m45, flag=2)
sig_SemiTag_Dstar_gamma_m50_df = PandasToRD(df_SemilepTag_Dstar_gamma_m50, flag=2)

sig_SemiTag_Dstar_pi0_m00_df = PandasToRD(df_SemilepTag_Dstar_pi0_m00, flag=2)
sig_SemiTag_Dstar_pi0_m05_df = PandasToRD(df_SemilepTag_Dstar_pi0_m05, flag=2)
sig_SemiTag_Dstar_pi0_m10_df = PandasToRD(df_SemilepTag_Dstar_pi0_m10, flag=2)
sig_SemiTag_Dstar_pi0_m15_df = PandasToRD(df_SemilepTag_Dstar_pi0_m15, flag=2)
sig_SemiTag_Dstar_pi0_m20_df = PandasToRD(df_SemilepTag_Dstar_pi0_m20, flag=2)
sig_SemiTag_Dstar_pi0_m25_df = PandasToRD(df_SemilepTag_Dstar_pi0_m25, flag=2)
sig_SemiTag_Dstar_pi0_m30_df = PandasToRD(df_SemilepTag_Dstar_pi0_m30, flag=2)
sig_SemiTag_Dstar_pi0_m35_df = PandasToRD(df_SemilepTag_Dstar_pi0_m35, flag=2)
sig_SemiTag_Dstar_pi0_m40_df = PandasToRD(df_SemilepTag_Dstar_pi0_m40, flag=2)
sig_SemiTag_Dstar_pi0_m45_df = PandasToRD(df_SemilepTag_Dstar_pi0_m45, flag=2)
sig_SemiTag_Dstar_pi0_m50_df = PandasToRD(df_SemilepTag_Dstar_pi0_m50, flag=2)



BkgHtag_D_df = PandasToRD(df_BkgHtag_D, flag=1)
BkgHtag_Dstar_gamma_df = PandasToRD(df_BkgHtag_Dstar_gamma, flag=1)
BkgHtag_Dstar_pi0_df = PandasToRD(df_BkgHtag_Dstar_pi0, flag=1)

BkgStag_D_df = PandasToRD(df_BkgStag_D, flag=2)
BkgStag_Dstar_gamma_df = PandasToRD(df_BkgStag_Dstar_gamma, flag=2)
BkgStag_Dstar_pi0_df = PandasToRD(df_BkgStag_Dstar_pi0, flag=2)

# %%
sig_SemiTag_Dstar_gamma_m00_df.Display().Print()
# Out:
# +-----+-------------+-------------+------------+-------------+
# | Row | Mmax2       | Mmin2       | Xps        | q2          |
# +-----+-------------+-------------+------------+-------------+
# | 0   | 0.66185046  | -2.5967604  | 1.0464084  | -0.59989600 |
# +-----+-------------+-------------+------------+-------------+
# | 1   | -0.17187269 | -3.4309141  | 1.0735682  | -2.1338954  |
# +-----+-------------+-------------+------------+-------------+
# | 2   | 0.38078374  | -0.49157460 | 0.99918299 | 0.91132134  |
# +-----+-------------+-------------+------------+-------------+
# | 3   | 0.25867926  | -2.6428963  | 1.0059750  | -0.60213939 |
# +-----+-------------+-------------+------------+-------------+
# | 4   | 0.94727171  | -1.7244010  | 1.0429671  | -0.46026284 |
# +-----+-------------+-------------+------------+-------------+

# %%
BkgStag_D_df.Display().Print()
# Out:
# +-----+------------+------------+------------+-------------+
# | Row | Mmax2      | Mmin2      | Xps        | q2          |
# +-----+------------+------------+------------+-------------+
# | 0   | 1.8766090  | 0.55651016 | 0.94952663 | 0.33670732  |
# +-----+------------+------------+------------+-------------+
# | 1   | 8.4726226  | 6.8637081  | 0.73993005 | 7.7386855   |
# +-----+------------+------------+------------+-------------+
# | 2   | 0.69853971 | -1.4267253 | 1.0139767  | 0.063167769 |
# +-----+------------+------------+------------+-------------+
# | 3   | 0.87790797 | -2.4179979 | 1.0485570  | -0.97730843 |
# +-----+------------+------------+------------+-------------+
# | 4   | 24.602293  | 24.234566  | 0.12282548 | 24.535098   |
# +-----+------------+------------+------------+-------------+

# %%
BkgStag_Dstar_gamma_df.Display().Print()
# Out:
# +-----+------------+------------+-------------+-------------+
# | Row | Mmax2      | Mmin2      | Xps         | q2          |
# +-----+------------+------------+-------------+-------------+
# | 0   | 1000.0000  | 1000.0000  | 0.80766651  | 4.7586385   |
# +-----+------------+------------+-------------+-------------+
# | 1   | 0.63463875 | -2.4472171 | 1.0647318   | -0.30301426 |
# +-----+------------+------------+-------------+-------------+
# | 2   | 1000.0000  | 1000.0000  | 0.92924128  | 3.3000620   |
# +-----+------------+------------+-------------+-------------+
# | 3   | 25.623993  | 25.455219  | 0.085676247 | 25.638403   |
# +-----+------------+------------+-------------+-------------+
# | 4   | 22.903881  | 22.566723  | 0.17323151  | 22.934589   |
# +-----+------------+------------+-------------+-------------+

# %%
BkgStag_Dstar_pi0_df.Display().Print()
# Out:
# +-----+------------+-------------+------------+-------------+
# | Row | Mmax2      | Mmin2       | Xps        | q2          |
# +-----+------------+-------------+------------+-------------+
# | 0   | 20.010501  | 19.292177   | 0.28043553 | 19.799446   |
# +-----+------------+-------------+------------+-------------+
# | 1   | 1000.0000  | 1000.0000   | 0.97089821 | 0.47922164  |
# +-----+------------+-------------+------------+-------------+
# | 2   | 0.33430124 | -0.54525719 | 1.0096603  | -0.31220786 |
# +-----+------------+-------------+------------+-------------+
# | 3   | 13.561489  | 11.784972   | 0.55444711 | 13.030591   |
# +-----+------------+-------------+------------+-------------+
# | 4   | 0.59394175 | -0.36204507 | 1.0088497  | 0.55588084  |
# +-----+------------+-------------+------------+-------------+

# %%
BkgHtag_D_df.Display().Print()
# Out:
# +-----+-------------+-----------+
# | Row | Xps         | q2        |
# +-----+-------------+-----------+
# | 0   | 0.33739281  | 18.623761 |
# +-----+-------------+-----------+
# | 1   | 0.084017220 | 25.703989 |
# +-----+-------------+-----------+
# | 2   | 0.11950529  | 24.827559 |
# +-----+-------------+-----------+
# | 3   | 0.45481893  | 15.702630 |
# +-----+-------------+-----------+
# | 4   | 0.98800633  | 1.4070288 |
# +-----+-------------+-----------+

# %%
BkgHtag_Dstar_gamma_df.Display().Print()
# Out:
# +-----+------------+-----------+
# | Row | Xps        | q2        |
# +-----+------------+-----------+
# | 0   | 0.17471340 | 23.150837 |
# +-----+------------+-----------+
# | 1   | 0.38508812 | 17.714987 |
# +-----+------------+-----------+
# | 2   | 0.31878478 | 18.906615 |
# +-----+------------+-----------+
# | 3   | 0.62313384 | 10.716304 |
# +-----+------------+-----------+
# | 4   | 0.30555732 | 19.550315 |
# +-----+------------+-----------+

# %%
BkgHtag_Dstar_pi0_df.Display().Print()
# Out:
# +-----+------------+-------------+
# | Row | Xps        | q2          |
# +-----+------------+-------------+
# | 0   | 0.34016465 | 18.566823   |
# +-----+------------+-------------+
# | 1   | 0.99401074 | -0.68230523 |
# +-----+------------+-------------+
# | 2   | 0.52584847 | 14.191362   |
# +-----+------------+-------------+
# | 3   | 0.98957561 | 1.3991965   |
# +-----+------------+-------------+
# | 4   | 0.98698916 | -1.5165339  |
# +-----+------------+-------------+

# %% [markdown]
# ## Semileptonic Tags

# %%
bins = 200
Mmin_min = -5
Mmin_max = 28
Mmax_min = -1
Mmax_max = 27
q2_min = -3
q2_max = 27

# ------------  Mmin and Mmax variables

# D tag
hS_D_m00_Mmin2 = sig_SemiTag_D_m00_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_D_m05_Mmin2 = sig_SemiTag_D_m05_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_D_m10_Mmin2 = sig_SemiTag_D_m10_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_D_m15_Mmin2 = sig_SemiTag_D_m15_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_D_m20_Mmin2 = sig_SemiTag_D_m20_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_D_m25_Mmin2 = sig_SemiTag_D_m25_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_D_m30_Mmin2 = sig_SemiTag_D_m30_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_D_m35_Mmin2 = sig_SemiTag_D_m35_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_D_m40_Mmin2 = sig_SemiTag_D_m40_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_D_m45_Mmin2 = sig_SemiTag_D_m45_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_D_m50_Mmin2 = sig_SemiTag_D_m50_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")

hS_D_m00_Mmax2 = sig_SemiTag_D_m00_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_D_m05_Mmax2 = sig_SemiTag_D_m05_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_D_m10_Mmax2 = sig_SemiTag_D_m10_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_D_m15_Mmax2 = sig_SemiTag_D_m15_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_D_m20_Mmax2 = sig_SemiTag_D_m20_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_D_m25_Mmax2 = sig_SemiTag_D_m25_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_D_m30_Mmax2 = sig_SemiTag_D_m30_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_D_m35_Mmax2 = sig_SemiTag_D_m35_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_D_m40_Mmax2 = sig_SemiTag_D_m40_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_D_m45_Mmax2 = sig_SemiTag_D_m45_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_D_m50_Mmax2 = sig_SemiTag_D_m50_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
# D0star gamma tag
hS_Dstar_gamma_m00_Mmin2 = sig_SemiTag_Dstar_gamma_m00_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_Dstar_gamma_m05_Mmin2 = sig_SemiTag_Dstar_gamma_m05_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_Dstar_gamma_m10_Mmin2 = sig_SemiTag_Dstar_gamma_m10_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_Dstar_gamma_m15_Mmin2 = sig_SemiTag_Dstar_gamma_m15_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_Dstar_gamma_m20_Mmin2 = sig_SemiTag_Dstar_gamma_m20_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_Dstar_gamma_m25_Mmin2 = sig_SemiTag_Dstar_gamma_m25_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_Dstar_gamma_m30_Mmin2 = sig_SemiTag_Dstar_gamma_m30_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_Dstar_gamma_m35_Mmin2 = sig_SemiTag_Dstar_gamma_m35_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_Dstar_gamma_m40_Mmin2 = sig_SemiTag_Dstar_gamma_m40_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_Dstar_gamma_m45_Mmin2 = sig_SemiTag_Dstar_gamma_m45_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_Dstar_gamma_m50_Mmin2 = sig_SemiTag_Dstar_gamma_m50_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")

hS_Dstar_gamma_m00_Mmax2 = sig_SemiTag_Dstar_gamma_m00_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_Dstar_gamma_m05_Mmax2 = sig_SemiTag_Dstar_gamma_m05_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_Dstar_gamma_m10_Mmax2 = sig_SemiTag_Dstar_gamma_m10_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_Dstar_gamma_m15_Mmax2 = sig_SemiTag_Dstar_gamma_m15_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_Dstar_gamma_m20_Mmax2 = sig_SemiTag_Dstar_gamma_m20_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_Dstar_gamma_m25_Mmax2 = sig_SemiTag_Dstar_gamma_m25_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_Dstar_gamma_m30_Mmax2 = sig_SemiTag_Dstar_gamma_m30_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_Dstar_gamma_m35_Mmax2 = sig_SemiTag_Dstar_gamma_m35_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_Dstar_gamma_m40_Mmax2 = sig_SemiTag_Dstar_gamma_m40_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_Dstar_gamma_m45_Mmax2 = sig_SemiTag_Dstar_gamma_m45_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_Dstar_gamma_m50_Mmax2 = sig_SemiTag_Dstar_gamma_m50_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
# D0star pi0 tag
hS_Dstar_pi0_m00_Mmin2 = sig_SemiTag_Dstar_pi0_m00_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_Dstar_pi0_m05_Mmin2 = sig_SemiTag_Dstar_pi0_m05_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_Dstar_pi0_m10_Mmin2 = sig_SemiTag_Dstar_pi0_m10_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_Dstar_pi0_m15_Mmin2 = sig_SemiTag_Dstar_pi0_m15_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_Dstar_pi0_m20_Mmin2 = sig_SemiTag_Dstar_pi0_m20_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_Dstar_pi0_m25_Mmin2 = sig_SemiTag_Dstar_pi0_m25_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_Dstar_pi0_m30_Mmin2 = sig_SemiTag_Dstar_pi0_m30_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_Dstar_pi0_m35_Mmin2 = sig_SemiTag_Dstar_pi0_m35_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_Dstar_pi0_m40_Mmin2 = sig_SemiTag_Dstar_pi0_m40_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_Dstar_pi0_m45_Mmin2 = sig_SemiTag_Dstar_pi0_m45_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_Dstar_pi0_m50_Mmin2 = sig_SemiTag_Dstar_pi0_m50_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")

hS_Dstar_pi0_m00_Mmax2 = sig_SemiTag_Dstar_pi0_m00_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_Dstar_pi0_m05_Mmax2 = sig_SemiTag_Dstar_pi0_m05_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_Dstar_pi0_m10_Mmax2 = sig_SemiTag_Dstar_pi0_m10_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_Dstar_pi0_m15_Mmax2 = sig_SemiTag_Dstar_pi0_m15_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_Dstar_pi0_m20_Mmax2 = sig_SemiTag_Dstar_pi0_m20_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_Dstar_pi0_m25_Mmax2 = sig_SemiTag_Dstar_pi0_m25_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_Dstar_pi0_m30_Mmax2 = sig_SemiTag_Dstar_pi0_m30_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_Dstar_pi0_m35_Mmax2 = sig_SemiTag_Dstar_pi0_m35_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_Dstar_pi0_m40_Mmax2 = sig_SemiTag_Dstar_pi0_m40_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_Dstar_pi0_m45_Mmax2 = sig_SemiTag_Dstar_pi0_m45_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_Dstar_pi0_m50_Mmax2 = sig_SemiTag_Dstar_pi0_m50_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")

# Background per tag
hBkgStag_D_Mmin2 = BkgStag_D_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hBkgStag_Dstar_gamma_Mmin2 = BkgStag_Dstar_gamma_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hBkgStag_Dstar_pi0_Mmin2 = BkgStag_Dstar_pi0_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")


hBkgStag_D_Mmax2 = BkgStag_D_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hBkgStag_Dstar_gamma_Mmax2 = BkgStag_Dstar_gamma_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hBkgStag_Dstar_pi0_Mmax2 = BkgStag_Dstar_pi0_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")



# ------------  Xps variable
Xps_min = 0.0
Xps_max = 1.2
# D tag
hS_D_m00_Xps = sig_SemiTag_D_m00_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_D_m05_Xps = sig_SemiTag_D_m05_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_D_m10_Xps = sig_SemiTag_D_m10_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_D_m15_Xps = sig_SemiTag_D_m15_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_D_m20_Xps = sig_SemiTag_D_m20_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_D_m25_Xps = sig_SemiTag_D_m25_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_D_m30_Xps = sig_SemiTag_D_m30_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_D_m35_Xps = sig_SemiTag_D_m35_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_D_m40_Xps = sig_SemiTag_D_m40_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_D_m45_Xps = sig_SemiTag_D_m45_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_D_m50_Xps = sig_SemiTag_D_m50_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
# D0star gamma tag
hS_Dstar_gamma_m00_Xps = sig_SemiTag_Dstar_gamma_m00_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_Dstar_gamma_m05_Xps = sig_SemiTag_Dstar_gamma_m05_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_Dstar_gamma_m10_Xps = sig_SemiTag_Dstar_gamma_m10_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_Dstar_gamma_m15_Xps = sig_SemiTag_Dstar_gamma_m15_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_Dstar_gamma_m20_Xps = sig_SemiTag_Dstar_gamma_m20_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_Dstar_gamma_m25_Xps = sig_SemiTag_Dstar_gamma_m25_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_Dstar_gamma_m30_Xps = sig_SemiTag_Dstar_gamma_m30_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_Dstar_gamma_m35_Xps = sig_SemiTag_Dstar_gamma_m35_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_Dstar_gamma_m40_Xps = sig_SemiTag_Dstar_gamma_m40_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_Dstar_gamma_m45_Xps = sig_SemiTag_Dstar_gamma_m45_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_Dstar_gamma_m50_Xps = sig_SemiTag_Dstar_gamma_m50_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
# D0star pi0 tag
hS_Dstar_pi0_m00_Xps = sig_SemiTag_Dstar_pi0_m00_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_Dstar_pi0_m05_Xps = sig_SemiTag_Dstar_pi0_m05_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_Dstar_pi0_m10_Xps = sig_SemiTag_Dstar_pi0_m10_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_Dstar_pi0_m15_Xps = sig_SemiTag_Dstar_pi0_m15_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_Dstar_pi0_m20_Xps = sig_SemiTag_Dstar_pi0_m20_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_Dstar_pi0_m25_Xps = sig_SemiTag_Dstar_pi0_m25_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_Dstar_pi0_m30_Xps = sig_SemiTag_Dstar_pi0_m30_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_Dstar_pi0_m35_Xps = sig_SemiTag_Dstar_pi0_m35_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_Dstar_pi0_m40_Xps = sig_SemiTag_Dstar_pi0_m40_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_Dstar_pi0_m45_Xps = sig_SemiTag_Dstar_pi0_m45_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_Dstar_pi0_m50_Xps = sig_SemiTag_Dstar_pi0_m50_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
# Background per tag
hBkgStag_D_Xps = BkgStag_D_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hBkgStag_Dstar_gamma_Xps = BkgStag_Dstar_gamma_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hBkgStag_Dstar_pi0_Xps = BkgStag_Dstar_pi0_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")


# ------------  variable q^2
hS_D_m00_q2 = sig_SemiTag_D_m00_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_D_m05_q2 = sig_SemiTag_D_m05_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_D_m10_q2 = sig_SemiTag_D_m10_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_D_m15_q2 = sig_SemiTag_D_m15_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_D_m20_q2 = sig_SemiTag_D_m20_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_D_m25_q2 = sig_SemiTag_D_m25_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_D_m30_q2 = sig_SemiTag_D_m30_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_D_m35_q2 = sig_SemiTag_D_m35_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_D_m40_q2 = sig_SemiTag_D_m40_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_D_m45_q2 = sig_SemiTag_D_m45_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_D_m50_q2 = sig_SemiTag_D_m50_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")

# D0star gamma tag
hS_Dstar_gamma_m00_q2 = sig_SemiTag_Dstar_gamma_m00_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_Dstar_gamma_m05_q2 = sig_SemiTag_Dstar_gamma_m05_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_Dstar_gamma_m10_q2 = sig_SemiTag_Dstar_gamma_m10_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_Dstar_gamma_m15_q2 = sig_SemiTag_Dstar_gamma_m15_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_Dstar_gamma_m20_q2 = sig_SemiTag_Dstar_gamma_m20_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_Dstar_gamma_m25_q2 = sig_SemiTag_Dstar_gamma_m25_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_Dstar_gamma_m30_q2 = sig_SemiTag_Dstar_gamma_m30_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_Dstar_gamma_m35_q2 = sig_SemiTag_Dstar_gamma_m35_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_Dstar_gamma_m40_q2 = sig_SemiTag_Dstar_gamma_m40_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_Dstar_gamma_m45_q2 = sig_SemiTag_Dstar_gamma_m45_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_Dstar_gamma_m50_q2 = sig_SemiTag_Dstar_gamma_m50_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")

# D0star pi0 tag
hS_Dstar_pi0_m00_q2 = sig_SemiTag_Dstar_pi0_m00_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_Dstar_pi0_m05_q2 = sig_SemiTag_Dstar_pi0_m05_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_Dstar_pi0_m10_q2 = sig_SemiTag_Dstar_pi0_m10_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_Dstar_pi0_m15_q2 = sig_SemiTag_Dstar_pi0_m15_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_Dstar_pi0_m20_q2 = sig_SemiTag_Dstar_pi0_m20_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_Dstar_pi0_m25_q2 = sig_SemiTag_Dstar_pi0_m25_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_Dstar_pi0_m30_q2 = sig_SemiTag_Dstar_pi0_m30_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_Dstar_pi0_m35_q2 = sig_SemiTag_Dstar_pi0_m35_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_Dstar_pi0_m40_q2 = sig_SemiTag_Dstar_pi0_m40_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_Dstar_pi0_m45_q2 = sig_SemiTag_Dstar_pi0_m45_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_Dstar_pi0_m50_q2 = sig_SemiTag_Dstar_pi0_m50_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")

# Background per tag
hBkgStag_D_q2 = BkgStag_D_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hBkgStag_Dstar_gamma_q2 = BkgStag_Dstar_gamma_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hBkgStag_Dstar_pi0_q2 = BkgStag_Dstar_pi0_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")

# %% [markdown]
# ## Hadronic Tags

# %%
bins_Had =50


q2_min_Had = -3.5
q2_max_Had = 27




# ------------  Xps variable
Xps_min_Had = 0.15
Xps_max_Had = 1.1
# D tag
hS_Had_D_m00_Xps = sig_HadTag_D_m00_df.Histo1D(("Xps", "Xps", bins_Had, Xps_min_Had, Xps_max_Had), "Xps")
hS_Had_D_m05_Xps = sig_HadTag_D_m05_df.Histo1D(("Xps", "Xps", bins_Had, Xps_min_Had, Xps_max_Had), "Xps")
hS_Had_D_m10_Xps = sig_HadTag_D_m10_df.Histo1D(("Xps", "Xps", bins_Had, Xps_min_Had, Xps_max_Had), "Xps")
hS_Had_D_m15_Xps = sig_HadTag_D_m15_df.Histo1D(("Xps", "Xps", bins_Had, Xps_min_Had, Xps_max_Had), "Xps")
hS_Had_D_m20_Xps = sig_HadTag_D_m20_df.Histo1D(("Xps", "Xps", bins_Had, Xps_min_Had, Xps_max_Had), "Xps")
hS_Had_D_m25_Xps = sig_HadTag_D_m25_df.Histo1D(("Xps", "Xps", bins_Had, Xps_min_Had, Xps_max_Had), "Xps")
hS_Had_D_m30_Xps = sig_HadTag_D_m30_df.Histo1D(("Xps", "Xps", bins_Had, Xps_min_Had, Xps_max_Had), "Xps")
hS_Had_D_m35_Xps = sig_HadTag_D_m35_df.Histo1D(("Xps", "Xps", bins_Had, Xps_min_Had, Xps_max_Had), "Xps")
hS_Had_D_m40_Xps = sig_HadTag_D_m40_df.Histo1D(("Xps", "Xps", bins_Had, Xps_min_Had, Xps_max_Had), "Xps")
hS_Had_D_m45_Xps = sig_HadTag_D_m45_df.Histo1D(("Xps", "Xps", bins_Had, Xps_min_Had, Xps_max_Had), "Xps")
hS_Had_D_m50_Xps = sig_HadTag_D_m50_df.Histo1D(("Xps", "Xps", bins_Had, Xps_min_Had, Xps_max_Had), "Xps")
# D0star gamma tag
hS_Had_Dstar_gamma_m00_Xps = sig_HadTag_Dstar_gamma_m00_df.Histo1D(("Xps", "Xps", bins_Had, Xps_min_Had, Xps_max_Had), "Xps")
hS_Had_Dstar_gamma_m05_Xps = sig_HadTag_Dstar_gamma_m05_df.Histo1D(("Xps", "Xps", bins_Had, Xps_min_Had, Xps_max_Had), "Xps")
hS_Had_Dstar_gamma_m10_Xps = sig_HadTag_Dstar_gamma_m10_df.Histo1D(("Xps", "Xps", bins_Had, Xps_min_Had, Xps_max_Had), "Xps")
hS_Had_Dstar_gamma_m15_Xps = sig_HadTag_Dstar_gamma_m15_df.Histo1D(("Xps", "Xps", bins_Had, Xps_min_Had, Xps_max_Had), "Xps")
hS_Had_Dstar_gamma_m20_Xps = sig_HadTag_Dstar_gamma_m20_df.Histo1D(("Xps", "Xps", bins_Had, Xps_min_Had, Xps_max_Had), "Xps")
hS_Had_Dstar_gamma_m25_Xps = sig_HadTag_Dstar_gamma_m25_df.Histo1D(("Xps", "Xps", bins_Had, Xps_min_Had, Xps_max_Had), "Xps")
hS_Had_Dstar_gamma_m30_Xps = sig_HadTag_Dstar_gamma_m30_df.Histo1D(("Xps", "Xps", bins_Had, Xps_min_Had, Xps_max_Had), "Xps")
hS_Had_Dstar_gamma_m35_Xps = sig_HadTag_Dstar_gamma_m35_df.Histo1D(("Xps", "Xps", bins_Had, Xps_min_Had, Xps_max_Had), "Xps")
hS_Had_Dstar_gamma_m40_Xps = sig_HadTag_Dstar_gamma_m40_df.Histo1D(("Xps", "Xps", bins_Had, Xps_min_Had, Xps_max_Had), "Xps")
hS_Had_Dstar_gamma_m45_Xps = sig_HadTag_Dstar_gamma_m45_df.Histo1D(("Xps", "Xps", bins_Had, Xps_min_Had, Xps_max_Had), "Xps")
hS_Had_Dstar_gamma_m50_Xps = sig_HadTag_Dstar_gamma_m50_df.Histo1D(("Xps", "Xps", bins_Had, Xps_min_Had, Xps_max_Had), "Xps")
# D0star pi0 tag
hS_Had_Dstar_pi0_m00_Xps = sig_HadTag_Dstar_pi0_m00_df.Histo1D(("Xps", "Xps", bins_Had, Xps_min_Had, Xps_max_Had), "Xps")
hS_Had_Dstar_pi0_m05_Xps = sig_HadTag_Dstar_pi0_m05_df.Histo1D(("Xps", "Xps", bins_Had, Xps_min_Had, Xps_max_Had), "Xps")
hS_Had_Dstar_pi0_m10_Xps = sig_HadTag_Dstar_pi0_m10_df.Histo1D(("Xps", "Xps", bins_Had, Xps_min_Had, Xps_max_Had), "Xps")
hS_Had_Dstar_pi0_m15_Xps = sig_HadTag_Dstar_pi0_m15_df.Histo1D(("Xps", "Xps", bins_Had, Xps_min_Had, Xps_max_Had), "Xps")
hS_Had_Dstar_pi0_m20_Xps = sig_HadTag_Dstar_pi0_m20_df.Histo1D(("Xps", "Xps", bins_Had, Xps_min_Had, Xps_max_Had), "Xps")
hS_Had_Dstar_pi0_m25_Xps = sig_HadTag_Dstar_pi0_m25_df.Histo1D(("Xps", "Xps", bins_Had, Xps_min_Had, Xps_max_Had), "Xps")
hS_Had_Dstar_pi0_m30_Xps = sig_HadTag_Dstar_pi0_m30_df.Histo1D(("Xps", "Xps", bins_Had, Xps_min_Had, Xps_max_Had), "Xps")
hS_Had_Dstar_pi0_m35_Xps = sig_HadTag_Dstar_pi0_m35_df.Histo1D(("Xps", "Xps", bins_Had, Xps_min_Had, Xps_max_Had), "Xps")
hS_Had_Dstar_pi0_m40_Xps = sig_HadTag_Dstar_pi0_m40_df.Histo1D(("Xps", "Xps", bins_Had, Xps_min_Had, Xps_max_Had), "Xps")
hS_Had_Dstar_pi0_m45_Xps = sig_HadTag_Dstar_pi0_m45_df.Histo1D(("Xps", "Xps", bins_Had, Xps_min_Had, Xps_max_Had), "Xps")
hS_Had_Dstar_pi0_m50_Xps = sig_HadTag_Dstar_pi0_m50_df.Histo1D(("Xps", "Xps", bins_Had, Xps_min_Had, Xps_max_Had), "Xps")
# Background per tag
hBkgHtag_D_Xps = BkgHtag_D_df.Histo1D(("Xps", "Xps", bins_Had, Xps_min, Xps_max), "Xps")
hBkgHtag_Dstar_gamma_Xps = BkgHtag_Dstar_gamma_df.Histo1D(("Xps", "Xps", bins_Had, Xps_min, Xps_max), "Xps")
hBkgHtag_Dstar_pi0_Xps = BkgHtag_Dstar_pi0_df.Histo1D(("Xps", "Xps", bins_Had, Xps_min, Xps_max), "Xps")


# ------------  variable q^2
hS_Had_D_m00_q2 = sig_HadTag_D_m00_df.Histo1D(("q2", "q2", bins_Had, q2_min_Had, q2_max_Had), "q2")
hS_Had_D_m05_q2 = sig_HadTag_D_m05_df.Histo1D(("q2", "q2", bins_Had, q2_min_Had, q2_max_Had), "q2")
hS_Had_D_m10_q2 = sig_HadTag_D_m10_df.Histo1D(("q2", "q2", bins_Had, q2_min_Had, q2_max_Had), "q2")
hS_Had_D_m15_q2 = sig_HadTag_D_m15_df.Histo1D(("q2", "q2", bins_Had, q2_min_Had, q2_max_Had), "q2")
hS_Had_D_m20_q2 = sig_HadTag_D_m20_df.Histo1D(("q2", "q2", bins_Had, q2_min_Had, q2_max_Had), "q2")
hS_Had_D_m25_q2 = sig_HadTag_D_m25_df.Histo1D(("q2", "q2", bins_Had, q2_min_Had, q2_max_Had), "q2")
hS_Had_D_m30_q2 = sig_HadTag_D_m30_df.Histo1D(("q2", "q2", bins_Had, q2_min_Had, q2_max_Had), "q2")
hS_Had_D_m35_q2 = sig_HadTag_D_m35_df.Histo1D(("q2", "q2", bins_Had, q2_min_Had, q2_max_Had), "q2")
hS_Had_D_m40_q2 = sig_HadTag_D_m40_df.Histo1D(("q2", "q2", bins_Had, q2_min_Had, q2_max_Had), "q2")
hS_Had_D_m45_q2 = sig_HadTag_D_m45_df.Histo1D(("q2", "q2", bins_Had, q2_min_Had, q2_max_Had), "q2")
hS_Had_D_m50_q2 = sig_HadTag_D_m50_df.Histo1D(("q2", "q2", bins_Had, q2_min_Had, q2_max_Had), "q2")

# D0star gamma tag
hS_Had_Dstar_gamma_m00_q2 = sig_HadTag_Dstar_gamma_m00_df.Histo1D(("q2", "q2", bins_Had, q2_min_Had, q2_max_Had), "q2")
hS_Had_Dstar_gamma_m05_q2 = sig_HadTag_Dstar_gamma_m05_df.Histo1D(("q2", "q2", bins_Had, q2_min_Had, q2_max_Had), "q2")
hS_Had_Dstar_gamma_m10_q2 = sig_HadTag_Dstar_gamma_m10_df.Histo1D(("q2", "q2", bins_Had, q2_min_Had, q2_max_Had), "q2")
hS_Had_Dstar_gamma_m15_q2 = sig_HadTag_Dstar_gamma_m15_df.Histo1D(("q2", "q2", bins_Had, q2_min_Had, q2_max_Had), "q2")
hS_Had_Dstar_gamma_m20_q2 = sig_HadTag_Dstar_gamma_m20_df.Histo1D(("q2", "q2", bins_Had, q2_min_Had, q2_max_Had), "q2")
hS_Had_Dstar_gamma_m25_q2 = sig_HadTag_Dstar_gamma_m25_df.Histo1D(("q2", "q2", bins_Had, q2_min_Had, q2_max_Had), "q2")
hS_Had_Dstar_gamma_m30_q2 = sig_HadTag_Dstar_gamma_m30_df.Histo1D(("q2", "q2", bins_Had, q2_min_Had, q2_max_Had), "q2")
hS_Had_Dstar_gamma_m35_q2 = sig_HadTag_Dstar_gamma_m35_df.Histo1D(("q2", "q2", bins_Had, q2_min_Had, q2_max_Had), "q2")
hS_Had_Dstar_gamma_m40_q2 = sig_HadTag_Dstar_gamma_m40_df.Histo1D(("q2", "q2", bins_Had, q2_min_Had, q2_max_Had), "q2")
hS_Had_Dstar_gamma_m45_q2 = sig_HadTag_Dstar_gamma_m45_df.Histo1D(("q2", "q2", bins_Had, q2_min_Had, q2_max_Had), "q2")
hS_Had_Dstar_gamma_m50_q2 = sig_HadTag_Dstar_gamma_m50_df.Histo1D(("q2", "q2", bins_Had, q2_min_Had, q2_max_Had), "q2")

# D0star pi0 tag
hS_Had_Dstar_pi0_m00_q2 = sig_HadTag_Dstar_pi0_m00_df.Histo1D(("q2", "q2", bins_Had, q2_min_Had, q2_max_Had), "q2")
hS_Had_Dstar_pi0_m05_q2 = sig_HadTag_Dstar_pi0_m05_df.Histo1D(("q2", "q2", bins_Had, q2_min_Had, q2_max_Had), "q2")
hS_Had_Dstar_pi0_m10_q2 = sig_HadTag_Dstar_pi0_m10_df.Histo1D(("q2", "q2", bins_Had, q2_min_Had, q2_max_Had), "q2")
hS_Had_Dstar_pi0_m15_q2 = sig_HadTag_Dstar_pi0_m15_df.Histo1D(("q2", "q2", bins_Had, q2_min_Had, q2_max_Had), "q2")
hS_Had_Dstar_pi0_m20_q2 = sig_HadTag_Dstar_pi0_m20_df.Histo1D(("q2", "q2", bins_Had, q2_min_Had, q2_max_Had), "q2")
hS_Had_Dstar_pi0_m25_q2 = sig_HadTag_Dstar_pi0_m25_df.Histo1D(("q2", "q2", bins_Had, q2_min_Had, q2_max_Had), "q2")
hS_Had_Dstar_pi0_m30_q2 = sig_HadTag_Dstar_pi0_m30_df.Histo1D(("q2", "q2", bins_Had, q2_min_Had, q2_max_Had), "q2")
hS_Had_Dstar_pi0_m35_q2 = sig_HadTag_Dstar_pi0_m35_df.Histo1D(("q2", "q2", bins_Had, q2_min_Had, q2_max_Had), "q2")
hS_Had_Dstar_pi0_m40_q2 = sig_HadTag_Dstar_pi0_m40_df.Histo1D(("q2", "q2", bins_Had, q2_min_Had, q2_max_Had), "q2")
hS_Had_Dstar_pi0_m45_q2 = sig_HadTag_Dstar_pi0_m45_df.Histo1D(("q2", "q2", bins_Had, q2_min_Had, q2_max_Had), "q2")
hS_Had_Dstar_pi0_m50_q2 = sig_HadTag_Dstar_pi0_m50_df.Histo1D(("q2", "q2", bins_Had, q2_min_Had, q2_max_Had), "q2")
# Background per tag
hBkgHtag_D_q2 = BkgHtag_D_df.Histo1D(("q2", "q2", bins_Had, q2_min, q2_max), "q2")
hBkgHtag_Dstar_gamma_q2 = BkgHtag_Dstar_gamma_df.Histo1D(("q2", "q2", bins_Had, q2_min, q2_max), "q2")
hBkgHtag_Dstar_pi0_q2 = BkgHtag_Dstar_pi0_df.Histo1D(("q2", "q2", bins_Had, q2_min, q2_max), "q2")

# %% [markdown]
# ## Saving the histograms in root files
# For Semileptonic tags

# %% [markdown]
# Mmin2 and Mmax2

# %%
# Lest's create the root files
# D tag
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m00_Mmin2_pdf.root', 'RECREATE' )
hS_D_m00_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m05_Mmin2_pdf.root', 'RECREATE' )
hS_D_m05_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m10_Mmin2_pdf.root', 'RECREATE' )
hS_D_m10_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m15_Mmin2_pdf.root', 'RECREATE' )
hS_D_m15_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m20_Mmin2_pdf.root', 'RECREATE' )
hS_D_m20_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m25_Mmin2_pdf.root', 'RECREATE' )
hS_D_m25_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m30_Mmin2_pdf.root', 'RECREATE' )
hS_D_m30_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m35_Mmin2_pdf.root', 'RECREATE' )
hS_D_m35_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m40_Mmin2_pdf.root', 'RECREATE' )
hS_D_m40_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m45_Mmin2_pdf.root', 'RECREATE' )
hS_D_m45_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m50_Mmin2_pdf.root', 'RECREATE' )
hS_D_m50_Mmin2.Write()
myfile.Close()

myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m00_Mmax2_pdf.root', 'RECREATE' )
hS_D_m00_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m05_Mmax2_pdf.root', 'RECREATE' )
hS_D_m05_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m10_Mmax2_pdf.root', 'RECREATE' )
hS_D_m10_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m15_Mmax2_pdf.root', 'RECREATE' )
hS_D_m15_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m20_Mmax2_pdf.root', 'RECREATE' )
hS_D_m20_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m25_Mmax2_pdf.root', 'RECREATE' )
hS_D_m25_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m30_Mmax2_pdf.root', 'RECREATE' )
hS_D_m30_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m35_Mmax2_pdf.root', 'RECREATE' )
hS_D_m35_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m40_Mmax2_pdf.root', 'RECREATE' )
hS_D_m40_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m45_Mmax2_pdf.root', 'RECREATE' )
hS_D_m45_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m50_Mmax2_pdf.root', 'RECREATE' )
hS_D_m50_Mmax2.Write()
myfile.Close()

# %%
# Lest's create the root files
# Dstar_gamma tag
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m00_Mmin2_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m00_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m05_Mmin2_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m05_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m10_Mmin2_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m10_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m15_Mmin2_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m15_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m20_Mmin2_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m20_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m25_Mmin2_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m25_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m30_Mmin2_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m30_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m35_Mmin2_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m35_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m40_Mmin2_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m40_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m45_Mmin2_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m45_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m50_Mmin2_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m50_Mmin2.Write()
myfile.Close()

myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m00_Mmax2_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m00_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m05_Mmax2_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m05_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m10_Mmax2_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m10_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m15_Mmax2_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m15_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m20_Mmax2_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m20_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m25_Mmax2_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m25_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m30_Mmax2_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m30_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m35_Mmax2_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m35_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m40_Mmax2_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m40_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m45_Mmax2_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m45_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m50_Mmax2_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m50_Mmax2.Write()
myfile.Close()

# %%
# Lest's create the root files
# Dstar_pi0 tag
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m00_Mmin2_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m00_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m05_Mmin2_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m05_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m10_Mmin2_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m10_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m15_Mmin2_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m15_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m20_Mmin2_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m20_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m25_Mmin2_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m25_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m30_Mmin2_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m30_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m35_Mmin2_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m35_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m40_Mmin2_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m40_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m45_Mmin2_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m45_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m50_Mmin2_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m50_Mmin2.Write()
myfile.Close()

myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m00_Mmax2_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m00_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m05_Mmax2_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m05_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m10_Mmax2_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m10_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m15_Mmax2_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m15_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m20_Mmax2_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m20_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m25_Mmax2_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m25_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m30_Mmax2_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m30_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m35_Mmax2_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m35_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m40_Mmax2_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m40_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m45_Mmax2_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m45_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m50_Mmax2_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m50_Mmax2.Write()
myfile.Close()

# %%
# Now for background files
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgStag_D_Mmin2_pdf.root', 'RECREATE' )
hBkgStag_D_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_gamma_Mmin2_pdf.root', 'RECREATE' )
hBkgStag_Dstar_gamma_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_pi0_Mmin2_pdf.root', 'RECREATE' )
hBkgStag_Dstar_pi0_Mmin2.Write()
myfile.Close()

myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgStag_D_Mmax2_pdf.root', 'RECREATE' )
hBkgStag_D_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_gamma_Mmax2_pdf.root', 'RECREATE' )
hBkgStag_Dstar_gamma_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_pi0_Mmax2_pdf.root', 'RECREATE' )
hBkgStag_Dstar_pi0_Mmax2.Write()
myfile.Close()

# %% [markdown]
# Xps

# %%
# Lest's create the root files for Xps
# D tag
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m00_Xps_pdf.root', 'RECREATE' )
hS_D_m00_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m05_Xps_pdf.root', 'RECREATE' )
hS_D_m05_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m10_Xps_pdf.root', 'RECREATE' )
hS_D_m10_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m15_Xps_pdf.root', 'RECREATE' )
hS_D_m15_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m20_Xps_pdf.root', 'RECREATE' )
hS_D_m20_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m25_Xps_pdf.root', 'RECREATE' )
hS_D_m25_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m30_Xps_pdf.root', 'RECREATE' )
hS_D_m30_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m35_Xps_pdf.root', 'RECREATE' )
hS_D_m35_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m40_Xps_pdf.root', 'RECREATE' )
hS_D_m40_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m45_Xps_pdf.root', 'RECREATE' )
hS_D_m45_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_D_m50_Xps_pdf.root', 'RECREATE' )
hS_D_m50_Xps.Write()
myfile.Close()

# %%
# Lest's create the root files for Xps
# D_star_gama tag
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m00_Xps_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m00_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m05_Xps_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m05_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m10_Xps_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m10_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m15_Xps_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m15_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m20_Xps_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m20_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m25_Xps_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m25_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m30_Xps_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m30_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m35_Xps_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m35_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m40_Xps_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m40_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m45_Xps_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m45_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m50_Xps_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m50_Xps.Write()
myfile.Close()

# %%
# Lest's create the root files for Xps
# D_star_pi0 tag
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m00_Xps_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m00_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m05_Xps_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m05_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m10_Xps_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m10_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m15_Xps_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m15_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m20_Xps_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m20_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m25_Xps_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m25_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m30_Xps_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m30_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m35_Xps_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m35_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m40_Xps_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m40_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m45_Xps_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m45_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m50_Xps_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m50_Xps.Write()
myfile.Close()

# %%
# Now for background files
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgStag_D_Xps_pdf.root', 'RECREATE' )
hBkgStag_D_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_gamma_Xps_pdf.root', 'RECREATE' )
hBkgStag_Dstar_gamma_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_pi0_Xps_pdf.root', 'RECREATE' )
hBkgStag_Dstar_pi0_Xps.Write()
myfile.Close()

# %% [markdown]
# ## ROOT files for q2

# %%
# Lest's create the root files
# D tag
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m00_q2_pdf.root', 'RECREATE' )
hS_D_m00_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m05_q2_pdf.root', 'RECREATE' )
hS_D_m05_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m10_q2_pdf.root', 'RECREATE' )
hS_D_m10_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m15_q2_pdf.root', 'RECREATE' )
hS_D_m15_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m20_q2_pdf.root', 'RECREATE' )
hS_D_m20_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m25_q2_pdf.root', 'RECREATE' )
hS_D_m25_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m30_q2_pdf.root', 'RECREATE' )
hS_D_m30_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m35_q2_pdf.root', 'RECREATE' )
hS_D_m35_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m40_q2_pdf.root', 'RECREATE' )
hS_D_m40_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m45_q2_pdf.root', 'RECREATE' )
hS_D_m45_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_D_m50_q2_pdf.root', 'RECREATE' )
hS_D_m50_q2.Write()
myfile.Close()

# %%
# Dstar_gamma tag
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m00_q2_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m00_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m05_q2_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m05_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m10_q2_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m10_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m15_q2_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m15_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m20_q2_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m20_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m25_q2_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m25_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m30_q2_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m30_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m35_q2_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m35_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m40_q2_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m40_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m45_q2_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m45_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m50_q2_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m50_q2.Write()
myfile.Close()

# %%
# Dstar_pi0 tag
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m00_q2_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m00_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m05_q2_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m05_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m10_q2_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m10_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m15_q2_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m15_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m20_q2_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m20_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m25_q2_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m25_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m30_q2_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m30_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m35_q2_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m35_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m40_q2_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m40_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m45_q2_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m45_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m50_q2_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m50_q2.Write()
myfile.Close()

# %%
# Now for background files
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgStag_D_q2_pdf.root', 'RECREATE' )
hBkgStag_D_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_gamma_q2_pdf.root', 'RECREATE' )
hBkgStag_Dstar_gamma_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_pi0_q2_pdf.root', 'RECREATE' )
hBkgStag_Dstar_pi0_q2.Write()
myfile.Close()

# %% [markdown]
# ## Hadronic tags
# Mmin2 and Mmax2

# %% [markdown]
# # Lest's create the root files
# # D tag
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_D_m00_Mmin2_pdf.root', 'RECREATE' )
# hS_Had_D_m00_Mmin2.Write()
# myfile.Close()
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_D_m10_Mmin2_pdf.root', 'RECREATE' )
# hS_Had_D_m10_Mmin2.Write()
# myfile.Close()
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_D_m20_Mmin2_pdf.root', 'RECREATE' )
# hS_Had_D_m20_Mmin2.Write()
# myfile.Close()
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_D_m30_Mmin2_pdf.root', 'RECREATE' )
# hS_Had_D_m30_Mmin2.Write()
# myfile.Close()
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_D_m40_Mmin2_pdf.root', 'RECREATE' )
# hS_Had_D_m40_Mmin2.Write()
# myfile.Close()
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_D_m50_Mmin2_pdf.root', 'RECREATE' )
# hS_Had_D_m50_Mmin2.Write()
# myfile.Close()
#
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_D_m00_Mmax2_pdf.root', 'RECREATE' )
# hS_Had_D_m00_Mmax2.Write()
# myfile.Close()
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_D_m10_Mmax2_pdf.root', 'RECREATE' )
# hS_Had_D_m10_Mmax2.Write()
# myfile.Close()
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_D_m20_Mmax2_pdf.root', 'RECREATE' )
# hS_Had_D_m20_Mmax2.Write()
# myfile.Close()
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_D_m30_Mmax2_pdf.root', 'RECREATE' )
# hS_Had_D_m30_Mmax2.Write()
# myfile.Close()
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_D_m40_Mmax2_pdf.root', 'RECREATE' )
# hS_Had_D_m40_Mmax2.Write()
# myfile.Close()
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_D_m50_Mmax2_pdf.root', 'RECREATE' )
# hS_Had_D_m50_Mmax2.Write()
# myfile.Close()

# %% [markdown]
# # Lest's create the root files
# # Dstar_gamma tag
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m00_Mmin2_pdf.root', 'RECREATE' )
# hS_Had_Dstar_gamma_m00_Mmin2.Write()
# myfile.Close()
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m10_Mmin2_pdf.root', 'RECREATE' )
# hS_Had_Dstar_gamma_m10_Mmin2.Write()
# myfile.Close()
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m20_Mmin2_pdf.root', 'RECREATE' )
# hS_Had_Dstar_gamma_m20_Mmin2.Write()
# myfile.Close()
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m30_Mmin2_pdf.root', 'RECREATE' )
# hS_Had_Dstar_gamma_m30_Mmin2.Write()
# myfile.Close()
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m40_Mmin2_pdf.root', 'RECREATE' )
# hS_Had_Dstar_gamma_m40_Mmin2.Write()
# myfile.Close()
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m50_Mmin2_pdf.root', 'RECREATE' )
# hS_Had_Dstar_gamma_m50_Mmin2.Write()
# myfile.Close()
#
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m00_Mmax2_pdf.root', 'RECREATE' )
# hS_Had_Dstar_gamma_m00_Mmax2.Write()
# myfile.Close()
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m10_Mmax2_pdf.root', 'RECREATE' )
# hS_Had_Dstar_gamma_m10_Mmax2.Write()
# myfile.Close()
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m20_Mmax2_pdf.root', 'RECREATE' )
# hS_Had_Dstar_gamma_m20_Mmax2.Write()
# myfile.Close()
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m30_Mmax2_pdf.root', 'RECREATE' )
# hS_Had_Dstar_gamma_m30_Mmax2.Write()
# myfile.Close()
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m40_Mmax2_pdf.root', 'RECREATE' )
# hS_Had_Dstar_gamma_m40_Mmax2.Write()
# myfile.Close()
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m50_Mmax2_pdf.root', 'RECREATE' )
# hS_Had_Dstar_gamma_m50_Mmax2.Write()
# myfile.Close()

# %% [markdown]
# # Lest's create the root files
# # Dstar_pi0 tag
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m00_Mmin2_pdf.root', 'RECREATE' )
# hS_Had_Dstar_pi0_m00_Mmin2.Write()
# myfile.Close()
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m10_Mmin2_pdf.root', 'RECREATE' )
# hS_Had_Dstar_pi0_m10_Mmin2.Write()
# myfile.Close()
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m20_Mmin2_pdf.root', 'RECREATE' )
# hS_Had_Dstar_pi0_m20_Mmin2.Write()
# myfile.Close()
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m30_Mmin2_pdf.root', 'RECREATE' )
# hS_Had_Dstar_pi0_m30_Mmin2.Write()
# myfile.Close()
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m40_Mmin2_pdf.root', 'RECREATE' )
# hS_Had_Dstar_pi0_m40_Mmin2.Write()
# myfile.Close()
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m50_Mmin2_pdf.root', 'RECREATE' )
# hS_Had_Dstar_pi0_m50_Mmin2.Write()
# myfile.Close()
#
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m00_Mmax2_pdf.root', 'RECREATE' )
# hS_Had_Dstar_pi0_m00_Mmax2.Write()
# myfile.Close()
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m10_Mmax2_pdf.root', 'RECREATE' )
# hS_Had_Dstar_pi0_m10_Mmax2.Write()
# myfile.Close()
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m20_Mmax2_pdf.root', 'RECREATE' )
# hS_Had_Dstar_pi0_m20_Mmax2.Write()
# myfile.Close()
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m30_Mmax2_pdf.root', 'RECREATE' )
# hS_Had_Dstar_pi0_m30_Mmax2.Write()
# myfile.Close()
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m40_Mmax2_pdf.root', 'RECREATE' )
# hS_Had_Dstar_pi0_m40_Mmax2.Write()
# myfile.Close()
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m50_Mmax2_pdf.root', 'RECREATE' )
# hS_Had_Dstar_pi0_m50_Mmax2.Write()
# myfile.Close()

# %% [markdown]
# # Now for background files
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgHtag_D_Mmin2_pdf.root', 'RECREATE' )
# hBkgHtag_D_Mmin2.Write()
# myfile.Close()
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgHtag_Dstar_gamma_Mmin2_pdf.root', 'RECREATE' )
# hBkgHtag_Dstar_gamma_Mmin2.Write()
# myfile.Close()
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgHtag_Dstar_pi0_Mmin2_pdf.root', 'RECREATE' )
# hBkgHtag_Dstar_pi0_Mmin2.Write()
# myfile.Close()
#
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgHtag_D_Mmax2_pdf.root', 'RECREATE' )
# hBkgHtag_D_Mmax2.Write()
# myfile.Close()
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgHtag_Dstar_gamma_Mmax2_pdf.root', 'RECREATE' )
# hBkgHtag_Dstar_gamma_Mmax2.Write()
# myfile.Close()
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgHtag_Dstar_pi0_Mmax2_pdf.root', 'RECREATE' )
# hBkgHtag_Dstar_pi0_Mmax2.Write()
# myfile.Close()

# %% [markdown]
# Xps

# %%
# Lest's create the root files for Xps
# D tag
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_D_m00_Xps_pdf.root', 'RECREATE' )
hS_Had_D_m00_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_D_m05_Xps_pdf.root', 'RECREATE' )
hS_Had_D_m05_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_D_m10_Xps_pdf.root', 'RECREATE' )
hS_Had_D_m10_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_D_m15_Xps_pdf.root', 'RECREATE' )
hS_Had_D_m15_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_D_m20_Xps_pdf.root', 'RECREATE' )
hS_Had_D_m20_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_D_m25_Xps_pdf.root', 'RECREATE' )
hS_Had_D_m25_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_D_m30_Xps_pdf.root', 'RECREATE' )
hS_Had_D_m30_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_D_m35_Xps_pdf.root', 'RECREATE' )
hS_Had_D_m35_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_D_m40_Xps_pdf.root', 'RECREATE' )
hS_Had_D_m40_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_D_m45_Xps_pdf.root', 'RECREATE' )
hS_Had_D_m45_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_D_m50_Xps_pdf.root', 'RECREATE' )
hS_Had_D_m50_Xps.Write()
myfile.Close()

# %%
# Lest's create the root files for Xps
# D_star_gama tag
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m00_Xps_pdf.root', 'RECREATE' )
hS_Had_Dstar_gamma_m00_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m05_Xps_pdf.root', 'RECREATE' )
hS_Had_Dstar_gamma_m05_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m10_Xps_pdf.root', 'RECREATE' )
hS_Had_Dstar_gamma_m10_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m15_Xps_pdf.root', 'RECREATE' )
hS_Had_Dstar_gamma_m15_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m20_Xps_pdf.root', 'RECREATE' )
hS_Had_Dstar_gamma_m20_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m25_Xps_pdf.root', 'RECREATE' )
hS_Had_Dstar_gamma_m25_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m30_Xps_pdf.root', 'RECREATE' )
hS_Had_Dstar_gamma_m30_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m35_Xps_pdf.root', 'RECREATE' )
hS_Had_Dstar_gamma_m35_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m40_Xps_pdf.root', 'RECREATE' )
hS_Had_Dstar_gamma_m40_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m45_Xps_pdf.root', 'RECREATE' )
hS_Had_Dstar_gamma_m45_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m50_Xps_pdf.root', 'RECREATE' )
hS_Had_Dstar_gamma_m50_Xps.Write()
myfile.Close()

# %%
# Lest's create the root files for Xps
# D_star_pi0 tag
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m00_Xps_pdf.root', 'RECREATE' )
hS_Had_Dstar_pi0_m00_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m05_Xps_pdf.root', 'RECREATE' )
hS_Had_Dstar_pi0_m05_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m10_Xps_pdf.root', 'RECREATE' )
hS_Had_Dstar_pi0_m10_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m15_Xps_pdf.root', 'RECREATE' )
hS_Had_Dstar_pi0_m15_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m20_Xps_pdf.root', 'RECREATE' )
hS_Had_Dstar_pi0_m20_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m25_Xps_pdf.root', 'RECREATE' )
hS_Had_Dstar_pi0_m25_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m30_Xps_pdf.root', 'RECREATE' )
hS_Had_Dstar_pi0_m30_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m35_Xps_pdf.root', 'RECREATE' )
hS_Had_Dstar_pi0_m35_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m40_Xps_pdf.root', 'RECREATE' )
hS_Had_Dstar_pi0_m40_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m45_Xps_pdf.root', 'RECREATE' )
hS_Had_Dstar_pi0_m45_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m50_Xps_pdf.root', 'RECREATE' )
hS_Had_Dstar_pi0_m50_Xps.Write()
myfile.Close()

# %%
# Now for background files
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgHtag_D_Xps_pdf.root', 'RECREATE' )
hBkgHtag_D_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgHtag_Dstar_gamma_Xps_pdf.root', 'RECREATE' )
hBkgHtag_Dstar_gamma_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgHtag_Dstar_pi0_Xps_pdf.root', 'RECREATE' )
hBkgHtag_Dstar_pi0_Xps.Write()
myfile.Close()

# %% [markdown]
# q2

# %%
# Lest's create the root files
# D tag
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_D_m00_q2_pdf.root', 'RECREATE' )
hS_Had_D_m00_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_D_m05_q2_pdf.root', 'RECREATE' )
hS_Had_D_m05_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_D_m10_q2_pdf.root', 'RECREATE' )
hS_Had_D_m10_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_D_m15_q2_pdf.root', 'RECREATE' )
hS_Had_D_m15_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_D_m20_q2_pdf.root', 'RECREATE' )
hS_Had_D_m20_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_D_m25_q2_pdf.root', 'RECREATE' )
hS_Had_D_m25_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_D_m30_q2_pdf.root', 'RECREATE' )
hS_Had_D_m30_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_D_m35_q2_pdf.root', 'RECREATE' )
hS_Had_D_m35_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_D_m40_q2_pdf.root', 'RECREATE' )
hS_Had_D_m40_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_D_m45_q2_pdf.root', 'RECREATE' )
hS_Had_D_m45_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_D_m50_q2_pdf.root', 'RECREATE' )
hS_Had_D_m50_q2.Write()
myfile.Close()

# %%
# Dstar_gamma tag
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m00_q2_pdf.root', 'RECREATE' )
hS_Had_Dstar_gamma_m00_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m05_q2_pdf.root', 'RECREATE' )
hS_Had_Dstar_gamma_m05_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m10_q2_pdf.root', 'RECREATE' )
hS_Had_Dstar_gamma_m10_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m15_q2_pdf.root', 'RECREATE' )
hS_Had_Dstar_gamma_m15_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m20_q2_pdf.root', 'RECREATE' )
hS_Had_Dstar_gamma_m20_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m25_q2_pdf.root', 'RECREATE' )
hS_Had_Dstar_gamma_m25_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m30_q2_pdf.root', 'RECREATE' )
hS_Had_Dstar_gamma_m30_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m35_q2_pdf.root', 'RECREATE' )
hS_Had_Dstar_gamma_m35_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m40_q2_pdf.root', 'RECREATE' )
hS_Had_Dstar_gamma_m40_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m45_q2_pdf.root', 'RECREATE' )
hS_Had_Dstar_gamma_m45_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m50_q2_pdf.root', 'RECREATE' )
hS_Had_Dstar_gamma_m50_q2.Write()
myfile.Close()

# %%
# Dstar_pi0 tag
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m00_q2_pdf.root', 'RECREATE' )
hS_Had_Dstar_pi0_m00_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m05_q2_pdf.root', 'RECREATE' )
hS_Had_Dstar_pi0_m05_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m10_q2_pdf.root', 'RECREATE' )
hS_Had_Dstar_pi0_m10_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m15_q2_pdf.root', 'RECREATE' )
hS_Had_Dstar_pi0_m15_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m20_q2_pdf.root', 'RECREATE' )
hS_Had_Dstar_pi0_m20_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m25_q2_pdf.root', 'RECREATE' )
hS_Had_Dstar_pi0_m25_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m30_q2_pdf.root', 'RECREATE' )
hS_Had_Dstar_pi0_m30_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m35_q2_pdf.root', 'RECREATE' )
hS_Had_Dstar_pi0_m35_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m40_q2_pdf.root', 'RECREATE' )
hS_Had_Dstar_pi0_m40_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m45_q2_pdf.root', 'RECREATE' )
hS_Had_Dstar_pi0_m45_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m50_q2_pdf.root', 'RECREATE' )
hS_Had_Dstar_pi0_m50_q2.Write()
myfile.Close()

# %%
# Now for background files
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgHtag_D_q2_pdf.root', 'RECREATE' )
hBkgHtag_D_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgHtag_Dstar_gamma_q2_pdf.root', 'RECREATE' )
hBkgHtag_Dstar_gamma_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgHtag_Dstar_pi0_q2_pdf.root', 'RECREATE' )
hBkgHtag_Dstar_pi0_q2.Write()
myfile.Close()

# %% [markdown]
# M_min2Low = -5.0
# M_min2Up = 27.0
#
# M_max2Low = -1.0
# M_max2Up = 27.0
#
# nbinsH = 15
# nbinsL = 15
#
#
# hS_2D_m00 = sig_m00_df.Histo2D(("hS_2D_m00", "hS_2D_m00", nbinsL, M_min2Low, M_min2Up, nbinsH, M_max2Low, M_max2Up), "Mmin2", "Mmax2")
# hS_2D_m10 = sig_m10_df.Histo2D(("hS_2D_m10", "hS_2D_m10", nbinsL, M_min2Low, M_min2Up, nbinsH, M_max2Low, M_max2Up), "Mmin2", "Mmax2")
# hS_2D_m20 = sig_m20_df.Histo2D(("hS_2D_m20", "hS_2D_m20", nbinsL, M_min2Low, M_min2Up, nbinsH, M_max2Low, M_max2Up), "Mmin2", "Mmax2")
# hS_2D_m30 = sig_m30_df.Histo2D(("hS_2D_m30", "hS_2D_m30", nbinsL, M_min2Low, M_min2Up, nbinsH, M_max2Low, M_max2Up), "Mmin2", "Mmax2")
# hS_2D_m40 = sig_m40_df.Histo2D(("hS_2D_m40", "hS_2D_m40", nbinsL, M_min2Low, M_min2Up, nbinsH, M_max2Low, M_max2Up), "Mmin2", "Mmax2")
# hS_2D_m50 = sig_m50_df.Histo2D(("hS_2D_m50", "hS_2D_m50", nbinsL, M_min2Low, M_min2Up, nbinsH, M_max2Low, M_max2Up), "Mmin2", "Mmax2")
#
# hpi_taunu_2D = pi_taunu_df.Histo2D(("hpi_taunu_2D", "hpi_taunu_2D", nbinsL, M_min2Low, M_min2Up, nbinsH, M_max2Low, M_max2Up), "Mmin2", "Mmax2")
# hpi_nunu_2D = pi_nunu_df.Histo2D(("hpi_nunu_2D", "hpi_nunu_2D", nbinsL, M_min2Low, M_min2Up, nbinsH, M_max2Low, M_max2Up), "Mmin2", "Mmax2")

# %% [markdown]
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_2D_m00_pdf.root', 'RECREATE' )
# hS_2D_m00.Write()
# myfile.Close()
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_2D_m10_pdf.root', 'RECREATE' )
# hS_2D_m10.Write()
# myfile.Close()
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_2D_m20_pdf.root', 'RECREATE' )
# hS_2D_m20.Write()
# myfile.Close()
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_2D_m30_pdf.root', 'RECREATE' )
# hS_2D_m30.Write()
# myfile.Close()
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_2D_m40_pdf.root', 'RECREATE' )
# hS_2D_m40.Write()
# myfile.Close()
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_2D_m50_pdf.root', 'RECREATE' )
# hS_2D_m50.Write()
# myfile.Close()
#
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hpi_taunu_2D_pdf.root', 'RECREATE' )
# hpi_taunu_2D.Write()
# myfile.Close()
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hpi_nunu_2D_pdf.root', 'RECREATE' )
# hpi_nunu_2D.Write()
# myfile.Close()

# %%
f1 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_D_m00_Mmin2_pdf.root')
f2 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_D_m50_Mmin2_pdf.root')
f3 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_D_m00_Mmax2_pdf.root')
f4 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_D_m50_Mmax2_pdf.root')

f5 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgStag_D_Mmin2_pdf.root')
f6 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgStag_D_Mmax2_pdf.root')


hS_D_m00_Mmin2_pdf = ROOT.TH1D('hS_D_m00_Mmin2','hS_D_m00_Mmin2' , bins, Mmin_min, Mmin_max)
hS_D_m00_Mmin2_pdf = f1.Get("Mmin2")
hS_D_m50_Mmin2_pdf = ROOT.TH1D('hS_D_m50_Mmin2','hS_D_m50_Mmin2' , bins, Mmin_min, Mmin_max)
hS_D_m50_Mmin2_pdf = f2.Get("Mmin2")
hS_D_m00_Mmax2_pdf = ROOT.TH1D('hS_D_m00_Mmax2','hS_D_m00_Mmax2' , bins, Mmax_min, Mmax_max)
hS_D_m00_Mmax2_pdf = f3.Get("Mmax2")
hS_D_m50_Mmax2_pdf = ROOT.TH1D('hS_D_m50_Mmax2','hS_D_m50_Mmax2' , bins, Mmax_min, Mmax_max)
hS_D_m50_Mmax2_pdf = f4.Get("Mmax2")

hBkgStag_D_Mmin2_pdf = ROOT.TH1D('hBkgStag_D_Mmin2','hBkgStag_D_Mmin2' , bins, Mmin_min, Mmin_max)
hBkgStag_D_Mmin2_pdf = f5.Get("Mmin2")


hBkgStag_D_Mmax2_pdf = ROOT.TH1D('hBkgStag_D_Mmax2','hBkgStag_D_Mmax2' , bins, Mmin_min, Mmin_max)
hBkgStag_D_Mmax2_pdf = f6.Get("Mmax2")

# %%
print(bins)
# Out:
# 200

# %%
c1 = ROOT.TCanvas("a","a",800,400)

c1.Divide(2)
c1.cd(1)
hS_D_m00_Mmin2_pdf.Draw()
hS_D_m50_Mmin2_pdf.Draw("SAME")
hBkgStag_D_Mmin2_pdf.Draw("SAME")
#hpi_nunu_Mmin2_pdf.Draw("SAME")
c1.cd(2)
hS_D_m00_Mmax2_pdf.Draw()
hS_D_m50_Mmax2_pdf.Draw("SAME")
hBkgStag_D_Mmax2_pdf.Draw("SAME")
#hpi_nunu_Mmax2_pdf.Draw("SAME")
c1.Draw()

# %%
f7 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_D_m00_Xps_pdf.root')
f8 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_D_m50_Xps_pdf.root')
f9 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m00_Xps_pdf.root')
f10 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m50_Xps_pdf.root')
f11 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m00_Xps_pdf.root')
f12 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m50_Xps_pdf.root')


f13 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgStag_D_Xps_pdf.root')
f14 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_gamma_Xps_pdf.root')
f15 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_pi0_Xps_pdf.root')



hS_D_m00_Xps_pdf = ROOT.TH1D('hS_D_m00_Xps','hS_D_m00_Xps' , bins, Xps_min, Xps_max)
hS_D_m00_Xps_pdf = f7.Get("Xps")
hS_D_m50_Xps_pdf = ROOT.TH1D('hS_D_m50_Xps','hS_D_m50_Xps' , bins, Xps_min, Xps_max)
hS_D_m50_Xps_pdf = f8.Get("Xps")
hS_Dstar_gamma_m00_Xps_pdf = ROOT.TH1D('hS_Dstar_gamma_m00_Xps','hS_Dstar_gamma_m00_Xps' , bins, Xps_min, Xps_max)
hS_Dstar_gamma_m00_Xps_pdf = f9.Get("Xps")
hS_Dstar_gamma_m50_Xps_pdf = ROOT.TH1D('hS_Dstar_gamma_m50_Xps','hS_Dstar_gamma_m50_Xps' , bins, Xps_min, Xps_max)
hS_Dstar_gamma_m50_Xps_pdf = f10.Get("Xps")
hS_Dstar_pi0_m00_Xps_pdf = ROOT.TH1D('hS_Dstar_pi0_m00_Xps','hS_Dstar_pi0_m00_Xps' , bins, Xps_min, Xps_max)
hS_Dstar_pi0_m00_Xps_pdf = f11.Get("Xps")
hS_Dstar_pi0_m50_Xps_pdf = ROOT.TH1D('hS_Dstar_pi0_m50_Xps','hS_Dstar_pi0_m50_Xps' , bins, Xps_min, Xps_max)
hS_Dstar_pi0_m50_Xps_pdf = f12.Get("Xps")

hBkgStag_D_Xps_pdf = ROOT.TH1D('hBkgStag_D_Xps','hBkgStag_D_Xps' , bins, Xps_min, Xps_max)
hBkgStag_D_Xps_pdf = f13.Get("Xps")


hBkgStag_Dstar_gamma_Xps_pdf = ROOT.TH1D('hBkgStag_Dstar_gamma_Xps','hBkgStag_Dstar_gamma_Xps' , bins, Xps_min, Xps_max)
hBkgStag_Dstar_gamma_Xps_pdf = f14.Get("Xps")
hBkgStag_Dstar_pi0_Xps_pdf = ROOT.TH1D('hBkgStag_Dstar_pi0_Xps','hBkgStag_Dstar_pi0_Xps' , bins, Xps_min, Xps_max)
hBkgStag_Dstar_pi0_Xps_pdf = f15.Get("Xps")

# %%
c2 = ROOT.TCanvas("b","b",1200,600)

c2.Divide(3)
c2.cd(1)
hS_D_m00_Xps_pdf.Draw()
hS_D_m50_Xps_pdf.Draw("SAME")
hBkgStag_D_Xps_pdf.Draw("SAME")
#hpi_nunu_Mmin2_pdf.Draw("SAME")
c2.cd(2)
hS_Dstar_gamma_m00_Xps_pdf.Draw()
hS_Dstar_gamma_m50_Xps_pdf.Draw("SAME")
hBkgStag_Dstar_gamma_Xps_pdf.Draw("SAME")

c2.cd(3)
hS_Dstar_pi0_m00_Xps_pdf.Draw()
hS_Dstar_pi0_m50_Xps_pdf.Draw("SAME")
hBkgStag_Dstar_pi0_Xps_pdf.Draw("SAME")
c2.Draw()

# %%
f16 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_D_m00_Mmin2_pdf.root')
f17 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_D_m50_Mmin2_pdf.root')
f18 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m00_Mmin2_pdf.root')
f19 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m50_Mmin2_pdf.root')
f20 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m00_Mmin2_pdf.root')
f21 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m50_Mmin2_pdf.root')

f22 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgStag_D_Mmin2_pdf.root')
f23 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_gamma_Mmin2_pdf.root')
f24 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_pi0_Mmin2_pdf.root')

f25 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_D_m00_Mmax2_pdf.root')
f26 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_D_m50_Mmax2_pdf.root')
f27 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m00_Mmax2_pdf.root')
f28 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m50_Mmax2_pdf.root')
f29 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m00_Mmax2_pdf.root')
f30 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m50_Mmax2_pdf.root')

f31 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgStag_D_Mmax2_pdf.root')
f32 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_gamma_Mmax2_pdf.root')
f33 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_pi0_Mmax2_pdf.root')


hS_D_m00_Mmin2_pdf = ROOT.TH1D('hS_D_m00_Mmin2','hS_D_m00_Mmin2' , bins, Mmin_min, Mmin_max)
hS_D_m00_Mmin2_pdf = f16.Get("Mmin2")
hS_D_m50_Mmin2_pdf = ROOT.TH1D('hS_D_m50_Mmin2','hS_D_m50_Mmin2' , bins, Mmin_min, Mmin_max)
hS_D_m50_Mmin2_pdf = f17.Get("Mmin2")
hS_Dstar_gamma_m00_Mmin2_pdf = ROOT.TH1D('hS_Dstar_gamma_m00_Mmin2','hS_Dstar_gamma_m00_Mmin2' , bins, Mmin_min, Mmin_max)
hS_Dstar_gamma_m00_Mmin2_pdf = f18.Get("Mmin2")
hS_Dstar_gamma_m50_Mmin2_pdf = ROOT.TH1D('hS_Dstar_gamma_m50_Mmin2','hS_Dstar_gamma_m50_Mmin2' , bins, Mmin_min, Mmin_max)
hS_Dstar_gamma_m50_Mmin2_pdf = f19.Get("Mmin2")
hS_Dstar_pi0_m00_Mmin2_pdf = ROOT.TH1D('hS_Dstar_pi0_m00_Mmin2','hS_Dstar_pi0_m00_Mmin2' , bins, Mmin_min, Mmin_max)
hS_Dstar_pi0_m00_Mmin2_pdf = f20.Get("Mmin2")
hS_Dstar_pi0_m50_Mmin2_pdf = ROOT.TH1D('hS_Dstar_pi0_m50_Mmin2','hS_Dstar_pi0_m50_Mmin2' , bins, Mmin_min, Mmin_max)
hS_Dstar_pi0_m50_Mmin2_pdf = f21.Get("Mmin2")


hBkgStag_D_Mmin2_pdf = ROOT.TH1D('hBkgStag_D_Mmin2','hBkgStag_D_Mmin2' , bins, Mmin_min, Mmin_max)
hBkgStag_D_Mmin2_pdf = f22.Get("Mmin2")
hBkgStag_Dstar_gamma_Mmin2_pdf = ROOT.TH1D('hBkgStag_Dstar_gamma_Mmin2','hBkgStag_Dstar_gamma_Mmin2' , bins, Mmin_min, Mmin_max)
hBkgStag_Dstar_gamma_Mmin2_pdf = f23.Get("Mmin2")
hBkgStag_Dstar_pi0_Mmin2_pdf = ROOT.TH1D('hBkgStag_Dstar_pi0_Mmin2','hBkgStag_Dstar_pi0_Mmin2' , bins, Mmin_min, Mmin_max)
hBkgStag_Dstar_pi0_Mmin2_pdf = f24.Get("Mmin2")

# %%
hS_D_m00_Mmax2_pdf = ROOT.TH1D('hS_D_m00_Mmax2','hS_D_m00_Mmax2' , bins, Mmax_min, Mmax_max)
hS_D_m00_Mmax2_pdf = f25.Get("Mmax2")
hS_D_m50_Mmax2_pdf = ROOT.TH1D('hS_D_m50_Mmax2','hS_D_m50_Mmax2' , bins, Mmax_min, Mmax_max)
hS_D_m50_Mmax2_pdf = f26.Get("Mmax2")
hS_Dstar_gamma_m00_Mmax2_pdf = ROOT.TH1D('hS_Dstar_gamma_m00_Mmax2','hS_Dstar_gamma_m00_Mmax2' , bins, Mmax_min, Mmax_max)
hS_Dstar_gamma_m00_Mmax2_pdf = f27.Get("Mmax2")
hS_Dstar_gamma_m50_Mmax2_pdf = ROOT.TH1D('hS_Dstar_gamma_m50_Mmax2','hS_Dstar_gamma_m50_Mmax2' , bins, Mmax_min, Mmax_max)
hS_Dstar_gamma_m50_Mmax2_pdf = f28.Get("Mmax2")
hS_Dstar_pi0_m00_Mmax2_pdf = ROOT.TH1D('hS_Dstar_pi0_m00_Mmax2','hS_Dstar_pi0_m00_Mmax2' , bins, Mmax_min, Mmax_max)
hS_Dstar_pi0_m00_Mmax2_pdf = f29.Get("Mmax2")
hS_Dstar_pi0_m50_Mmax2_pdf = ROOT.TH1D('hS_Dstar_pi0_m50_Mmax2','hS_Dstar_pi0_m50_Mmax2' , bins, Mmax_min, Mmax_max)
hS_Dstar_pi0_m50_Mmax2_pdf = f30.Get("Mmax2")


hBkgStag_D_Mmax2_pdf = ROOT.TH1D('hBkgStag_D_Mmax2','hBkgStag_D_Mmax2' , bins, Mmax_min, Mmax_max)
hBkgStag_D_Mmax2_pdf = f31.Get("Mmax2")
hBkgStag_Dstar_gamma_Mmax2_pdf = ROOT.TH1D('hBkgStag_Dstar_gamma_Mmax2','hBkgStag_Dstar_gamma_Mmax2' , bins, Mmax_min, Mmax_max)
hBkgStag_Dstar_gamma_Mmax2_pdf = f32.Get("Mmax2")
hBkgStag_Dstar_pi0_Mmax2_pdf = ROOT.TH1D('hBkgStag_Dstar_pi0_Mmax2','hBkgStag_Dstar_pi0_Mmax2' , bins, Mmax_min, Mmax_max)
hBkgStag_Dstar_pi0_Mmax2_pdf = f33.Get("Mmax2")

# %%
c3 = ROOT.TCanvas("c","c",1200,600)

c3.Divide(3)
c3.cd(1)
hS_D_m00_Mmin2_pdf.Draw()
hS_D_m50_Mmin2_pdf.Draw("SAME")
hBkgStag_D_Mmin2_pdf.Draw("SAME")
#hpi_nunu_Mmin2_pdf.Draw("SAME")
c3.cd(2)
hS_Dstar_gamma_m00_Mmin2_pdf.Draw()
hS_Dstar_gamma_m50_Mmin2_pdf.Draw("SAME")
hBkgStag_Dstar_gamma_Mmin2_pdf.Draw("SAME")

c3.cd(3)
hS_Dstar_pi0_m00_Mmin2_pdf.Draw()
hS_Dstar_pi0_m50_Mmin2_pdf.Draw("SAME")
hBkgStag_Dstar_pi0_Mmin2_pdf.Draw("SAME")
c3.Draw()

# %%
c4 = ROOT.TCanvas("d","d",1200,600)

c4.Divide(3)
c4.cd(1)
hS_D_m00_Mmax2_pdf.Draw()
hS_D_m50_Mmax2_pdf.Draw("SAME")
hBkgStag_D_Mmax2_pdf.Draw("SAME")
#hpi_nunu_Mmax2_pdf.Draw("SAME")
c4.cd(2)
hS_Dstar_gamma_m00_Mmax2_pdf.Draw()
hS_Dstar_gamma_m50_Mmax2_pdf.Draw("SAME")
hBkgStag_Dstar_gamma_Mmax2_pdf.Draw("SAME")

c4.cd(3)
hS_Dstar_pi0_m00_Mmax2_pdf.Draw()
hS_Dstar_pi0_m50_Mmax2_pdf.Draw("SAME")
hBkgStag_Dstar_pi0_Mmax2_pdf.Draw("SAME")
c4.Draw()

# %% [markdown]
# fm00_2D = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_2D_m00_pdf.root')
# fm50_2D = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_2D_m50_pdf.root')
# fpi_taunu_2D = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hpi_taunu_2D_pdf.root')
# fpi_nunu_2D = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hpi_nunu_2D_pdf.root')
#
#
#
#
# hS_m00_2D_pdf = ROOT.TH2D('hS_m00_2D_pdf','hS_m00_2D_pdf' , nbinsL, M_min2Low, M_min2Up, nbinsH, M_max2Low, M_max2Up)
# hS_m00_2D_pdf = fm00_2D.Get("hS_2D_m00")
# hS_m50_2D_pdf = ROOT.TH2D('hS_m50_2D_pdf','hS_m50_2D_pdf' , nbinsL, M_min2Low, M_min2Up, nbinsH, M_max2Low, M_max2Up)
# hS_m50_2D_pdf = fm50_2D.Get("hS_2D_m50")
# hpi_taunu_2D_pdf = ROOT.TH2D('hpi_taunu_2D_pdf','hpi_taunu_2D_pdf' , nbinsL, M_min2Low, M_min2Up, nbinsH, M_max2Low, M_max2Up)
# hpi_taunu_2D_pdf = fpi_taunu_2D.Get("hpi_taunu_2D")
# hpi_nunu_2D_pdf = ROOT.TH2D('hpi_nunu_2D_pdf','hpi_nunu_2D_pdf' , nbinsL, M_min2Low, M_min2Up, nbinsH, M_max2Low, M_max2Up)
# hpi_nunu_2D_pdf = fpi_nunu_2D.Get("hpi_nunu_2D")

# %% [markdown]
# c3 = ROOT.TCanvas("c3","c3",800,400)
#
# c3.Divide(4)
# c3.cd(1)
# hS_m00_2D_pdf.Draw("CONTZ")
# c3.cd(2)
# hS_m50_2D_pdf.Draw("CONTZ")
# c3.cd(3)
# hpi_taunu_2D_pdf.Draw("CONTZ")
# c3.cd(4)
# hpi_nunu_2D_pdf.Draw("CONTZ")
# c3.Draw()

# %%
f34 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_D_m00_q2_pdf.root')
f35 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_D_m50_q2_pdf.root')
f36 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m00_q2_pdf.root')
f37 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m50_q2_pdf.root')
f38 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m00_q2_pdf.root')
f39 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m50_q2_pdf.root')


f40 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgStag_D_q2_pdf.root')
f41 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_gamma_q2_pdf.root')
f42 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_pi0_q2_pdf.root')



hS_D_m00_q2_pdf = ROOT.TH1D('hS_D_m00_q2','hS_D_m00_q2' , bins, q2_min, q2_max)
hS_D_m00_q2_pdf = f34.Get("q2")
hS_D_m50_q2_pdf = ROOT.TH1D('hS_D_m50_q2','hS_D_m50_q2' , bins, q2_min, q2_max)
hS_D_m50_q2_pdf = f35.Get("q2")
hS_Dstar_gamma_m00_q2_pdf = ROOT.TH1D('hS_Dstar_gamma_m00_q2','hS_Dstar_gamma_m00_q2' , bins, q2_min, q2_max)
hS_Dstar_gamma_m00_q2_pdf = f36.Get("q2")
hS_Dstar_gamma_m50_q2_pdf = ROOT.TH1D('hS_Dstar_gamma_m50_q2','hS_Dstar_gamma_m50_q2' , bins, q2_min, q2_max)
hS_Dstar_gamma_m50_q2_pdf = f37.Get("q2")
hS_Dstar_pi0_m00_q2_pdf = ROOT.TH1D('hS_Dstar_pi0_m00_q2','hS_Dstar_pi0_m00_q2' , bins, q2_min, q2_max)
hS_Dstar_pi0_m00_q2_pdf = f38.Get("q2")
hS_Dstar_pi0_m50_q2_pdf = ROOT.TH1D('hS_Dstar_pi0_m50_q2','hS_Dstar_pi0_m50_q2' , bins, q2_min, q2_max)
hS_Dstar_pi0_m50_q2_pdf = f39.Get("q2")

hBkgStag_D_q2_pdf = ROOT.TH1D('hBkgStag_D_q2','hBkgStag_D_q2' , bins, q2_min, q2_max)
hBkgStag_D_q2_pdf = f40.Get("q2")
hBkgStag_Dstar_gamma_q2_pdf = ROOT.TH1D('hBkgStag_Dstar_gamma_q2','hBkgStag_Dstar_gamma_q2' , bins, q2_min, q2_max)
hBkgStag_Dstar_gamma_q2_pdf = f41.Get("q2")
hBkgStag_Dstar_pi0_q2_pdf = ROOT.TH1D('hBkgStag_Dstar_pi0_q2','hBkgStag_Dstar_pi0_q2' , bins, q2_min, q2_max)
hBkgStag_Dstar_pi0_q2_pdf = f42.Get("q2")

# %%
c5 = ROOT.TCanvas("e","e",1200,600)

c5.Divide(3)
c5.cd(1)
hS_D_m00_q2_pdf.Draw()
hS_D_m50_q2_pdf.Draw("SAME")
hBkgStag_D_q2_pdf.Draw("SAME")
#hpi_nunu_Mmin2_pdf.Draw("SAME")
c5.cd(2)
hS_Dstar_gamma_m00_q2_pdf.Draw()
hS_Dstar_gamma_m50_q2_pdf.Draw("SAME")
hBkgStag_Dstar_gamma_q2_pdf.Draw("SAME")

c5.cd(3)
hS_Dstar_pi0_m00_q2_pdf.Draw()
hS_Dstar_pi0_m50_q2_pdf.Draw("SAME")
hBkgStag_Dstar_pi0_q2_pdf.Draw("SAME")
c5.Draw()

# %% [markdown]
# ## Hadrionic tags

# %% [markdown]
# f43 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_D_m00_Mmin2_pdf.root')
# f44 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_D_m50_Mmin2_pdf.root')
# f45 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_D_m00_Mmax2_pdf.root')
# f46 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_D_m50_Mmax2_pdf.root')
#
# f47 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgHtag_D_Mmin2_pdf.root')
# f48 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgHtag_D_Mmax2_pdf.root')
#
#
# hS_Had_D_m00_Mmin2_pdf = ROOT.TH1D('hS_Had_D_m00_Mmin2','hS_Had_D_m00_Mmin2' , bins, Mmin_min, Mmin_max)
# hS_Had_D_m00_Mmin2_pdf = f43.Get("Mmin2")
# hS_Had_D_m50_Mmin2_pdf = ROOT.TH1D('hS_Had_D_m50_Mmin2','hS_Had_D_m50_Mmin2' , bins, Mmin_min, Mmin_max)
# hS_Had_D_m50_Mmin2_pdf = f44.Get("Mmin2")
# hS_Had_D_m00_Mmax2_pdf = ROOT.TH1D('hS_Had_D_m00_Mmax2','hS_Had_D_m00_Mmax2' , bins, Mmax_min, Mmax_max)
# hS_Had_D_m00_Mmax2_pdf = f45.Get("Mmax2")
# hS_Had_D_m50_Mmax2_pdf = ROOT.TH1D('hS_Had_D_m50_Mmax2','hS_Had_D_m50_Mmax2' , bins, Mmax_min, Mmax_max)
# hS_Had_D_m50_Mmax2_pdf = f46.Get("Mmax2")
#
# hBkgHtag_D_Mmin2_pdf = ROOT.TH1D('hBkgHtag_D_Mmin2','hBkgHtag_D_Mmin2' , bins, Mmin_min, Mmin_max)
# hBkgHtag_D_Mmin2_pdf = f47.Get("Mmin2")
#
#
# hBkgHtag_D_Mmax2_pdf = ROOT.TH1D('hBkgHtag_D_Mmax2','hBkgHtag_D_Mmax2' , bins, Mmin_min, Mmin_max)
# hBkgHtag_D_Mmax2_pdf = f48.Get("Mmax2")

# %% [markdown]
# c6 = ROOT.TCanvas("f","f",800,400)
#
# c6.Divide(2)
# c6.cd(1)
# hS_Had_D_m00_Mmin2_pdf.Draw()
# hS_Had_D_m50_Mmin2_pdf.Draw("SAME")
# hBkgHtag_D_Mmin2_pdf.Draw("SAME")
# #hpi_nunu_Mmin2_pdf.Draw("SAME")
# c6.cd(2)
# hS_Had_D_m00_Mmax2_pdf.Draw()
# hS_Had_D_m50_Mmax2_pdf.Draw("SAME")
# hBkgHtag_D_Mmax2_pdf.Draw("SAME")
# #hpi_nunu_Mmax2_pdf.Draw("SAME")
# c6.Draw()

# %% [markdown]
# f49 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_D_m00_Mmin2_pdf.root')
# f50 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_D_m50_Mmin2_pdf.root')
# f51 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m00_Mmin2_pdf.root')
# f52 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m50_Mmin2_pdf.root')
# f53 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m00_Mmin2_pdf.root')
# f54 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m50_Mmin2_pdf.root')
#
# f55 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgHtag_D_Mmin2_pdf.root')
# f56 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgHtag_Dstar_gamma_Mmin2_pdf.root')
# f57 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgHtag_Dstar_pi0_Mmin2_pdf.root')
#
# f58 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_D_m00_Mmax2_pdf.root')
# f59 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_D_m50_Mmax2_pdf.root')
# f60 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m00_Mmax2_pdf.root')
# f61 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m50_Mmax2_pdf.root')
# f62 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m00_Mmax2_pdf.root')
# f63 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m50_Mmax2_pdf.root')
#
# f64 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgHtag_D_Mmax2_pdf.root')
# f65 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgHtag_Dstar_gamma_Mmax2_pdf.root')
# f66 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgHtag_Dstar_pi0_Mmax2_pdf.root')
#
#
# hS_Had_D_m00_Mmin2_pdf = ROOT.TH1D('hS_Had_D_m00_Mmin2','hS_Had_D_m00_Mmin2' , bins, Mmin_min, Mmin_max)
# hS_Had_D_m00_Mmin2_pdf = f49.Get("Mmin2")
# hS_Had_D_m50_Mmin2_pdf = ROOT.TH1D('hS_Had_D_m50_Mmin2','hS_Had_D_m50_Mmin2' , bins, Mmin_min, Mmin_max)
# hS_Had_D_m50_Mmin2_pdf = f50.Get("Mmin2")
# hS_Had_Dstar_gamma_m00_Mmin2_pdf = ROOT.TH1D('hS_Had_Dstar_gamma_m00_Mmin2','hS_Had_Dstar_gamma_m00_Mmin2' , bins, Mmin_min, Mmin_max)
# hS_Had_Dstar_gamma_m00_Mmin2_pdf = f51.Get("Mmin2")
# hS_Had_Dstar_gamma_m50_Mmin2_pdf = ROOT.TH1D('hS_Had_Dstar_gamma_m50_Mmin2','hS_Had_Dstar_gamma_m50_Mmin2' , bins, Mmin_min, Mmin_max)
# hS_Had_Dstar_gamma_m50_Mmin2_pdf = f52.Get("Mmin2")
# hS_Had_Dstar_pi0_m00_Mmin2_pdf = ROOT.TH1D('hS_Had_Dstar_pi0_m00_Mmin2','hS_Had_Dstar_pi0_m00_Mmin2' , bins, Mmin_min, Mmin_max)
# hS_Had_Dstar_pi0_m00_Mmin2_pdf = f53.Get("Mmin2")
# hS_Had_Dstar_pi0_m50_Mmin2_pdf = ROOT.TH1D('hS_Had_Dstar_pi0_m50_Mmin2','hS_Had_Dstar_pi0_m50_Mmin2' , bins, Mmin_min, Mmin_max)
# hS_Had_Dstar_pi0_m50_Mmin2_pdf = f54.Get("Mmin2")
#
#
# hBkgHtag_D_Mmin2_pdf = ROOT.TH1D('hBkgHtag_D_Mmin2','hBkgHtag_D_Mmin2' , bins, Mmin_min, Mmin_max)
# hBkgHtag_D_Mmin2_pdf = f55.Get("Mmin2")
# hBkgHtag_Dstar_gamma_Mmin2_pdf = ROOT.TH1D('hBkgHtag_Dstar_gamma_Mmin2','hBkgHtag_Dstar_gamma_Mmin2' , bins, Mmin_min, Mmin_max)
# hBkgHtag_Dstar_gamma_Mmin2_pdf = f56.Get("Mmin2")
# hBkgHtag_Dstar_pi0_Mmin2_pdf = ROOT.TH1D('hBkgHtag_Dstar_pi0_Mmin2','hBkgHtag_Dstar_pi0_Mmin2' , bins, Mmin_min, Mmin_max)
# hBkgHtag_Dstar_pi0_Mmin2_pdf = f57.Get("Mmin2")
#
#
# hS_Had_D_m00_Mmax2_pdf = ROOT.TH1D('hS_Had_D_m00_Mmax2','hS_Had_D_m00_Mmax2' , bins, Mmax_min, Mmax_max)
# hS_Had_D_m00_Mmax2_pdf = f58.Get("Mmax2")
# hS_Had_D_m50_Mmax2_pdf = ROOT.TH1D('hS_Had_D_m50_Mmax2','hS_Had_D_m50_Mmax2' , bins, Mmax_min, Mmax_max)
# hS_Had_D_m50_Mmax2_pdf = f59.Get("Mmax2")
# hS_Had_Dstar_gamma_m00_Mmax2_pdf = ROOT.TH1D('hS_Had_Dstar_gamma_m00_Mmax2','hS_Had_Dstar_gamma_m00_Mmax2' , bins, Mmax_min, Mmax_max)
# hS_Had_Dstar_gamma_m00_Mmax2_pdf = f60.Get("Mmax2")
# hS_Had_Dstar_gamma_m50_Mmax2_pdf = ROOT.TH1D('hS_Had_Dstar_gamma_m50_Mmax2','hS_Had_Dstar_gamma_m50_Mmax2' , bins, Mmax_min, Mmax_max)
# hS_Had_Dstar_gamma_m50_Mmax2_pdf = f61.Get("Mmax2")
# hS_Had_Dstar_pi0_m00_Mmax2_pdf = ROOT.TH1D('hS_Had_Dstar_pi0_m00_Mmax2','hS_Had_Dstar_pi0_m00_Mmax2' , bins, Mmax_min, Mmax_max)
# hS_Had_Dstar_pi0_m00_Mmax2_pdf = f62.Get("Mmax2")
# hS_Had_Dstar_pi0_m50_Mmax2_pdf = ROOT.TH1D('hS_Had_Dstar_pi0_m50_Mmax2','hS_Had_Dstar_pi0_m50_Mmax2' , bins, Mmax_min, Mmax_max)
# hS_Had_Dstar_pi0_m50_Mmax2_pdf = f63.Get("Mmax2")
#
#
# hBkgHtag_D_Mmax2_pdf = ROOT.TH1D('hBkgHtag_D_Mmax2','hBkgHtag_D_Mmax2' , bins, Mmax_min, Mmax_max)
# hBkgHtag_D_Mmax2_pdf = f64.Get("Mmax2")
# hBkgHtag_Dstar_gamma_Mmax2_pdf = ROOT.TH1D('hBkgHtag_Dstar_gamma_Mmax2','hBkgHtag_Dstar_gamma_Mmax2' , bins, Mmax_min, Mmax_max)
# hBkgHtag_Dstar_gamma_Mmax2_pdf = f65.Get("Mmax2")
# hBkgHtag_Dstar_pi0_Mmax2_pdf = ROOT.TH1D('hBkgHtag_Dstar_pi0_Mmax2','hBkgHtag_Dstar_pi0_Mmax2' , bins, Mmax_min, Mmax_max)
# hBkgHtag_Dstar_pi0_Mmax2_pdf = f66.Get("Mmax2")

# %% [markdown]
# c7 = ROOT.TCanvas("g","g",1200,600)
#
# c7.Divide(3)
# c7.cd(1)
# hS_Had_D_m00_Mmin2_pdf.Draw()
# hS_Had_D_m50_Mmin2_pdf.Draw("SAME")
# hBkgStag_D_Mmin2_pdf.Draw("SAME")
# #hpi_nunu_Mmin2_pdf.Draw("SAME")
# c7.cd(2)
# hS_Had_Dstar_gamma_m00_Mmin2_pdf.Draw()
# hS_Had_Dstar_gamma_m50_Mmin2_pdf.Draw("SAME")
# hBkgStag_Dstar_gamma_Mmin2_pdf.Draw("SAME")
#
# c7.cd(3)
# hS_Had_Dstar_pi0_m00_Mmin2_pdf.Draw()
# hS_Had_Dstar_pi0_m50_Mmin2_pdf.Draw("SAME")
# hBkgStag_Dstar_pi0_Mmin2_pdf.Draw("SAME")
# c7.Draw()

# %% [markdown]
# c8 = ROOT.TCanvas("h","h",1200,600)
#
# c8.Divide(3)
# c8.cd(1)
# hS_Had_D_m00_Mmax2_pdf.Draw()
# hS_Had_D_m50_Mmax2_pdf.Draw("SAME")
# hBkgStag_D_Mmax2_pdf.Draw("SAME")
# #hpi_nunu_Mmax2_pdf.Draw("SAME")
# c8.cd(2)
# hS_Had_Dstar_gamma_m00_Mmax2_pdf.Draw()
# hS_Had_Dstar_gamma_m50_Mmax2_pdf.Draw("SAME")
# hBkgStag_Dstar_gamma_Mmax2_pdf.Draw("SAME")
#
# c8.cd(3)
# hS_Had_Dstar_pi0_m00_Mmax2_pdf.Draw()
# hS_Had_Dstar_pi0_m50_Mmax2_pdf.Draw("SAME")
# hBkgStag_Dstar_pi0_Mmax2_pdf.Draw("SAME")
# c8.Draw()

# %%
f67 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_D_m00_Xps_pdf.root')
f68 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_D_m50_Xps_pdf.root')
f69 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m00_Xps_pdf.root')
f70 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m50_Xps_pdf.root')
f71 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m00_Xps_pdf.root')
f72 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m50_Xps_pdf.root')


f73 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgHtag_D_Xps_pdf.root')
f74 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgHtag_Dstar_gamma_Xps_pdf.root')
f75 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgHtag_Dstar_pi0_Xps_pdf.root')



hS_Had_D_m00_Xps_pdf = ROOT.TH1D('hS_Had_D_m00_Xps','hS_Had_D_m00_Xps' , bins_Had, Xps_min, Xps_max)
hS_Had_D_m00_Xps_pdf = f67.Get("Xps")
hS_Had_D_m50_Xps_pdf = ROOT.TH1D('hS_Had_D_m50_Xps','hS_Had_D_m50_Xps' , bins_Had, Xps_min, Xps_max)
hS_Had_D_m50_Xps_pdf = f68.Get("Xps")
hS_Had_Dstar_gamma_m00_Xps_pdf = ROOT.TH1D('hS_Had_Dstar_gamma_m00_Xps','hS_Had_Dstar_gamma_m00_Xps' , bins_Had, Xps_min, Xps_max)
hS_Had_Dstar_gamma_m00_Xps_pdf = f69.Get("Xps")
hS_Had_Dstar_gamma_m50_Xps_pdf = ROOT.TH1D('hS_Had_Dstar_gamma_m50_Xps','hS_Had_Dstar_gamma_m50_Xps' , bins_Had, Xps_min, Xps_max)
hS_Had_Dstar_gamma_m50_Xps_pdf = f70.Get("Xps")
hS_Had_Dstar_pi0_m00_Xps_pdf = ROOT.TH1D('hS_Had_Dstar_pi0_m00_Xps','hS_Had_Dstar_pi0_m00_Xps' , bins_Had, Xps_min, Xps_max)
hS_Had_Dstar_pi0_m00_Xps_pdf = f71.Get("Xps")
hS_Had_Dstar_pi0_m50_Xps_pdf = ROOT.TH1D('hS_Had_Dstar_pi0_m50_Xps','hS_Had_Dstar_pi0_m50_Xps' , bins_Had, Xps_min, Xps_max)
hS_Had_Dstar_pi0_m50_Xps_pdf = f72.Get("Xps")

hBkgHtag_D_Xps_pdf = ROOT.TH1D('hBkgHtag_D_Xps','hBkgHtag_D_Xps' , bins_Had, Xps_min, Xps_max)
hBkgHtag_D_Xps_pdf = f73.Get("Xps")


hBkgHtag_Dstar_gamma_Xps_pdf = ROOT.TH1D('hBkgHtag_Dstar_gamma_Xps','hBkgHtag_Dstar_gamma_Xps' , bins_Had, Xps_min, Xps_max)
hBkgHtag_Dstar_gamma_Xps_pdf = f74.Get("Xps")
hBkgHtag_Dstar_pi0_Xps_pdf = ROOT.TH1D('hBkgHtag_Dstar_pi0_Xps','hBkgHtag_Dstar_pi0_Xps' , bins_Had, Xps_min, Xps_max)
hBkgHtag_Dstar_pi0_Xps_pdf = f75.Get("Xps")

# %%
c9 = ROOT.TCanvas("i","i",1200,600)

c9.Divide(3)
c9.cd(1)
hS_Had_D_m00_Xps_pdf.Draw()
hS_Had_D_m50_Xps_pdf.Draw("SAME")
hBkgHtag_D_Xps_pdf.Draw("SAME")
#hpi_nunu_Mmin2_pdf.Draw("SAME")
c9.cd(2)
hS_Had_Dstar_gamma_m00_Xps_pdf.Draw()
hS_Had_Dstar_gamma_m50_Xps_pdf.Draw("SAME")
hBkgHtag_Dstar_gamma_Xps_pdf.Draw("SAME")

c9.cd(3)
hS_Had_Dstar_pi0_m00_Xps_pdf.Draw()
hS_Had_Dstar_pi0_m50_Xps_pdf.Draw("SAME")
hBkgHtag_Dstar_pi0_Xps_pdf.Draw("SAME")
c9.Draw()

# %%
f76 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_D_m00_q2_pdf.root')
f77 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_D_m50_q2_pdf.root')
f78 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m00_q2_pdf.root')
f79 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m50_q2_pdf.root')
f80 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m00_q2_pdf.root')
f81 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m50_q2_pdf.root')


f82 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgHtag_D_q2_pdf.root')
f83 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgHtag_Dstar_gamma_q2_pdf.root')
f84 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgHtag_Dstar_pi0_q2_pdf.root')



hS_Had_D_m00_q2_pdf = ROOT.TH1D('hS_Had_D_m00_q2','hS_Had_D_m00_q2' , bins_Had, q2_min, q2_max)
hS_Had_D_m00_q2_pdf = f76.Get("q2")
hS_Had_D_m50_q2_pdf = ROOT.TH1D('hS_Had_D_m50_q2','hS_Had_D_m50_q2' , bins_Had, q2_min, q2_max)
hS_Had_D_m50_q2_pdf = f77.Get("q2")
hS_Had_Dstar_gamma_m00_q2_pdf = ROOT.TH1D('hS_Had_Dstar_gamma_m00_q2','hS_Had_Dstar_gamma_m00_q2' , bins_Had, q2_min, q2_max)
hS_Had_Dstar_gamma_m00_q2_pdf = f78.Get("q2")
hS_Had_Dstar_gamma_m50_q2_pdf = ROOT.TH1D('hS_Had_Dstar_gamma_m50_q2','hS_Had_Dstar_gamma_m50_q2' , bins_Had, q2_min, q2_max)
hS_Had_Dstar_gamma_m50_q2_pdf = f79.Get("q2")
hS_Had_Dstar_pi0_m00_q2_pdf = ROOT.TH1D('hS_Had_Dstar_pi0_m00_q2','hS_Had_Dstar_pi0_m00_q2' , bins_Had, q2_min, q2_max)
hS_Had_Dstar_pi0_m00_q2_pdf = f80.Get("q2")
hS_Had_Dstar_pi0_m50_q2_pdf = ROOT.TH1D('hS_Had_Dstar_pi0_m50_q2','hS_Had_Dstar_pi0_m50_q2' , bins_Had, q2_min, q2_max)
hS_Had_Dstar_pi0_m50_q2_pdf = f81.Get("q2")

hBkgHtag_D_q2_pdf = ROOT.TH1D('hBkgHtag_D_q2','hBkgHtag_D_q2' , bins_Had, q2_min, q2_max)
hBkgHtag_D_q2_pdf = f82.Get("q2")
hBkgHtag_Dstar_gamma_q2_pdf = ROOT.TH1D('hBkgHtag_Dstar_gamma_q2','hBkgHtag_Dstar_gamma_q2' , bins_Had, q2_min, q2_max)
hBkgHtag_Dstar_gamma_q2_pdf = f83.Get("q2")
hBkgHtag_Dstar_pi0_q2_pdf = ROOT.TH1D('hBkgHtag_Dstar_pi0_q2','hBkgHtag_Dstar_pi0_q2' , bins_Had, q2_min, q2_max)
hBkgHtag_Dstar_pi0_q2_pdf = f84.Get("q2")

# %%
c10 = ROOT.TCanvas("j","j",1200,600)

c10.Divide(3)
c10.cd(1)
hS_Had_D_m00_q2_pdf.Draw()
hS_Had_D_m50_q2_pdf.Draw("SAME")
hBkgHtag_D_q2_pdf.Draw("SAME")
#hpi_nunu_Mmin2_pdf.Draw("SAME")
c10.cd(2)
hS_Had_Dstar_gamma_m00_q2_pdf.Draw()
hS_Had_Dstar_gamma_m50_q2_pdf.Draw("SAME")
hBkgHtag_Dstar_gamma_q2_pdf.Draw("SAME")

c10.cd(3)
hS_Had_Dstar_pi0_m00_q2_pdf.Draw()
hS_Had_Dstar_pi0_m50_q2_pdf.Draw("SAME")
hBkgHtag_Dstar_pi0_q2_pdf.Draw("SAME")
c10.Draw()
