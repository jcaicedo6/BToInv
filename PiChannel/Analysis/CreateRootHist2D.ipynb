# %%
import ROOT
import numpy as np
import pandas as pd
import random

import matplotlib.pyplot as plt
import time
import math, copy

# %%
df_HadronicTag_m00 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_m00_wc.csv')
df_HadronicTag_m10 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_m10_wc.csv')
df_HadronicTag_m20 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_m20_wc.csv')
df_HadronicTag_m30 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_m30_wc.csv')
df_HadronicTag_m40 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_m40_wc.csv')
df_HadronicTag_m50 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_m50_wc.csv')

df_HadronicTag_Dstar_gamma_m00 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m00_wc.csv')
df_HadronicTag_Dstar_gamma_m10 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m10_wc.csv')
df_HadronicTag_Dstar_gamma_m20 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m20_wc.csv')
df_HadronicTag_Dstar_gamma_m30 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m30_wc.csv')
df_HadronicTag_Dstar_gamma_m40 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m40_wc.csv')
df_HadronicTag_Dstar_gamma_m50 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m50_wc.csv')

df_HadronicTag_Dstar_pi0_m00 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m00_wc.csv')
df_HadronicTag_Dstar_pi0_m10 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m10_wc.csv')
df_HadronicTag_Dstar_pi0_m20 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m20_wc.csv')
df_HadronicTag_Dstar_pi0_m30 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m30_wc.csv')
df_HadronicTag_Dstar_pi0_m40 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m40_wc.csv')
df_HadronicTag_Dstar_pi0_m50 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m50_wc.csv')

df_SemilepTag_m00 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_m00_wc.csv')
df_SemilepTag_m10 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_m10_wc.csv')
df_SemilepTag_m20 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_m20_wc.csv')
df_SemilepTag_m30 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_m30_wc.csv')
df_SemilepTag_m40 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_m40_wc.csv')
df_SemilepTag_m50 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_m50_wc.csv')

df_SemilepTag_Dstar_gamma_m00 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m00_wc.csv')
df_SemilepTag_Dstar_gamma_m10 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m10_wc.csv')
df_SemilepTag_Dstar_gamma_m20 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m20_wc.csv')
df_SemilepTag_Dstar_gamma_m30 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m30_wc.csv')
df_SemilepTag_Dstar_gamma_m40 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m40_wc.csv')
df_SemilepTag_Dstar_gamma_m50 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m50_wc.csv')

df_SemilepTag_Dstar_pi0_m00 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_pi0_m00_wc.csv')
df_SemilepTag_Dstar_pi0_m10 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_pi0_m10_wc.csv')
df_SemilepTag_Dstar_pi0_m20 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_pi0_m20_wc.csv')
df_SemilepTag_Dstar_pi0_m30 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_pi0_m30_wc.csv')
df_SemilepTag_Dstar_pi0_m40 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_pi0_m40_wc.csv')
df_SemilepTag_Dstar_pi0_m50 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_pi0_m50_wc.csv')

df_BkgHtag_D = pd.read_csv('../Analysis/Files/CSV_Files/BkgHtag_D_wc.csv')
df_BkgHtag_Dstar_gamma = pd.read_csv('../Analysis/Files/CSV_Files/BkgHtag_Dstar_gamma_wc.csv')
df_BkgHtag_Dstar_pi0 = pd.read_csv('../Analysis/Files/CSV_Files/BkgHtag_Dstar_pi0_wc.csv')

df_BkgStag_D = pd.read_csv('../Analysis/Files/CSV_Files/BkgStag_D_wc.csv')
df_BkgStag_Dstar_gamma = pd.read_csv('../Analysis/Files/CSV_Files/BkgStag_Dstar_gamma_wc.csv')
df_BkgStag_Dstar_pi0 = pd.read_csv('../Analysis/Files/CSV_Files/BkgStag_Dstar_pi0_wc.csv')

# %%
print(len(df_SemilepTag_Dstar_gamma_m00))
# Out:
# 33735

# %%
df_BkgStag_D
# Out:
#        Unnamed: 0  nEta  nEtaPrime  nTracks_  track_sig_genMotherPDG  \
# 0           53022   0.0        0.0       4.0                  -521.0
# 1           57803   0.0        0.0       4.0                   521.0
# 2           20134   0.0        0.0       6.0                  -521.0
# 3           35379   0.0        0.0       6.0                  -521.0
# 4            4179   0.0        0.0       4.0                   -15.0
# ...           ...   ...        ...       ...                     ...
# 60600       25318   0.0        0.0       6.0                 10411.0
# 60601       64074   0.0        0.0       6.0                -10411.0
# 60602        8244   0.0        0.0       6.0                 10411.0
# 60603       12055   0.0        0.0       6.0                -10411.0
# 60604       57570   0.0        0.0       6.0                -10411.0
#
#        track_tag_genMotherPDG  pi_tag_genMotherPDG  D_tag_M   B_tag_M  \
# ...

# %%
df_BkgStag_Dstar_gamma
# Out:
#        Unnamed: 0  nEta  nEtaPrime  nTracks_  track_sig_genMotherPDG  \
# 0           12591   0.0        0.0       6.0                  -521.0
# 1            1463   0.0        0.0       6.0                  1114.0
# 2            9624   0.0        0.0       4.0                    15.0
# 3           19902   0.0        0.0       4.0                    15.0
# 4            5504   0.0        0.0       6.0                   521.0
# ...           ...   ...        ...       ...                     ...
# 17681       30232   0.0        0.0       6.0                -20413.0
# 17682       36190   0.0        0.0       6.0                 20413.0
# 17683        9005   0.0        0.0       6.0                 20413.0
# 17684       18918   0.0        0.0       6.0                 20413.0
# 17685        3914   0.0        0.0       6.0                -20413.0
#
#        track_tag_genMotherPDG  pi_tag_genMotherPDG   D_tag_M   B_tag_M  \
# ...

# %%
df_BkgStag_Dstar_pi0
# Out:
#        Unnamed: 0  nEta  nEtaPrime  nTracks_  track_sig_genMotherPDG  \
# 0           46381   0.0        0.0       4.0                    15.0
# 1           51501   0.0        0.0       6.0                   521.0
# 2           33173   0.0        0.0       6.0                  -521.0
# 3            6333   0.0        0.0       6.0                   323.0
# 4           19970   0.0        0.0       6.0                   521.0
# ...           ...   ...        ...       ...                     ...
# 57580       41122   0.0        0.0       6.0                -20413.0
# 57581       33781   0.0        0.0       6.0                -20413.0
# 57582       41331   0.0        0.0       6.0                 20413.0
# 57583        4335   0.0        0.0       6.0                 20413.0
# 57584        2996   0.0        0.0       6.0                 20413.0
#
#        track_tag_genMotherPDG  pi_tag_genMotherPDG   D_tag_M   B_tag_M  \
# ...

# %%
def PandasToRD(df, flag):
    # Extract the leafs from pandas df
    #leafs = df.columns.values.tolist()
    if flag == 1:
        leafs = ['Xps', 'q2']
    else: leafs = ['Mmin2', 'Mmax2', 'Xps', 'q2']
    # Read the pandas dataframe in form of dictionary
    df_dic = {key: df[key].values for key in leafs}
    # write the dictionary with numpy arrays to a RDataframe
    RD_df = ROOT.RDF.MakeNumpyDataFrame(df_dic)
    #RD_df = ROOT.RDF.FromCSV("myfile.csv")
    return RD_df

# %%
sig_HadTag_D_m00_df = PandasToRD(df_HadronicTag_m00, flag=1)
sig_HadTag_D_m10_df = PandasToRD(df_HadronicTag_m10, flag=1)
sig_HadTag_D_m20_df = PandasToRD(df_HadronicTag_m20, flag=1)
sig_HadTag_D_m30_df = PandasToRD(df_HadronicTag_m30, flag=1)
sig_HadTag_D_m40_df = PandasToRD(df_HadronicTag_m40, flag=1)
sig_HadTag_D_m50_df = PandasToRD(df_HadronicTag_m50, flag=1)

sig_HadTag_Dstar_gamma_m00_df = PandasToRD(df_HadronicTag_Dstar_gamma_m00, flag=1)
sig_HadTag_Dstar_gamma_m10_df = PandasToRD(df_HadronicTag_Dstar_gamma_m10, flag=1)
sig_HadTag_Dstar_gamma_m20_df = PandasToRD(df_HadronicTag_Dstar_gamma_m20, flag=1)
sig_HadTag_Dstar_gamma_m30_df = PandasToRD(df_HadronicTag_Dstar_gamma_m30, flag=1)
sig_HadTag_Dstar_gamma_m40_df = PandasToRD(df_HadronicTag_Dstar_gamma_m40, flag=1)
sig_HadTag_Dstar_gamma_m50_df = PandasToRD(df_HadronicTag_Dstar_gamma_m50, flag=1)

sig_HadTag_Dstar_pi0_m00_df = PandasToRD(df_HadronicTag_Dstar_pi0_m00, flag=1)
sig_HadTag_Dstar_pi0_m10_df = PandasToRD(df_HadronicTag_Dstar_pi0_m10, flag=1)
sig_HadTag_Dstar_pi0_m20_df = PandasToRD(df_HadronicTag_Dstar_pi0_m20, flag=1)
sig_HadTag_Dstar_pi0_m30_df = PandasToRD(df_HadronicTag_Dstar_pi0_m30, flag=1)
sig_HadTag_Dstar_pi0_m40_df = PandasToRD(df_HadronicTag_Dstar_pi0_m40, flag=1)
sig_HadTag_Dstar_pi0_m50_df = PandasToRD(df_HadronicTag_Dstar_pi0_m50, flag=1)

sig_SemiTag_D_m00_df = PandasToRD(df_SemilepTag_m00, flag=2)
sig_SemiTag_D_m10_df = PandasToRD(df_SemilepTag_m10, flag=2)
sig_SemiTag_D_m20_df = PandasToRD(df_SemilepTag_m20, flag=2)
sig_SemiTag_D_m30_df = PandasToRD(df_SemilepTag_m30, flag=2)
sig_SemiTag_D_m40_df = PandasToRD(df_SemilepTag_m40, flag=2)
sig_SemiTag_D_m50_df = PandasToRD(df_SemilepTag_m50, flag=2)

sig_SemiTag_Dstar_gamma_m00_df = PandasToRD(df_SemilepTag_Dstar_gamma_m00, flag=2)
sig_SemiTag_Dstar_gamma_m10_df = PandasToRD(df_SemilepTag_Dstar_gamma_m10, flag=2)
sig_SemiTag_Dstar_gamma_m20_df = PandasToRD(df_SemilepTag_Dstar_gamma_m20, flag=2)
sig_SemiTag_Dstar_gamma_m30_df = PandasToRD(df_SemilepTag_Dstar_gamma_m30, flag=2)
sig_SemiTag_Dstar_gamma_m40_df = PandasToRD(df_SemilepTag_Dstar_gamma_m40, flag=2)
sig_SemiTag_Dstar_gamma_m50_df = PandasToRD(df_SemilepTag_Dstar_gamma_m50, flag=2)

sig_SemiTag_Dstar_pi0_m00_df = PandasToRD(df_SemilepTag_Dstar_pi0_m00, flag=2)
sig_SemiTag_Dstar_pi0_m10_df = PandasToRD(df_SemilepTag_Dstar_pi0_m10, flag=2)
sig_SemiTag_Dstar_pi0_m20_df = PandasToRD(df_SemilepTag_Dstar_pi0_m20, flag=2)
sig_SemiTag_Dstar_pi0_m30_df = PandasToRD(df_SemilepTag_Dstar_pi0_m30, flag=2)
sig_SemiTag_Dstar_pi0_m40_df = PandasToRD(df_SemilepTag_Dstar_pi0_m40, flag=2)
sig_SemiTag_Dstar_pi0_m50_df = PandasToRD(df_SemilepTag_Dstar_pi0_m50, flag=2)



BkgHtag_D_df = PandasToRD(df_BkgHtag_D, flag=1)
BkgHtag_Dstar_gamma_df = PandasToRD(df_BkgHtag_Dstar_gamma, flag=1)
BkgHtag_Dstar_pi0_df = PandasToRD(df_BkgHtag_Dstar_pi0, flag=1)

BkgStag_D_df = PandasToRD(df_BkgStag_D, flag=2)
BkgStag_Dstar_gamma_df = PandasToRD(df_BkgStag_Dstar_gamma, flag=2)
BkgStag_Dstar_pi0_df = PandasToRD(df_BkgStag_Dstar_pi0, flag=2)

# %%
sig_SemiTag_Dstar_gamma_m00_df.Display().Print()
# Out:
# +-----+--------------+------------+------------+-------------+
# | Row | Mmax2        | Mmin2      | Xps        | q2          |
# +-----+--------------+------------+------------+-------------+
# | 0   | -0.071415298 | -1.1807318 | 0.91907919 | 0.21744936  |
# +-----+--------------+------------+------------+-------------+
# | 1   | 3.5778421    | 0.60901537 | 0.94461432 | 2.6151102   |
# +-----+--------------+------------+------------+-------------+
# | 2   | 2.0982561    | -1.0768692 | 1.0161768  | 0.84871722  |
# +-----+--------------+------------+------------+-------------+
# | 3   | 1000.0000    | 1000.0000  | 1.0612728  | -0.51584734 |
# +-----+--------------+------------+------------+-------------+
# | 4   | 0.94415751   | -2.4377098 | 1.0251676  | -0.61515518 |
# +-----+--------------+------------+------------+-------------+

# %%
BkgStag_D_df.Display().Print()
# Out:
# +-----+------------+------------+------------+-------------+
# | Row | Mmax2      | Mmin2      | Xps        | q2          |
# +-----+------------+------------+------------+-------------+
# | 0   | 19.751507  | 18.861752  | 0.31834992 | 19.283635   |
# +-----+------------+------------+------------+-------------+
# | 1   | 20.120706  | 19.667821  | 0.28781591 | 20.148458   |
# +-----+------------+------------+------------+-------------+
# | 2   | 0.71342388 | -2.5575623 | 1.0381701  | -0.71248909 |
# +-----+------------+------------+------------+-------------+
# | 3   | 1.5322796  | 0.22107249 | 0.99855036 | 1.3878054   |
# +-----+------------+------------+------------+-------------+
# | 4   | 14.177528  | 12.617977  | 0.51547643 | 13.415927   |
# +-----+------------+------------+------------+-------------+

# %%
BkgStag_Dstar_gamma_df.Display().Print()
# Out:
# +-----+-------------+------------+------------+------------+
# | Row | Mmax2       | Mmin2      | Xps        | q2         |
# +-----+-------------+------------+------------+------------+
# | 0   | 15.130852   | 14.364572  | 0.46802040 | 14.395199  |
# +-----+-------------+------------+------------+------------+
# | 1   | 24.830190   | 24.506037  | 0.11710317 | 24.791441  |
# +-----+-------------+------------+------------+------------+
# | 2   | 7.5583316   | 6.1074351  | 0.72408003 | 6.6413122  |
# +-----+-------------+------------+------------+------------+
# | 3   | 9.2845429   | 7.5432784  | 0.70254410 | 8.7032267  |
# +-----+-------------+------------+------------+------------+
# | 4   | -0.17176445 | -2.8503689 | 1.0553928  | -1.2154889 |
# +-----+-------------+------------+------------+------------+

# %%
BkgStag_Dstar_pi0_df.Display().Print()
# Out:
# +-----+------------+-------------+------------+-------------+
# | Row | Mmax2      | Mmin2       | Xps        | q2          |
# +-----+------------+-------------+------------+-------------+
# | 0   | 2.7595868  | -0.33071101 | 0.98243484 | 1.5309437   |
# +-----+------------+-------------+------------+-------------+
# | 1   | 0.57434646 | -2.6674591  | 1.0548590  | -0.65936675 |
# +-----+------------+-------------+------------+-------------+
# | 2   | 1000.0000  | 1000.0000   | 1.0921164  | -1.4179040  |
# +-----+------------+-------------+------------+-------------+
# | 3   | 24.292506  | 23.883218   | 0.13453382 | 24.206528   |
# +-----+------------+-------------+------------+-------------+
# | 4   | 1.1851472  | 0.25841515  | 0.97016184 | 0.74212811  |
# +-----+------------+-------------+------------+-------------+

# %%
BkgHtag_D_df.Display().Print()
# Out:
# +-----+------------+-----------+
# | Row | Xps        | q2        |
# +-----+------------+-----------+
# | 0   | 0.57025192 | 12.656814 |
# +-----+------------+-----------+
# | 1   | 0.99144500 | 1.9996194 |
# +-----+------------+-----------+
# | 2   | 0.12999656 | 24.328465 |
# +-----+------------+-----------+
# | 3   | 0.84446484 | 4.2265782 |
# +-----+------------+-----------+
# | 4   | 0.22873917 | 21.946838 |
# +-----+------------+-----------+

# %%
BkgHtag_Dstar_gamma_df.Display().Print()
# Out:
# +-----+------------+------------+
# | Row | Xps        | q2         |
# +-----+------------+------------+
# | 0   | 0.70756989 | 7.2101419  |
# +-----+------------+------------+
# | 1   | 0.34026119 | 18.127981  |
# +-----+------------+------------+
# | 2   | 0.30671505 | 18.958705  |
# +-----+------------+------------+
# | 3   | 0.99242547 | -2.0162716 |
# +-----+------------+------------+
# | 4   | 0.17700080 | 22.858873  |
# +-----+------------+------------+

# %%
BkgHtag_Dstar_pi0_df.Display().Print()
# Out:
# +-----+------------+-------------+
# | Row | Xps        | q2          |
# +-----+------------+-------------+
# | 0   | 0.98919954 | -0.30579085 |
# +-----+------------+-------------+
# | 1   | 0.62497177 | 11.269931   |
# +-----+------------+-------------+
# | 2   | 0.61562473 | 11.172438   |
# +-----+------------+-------------+
# | 3   | 0.65322273 | 10.546984   |
# +-----+------------+-------------+
# | 4   | 0.24531085 | 20.947940   |
# +-----+------------+-------------+

# %% [markdown]
# ## Semileptonic Tags

# %%
bins = 10
Mmin_min = -5
Mmin_max = 28
Mmax_min = -1
Mmax_max = 27
q2_min = -3
q2_max = 27

# ------------  Mmin and Mmax variables

# D tag
hS_D_m00_Mmin2 = sig_SemiTag_D_m00_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_D_m10_Mmin2 = sig_SemiTag_D_m10_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_D_m20_Mmin2 = sig_SemiTag_D_m20_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_D_m30_Mmin2 = sig_SemiTag_D_m30_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_D_m40_Mmin2 = sig_SemiTag_D_m40_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_D_m50_Mmin2 = sig_SemiTag_D_m50_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")

hS_D_m00_Mmax2 = sig_SemiTag_D_m00_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_D_m10_Mmax2 = sig_SemiTag_D_m10_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_D_m20_Mmax2 = sig_SemiTag_D_m20_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_D_m30_Mmax2 = sig_SemiTag_D_m30_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_D_m40_Mmax2 = sig_SemiTag_D_m40_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_D_m50_Mmax2 = sig_SemiTag_D_m50_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
# D0star gamma tag
hS_Dstar_gamma_m00_Mmin2 = sig_SemiTag_Dstar_gamma_m00_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_Dstar_gamma_m10_Mmin2 = sig_SemiTag_Dstar_gamma_m10_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_Dstar_gamma_m20_Mmin2 = sig_SemiTag_Dstar_gamma_m20_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_Dstar_gamma_m30_Mmin2 = sig_SemiTag_Dstar_gamma_m30_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_Dstar_gamma_m40_Mmin2 = sig_SemiTag_Dstar_gamma_m40_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_Dstar_gamma_m50_Mmin2 = sig_SemiTag_Dstar_gamma_m50_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")

hS_Dstar_gamma_m00_Mmax2 = sig_SemiTag_Dstar_gamma_m00_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_Dstar_gamma_m10_Mmax2 = sig_SemiTag_Dstar_gamma_m10_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_Dstar_gamma_m20_Mmax2 = sig_SemiTag_Dstar_gamma_m20_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_Dstar_gamma_m30_Mmax2 = sig_SemiTag_Dstar_gamma_m30_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_Dstar_gamma_m40_Mmax2 = sig_SemiTag_Dstar_gamma_m40_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_Dstar_gamma_m50_Mmax2 = sig_SemiTag_Dstar_gamma_m50_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
# D0star pi0 tag
hS_Dstar_pi0_m00_Mmin2 = sig_SemiTag_Dstar_pi0_m00_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_Dstar_pi0_m10_Mmin2 = sig_SemiTag_Dstar_pi0_m10_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_Dstar_pi0_m20_Mmin2 = sig_SemiTag_Dstar_pi0_m20_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_Dstar_pi0_m30_Mmin2 = sig_SemiTag_Dstar_pi0_m30_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_Dstar_pi0_m40_Mmin2 = sig_SemiTag_Dstar_pi0_m40_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_Dstar_pi0_m50_Mmin2 = sig_SemiTag_Dstar_pi0_m50_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")

hS_Dstar_pi0_m00_Mmax2 = sig_SemiTag_Dstar_pi0_m00_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_Dstar_pi0_m10_Mmax2 = sig_SemiTag_Dstar_pi0_m10_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_Dstar_pi0_m20_Mmax2 = sig_SemiTag_Dstar_pi0_m20_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_Dstar_pi0_m30_Mmax2 = sig_SemiTag_Dstar_pi0_m30_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_Dstar_pi0_m40_Mmax2 = sig_SemiTag_Dstar_pi0_m40_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_Dstar_pi0_m50_Mmax2 = sig_SemiTag_Dstar_pi0_m50_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")


# Background per tag
hBkgStag_D_Mmin2 = BkgStag_D_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hBkgStag_Dstar_gamma_Mmin2 = BkgStag_Dstar_gamma_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hBkgStag_Dstar_pi0_Mmin2 = BkgStag_Dstar_pi0_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")


hBkgStag_D_Mmax2 = BkgStag_D_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hBkgStag_Dstar_gamma_Mmax2 = BkgStag_Dstar_gamma_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hBkgStag_Dstar_pi0_Mmax2 = BkgStag_Dstar_pi0_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")



# ------------  Xps variable
Xps_min = 0.0
Xps_max = 1.2
# D tag
hS_D_m00_Xps = sig_SemiTag_D_m00_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_D_m10_Xps = sig_SemiTag_D_m10_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_D_m20_Xps = sig_SemiTag_D_m20_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_D_m30_Xps = sig_SemiTag_D_m30_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_D_m40_Xps = sig_SemiTag_D_m40_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_D_m50_Xps = sig_SemiTag_D_m50_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
# D0star gamma tag
hS_Dstar_gamma_m00_Xps = sig_SemiTag_Dstar_gamma_m00_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_Dstar_gamma_m10_Xps = sig_SemiTag_Dstar_gamma_m10_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_Dstar_gamma_m20_Xps = sig_SemiTag_Dstar_gamma_m20_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_Dstar_gamma_m30_Xps = sig_SemiTag_Dstar_gamma_m30_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_Dstar_gamma_m40_Xps = sig_SemiTag_Dstar_gamma_m40_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_Dstar_gamma_m50_Xps = sig_SemiTag_Dstar_gamma_m50_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
# D0star pi0 tag
hS_Dstar_pi0_m00_Xps = sig_SemiTag_Dstar_pi0_m00_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_Dstar_pi0_m10_Xps = sig_SemiTag_Dstar_pi0_m10_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_Dstar_pi0_m20_Xps = sig_SemiTag_Dstar_pi0_m20_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_Dstar_pi0_m30_Xps = sig_SemiTag_Dstar_pi0_m30_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_Dstar_pi0_m40_Xps = sig_SemiTag_Dstar_pi0_m40_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_Dstar_pi0_m50_Xps = sig_SemiTag_Dstar_pi0_m50_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
# Background per tag
hBkgStag_D_Xps = BkgStag_D_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hBkgStag_Dstar_gamma_Xps = BkgStag_Dstar_gamma_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hBkgStag_Dstar_pi0_Xps = BkgStag_Dstar_pi0_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")


# ------------  variable q^2
hS_D_m00_q2 = sig_SemiTag_D_m00_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_D_m10_q2 = sig_SemiTag_D_m10_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_D_m20_q2 = sig_SemiTag_D_m20_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_D_m30_q2 = sig_SemiTag_D_m30_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_D_m40_q2 = sig_SemiTag_D_m40_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_D_m50_q2 = sig_SemiTag_D_m50_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")

# D0star gamma tag
hS_Dstar_gamma_m00_q2 = sig_SemiTag_Dstar_gamma_m00_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_Dstar_gamma_m10_q2 = sig_SemiTag_Dstar_gamma_m10_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_Dstar_gamma_m20_q2 = sig_SemiTag_Dstar_gamma_m20_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_Dstar_gamma_m30_q2 = sig_SemiTag_Dstar_gamma_m30_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_Dstar_gamma_m40_q2 = sig_SemiTag_Dstar_gamma_m40_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_Dstar_gamma_m50_q2 = sig_SemiTag_Dstar_gamma_m50_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")

# D0star pi0 tag
hS_Dstar_pi0_m00_q2 = sig_SemiTag_Dstar_pi0_m00_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_Dstar_pi0_m10_q2 = sig_SemiTag_Dstar_pi0_m10_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_Dstar_pi0_m20_q2 = sig_SemiTag_Dstar_pi0_m20_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_Dstar_pi0_m30_q2 = sig_SemiTag_Dstar_pi0_m30_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_Dstar_pi0_m40_q2 = sig_SemiTag_Dstar_pi0_m40_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_Dstar_pi0_m50_q2 = sig_SemiTag_Dstar_pi0_m50_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")

# Background per tag
hBkgStag_D_q2 = BkgStag_D_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hBkgStag_Dstar_gamma_q2 = BkgStag_Dstar_gamma_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hBkgStag_Dstar_pi0_q2 = BkgStag_Dstar_pi0_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")

# %% [markdown]
# ## Hadronic Tags

# %%
bins = 200
Mmin_min = -5
Mmin_max = 28
Mmax_min = -1
Mmax_max = 27
q2_min = -3
q2_max = 27

# ------------  Mmin and Mmax variables

# D tag
hS_Had_D_m00_Mmin2 = sig_HadTag_D_m00_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_Had_D_m10_Mmin2 = sig_HadTag_D_m10_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_Had_D_m20_Mmin2 = sig_HadTag_D_m20_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_Had_D_m30_Mmin2 = sig_HadTag_D_m30_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_Had_D_m40_Mmin2 = sig_HadTag_D_m40_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_Had_D_m50_Mmin2 = sig_HadTag_D_m50_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")

hS_Had_D_m00_Mmax2 = sig_HadTag_D_m00_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_Had_D_m10_Mmax2 = sig_HadTag_D_m10_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_Had_D_m20_Mmax2 = sig_HadTag_D_m20_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_Had_D_m30_Mmax2 = sig_HadTag_D_m30_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_Had_D_m40_Mmax2 = sig_HadTag_D_m40_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_Had_D_m50_Mmax2 = sig_HadTag_D_m50_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
# D0star gamma tag
hS_Had_Dstar_gamma_m00_Mmin2 = sig_HadTag_Dstar_gamma_m00_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_Had_Dstar_gamma_m10_Mmin2 = sig_HadTag_Dstar_gamma_m10_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_Had_Dstar_gamma_m20_Mmin2 = sig_HadTag_Dstar_gamma_m20_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_Had_Dstar_gamma_m30_Mmin2 = sig_HadTag_Dstar_gamma_m30_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_Had_Dstar_gamma_m40_Mmin2 = sig_HadTag_Dstar_gamma_m40_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_Had_Dstar_gamma_m50_Mmin2 = sig_HadTag_Dstar_gamma_m50_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")

hS_Had_Dstar_gamma_m00_Mmax2 = sig_HadTag_Dstar_gamma_m00_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_Had_Dstar_gamma_m10_Mmax2 = sig_HadTag_Dstar_gamma_m10_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_Had_Dstar_gamma_m20_Mmax2 = sig_HadTag_Dstar_gamma_m20_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_Had_Dstar_gamma_m30_Mmax2 = sig_HadTag_Dstar_gamma_m30_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_Had_Dstar_gamma_m40_Mmax2 = sig_HadTag_Dstar_gamma_m40_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_Had_Dstar_gamma_m50_Mmax2 = sig_HadTag_Dstar_gamma_m50_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
# D0star pi0 tag
hS_Had_Dstar_pi0_m00_Mmin2 = sig_HadTag_Dstar_pi0_m00_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_Had_Dstar_pi0_m10_Mmin2 = sig_HadTag_Dstar_pi0_m10_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_Had_Dstar_pi0_m20_Mmin2 = sig_HadTag_Dstar_pi0_m20_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_Had_Dstar_pi0_m30_Mmin2 = sig_HadTag_Dstar_pi0_m30_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_Had_Dstar_pi0_m40_Mmin2 = sig_HadTag_Dstar_pi0_m40_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hS_Had_Dstar_pi0_m50_Mmin2 = sig_HadTag_Dstar_pi0_m50_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")

hS_Had_Dstar_pi0_m00_Mmax2 = sig_HadTag_Dstar_pi0_m00_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_Had_Dstar_pi0_m10_Mmax2 = sig_HadTag_Dstar_pi0_m10_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_Had_Dstar_pi0_m20_Mmax2 = sig_HadTag_Dstar_pi0_m20_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_Had_Dstar_pi0_m30_Mmax2 = sig_HadTag_Dstar_pi0_m30_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_Had_Dstar_pi0_m40_Mmax2 = sig_HadTag_Dstar_pi0_m40_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hS_Had_Dstar_pi0_m50_Mmax2 = sig_HadTag_Dstar_pi0_m50_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")


# Background per tag
hBkgHtag_D_Mmin2 = BkgHtag_D_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hBkgHtag_Dstar_gamma_Mmin2 = BkgHtag_Dstar_gamma_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")
hBkgHtag_Dstar_pi0_Mmin2 = BkgHtag_Dstar_pi0_df.Histo1D(("Mmin2", "Mmin2", bins, Mmin_min, Mmin_max), "Mmin2")


hBkgHtag_D_Mmax2 = BkgHtag_D_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hBkgHtag_Dstar_gamma_Mmax2 = BkgHtag_Dstar_gamma_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")
hBkgHtag_Dstar_pi0_Mmax2 = BkgHtag_Dstar_pi0_df.Histo1D(("Mmax2", "Mmax2", bins, Mmax_min, Mmax_max), "Mmax2")



# ------------  Xps variable
Xps_min = 0.0
Xps_max = 1.2
# D tag
hS_Had_D_m00_Xps = sig_HadTag_D_m00_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_Had_D_m10_Xps = sig_HadTag_D_m10_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_Had_D_m20_Xps = sig_HadTag_D_m20_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_Had_D_m30_Xps = sig_HadTag_D_m30_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_Had_D_m40_Xps = sig_HadTag_D_m40_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_Had_D_m50_Xps = sig_HadTag_D_m50_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
# D0star gamma tag
hS_Had_Dstar_gamma_m00_Xps = sig_HadTag_Dstar_gamma_m00_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_Had_Dstar_gamma_m10_Xps = sig_HadTag_Dstar_gamma_m10_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_Had_Dstar_gamma_m20_Xps = sig_HadTag_Dstar_gamma_m20_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_Had_Dstar_gamma_m30_Xps = sig_HadTag_Dstar_gamma_m30_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_Had_Dstar_gamma_m40_Xps = sig_HadTag_Dstar_gamma_m40_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_Had_Dstar_gamma_m50_Xps = sig_HadTag_Dstar_gamma_m50_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
# D0star pi0 tag
hS_Had_Dstar_pi0_m00_Xps = sig_HadTag_Dstar_pi0_m00_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_Had_Dstar_pi0_m10_Xps = sig_HadTag_Dstar_pi0_m10_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_Had_Dstar_pi0_m20_Xps = sig_HadTag_Dstar_pi0_m20_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_Had_Dstar_pi0_m30_Xps = sig_HadTag_Dstar_pi0_m30_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_Had_Dstar_pi0_m40_Xps = sig_HadTag_Dstar_pi0_m40_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hS_Had_Dstar_pi0_m50_Xps = sig_HadTag_Dstar_pi0_m50_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
# Background per tag
hBkgHtag_D_Xps = BkgHtag_D_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hBkgHtag_Dstar_gamma_Xps = BkgHtag_Dstar_gamma_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")
hBkgHtag_Dstar_pi0_Xps = BkgHtag_Dstar_pi0_df.Histo1D(("Xps", "Xps", bins, Xps_min, Xps_max), "Xps")


# ------------  variable q^2
hS_Had_D_m00_q2 = sig_HadTag_D_m00_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_Had_D_m10_q2 = sig_HadTag_D_m10_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_Had_D_m20_q2 = sig_HadTag_D_m20_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_Had_D_m30_q2 = sig_HadTag_D_m30_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_Had_D_m40_q2 = sig_HadTag_D_m40_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_Had_D_m50_q2 = sig_HadTag_D_m50_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")

# D0star gamma tag
hS_Had_Dstar_gamma_m00_q2 = sig_HadTag_Dstar_gamma_m00_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_Had_Dstar_gamma_m10_q2 = sig_HadTag_Dstar_gamma_m10_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_Had_Dstar_gamma_m20_q2 = sig_HadTag_Dstar_gamma_m20_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_Had_Dstar_gamma_m30_q2 = sig_HadTag_Dstar_gamma_m30_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_Had_Dstar_gamma_m40_q2 = sig_HadTag_Dstar_gamma_m40_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_Had_Dstar_gamma_m50_q2 = sig_HadTag_Dstar_gamma_m50_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")

# D0star pi0 tag
hS_Had_Dstar_pi0_m00_q2 = sig_HadTag_Dstar_pi0_m00_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_Had_Dstar_pi0_m10_q2 = sig_HadTag_Dstar_pi0_m10_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_Had_Dstar_pi0_m20_q2 = sig_HadTag_Dstar_pi0_m20_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_Had_Dstar_pi0_m30_q2 = sig_HadTag_Dstar_pi0_m30_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_Had_Dstar_pi0_m40_q2 = sig_HadTag_Dstar_pi0_m40_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hS_Had_Dstar_pi0_m50_q2 = sig_HadTag_Dstar_pi0_m50_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")

# Background per tag
hBkgHtag_D_q2 = BkgHtag_D_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hBkgHtag_Dstar_gamma_q2 = BkgHtag_Dstar_gamma_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")
hBkgHtag_Dstar_pi0_q2 = BkgHtag_Dstar_pi0_df.Histo1D(("q2", "q2", bins, q2_min, q2_max), "q2")

# %% [markdown]
# ## Saving the histograms in root files
# For Semileptonic tags

# %% [markdown]
# Mmin2 and Mmax2

# %%
# Lest's create the root files
# D tag
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_D_m00_Mmin2_pdf.root', 'RECREATE' )
hS_D_m00_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_D_m10_Mmin2_pdf.root', 'RECREATE' )
hS_D_m10_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_D_m20_Mmin2_pdf.root', 'RECREATE' )
hS_D_m20_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_D_m30_Mmin2_pdf.root', 'RECREATE' )
hS_D_m30_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_D_m40_Mmin2_pdf.root', 'RECREATE' )
hS_D_m40_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_D_m50_Mmin2_pdf.root', 'RECREATE' )
hS_D_m50_Mmin2.Write()
myfile.Close()

myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_D_m00_Mmax2_pdf.root', 'RECREATE' )
hS_D_m00_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_D_m10_Mmax2_pdf.root', 'RECREATE' )
hS_D_m10_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_D_m20_Mmax2_pdf.root', 'RECREATE' )
hS_D_m20_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_D_m30_Mmax2_pdf.root', 'RECREATE' )
hS_D_m30_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_D_m40_Mmax2_pdf.root', 'RECREATE' )
hS_D_m40_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_D_m50_Mmax2_pdf.root', 'RECREATE' )
hS_D_m50_Mmax2.Write()
myfile.Close()

# %%
# Lest's create the root files
# Dstar_gamma tag
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m00_Mmin2_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m00_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m10_Mmin2_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m10_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m20_Mmin2_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m20_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m30_Mmin2_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m30_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m40_Mmin2_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m40_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m50_Mmin2_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m50_Mmin2.Write()
myfile.Close()

myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m00_Mmax2_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m00_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m10_Mmax2_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m10_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m20_Mmax2_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m20_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m30_Mmax2_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m30_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m40_Mmax2_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m40_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m50_Mmax2_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m50_Mmax2.Write()
myfile.Close()

# %%
# Lest's create the root files
# Dstar_pi0 tag
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m00_Mmin2_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m00_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m10_Mmin2_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m10_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m20_Mmin2_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m20_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m30_Mmin2_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m30_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m40_Mmin2_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m40_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m50_Mmin2_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m50_Mmin2.Write()
myfile.Close()

myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m00_Mmax2_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m00_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m10_Mmax2_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m10_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m20_Mmax2_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m20_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m30_Mmax2_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m30_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m40_Mmax2_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m40_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m50_Mmax2_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m50_Mmax2.Write()
myfile.Close()

# %%
# Now for background files
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgStag_D_Mmin2_pdf.root', 'RECREATE' )
hBkgStag_D_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_gamma_Mmin2_pdf.root', 'RECREATE' )
hBkgStag_Dstar_gamma_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_pi0_Mmin2_pdf.root', 'RECREATE' )
hBkgStag_Dstar_pi0_Mmin2.Write()
myfile.Close()

myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgStag_D_Mmax2_pdf.root', 'RECREATE' )
hBkgStag_D_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_gamma_Mmax2_pdf.root', 'RECREATE' )
hBkgStag_Dstar_gamma_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_pi0_Mmax2_pdf.root', 'RECREATE' )
hBkgStag_Dstar_pi0_Mmax2.Write()
myfile.Close()

# %% [markdown]
# Xps

# %%
# Lest's create the root files for Xps
# D tag
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_D_m00_Xps_pdf.root', 'RECREATE' )
hS_D_m00_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_D_m10_Xps_pdf.root', 'RECREATE' )
hS_D_m10_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_D_m20_Xps_pdf.root', 'RECREATE' )
hS_D_m20_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_D_m30_Xps_pdf.root', 'RECREATE' )
hS_D_m30_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_D_m40_Xps_pdf.root', 'RECREATE' )
hS_D_m40_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_D_m50_Xps_pdf.root', 'RECREATE' )
hS_D_m50_Xps.Write()
myfile.Close()

# %%
# Lest's create the root files for Xps
# D_star_gama tag
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m00_Xps_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m00_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m10_Xps_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m10_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m20_Xps_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m20_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m30_Xps_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m30_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m40_Xps_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m40_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m50_Xps_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m50_Xps.Write()
myfile.Close()

# %%
# Lest's create the root files for Xps
# D_star_pi0 tag
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m00_Xps_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m00_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m10_Xps_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m10_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m20_Xps_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m20_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m30_Xps_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m30_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m40_Xps_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m40_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m50_Xps_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m50_Xps.Write()
myfile.Close()

# %%
# Now for background files
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgStag_D_Xps_pdf.root', 'RECREATE' )
hBkgStag_D_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_gamma_Xps_pdf.root', 'RECREATE' )
hBkgStag_Dstar_gamma_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_pi0_Xps_pdf.root', 'RECREATE' )
hBkgStag_Dstar_pi0_Xps.Write()
myfile.Close()

# %% [markdown]
# ## ROOT files for q2

# %%
# Lest's create the root files
# D tag
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_D_m00_q2_pdf.root', 'RECREATE' )
hS_D_m00_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_D_m10_q2_pdf.root', 'RECREATE' )
hS_D_m10_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_D_m20_q2_pdf.root', 'RECREATE' )
hS_D_m20_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_D_m30_q2_pdf.root', 'RECREATE' )
hS_D_m30_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_D_m40_q2_pdf.root', 'RECREATE' )
hS_D_m40_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_D_m50_q2_pdf.root', 'RECREATE' )
hS_D_m50_q2.Write()
myfile.Close()

# %%
# Dstar_gamma tag
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m00_q2_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m00_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m10_q2_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m10_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m20_q2_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m20_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m30_q2_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m30_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m40_q2_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m40_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m50_q2_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m50_q2.Write()
myfile.Close()

# %%
# Dstar_pi0 tag
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m00_q2_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m00_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m10_q2_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m10_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m20_q2_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m20_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m30_q2_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m30_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m40_q2_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m40_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m50_q2_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m50_q2.Write()
myfile.Close()

# %%
# Now for background files
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgStag_D_q2_pdf.root', 'RECREATE' )
hBkgStag_D_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_gamma_q2_pdf.root', 'RECREATE' )
hBkgStag_Dstar_gamma_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_pi0_q2_pdf.root', 'RECREATE' )
hBkgStag_Dstar_pi0_q2.Write()
myfile.Close()

# %% [markdown]
# ## Hadronic tags
# Mmin2 and Mmax2

# %%
# Lest's create the root files
# D tag
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_D_m00_Mmin2_pdf.root', 'RECREATE' )
hS_Had_D_m00_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_D_m10_Mmin2_pdf.root', 'RECREATE' )
hS_Had_D_m10_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_D_m20_Mmin2_pdf.root', 'RECREATE' )
hS_Had_D_m20_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_D_m30_Mmin2_pdf.root', 'RECREATE' )
hS_Had_D_m30_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_D_m40_Mmin2_pdf.root', 'RECREATE' )
hS_Had_D_m40_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_D_m50_Mmin2_pdf.root', 'RECREATE' )
hS_Had_D_m50_Mmin2.Write()
myfile.Close()

myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_D_m00_Mmax2_pdf.root', 'RECREATE' )
hS_Had_D_m00_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_D_m10_Mmax2_pdf.root', 'RECREATE' )
hS_Had_D_m10_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_D_m20_Mmax2_pdf.root', 'RECREATE' )
hS_Had_D_m20_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_D_m30_Mmax2_pdf.root', 'RECREATE' )
hS_Had_D_m30_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_D_m40_Mmax2_pdf.root', 'RECREATE' )
hS_Had_D_m40_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_D_m50_Mmax2_pdf.root', 'RECREATE' )
hS_Had_D_m50_Mmax2.Write()
myfile.Close()

# %%
# Lest's create the root files
# Dstar_gamma tag
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m00_Mmin2_pdf.root', 'RECREATE' )
hS_Had_Dstar_gamma_m00_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m10_Mmin2_pdf.root', 'RECREATE' )
hS_Had_Dstar_gamma_m10_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m20_Mmin2_pdf.root', 'RECREATE' )
hS_Had_Dstar_gamma_m20_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m30_Mmin2_pdf.root', 'RECREATE' )
hS_Had_Dstar_gamma_m30_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m40_Mmin2_pdf.root', 'RECREATE' )
hS_Had_Dstar_gamma_m40_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m50_Mmin2_pdf.root', 'RECREATE' )
hS_Had_Dstar_gamma_m50_Mmin2.Write()
myfile.Close()

myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m00_Mmax2_pdf.root', 'RECREATE' )
hS_Had_Dstar_gamma_m00_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m10_Mmax2_pdf.root', 'RECREATE' )
hS_Had_Dstar_gamma_m10_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m20_Mmax2_pdf.root', 'RECREATE' )
hS_Had_Dstar_gamma_m20_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m30_Mmax2_pdf.root', 'RECREATE' )
hS_Had_Dstar_gamma_m30_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m40_Mmax2_pdf.root', 'RECREATE' )
hS_Had_Dstar_gamma_m40_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m50_Mmax2_pdf.root', 'RECREATE' )
hS_Had_Dstar_gamma_m50_Mmax2.Write()
myfile.Close()

# %%
# Lest's create the root files
# Dstar_pi0 tag
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m00_Mmin2_pdf.root', 'RECREATE' )
hS_Had_Dstar_pi0_m00_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m10_Mmin2_pdf.root', 'RECREATE' )
hS_Had_Dstar_pi0_m10_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m20_Mmin2_pdf.root', 'RECREATE' )
hS_Had_Dstar_pi0_m20_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m30_Mmin2_pdf.root', 'RECREATE' )
hS_Had_Dstar_pi0_m30_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m40_Mmin2_pdf.root', 'RECREATE' )
hS_Had_Dstar_pi0_m40_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m50_Mmin2_pdf.root', 'RECREATE' )
hS_Had_Dstar_pi0_m50_Mmin2.Write()
myfile.Close()

myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m00_Mmax2_pdf.root', 'RECREATE' )
hS_Had_Dstar_pi0_m00_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m10_Mmax2_pdf.root', 'RECREATE' )
hS_Had_Dstar_pi0_m10_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m20_Mmax2_pdf.root', 'RECREATE' )
hS_Had_Dstar_pi0_m20_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m30_Mmax2_pdf.root', 'RECREATE' )
hS_Had_Dstar_pi0_m30_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m40_Mmax2_pdf.root', 'RECREATE' )
hS_Had_Dstar_pi0_m40_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m50_Mmax2_pdf.root', 'RECREATE' )
hS_Had_Dstar_pi0_m50_Mmax2.Write()
myfile.Close()

# %%
# Now for background files
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgHtag_D_Mmin2_pdf.root', 'RECREATE' )
hBkgHtag_D_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgHtag_Dstar_gamma_Mmin2_pdf.root', 'RECREATE' )
hBkgHtag_Dstar_gamma_Mmin2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgHtag_Dstar_pi0_Mmin2_pdf.root', 'RECREATE' )
hBkgHtag_Dstar_pi0_Mmin2.Write()
myfile.Close()

myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgHtag_D_Mmax2_pdf.root', 'RECREATE' )
hBkgHtag_D_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgHtag_Dstar_gamma_Mmax2_pdf.root', 'RECREATE' )
hBkgHtag_Dstar_gamma_Mmax2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgHtag_Dstar_pi0_Mmax2_pdf.root', 'RECREATE' )
hBkgHtag_Dstar_pi0_Mmax2.Write()
myfile.Close()

# %% [markdown]
# Xps

# %%
# Lest's create the root files for Xps
# D tag
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_D_m00_Xps_pdf.root', 'RECREATE' )
hS_Had_D_m00_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_D_m10_Xps_pdf.root', 'RECREATE' )
hS_Had_D_m10_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_D_m20_Xps_pdf.root', 'RECREATE' )
hS_Had_D_m20_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_D_m30_Xps_pdf.root', 'RECREATE' )
hS_Had_D_m30_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_D_m40_Xps_pdf.root', 'RECREATE' )
hS_Had_D_m40_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_D_m50_Xps_pdf.root', 'RECREATE' )
hS_Had_D_m50_Xps.Write()
myfile.Close()

# %%
# Lest's create the root files for Xps
# D_star_gama tag
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m00_Xps_pdf.root', 'RECREATE' )
hS_Had_Dstar_gamma_m00_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m10_Xps_pdf.root', 'RECREATE' )
hS_Had_Dstar_gamma_m10_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m20_Xps_pdf.root', 'RECREATE' )
hS_Had_Dstar_gamma_m20_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m30_Xps_pdf.root', 'RECREATE' )
hS_Had_Dstar_gamma_m30_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m40_Xps_pdf.root', 'RECREATE' )
hS_Had_Dstar_gamma_m40_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m50_Xps_pdf.root', 'RECREATE' )
hS_Had_Dstar_gamma_m50_Xps.Write()
myfile.Close()

# %%
# Lest's create the root files for Xps
# D_star_pi0 tag
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m00_Xps_pdf.root', 'RECREATE' )
hS_Had_Dstar_pi0_m00_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m10_Xps_pdf.root', 'RECREATE' )
hS_Had_Dstar_pi0_m10_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m20_Xps_pdf.root', 'RECREATE' )
hS_Had_Dstar_pi0_m20_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m30_Xps_pdf.root', 'RECREATE' )
hS_Had_Dstar_pi0_m30_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m40_Xps_pdf.root', 'RECREATE' )
hS_Had_Dstar_pi0_m40_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m50_Xps_pdf.root', 'RECREATE' )
hS_Had_Dstar_pi0_m50_Xps.Write()
myfile.Close()

# %%
# Now for background files
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgHtag_D_Xps_pdf.root', 'RECREATE' )
hBkgHtag_D_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgHtag_Dstar_gamma_Xps_pdf.root', 'RECREATE' )
hBkgHtag_Dstar_gamma_Xps.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgHtag_Dstar_pi0_Xps_pdf.root', 'RECREATE' )
hBkgHtag_Dstar_pi0_Xps.Write()
myfile.Close()

# %% [markdown]
# q2

# %%
# Lest's create the root files
# D tag
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_D_m00_q2_pdf.root', 'RECREATE' )
hS_Had_D_m00_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_D_m10_q2_pdf.root', 'RECREATE' )
hS_Had_D_m10_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_D_m20_q2_pdf.root', 'RECREATE' )
hS_Had_D_m20_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_D_m30_q2_pdf.root', 'RECREATE' )
hS_Had_D_m30_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_D_m40_q2_pdf.root', 'RECREATE' )
hS_Had_D_m40_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_D_m50_q2_pdf.root', 'RECREATE' )
hS_Had_D_m50_q2.Write()
myfile.Close()

# %%
# Dstar_gamma tag
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m00_q2_pdf.root', 'RECREATE' )
hS_Had_Dstar_gamma_m00_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m10_q2_pdf.root', 'RECREATE' )
hS_Had_Dstar_gamma_m10_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m20_q2_pdf.root', 'RECREATE' )
hS_Had_Dstar_gamma_m20_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m30_q2_pdf.root', 'RECREATE' )
hS_Had_Dstar_gamma_m30_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m40_q2_pdf.root', 'RECREATE' )
hS_Had_Dstar_gamma_m40_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m50_q2_pdf.root', 'RECREATE' )
hS_Had_Dstar_gamma_m50_q2.Write()
myfile.Close()

# %%
# Dstar_pi0 tag
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m00_q2_pdf.root', 'RECREATE' )
hS_Had_Dstar_pi0_m00_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m10_q2_pdf.root', 'RECREATE' )
hS_Had_Dstar_pi0_m10_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m20_q2_pdf.root', 'RECREATE' )
hS_Had_Dstar_pi0_m20_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m30_q2_pdf.root', 'RECREATE' )
hS_Had_Dstar_pi0_m30_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m40_q2_pdf.root', 'RECREATE' )
hS_Had_Dstar_pi0_m40_q2.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m50_q2_pdf.root', 'RECREATE' )
hS_Had_Dstar_pi0_m50_q2.Write()
myfile.Close()

# %% [markdown]
# M_min2Low = -5.0
# M_min2Up = 27.0
#
# M_max2Low = -1.0
# M_max2Up = 27.0
#
# nbinsH = 15
# nbinsL = 15
#
#
# hS_2D_m00 = sig_m00_df.Histo2D(("hS_2D_m00", "hS_2D_m00", nbinsL, M_min2Low, M_min2Up, nbinsH, M_max2Low, M_max2Up), "Mmin2", "Mmax2")
# hS_2D_m10 = sig_m10_df.Histo2D(("hS_2D_m10", "hS_2D_m10", nbinsL, M_min2Low, M_min2Up, nbinsH, M_max2Low, M_max2Up), "Mmin2", "Mmax2")
# hS_2D_m20 = sig_m20_df.Histo2D(("hS_2D_m20", "hS_2D_m20", nbinsL, M_min2Low, M_min2Up, nbinsH, M_max2Low, M_max2Up), "Mmin2", "Mmax2")
# hS_2D_m30 = sig_m30_df.Histo2D(("hS_2D_m30", "hS_2D_m30", nbinsL, M_min2Low, M_min2Up, nbinsH, M_max2Low, M_max2Up), "Mmin2", "Mmax2")
# hS_2D_m40 = sig_m40_df.Histo2D(("hS_2D_m40", "hS_2D_m40", nbinsL, M_min2Low, M_min2Up, nbinsH, M_max2Low, M_max2Up), "Mmin2", "Mmax2")
# hS_2D_m50 = sig_m50_df.Histo2D(("hS_2D_m50", "hS_2D_m50", nbinsL, M_min2Low, M_min2Up, nbinsH, M_max2Low, M_max2Up), "Mmin2", "Mmax2")
#
# hpi_taunu_2D = pi_taunu_df.Histo2D(("hpi_taunu_2D", "hpi_taunu_2D", nbinsL, M_min2Low, M_min2Up, nbinsH, M_max2Low, M_max2Up), "Mmin2", "Mmax2")
# hpi_nunu_2D = pi_nunu_df.Histo2D(("hpi_nunu_2D", "hpi_nunu_2D", nbinsL, M_min2Low, M_min2Up, nbinsH, M_max2Low, M_max2Up), "Mmin2", "Mmax2")

# %% [markdown]
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_2D_m00_pdf.root', 'RECREATE' )
# hS_2D_m00.Write()
# myfile.Close()
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_2D_m10_pdf.root', 'RECREATE' )
# hS_2D_m10.Write()
# myfile.Close()
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_2D_m20_pdf.root', 'RECREATE' )
# hS_2D_m20.Write()
# myfile.Close()
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_2D_m30_pdf.root', 'RECREATE' )
# hS_2D_m30.Write()
# myfile.Close()
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_2D_m40_pdf.root', 'RECREATE' )
# hS_2D_m40.Write()
# myfile.Close()
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_2D_m50_pdf.root', 'RECREATE' )
# hS_2D_m50.Write()
# myfile.Close()
#
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hpi_taunu_2D_pdf.root', 'RECREATE' )
# hpi_taunu_2D.Write()
# myfile.Close()
# myfile = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hpi_nunu_2D_pdf.root', 'RECREATE' )
# hpi_nunu_2D.Write()
# myfile.Close()

# %%
f1 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_D_m00_Mmin2_pdf.root')
f2 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_D_m50_Mmin2_pdf.root')
f3 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_D_m00_Mmax2_pdf.root')
f4 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_D_m50_Mmax2_pdf.root')

f5 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgStag_D_Mmin2_pdf.root')
f6 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgStag_D_Mmax2_pdf.root')


hS_D_m00_Mmin2_pdf = ROOT.TH1D('hS_D_m00_Mmin2','hS_D_m00_Mmin2' , bins, Mmin_min, Mmin_max)
hS_D_m00_Mmin2_pdf = f1.Get("Mmin2")
hS_D_m50_Mmin2_pdf = ROOT.TH1D('hS_D_m50_Mmin2','hS_D_m50_Mmin2' , bins, Mmin_min, Mmin_max)
hS_D_m50_Mmin2_pdf = f2.Get("Mmin2")
hS_D_m00_Mmax2_pdf = ROOT.TH1D('hS_D_m00_Mmax2','hS_D_m00_Mmax2' , bins, Mmax_min, Mmax_max)
hS_D_m00_Mmax2_pdf = f3.Get("Mmax2")
hS_D_m50_Mmax2_pdf = ROOT.TH1D('hS_D_m50_Mmax2','hS_D_m50_Mmax2' , bins, Mmax_min, Mmax_max)
hS_D_m50_Mmax2_pdf = f4.Get("Mmax2")

hBkgStag_D_Mmin2_pdf = ROOT.TH1D('hBkgStag_D_Mmin2','hBkgStag_D_Mmin2' , bins, Mmin_min, Mmin_max)
hBkgStag_D_Mmin2_pdf = f5.Get("Mmin2")


hBkgStag_D_Mmax2_pdf = ROOT.TH1D('hBkgStag_D_Mmax2','hBkgStag_D_Mmax2' , bins, Mmin_min, Mmin_max)
hBkgStag_D_Mmax2_pdf = f6.Get("Mmax2")

# %%
c1 = ROOT.TCanvas("a","a",800,400)

c1.Divide(2)
c1.cd(1)
hS_D_m00_Mmin2_pdf.Draw()
hS_D_m50_Mmin2_pdf.Draw("SAME")
hBkgStag_D_Mmin2_pdf.Draw("SAME")
#hpi_nunu_Mmin2_pdf.Draw("SAME")
c1.cd(2)
hS_D_m00_Mmax2_pdf.Draw()
hS_D_m50_Mmax2_pdf.Draw("SAME")
hBkgStag_D_Mmax2_pdf.Draw("SAME")
#hpi_nunu_Mmax2_pdf.Draw("SAME")
c1.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: a

# %%
f7 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_D_m00_Xps_pdf.root')
f8 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_D_m50_Xps_pdf.root')
f9 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m00_Xps_pdf.root')
f10 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m50_Xps_pdf.root')
f11 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m00_Xps_pdf.root')
f12 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m50_Xps_pdf.root')


f13 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgStag_D_Xps_pdf.root')
f14 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_gamma_Xps_pdf.root')
f15 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_pi0_Xps_pdf.root')



hS_D_m00_Xps_pdf = ROOT.TH1D('hS_D_m00_Xps','hS_D_m00_Xps' , bins, Xps_min, Xps_max)
hS_D_m00_Xps_pdf = f7.Get("Xps")
hS_D_m50_Xps_pdf = ROOT.TH1D('hS_D_m50_Xps','hS_D_m50_Xps' , bins, Xps_min, Xps_max)
hS_D_m50_Xps_pdf = f8.Get("Xps")
hS_Dstar_gamma_m00_Xps_pdf = ROOT.TH1D('hS_Dstar_gamma_m00_Xps','hS_Dstar_gamma_m00_Xps' , bins, Xps_min, Xps_max)
hS_Dstar_gamma_m00_Xps_pdf = f9.Get("Xps")
hS_Dstar_gamma_m50_Xps_pdf = ROOT.TH1D('hS_Dstar_gamma_m50_Xps','hS_Dstar_gamma_m50_Xps' , bins, Xps_min, Xps_max)
hS_Dstar_gamma_m50_Xps_pdf = f10.Get("Xps")
hS_Dstar_pi0_m00_Xps_pdf = ROOT.TH1D('hS_Dstar_pi0_m00_Xps','hS_Dstar_pi0_m00_Xps' , bins, Xps_min, Xps_max)
hS_Dstar_pi0_m00_Xps_pdf = f11.Get("Xps")
hS_Dstar_pi0_m50_Xps_pdf = ROOT.TH1D('hS_Dstar_pi0_m50_Xps','hS_Dstar_pi0_m50_Xps' , bins, Xps_min, Xps_max)
hS_Dstar_pi0_m50_Xps_pdf = f12.Get("Xps")

hBkgStag_D_Xps_pdf = ROOT.TH1D('hBkgStag_D_Xps','hBkgStag_D_Xps' , bins, Xps_min, Xps_max)
hBkgStag_D_Xps_pdf = f13.Get("Xps")


hBkgStag_Dstar_gamma_Xps_pdf = ROOT.TH1D('hBkgStag_Dstar_gamma_Xps','hBkgStag_Dstar_gamma_Xps' , bins, Xps_min, Xps_max)
hBkgStag_Dstar_gamma_Xps_pdf = f14.Get("Xps")
hBkgStag_Dstar_pi0_Xps_pdf = ROOT.TH1D('hBkgStag_Dstar_pi0_Xps','hBkgStag_Dstar_pi0_Xps' , bins, Xps_min, Xps_max)
hBkgStag_Dstar_pi0_Xps_pdf = f15.Get("Xps")

# %%
c2 = ROOT.TCanvas("b","b",1200,600)

c2.Divide(3)
c2.cd(1)
hS_D_m00_Xps_pdf.Draw()
hS_D_m50_Xps_pdf.Draw("SAME")
hBkgStag_D_Xps_pdf.Draw("SAME")
#hpi_nunu_Mmin2_pdf.Draw("SAME")
c2.cd(2)
hS_Dstar_gamma_m00_Xps_pdf.Draw()
hS_Dstar_gamma_m50_Xps_pdf.Draw("SAME")
hBkgStag_Dstar_gamma_Xps_pdf.Draw("SAME")

c2.cd(3)
hS_Dstar_pi0_m00_Xps_pdf.Draw()
hS_Dstar_pi0_m50_Xps_pdf.Draw("SAME")
hBkgStag_Dstar_pi0_Xps_pdf.Draw("SAME")
c2.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: b

# %%
f16 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_D_m00_Mmin2_pdf.root')
f17 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_D_m50_Mmin2_pdf.root')
f18 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m00_Mmin2_pdf.root')
f19 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m50_Mmin2_pdf.root')
f20 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m00_Mmin2_pdf.root')
f21 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m50_Mmin2_pdf.root')

f22 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgStag_D_Mmin2_pdf.root')
f23 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_gamma_Mmin2_pdf.root')
f24 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_pi0_Mmin2_pdf.root')

f25 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_D_m00_Mmax2_pdf.root')
f26 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_D_m50_Mmax2_pdf.root')
f27 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m00_Mmax2_pdf.root')
f28 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m50_Mmax2_pdf.root')
f29 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m00_Mmax2_pdf.root')
f30 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m50_Mmax2_pdf.root')

f31 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgStag_D_Mmax2_pdf.root')
f32 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_gamma_Mmax2_pdf.root')
f33 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_pi0_Mmax2_pdf.root')


hS_D_m00_Mmin2_pdf = ROOT.TH1D('hS_D_m00_Mmin2','hS_D_m00_Mmin2' , bins, Mmin_min, Mmin_max)
hS_D_m00_Mmin2_pdf = f16.Get("Mmin2")
hS_D_m50_Mmin2_pdf = ROOT.TH1D('hS_D_m50_Mmin2','hS_D_m50_Mmin2' , bins, Mmin_min, Mmin_max)
hS_D_m50_Mmin2_pdf = f17.Get("Mmin2")
hS_Dstar_gamma_m00_Mmin2_pdf = ROOT.TH1D('hS_Dstar_gamma_m00_Mmin2','hS_Dstar_gamma_m00_Mmin2' , bins, Mmin_min, Mmin_max)
hS_Dstar_gamma_m00_Mmin2_pdf = f18.Get("Mmin2")
hS_Dstar_gamma_m50_Mmin2_pdf = ROOT.TH1D('hS_Dstar_gamma_m50_Mmin2','hS_Dstar_gamma_m50_Mmin2' , bins, Mmin_min, Mmin_max)
hS_Dstar_gamma_m50_Mmin2_pdf = f19.Get("Mmin2")
hS_Dstar_pi0_m00_Mmin2_pdf = ROOT.TH1D('hS_Dstar_pi0_m00_Mmin2','hS_Dstar_pi0_m00_Mmin2' , bins, Mmin_min, Mmin_max)
hS_Dstar_pi0_m00_Mmin2_pdf = f20.Get("Mmin2")
hS_Dstar_pi0_m50_Mmin2_pdf = ROOT.TH1D('hS_Dstar_pi0_m50_Mmin2','hS_Dstar_pi0_m50_Mmin2' , bins, Mmin_min, Mmin_max)
hS_Dstar_pi0_m50_Mmin2_pdf = f21.Get("Mmin2")


hBkgStag_D_Mmin2_pdf = ROOT.TH1D('hBkgStag_D_Mmin2','hBkgStag_D_Mmin2' , bins, Mmin_min, Mmin_max)
hBkgStag_D_Mmin2_pdf = f22.Get("Mmin2")
hBkgStag_Dstar_gamma_Mmin2_pdf = ROOT.TH1D('hBkgStag_Dstar_gamma_Mmin2','hBkgStag_Dstar_gamma_Mmin2' , bins, Mmin_min, Mmin_max)
hBkgStag_Dstar_gamma_Mmin2_pdf = f23.Get("Mmin2")
hBkgStag_Dstar_pi0_Mmin2_pdf = ROOT.TH1D('hBkgStag_Dstar_pi0_Mmin2','hBkgStag_Dstar_pi0_Mmin2' , bins, Mmin_min, Mmin_max)
hBkgStag_Dstar_pi0_Mmin2_pdf = f24.Get("Mmin2")

# %%
hS_D_m00_Mmax2_pdf = ROOT.TH1D('hS_D_m00_Mmax2','hS_D_m00_Mmax2' , bins, Mmax_min, Mmax_max)
hS_D_m00_Mmax2_pdf = f25.Get("Mmax2")
hS_D_m50_Mmax2_pdf = ROOT.TH1D('hS_D_m50_Mmax2','hS_D_m50_Mmax2' , bins, Mmax_min, Mmax_max)
hS_D_m50_Mmax2_pdf = f26.Get("Mmax2")
hS_Dstar_gamma_m00_Mmax2_pdf = ROOT.TH1D('hS_Dstar_gamma_m00_Mmax2','hS_Dstar_gamma_m00_Mmax2' , bins, Mmax_min, Mmax_max)
hS_Dstar_gamma_m00_Mmax2_pdf = f27.Get("Mmax2")
hS_Dstar_gamma_m50_Mmax2_pdf = ROOT.TH1D('hS_Dstar_gamma_m50_Mmax2','hS_Dstar_gamma_m50_Mmax2' , bins, Mmax_min, Mmax_max)
hS_Dstar_gamma_m50_Mmax2_pdf = f28.Get("Mmax2")
hS_Dstar_pi0_m00_Mmax2_pdf = ROOT.TH1D('hS_Dstar_pi0_m00_Mmax2','hS_Dstar_pi0_m00_Mmax2' , bins, Mmax_min, Mmax_max)
hS_Dstar_pi0_m00_Mmax2_pdf = f29.Get("Mmax2")
hS_Dstar_pi0_m50_Mmax2_pdf = ROOT.TH1D('hS_Dstar_pi0_m50_Mmax2','hS_Dstar_pi0_m50_Mmax2' , bins, Mmax_min, Mmax_max)
hS_Dstar_pi0_m50_Mmax2_pdf = f30.Get("Mmax2")


hBkgStag_D_Mmax2_pdf = ROOT.TH1D('hBkgStag_D_Mmax2','hBkgStag_D_Mmax2' , bins, Mmax_min, Mmax_max)
hBkgStag_D_Mmax2_pdf = f31.Get("Mmax2")
hBkgStag_Dstar_gamma_Mmax2_pdf = ROOT.TH1D('hBkgStag_Dstar_gamma_Mmax2','hBkgStag_Dstar_gamma_Mmax2' , bins, Mmax_min, Mmax_max)
hBkgStag_Dstar_gamma_Mmax2_pdf = f32.Get("Mmax2")
hBkgStag_Dstar_pi0_Mmax2_pdf = ROOT.TH1D('hBkgStag_Dstar_pi0_Mmax2','hBkgStag_Dstar_pi0_Mmax2' , bins, Mmax_min, Mmax_max)
hBkgStag_Dstar_pi0_Mmax2_pdf = f33.Get("Mmax2")

# %%
c3 = ROOT.TCanvas("c","c",1200,600)

c3.Divide(3)
c3.cd(1)
hS_D_m00_Mmin2_pdf.Draw()
hS_D_m50_Mmin2_pdf.Draw("SAME")
hBkgStag_D_Mmin2_pdf.Draw("SAME")
#hpi_nunu_Mmin2_pdf.Draw("SAME")
c3.cd(2)
hS_Dstar_gamma_m00_Mmin2_pdf.Draw()
hS_Dstar_gamma_m50_Mmin2_pdf.Draw("SAME")
hBkgStag_Dstar_gamma_Mmin2_pdf.Draw("SAME")

c3.cd(3)
hS_Dstar_pi0_m00_Mmin2_pdf.Draw()
hS_Dstar_pi0_m50_Mmin2_pdf.Draw("SAME")
hBkgStag_Dstar_pi0_Mmin2_pdf.Draw("SAME")
c3.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c

# %%
c4 = ROOT.TCanvas("d","d",1200,600)

c4.Divide(3)
c4.cd(1)
hS_D_m00_Mmax2_pdf.Draw()
hS_D_m50_Mmax2_pdf.Draw("SAME")
hBkgStag_D_Mmax2_pdf.Draw("SAME")
#hpi_nunu_Mmax2_pdf.Draw("SAME")
c4.cd(2)
hS_Dstar_gamma_m00_Mmax2_pdf.Draw()
hS_Dstar_gamma_m50_Mmax2_pdf.Draw("SAME")
hBkgStag_Dstar_gamma_Mmax2_pdf.Draw("SAME")

c4.cd(3)
hS_Dstar_pi0_m00_Mmax2_pdf.Draw()
hS_Dstar_pi0_m50_Mmax2_pdf.Draw("SAME")
hBkgStag_Dstar_pi0_Mmax2_pdf.Draw("SAME")
c4.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: d

# %% [markdown]
# fm00_2D = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_2D_m00_pdf.root')
# fm50_2D = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_2D_m50_pdf.root')
# fpi_taunu_2D = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hpi_taunu_2D_pdf.root')
# fpi_nunu_2D = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hpi_nunu_2D_pdf.root')
#
#
#
#
# hS_m00_2D_pdf = ROOT.TH2D('hS_m00_2D_pdf','hS_m00_2D_pdf' , nbinsL, M_min2Low, M_min2Up, nbinsH, M_max2Low, M_max2Up)
# hS_m00_2D_pdf = fm00_2D.Get("hS_2D_m00")
# hS_m50_2D_pdf = ROOT.TH2D('hS_m50_2D_pdf','hS_m50_2D_pdf' , nbinsL, M_min2Low, M_min2Up, nbinsH, M_max2Low, M_max2Up)
# hS_m50_2D_pdf = fm50_2D.Get("hS_2D_m50")
# hpi_taunu_2D_pdf = ROOT.TH2D('hpi_taunu_2D_pdf','hpi_taunu_2D_pdf' , nbinsL, M_min2Low, M_min2Up, nbinsH, M_max2Low, M_max2Up)
# hpi_taunu_2D_pdf = fpi_taunu_2D.Get("hpi_taunu_2D")
# hpi_nunu_2D_pdf = ROOT.TH2D('hpi_nunu_2D_pdf','hpi_nunu_2D_pdf' , nbinsL, M_min2Low, M_min2Up, nbinsH, M_max2Low, M_max2Up)
# hpi_nunu_2D_pdf = fpi_nunu_2D.Get("hpi_nunu_2D")

# %% [markdown]
# c3 = ROOT.TCanvas("c3","c3",800,400)
#
# c3.Divide(4)
# c3.cd(1)
# hS_m00_2D_pdf.Draw("CONTZ")
# c3.cd(2)
# hS_m50_2D_pdf.Draw("CONTZ")
# c3.cd(3)
# hpi_taunu_2D_pdf.Draw("CONTZ")
# c3.cd(4)
# hpi_nunu_2D_pdf.Draw("CONTZ")
# c3.Draw()

# %%
f34 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_D_m00_q2_pdf.root')
f35 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_D_m50_q2_pdf.root')
f36 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m00_q2_pdf.root')
f37 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m50_q2_pdf.root')
f38 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m00_q2_pdf.root')
f39 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m50_q2_pdf.root')


f40 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgStag_D_q2_pdf.root')
f41 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_gamma_q2_pdf.root')
f42 = ROOT.TFile('~/BToInv/PiChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_pi0_q2_pdf.root')



hS_D_m00_q2_pdf = ROOT.TH1D('hS_D_m00_q2','hS_D_m00_q2' , bins, q2_min, q2_max)
hS_D_m00_q2_pdf = f34.Get("q2")
hS_D_m50_q2_pdf = ROOT.TH1D('hS_D_m50_q2','hS_D_m50_q2' , bins, q2_min, q2_max)
hS_D_m50_q2_pdf = f35.Get("q2")
hS_Dstar_gamma_m00_q2_pdf = ROOT.TH1D('hS_Dstar_gamma_m00_q2','hS_Dstar_gamma_m00_q2' , bins, q2_min, q2_max)
hS_Dstar_gamma_m00_q2_pdf = f36.Get("q2")
hS_Dstar_gamma_m50_q2_pdf = ROOT.TH1D('hS_Dstar_gamma_m50_q2','hS_Dstar_gamma_m50_q2' , bins, q2_min, q2_max)
hS_Dstar_gamma_m50_q2_pdf = f37.Get("q2")
hS_Dstar_pi0_m00_q2_pdf = ROOT.TH1D('hS_Dstar_pi0_m00_q2','hS_Dstar_pi0_m00_q2' , bins, q2_min, q2_max)
hS_Dstar_pi0_m00_q2_pdf = f38.Get("q2")
hS_Dstar_pi0_m50_q2_pdf = ROOT.TH1D('hS_Dstar_pi0_m50_q2','hS_Dstar_pi0_m50_q2' , bins, q2_min, q2_max)
hS_Dstar_pi0_m50_q2_pdf = f39.Get("q2")

hBkgStag_D_q2_pdf = ROOT.TH1D('hBkgStag_D_q2','hBkgStag_D_q2' , bins, q2_min, q2_max)
hBkgStag_D_q2_pdf = f40.Get("q2")
hBkgStag_Dstar_gamma_q2_pdf = ROOT.TH1D('hBkgStag_Dstar_gamma_q2','hBkgStag_Dstar_gamma_q2' , bins, q2_min, q2_max)
hBkgStag_Dstar_gamma_q2_pdf = f41.Get("q2")
hBkgStag_Dstar_pi0_q2_pdf = ROOT.TH1D('hBkgStag_Dstar_pi0_q2','hBkgStag_Dstar_pi0_q2' , bins, q2_min, q2_max)
hBkgStag_Dstar_pi0_q2_pdf = f42.Get("q2")

# %%
c5 = ROOT.TCanvas("e","e",1200,600)

c5.Divide(3)
c5.cd(1)
hS_D_m00_q2_pdf.Draw()
hS_D_m50_q2_pdf.Draw("SAME")
hBkgStag_D_q2_pdf.Draw("SAME")
#hpi_nunu_Mmin2_pdf.Draw("SAME")
c5.cd(2)
hS_Dstar_gamma_m00_q2_pdf.Draw()
hS_Dstar_gamma_m50_q2_pdf.Draw("SAME")
hBkgStag_Dstar_gamma_q2_pdf.Draw("SAME")

c5.cd(3)
hS_Dstar_pi0_m00_q2_pdf.Draw()
hS_Dstar_pi0_m50_q2_pdf.Draw("SAME")
hBkgStag_Dstar_pi0_q2_pdf.Draw("SAME")
c5.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: e
