# %%
import numpy as np
import pandas as pd
import ROOT

import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.patches import Ellipse

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %matplotlib inline
# Out:
# Welcome to JupyROOT 6.26/06

# %%
df_HadronicTag_m00 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_m00_wc.csv')
df_HadronicTag_m05 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_m05_wc.csv')
df_HadronicTag_m10 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_m10_wc.csv')
df_HadronicTag_m15 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_m15_wc.csv')
df_HadronicTag_m20 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_m20_wc.csv')
df_HadronicTag_m25 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_m25_wc.csv')
df_HadronicTag_m30 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_m30_wc.csv')
df_HadronicTag_m35 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_m35_wc.csv')
df_HadronicTag_m40 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_m40_wc.csv')
df_HadronicTag_m45 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_m45_wc.csv')
df_HadronicTag_m50 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_m50_wc.csv')

df_HadronicTag_Dstar_gamma_m00 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m00_wc.csv')
df_HadronicTag_Dstar_gamma_m05 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m05_wc.csv')
df_HadronicTag_Dstar_gamma_m10 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m10_wc.csv')
df_HadronicTag_Dstar_gamma_m15 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m15_wc.csv')
df_HadronicTag_Dstar_gamma_m20 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m20_wc.csv')
df_HadronicTag_Dstar_gamma_m25 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m25_wc.csv')
df_HadronicTag_Dstar_gamma_m30 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m30_wc.csv')
df_HadronicTag_Dstar_gamma_m35 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m35_wc.csv')
df_HadronicTag_Dstar_gamma_m40 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m40_wc.csv')
df_HadronicTag_Dstar_gamma_m45 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m45_wc.csv')
df_HadronicTag_Dstar_gamma_m50 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m50_wc.csv')

df_HadronicTag_Dstar_pi0_m00 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m00_wc.csv')
df_HadronicTag_Dstar_pi0_m05 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m05_wc.csv')
df_HadronicTag_Dstar_pi0_m10 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m10_wc.csv')
df_HadronicTag_Dstar_pi0_m15 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m15_wc.csv')
df_HadronicTag_Dstar_pi0_m20 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m20_wc.csv')
df_HadronicTag_Dstar_pi0_m25 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m25_wc.csv')
df_HadronicTag_Dstar_pi0_m30 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m30_wc.csv')
df_HadronicTag_Dstar_pi0_m35 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m35_wc.csv')
df_HadronicTag_Dstar_pi0_m40 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m40_wc.csv')
df_HadronicTag_Dstar_pi0_m45 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m45_wc.csv')
df_HadronicTag_Dstar_pi0_m50 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m50_wc.csv')

df_SemilepTag_m00 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_m00_wc.csv')
df_SemilepTag_m05 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_m05_wc.csv')
df_SemilepTag_m10 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_m10_wc.csv')
df_SemilepTag_m15 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_m15_wc.csv')
df_SemilepTag_m20 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_m20_wc.csv')
df_SemilepTag_m25 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_m25_wc.csv')
df_SemilepTag_m30 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_m30_wc.csv')
df_SemilepTag_m35 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_m35_wc.csv')
df_SemilepTag_m40 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_m40_wc.csv')
df_SemilepTag_m45 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_m45_wc.csv')
df_SemilepTag_m50 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_m50_wc.csv')

df_SemilepTag_Dstar_gamma_m00 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m00_wc.csv')
df_SemilepTag_Dstar_gamma_m05 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m05_wc.csv')
df_SemilepTag_Dstar_gamma_m10 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m10_wc.csv')
df_SemilepTag_Dstar_gamma_m15 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m15_wc.csv')
df_SemilepTag_Dstar_gamma_m20 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m20_wc.csv')
df_SemilepTag_Dstar_gamma_m25 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m25_wc.csv')
df_SemilepTag_Dstar_gamma_m30 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m30_wc.csv')
df_SemilepTag_Dstar_gamma_m35 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m35_wc.csv')
df_SemilepTag_Dstar_gamma_m40 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m40_wc.csv')
df_SemilepTag_Dstar_gamma_m45 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m45_wc.csv')
df_SemilepTag_Dstar_gamma_m50 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m50_wc.csv')

df_SemilepTag_Dstar_pi0_m00 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_pi0_m00_wc.csv')
df_SemilepTag_Dstar_pi0_m05 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_pi0_m05_wc.csv')
df_SemilepTag_Dstar_pi0_m10 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_pi0_m10_wc.csv')
df_SemilepTag_Dstar_pi0_m15 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_pi0_m15_wc.csv')
df_SemilepTag_Dstar_pi0_m20 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_pi0_m20_wc.csv')
df_SemilepTag_Dstar_pi0_m25 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_pi0_m25_wc.csv')
df_SemilepTag_Dstar_pi0_m30 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_pi0_m30_wc.csv')
df_SemilepTag_Dstar_pi0_m35 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_pi0_m35_wc.csv')
df_SemilepTag_Dstar_pi0_m40 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_pi0_m40_wc.csv')
df_SemilepTag_Dstar_pi0_m45 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_pi0_m45_wc.csv')
df_SemilepTag_Dstar_pi0_m50 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_pi0_m50_wc.csv')

df_BkgHtag_D = pd.read_csv('../Analysis/Files/CSV_Files/BkgHtag_D_wc.csv')
df_BkgHtag_Dstar_gamma = pd.read_csv('../Analysis/Files/CSV_Files/BkgHtag_Dstar_gamma_wc.csv')
df_BkgHtag_Dstar_pi0 = pd.read_csv('../Analysis/Files/CSV_Files/BkgHtag_Dstar_pi0_wc.csv')

df_BkgStag_D = pd.read_csv('../Analysis/Files/CSV_Files/BkgStag_D_wc.csv')
df_BkgStag_Dstar_gamma = pd.read_csv('../Analysis/Files/CSV_Files/BkgStag_Dstar_gamma_wc.csv')
df_BkgStag_Dstar_pi0 = pd.read_csv('../Analysis/Files/CSV_Files/BkgStag_Dstar_pi0_wc.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [2], line 2
#       1 df_HadronicTag_m00 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_m00_wc.csv')
# ----> 2 df_HadronicTag_m05 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_m05_wc.csv')
#       3 df_HadronicTag_m10 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_m10_wc.csv')
#       4 df_HadronicTag_m15 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_m15_wc.csv')
#
# File ~/anaconda3/envs/RootPyEnv/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# ...

# %%
cols_Had = ['Xps', 'q2']

df_HadronicTag_m00 = df_HadronicTag_m00.filter(cols_Had, axis=1)
df_HadronicTag_m05 = df_HadronicTag_m05.filter(cols_Had, axis=1)
df_HadronicTag_m10 = df_HadronicTag_m10.filter(cols_Had, axis=1)
df_HadronicTag_m15 = df_HadronicTag_m15.filter(cols_Had, axis=1)
df_HadronicTag_m20 = df_HadronicTag_m20.filter(cols_Had, axis=1)
df_HadronicTag_m25 = df_HadronicTag_m25.filter(cols_Had, axis=1)
df_HadronicTag_m30 = df_HadronicTag_m30.filter(cols_Had, axis=1)
df_HadronicTag_m35 = df_HadronicTag_m35.filter(cols_Had, axis=1)
df_HadronicTag_m40 = df_HadronicTag_m40.filter(cols_Had, axis=1)
df_HadronicTag_m45 = df_HadronicTag_m45.filter(cols_Had, axis=1)
df_HadronicTag_m50 = df_HadronicTag_m50.filter(cols_Had, axis=1)

df_HadronicTag_Dstar_gamma_m00 = df_HadronicTag_Dstar_gamma_m00.filter(cols_Had, axis=1)
df_HadronicTag_Dstar_gamma_m05 = df_HadronicTag_Dstar_gamma_m05.filter(cols_Had, axis=1)
df_HadronicTag_Dstar_gamma_m10 = df_HadronicTag_Dstar_gamma_m10.filter(cols_Had, axis=1)
df_HadronicTag_Dstar_gamma_m15 = df_HadronicTag_Dstar_gamma_m15.filter(cols_Had, axis=1)
df_HadronicTag_Dstar_gamma_m20 = df_HadronicTag_Dstar_gamma_m20.filter(cols_Had, axis=1)
df_HadronicTag_Dstar_gamma_m25 = df_HadronicTag_Dstar_gamma_m25.filter(cols_Had, axis=1)
df_HadronicTag_Dstar_gamma_m30 = df_HadronicTag_Dstar_gamma_m30.filter(cols_Had, axis=1)
df_HadronicTag_Dstar_gamma_m35 = df_HadronicTag_Dstar_gamma_m35.filter(cols_Had, axis=1)
df_HadronicTag_Dstar_gamma_m40 = df_HadronicTag_Dstar_gamma_m40.filter(cols_Had, axis=1)
df_HadronicTag_Dstar_gamma_m45 = df_HadronicTag_Dstar_gamma_m45.filter(cols_Had, axis=1)
df_HadronicTag_Dstar_gamma_m50 = df_HadronicTag_Dstar_gamma_m50.filter(cols_Had, axis=1)


df_HadronicTag_Dstar_pi0_m00 = df_HadronicTag_Dstar_pi0_m00.filter(cols_Had, axis=1)
df_HadronicTag_Dstar_pi0_m05 = df_HadronicTag_Dstar_pi0_m05.filter(cols_Had, axis=1)
df_HadronicTag_Dstar_pi0_m10 = df_HadronicTag_Dstar_pi0_m10.filter(cols_Had, axis=1)
df_HadronicTag_Dstar_pi0_m15 = df_HadronicTag_Dstar_pi0_m15.filter(cols_Had, axis=1)
df_HadronicTag_Dstar_pi0_m20 = df_HadronicTag_Dstar_pi0_m20.filter(cols_Had, axis=1)
df_HadronicTag_Dstar_pi0_m25 = df_HadronicTag_Dstar_pi0_m25.filter(cols_Had, axis=1)
df_HadronicTag_Dstar_pi0_m30 = df_HadronicTag_Dstar_pi0_m30.filter(cols_Had, axis=1)
df_HadronicTag_Dstar_pi0_m35 = df_HadronicTag_Dstar_pi0_m35.filter(cols_Had, axis=1)
df_HadronicTag_Dstar_pi0_m40 = df_HadronicTag_Dstar_pi0_m40.filter(cols_Had, axis=1)
df_HadronicTag_Dstar_pi0_m45 = df_HadronicTag_Dstar_pi0_m45.filter(cols_Had, axis=1)
df_HadronicTag_Dstar_pi0_m50 = df_HadronicTag_Dstar_pi0_m50.filter(cols_Had, axis=1)

df_BkgHtag_D_eval = df_BkgHtag_D.filter(cols_Had, axis=1)
df_BkgHtag_Dstar_gamma_eval = df_BkgHtag_Dstar_gamma.filter(cols_Had, axis=1)
df_BkgHtag_Dstar_pi0_eval = df_BkgHtag_Dstar_pi0.filter(cols_Had, axis=1)

# %%
cols = ['Mmin2', 'Mmax2', 'Xps', 'q2']

df_SemilepTag_m00 = df_SemilepTag_m00.filter(cols, axis=1)
df_SemilepTag_m05 = df_SemilepTag_m05.filter(cols, axis=1)
df_SemilepTag_m10 = df_SemilepTag_m10.filter(cols, axis=1)
df_SemilepTag_m15 = df_SemilepTag_m15.filter(cols, axis=1)
df_SemilepTag_m20 = df_SemilepTag_m20.filter(cols, axis=1)
df_SemilepTag_m25 = df_SemilepTag_m25.filter(cols, axis=1)
df_SemilepTag_m30 = df_SemilepTag_m30.filter(cols, axis=1)
df_SemilepTag_m35 = df_SemilepTag_m35.filter(cols, axis=1)
df_SemilepTag_m40 = df_SemilepTag_m40.filter(cols, axis=1)
df_SemilepTag_m45 = df_SemilepTag_m45.filter(cols, axis=1)
df_SemilepTag_m50 = df_SemilepTag_m50.filter(cols, axis=1)

df_SemilepTag_Dstar_gamma_m00 = df_SemilepTag_Dstar_gamma_m00.filter(cols, axis=1)
df_SemilepTag_Dstar_gamma_m05 = df_SemilepTag_Dstar_gamma_m05.filter(cols, axis=1)
df_SemilepTag_Dstar_gamma_m10 = df_SemilepTag_Dstar_gamma_m10.filter(cols, axis=1)
df_SemilepTag_Dstar_gamma_m15 = df_SemilepTag_Dstar_gamma_m15.filter(cols, axis=1)
df_SemilepTag_Dstar_gamma_m20 = df_SemilepTag_Dstar_gamma_m20.filter(cols, axis=1)
df_SemilepTag_Dstar_gamma_m25 = df_SemilepTag_Dstar_gamma_m25.filter(cols, axis=1)
df_SemilepTag_Dstar_gamma_m30 = df_SemilepTag_Dstar_gamma_m30.filter(cols, axis=1)
df_SemilepTag_Dstar_gamma_m35 = df_SemilepTag_Dstar_gamma_m35.filter(cols, axis=1)
df_SemilepTag_Dstar_gamma_m40 = df_SemilepTag_Dstar_gamma_m40.filter(cols, axis=1)
df_SemilepTag_Dstar_gamma_m50 = df_SemilepTag_Dstar_gamma_m50.filter(cols, axis=1)

df_SemilepTag_Dstar_pi0_m00 = df_SemilepTag_Dstar_pi0_m00.filter(cols, axis=1)
df_SemilepTag_Dstar_pi0_m05 = df_SemilepTag_Dstar_pi0_m05.filter(cols, axis=1)
df_SemilepTag_Dstar_pi0_m10 = df_SemilepTag_Dstar_pi0_m10.filter(cols, axis=1)
df_SemilepTag_Dstar_pi0_m15 = df_SemilepTag_Dstar_pi0_m15.filter(cols, axis=1)
df_SemilepTag_Dstar_pi0_m20 = df_SemilepTag_Dstar_pi0_m20.filter(cols, axis=1)
df_SemilepTag_Dstar_pi0_m25 = df_SemilepTag_Dstar_pi0_m25.filter(cols, axis=1)
df_SemilepTag_Dstar_pi0_m30 = df_SemilepTag_Dstar_pi0_m30.filter(cols, axis=1)
df_SemilepTag_Dstar_pi0_m35 = df_SemilepTag_Dstar_pi0_m35.filter(cols, axis=1)
df_SemilepTag_Dstar_pi0_m40 = df_SemilepTag_Dstar_pi0_m40.filter(cols, axis=1)
df_SemilepTag_Dstar_pi0_m50 = df_SemilepTag_Dstar_pi0_m50.filter(cols, axis=1)

df_BkgStag_D = df_BkgStag_D.filter(cols, axis=1)
df_BkgStag_Dstar_gamma = df_BkgStag_Dstar_gamma.filter(cols, axis=1)
df_BkgStag_Dstar_pi0 = df_BkgStag_Dstar_pi0.filter(cols, axis=1)

# %%
# Crear funcion para columna etiqueta que  me ayude a separar entre tags
def LabelTag(df, flag):
    if flag == 1:
        df['tag'] = 1
    elif flag == 2:
        df['tag'] = 2
    else:
        df['tag'] = 3
    
    return df

# %%
# Adding a new column called 'tag', if flag = 1, 2, 3 tag = D, Dstar_gamma, Dstar_pi0
df_SemilepTag_m00 = LabelTag(df_SemilepTag_m00, flag=1)
df_SemilepTag_m05 = LabelTag(df_SemilepTag_m05, flag=1)
df_SemilepTag_m10 = LabelTag(df_SemilepTag_m10, flag=1)
df_SemilepTag_m15 = LabelTag(df_SemilepTag_m15, flag=1)
df_SemilepTag_m20 = LabelTag(df_SemilepTag_m20, flag=1)
df_SemilepTag_m25 = LabelTag(df_SemilepTag_m25, flag=1)
df_SemilepTag_m30 = LabelTag(df_SemilepTag_m30, flag=1)
df_SemilepTag_m35 = LabelTag(df_SemilepTag_m35, flag=1)
df_SemilepTag_m40 = LabelTag(df_SemilepTag_m40, flag=1)
df_SemilepTag_m50 = LabelTag(df_SemilepTag_m50, flag=1)

df_SemilepTag_Dstar_gamma_m00 = LabelTag(df_SemilepTag_Dstar_gamma_m00, flag=2)
df_SemilepTag_Dstar_gamma_m05 = LabelTag(df_SemilepTag_Dstar_gamma_m05, flag=2)
df_SemilepTag_Dstar_gamma_m10 = LabelTag(df_SemilepTag_Dstar_gamma_m10, flag=2)
df_SemilepTag_Dstar_gamma_m15 = LabelTag(df_SemilepTag_Dstar_gamma_m15, flag=2)
df_SemilepTag_Dstar_gamma_m20 = LabelTag(df_SemilepTag_Dstar_gamma_m20, flag=2)
df_SemilepTag_Dstar_gamma_m25 = LabelTag(df_SemilepTag_Dstar_gamma_m25, flag=2)
df_SemilepTag_Dstar_gamma_m30 = LabelTag(df_SemilepTag_Dstar_gamma_m30, flag=2)
df_SemilepTag_Dstar_gamma_m35 = LabelTag(df_SemilepTag_Dstar_gamma_m35, flag=2)
df_SemilepTag_Dstar_gamma_m40 = LabelTag(df_SemilepTag_Dstar_gamma_m40, flag=2)
df_SemilepTag_Dstar_gamma_m50 = LabelTag(df_SemilepTag_Dstar_gamma_m50, flag=2)

df_SemilepTag_Dstar_pi0_m00 = LabelTag(df_SemilepTag_Dstar_pi0_m00, flag=3)
df_SemilepTag_Dstar_pi0_m05 = LabelTag(df_SemilepTag_Dstar_pi0_m05, flag=3)
df_SemilepTag_Dstar_pi0_m10 = LabelTag(df_SemilepTag_Dstar_pi0_m10, flag=3)
df_SemilepTag_Dstar_pi0_m15 = LabelTag(df_SemilepTag_Dstar_pi0_m15, flag=3)
df_SemilepTag_Dstar_pi0_m20 = LabelTag(df_SemilepTag_Dstar_pi0_m20, flag=3)
df_SemilepTag_Dstar_pi0_m25 = LabelTag(df_SemilepTag_Dstar_pi0_m25, flag=3)
df_SemilepTag_Dstar_pi0_m30 = LabelTag(df_SemilepTag_Dstar_pi0_m30, flag=3)
df_SemilepTag_Dstar_pi0_m35 = LabelTag(df_SemilepTag_Dstar_pi0_m35, flag=3)
df_SemilepTag_Dstar_pi0_m40 = LabelTag(df_SemilepTag_Dstar_pi0_m40, flag=3)
df_SemilepTag_Dstar_pi0_m50 = LabelTag(df_SemilepTag_Dstar_pi0_m50, flag=3)

df_BkgStag_D = LabelTag(df_BkgStag_D, flag=1)
df_BkgStag_Dstar_gamma = LabelTag(df_BkgStag_Dstar_gamma, flag=2)
df_BkgStag_Dstar_pi0 = LabelTag(df_BkgStag_Dstar_pi0, flag=3)

# %%
df_BkgStag_Dstar_gamma
# Out:
#           Mmin2      Mmax2       Xps         q2  tag
# 0      9.138658   9.573060  0.664577   8.469360    2
# 1     10.736307  12.568528  0.596740  11.714176    2
# 2     14.257745  15.174846  0.476618  14.474396    2
# 3     10.807639  11.502253  0.606658  11.029805    2
# 4      5.461748   7.047490  0.776687   6.147828    2
# ...         ...        ...       ...        ...  ...
# 8607  12.546351  14.177915  0.538293  13.617475    2
# 8608   8.071857   9.218015  0.686457   8.257398    2
# 8609   0.699717   2.400156  0.952589   1.387644    2
# 8610  11.402657  12.589308  0.577420  12.032599    2
# 8611  10.293087  11.245801  0.641246  11.318602    2
#
# [8612 rows x 5 columns]

# %%
# Adding a new column called 'tag', if flag = 1, 2, 3 tag = D, Dstar_gamma, Dstar_pi0
df_HadronicTag_m00 = LabelTag(df_HadronicTag_m00, flag=1)
df_HadronicTag_m05 = LabelTag(df_HadronicTag_m05, flag=1)
df_HadronicTag_m10 = LabelTag(df_HadronicTag_m10, flag=1)
df_HadronicTag_m15 = LabelTag(df_HadronicTag_m15, flag=1)
df_HadronicTag_m20 = LabelTag(df_HadronicTag_m20, flag=1)
df_HadronicTag_m25 = LabelTag(df_HadronicTag_m25, flag=1)
df_HadronicTag_m30 = LabelTag(df_HadronicTag_m30, flag=1)
df_HadronicTag_m35 = LabelTag(df_HadronicTag_m35, flag=1)
df_HadronicTag_m40 = LabelTag(df_HadronicTag_m40, flag=1)
df_HadronicTag_m50 = LabelTag(df_HadronicTag_m50, flag=1)

df_HadronicTag_Dstar_gamma_m00 = LabelTag(df_HadronicTag_Dstar_gamma_m00, flag=2)
df_HadronicTag_Dstar_gamma_m05 = LabelTag(df_HadronicTag_Dstar_gamma_m05, flag=2)
df_HadronicTag_Dstar_gamma_m10 = LabelTag(df_HadronicTag_Dstar_gamma_m10, flag=2)
df_HadronicTag_Dstar_gamma_m15 = LabelTag(df_HadronicTag_Dstar_gamma_m15, flag=2)
df_HadronicTag_Dstar_gamma_m20 = LabelTag(df_HadronicTag_Dstar_gamma_m20, flag=2)
df_HadronicTag_Dstar_gamma_m25 = LabelTag(df_HadronicTag_Dstar_gamma_m25, flag=2)
df_HadronicTag_Dstar_gamma_m30 = LabelTag(df_HadronicTag_Dstar_gamma_m30, flag=2)
df_HadronicTag_Dstar_gamma_m35 = LabelTag(df_HadronicTag_Dstar_gamma_m35, flag=2)
df_HadronicTag_Dstar_gamma_m40 = LabelTag(df_HadronicTag_Dstar_gamma_m40, flag=2)
df_HadronicTag_Dstar_gamma_m50 = LabelTag(df_HadronicTag_Dstar_gamma_m50, flag=2)

df_HadronicTag_Dstar_pi0_m00 = LabelTag(df_HadronicTag_Dstar_pi0_m00, flag=3)
df_HadronicTag_Dstar_pi0_m05 = LabelTag(df_HadronicTag_Dstar_pi0_m05, flag=3)
df_HadronicTag_Dstar_pi0_m10 = LabelTag(df_HadronicTag_Dstar_pi0_m10, flag=3)
df_HadronicTag_Dstar_pi0_m15 = LabelTag(df_HadronicTag_Dstar_pi0_m15, flag=3)
df_HadronicTag_Dstar_pi0_m20 = LabelTag(df_HadronicTag_Dstar_pi0_m20, flag=3)
df_HadronicTag_Dstar_pi0_m25 = LabelTag(df_HadronicTag_Dstar_pi0_m25, flag=3)
df_HadronicTag_Dstar_pi0_m30 = LabelTag(df_HadronicTag_Dstar_pi0_m30, flag=3)
df_HadronicTag_Dstar_pi0_m35 = LabelTag(df_HadronicTag_Dstar_pi0_m35, flag=3)
df_HadronicTag_Dstar_pi0_m40 = LabelTag(df_HadronicTag_Dstar_pi0_m40, flag=3)
df_HadronicTag_Dstar_pi0_m50 = LabelTag(df_HadronicTag_Dstar_pi0_m50, flag=3)

df_BkgHtag_D = LabelTag(df_BkgHtag_D, flag=1)
df_BkgHtag_Dstar_gamma = LabelTag(df_BkgHtag_Dstar_gamma, flag=2)
df_BkgHtag_Dstar_pi0 = LabelTag(df_BkgHtag_Dstar_pi0, flag=3)

# %%
HadronicTag_m00_df = pd.concat([df_HadronicTag_m00, df_HadronicTag_Dstar_gamma_m00, df_HadronicTag_Dstar_pi0_m00])
HadronicTag_m10_df = pd.concat([df_HadronicTag_m10, df_HadronicTag_Dstar_gamma_m10, df_HadronicTag_Dstar_pi0_m10])
HadronicTag_m20_df = pd.concat([df_HadronicTag_m20, df_HadronicTag_Dstar_gamma_m20, df_HadronicTag_Dstar_pi0_m20])
HadronicTag_m30_df = pd.concat([df_HadronicTag_m30, df_HadronicTag_Dstar_gamma_m30, df_HadronicTag_Dstar_pi0_m30])
HadronicTag_m40_df = pd.concat([df_HadronicTag_m40, df_HadronicTag_Dstar_gamma_m40, df_HadronicTag_Dstar_pi0_m40])
HadronicTag_m50_df = pd.concat([df_HadronicTag_m50, df_HadronicTag_Dstar_gamma_m50, df_HadronicTag_Dstar_pi0_m50])


SemilepTag_m00_df = pd.concat([df_SemilepTag_m00, df_SemilepTag_Dstar_gamma_m00, df_SemilepTag_Dstar_pi0_m00])
SemilepTag_m05_df = pd.concat([df_SemilepTag_m05, df_SemilepTag_Dstar_gamma_m05, df_SemilepTag_Dstar_pi0_m05])
SemilepTag_m10_df = pd.concat([df_SemilepTag_m10, df_SemilepTag_Dstar_gamma_m10, df_SemilepTag_Dstar_pi0_m10])
SemilepTag_m15_df = pd.concat([df_SemilepTag_m15, df_SemilepTag_Dstar_gamma_m15, df_SemilepTag_Dstar_pi0_m15])
SemilepTag_m20_df = pd.concat([df_SemilepTag_m20, df_SemilepTag_Dstar_gamma_m20, df_SemilepTag_Dstar_pi0_m20])
SemilepTag_m25_df = pd.concat([df_SemilepTag_m25, df_SemilepTag_Dstar_gamma_m25, df_SemilepTag_Dstar_pi0_m25])
SemilepTag_m30_df = pd.concat([df_SemilepTag_m30, df_SemilepTag_Dstar_gamma_m30, df_SemilepTag_Dstar_pi0_m30])
SemilepTag_m35_df = pd.concat([df_SemilepTag_m35, df_SemilepTag_Dstar_gamma_m35, df_SemilepTag_Dstar_pi0_m35])
SemilepTag_m40_df = pd.concat([df_SemilepTag_m40, df_SemilepTag_Dstar_gamma_m40, df_SemilepTag_Dstar_pi0_m40])
SemilepTag_m50_df = pd.concat([df_SemilepTag_m50, df_SemilepTag_Dstar_gamma_m50, df_SemilepTag_Dstar_pi0_m50])

# %%
bkgHad_df = pd.concat([df_BkgHtag_D, df_BkgHtag_Dstar_gamma, df_BkgHtag_Dstar_pi0])
bkgSemi_df = pd.concat([df_BkgStag_D, df_BkgStag_Dstar_gamma, df_BkgStag_Dstar_pi0])

# %%
print(len(bkgSemi_df[bkgSemi_df["Mmin2"]==1000]))
print(len(SemilepTag_m00_df[SemilepTag_m00_df["Mmin2"]==1000]))
print(len(SemilepTag_m05_df[SemilepTag_m05_df["Mmin2"]==1000]))
# Out:
# 4569
# 13520
# 13314

# %%
df_BkgStag_Dstar_pi0
# Out:
#              Mmin2        Mmax2       Xps         q2  tag
# 0         3.040328     5.330319  0.877066   4.856105    3
# 1        16.253122    17.309050  0.412913  16.770939    3
# 2      1000.000000  1000.000000  0.637524  11.009306    3
# 3         8.791319    10.392286  0.645566   9.667444    3
# 4      1000.000000  1000.000000  0.406130  17.094971    3
# ...            ...          ...       ...        ...  ...
# 28718    10.099796    12.007322  0.616945  11.378295    3
# 28719    15.492954    16.686600  0.435098  16.399856    3
# 28720     8.076936    10.305842  0.686725   9.496163    3
# 28721    11.783686    12.191155  0.528006  12.614386    3
# 28722     9.987146    11.259516  0.594542  11.133436    3
#
# [28723 rows x 5 columns]

# %%
df_BkgStag_Dstar_gamma
# Out:
#           Mmin2      Mmax2       Xps         q2  tag
# 0      9.138658   9.573060  0.664577   8.469360    2
# 1     10.736307  12.568528  0.596740  11.714176    2
# 2     14.257745  15.174846  0.476618  14.474396    2
# 3     10.807639  11.502253  0.606658  11.029805    2
# 4      5.461748   7.047490  0.776687   6.147828    2
# ...         ...        ...       ...        ...  ...
# 8607  12.546351  14.177915  0.538293  13.617475    2
# 8608   8.071857   9.218015  0.686457   8.257398    2
# 8609   0.699717   2.400156  0.952589   1.387644    2
# 8610  11.402657  12.589308  0.577420  12.032599    2
# 8611  10.293087  11.245801  0.641246  11.318602    2
#
# [8612 rows x 5 columns]

# %%
bkgSemi_df
# Out:
#            Mmin2      Mmax2       Xps         q2  tag
# 0       7.124007   8.995769  0.715691   8.029353    1
# 1      -1.412415   1.645290  1.002482   0.143647    1
# 2       8.979328  10.771247  0.645189   9.901254    1
# 3       9.220257  10.306086  0.645865   9.307700    1
# 4      12.803103  14.050557  0.528166  13.611646    1
# ...          ...        ...       ...        ...  ...
# 28718  10.099796  12.007322  0.616945  11.378295    3
# 28719  15.492954  16.686600  0.435098  16.399856    3
# 28720   8.076936  10.305842  0.686725   9.496163    3
# 28721  11.783686  12.191155  0.528006  12.614386    3
# 28722   9.987146  11.259516  0.594542  11.133436    3
#
# [65844 rows x 5 columns]

# %% [markdown]
# def remove_outliers_iqr(df, whisker_width=1.5):
#     Q1 = df.quantile(0.25)
#     Q3 = df.quantile(0.75)
#     IQR = Q3 - Q1
#     lower_bound = Q1 - whisker_width * IQR
#     upper_bound = Q3 + whisker_width * IQR
#     return df[~((df < lower_bound) | (df > upper_bound)).any(axis=1)]

# %% [markdown]
# numerical_cols = bkgSemi_df.select_dtypes(include=np.number).columns
# bkgSemi_df = remove_outliers_iqr(bkgSemi_df[numerical_cols])

# %%
print(len(bkgSemi_df[bkgSemi_df["Mmin2"]==1000]))
print(len(SemilepTag_m00_df[SemilepTag_m00_df["Mmin2"]==1000]))
# Out:
# 4569
# 13520

# %%
bkgSemi_df
# Out:
#            Mmin2      Mmax2       Xps         q2  tag
# 0       7.124007   8.995769  0.715691   8.029353    1
# 1      -1.412415   1.645290  1.002482   0.143647    1
# 2       8.979328  10.771247  0.645189   9.901254    1
# 3       9.220257  10.306086  0.645865   9.307700    1
# 4      12.803103  14.050557  0.528166  13.611646    1
# ...          ...        ...       ...        ...  ...
# 28718  10.099796  12.007322  0.616945  11.378295    3
# 28719  15.492954  16.686600  0.435098  16.399856    3
# 28720   8.076936  10.305842  0.686725   9.496163    3
# 28721  11.783686  12.191155  0.528006  12.614386    3
# 28722   9.987146  11.259516  0.594542  11.133436    3
#
# [65844 rows x 5 columns]

# %%
bkgSemi_df = bkgSemi_df.drop(bkgSemi_df[(bkgSemi_df['Mmin2'] == 1000) | (bkgSemi_df['Mmax2'] == 1000)].index)

# %%
SemilepTag_m00_df = SemilepTag_m00_df.drop(SemilepTag_m00_df[(SemilepTag_m00_df['Mmin2'] == 1000) | (SemilepTag_m00_df['Mmax2'] == 1000)].index)
SemilepTag_m05_df = SemilepTag_m05_df.drop(SemilepTag_m05_df[(SemilepTag_m05_df['Mmin2'] == 1000) | (SemilepTag_m05_df['Mmax2'] == 1000)].index)
SemilepTag_m10_df = SemilepTag_m10_df.drop(SemilepTag_m10_df[(SemilepTag_m10_df['Mmin2'] == 1000) | (SemilepTag_m10_df['Mmax2'] == 1000)].index)
SemilepTag_m15_df = SemilepTag_m15_df.drop(SemilepTag_m15_df[(SemilepTag_m15_df['Mmin2'] == 1000) | (SemilepTag_m15_df['Mmax2'] == 1000)].index)
SemilepTag_m20_df = SemilepTag_m20_df.drop(SemilepTag_m20_df[(SemilepTag_m20_df['Mmin2'] == 1000) | (SemilepTag_m20_df['Mmax2'] == 1000)].index)
SemilepTag_m25_df = SemilepTag_m25_df.drop(SemilepTag_m25_df[(SemilepTag_m25_df['Mmin2'] == 1000) | (SemilepTag_m25_df['Mmax2'] == 1000)].index)
SemilepTag_m30_df = SemilepTag_m30_df.drop(SemilepTag_m30_df[(SemilepTag_m30_df['Mmin2'] == 1000) | (SemilepTag_m30_df['Mmax2'] == 1000)].index)
SemilepTag_m35_df = SemilepTag_m35_df.drop(SemilepTag_m35_df[(SemilepTag_m35_df['Mmin2'] == 1000) | (SemilepTag_m35_df['Mmax2'] == 1000)].index)
SemilepTag_m40_df = SemilepTag_m40_df.drop(SemilepTag_m40_df[(SemilepTag_m40_df['Mmin2'] == 1000) | (SemilepTag_m40_df['Mmax2'] == 1000)].index)
SemilepTag_m50_df = SemilepTag_m50_df.drop(SemilepTag_m50_df[(SemilepTag_m50_df['Mmin2'] == 1000) | (SemilepTag_m50_df['Mmax2'] == 1000)].index)

# %%
print(len(bkgSemi_df[bkgSemi_df["Mmin2"]==1000]))
print(len(SemilepTag_m00_df[SemilepTag_m00_df["Mmin2"]==1000]))
# Out:
# 0
# 0

# %%
print(len(bkgSemi_df[bkgSemi_df["Mmax2"]==1000]))
print(len(SemilepTag_m00_df[SemilepTag_m00_df["Mmax2"]==1000]))
# Out:
# 0
# 0

# %%
bkgSemi_df
# Out:
#            Mmin2      Mmax2       Xps         q2  tag
# 0       7.124007   8.995769  0.715691   8.029353    1
# 1      -1.412415   1.645290  1.002482   0.143647    1
# 3       9.220257  10.306086  0.645865   9.307700    1
# 5       8.907085  10.289651  0.667439   9.965352    1
# 6      11.545962  12.641209  0.578164  12.455721    1
# ...          ...        ...       ...        ...  ...
# 28718  10.099796  12.007322  0.616945  11.378295    3
# 28719  15.492954  16.686600  0.435098  16.399856    3
# 28720   8.076936  10.305842  0.686725   9.496163    3
# 28721  11.783686  12.191155  0.528006  12.614386    3
# 28722   9.987146  11.259516  0.594542  11.133436    3
#
# [55503 rows x 5 columns]

# %%
SemilepTag_m00_df
# Out:
#           Mmin2     Mmax2       Xps        q2  tag
# 0     -1.232027  1.935510  0.990473  0.895140    1
# 1     -0.987748  0.433718  0.998423 -1.334432    1
# 2      0.205110  3.147951  0.974204  2.415447    1
# 3      0.129904  2.249689  0.919528  1.920992    1
# 4     -1.484355  0.152932  1.022682 -1.566031    1
# ...         ...       ...       ...       ...  ...
# 62640  0.111516  0.246116  0.999953 -1.128342    3
# 62641 -0.467268  1.234569  0.953113  0.813525    3
# 62642 -0.236173  0.838493  1.013658  1.026054    3
# 62643 -1.555307  0.586589  1.010101 -1.204658    3
# 62645 -1.639749 -0.187049  0.949453 -0.568027    3
#
# [163775 rows x 5 columns]

# %%
bkgsemi_array_2D = bkgSemi_df[["Mmin2","Mmax2"]].to_numpy()

# %%
bkgsemi_array_2D
# Out:
# array([[ 7.12400683,  8.99576901],
#        [-1.41241487,  1.64528979],
#        [ 9.2202573 , 10.30608573],
#        ...,
#        [ 8.07693562, 10.30584178],
#        [11.783686  , 12.19115465],
#        [ 9.98714612, 11.25951643]])

# %%
SemilepTag_m00_arra_2D = SemilepTag_m00_df[['Mmin2','Mmax2']].to_numpy()
SemilepTag_m00_arra_2D
# Out:
# array([[-1.23202677,  1.93551032],
#        [-0.98774841,  0.43371839],
#        [ 0.2051101 ,  3.14795113],
#        ...,
#        [-0.23617345,  0.83849323],
#        [-1.55530671,  0.58658909],
#        [-1.63974894, -0.18704904]])

# %%
def PCA_Converter_rot(bkg_df, signals_df_list, var1, var2, scale=True):
    # Create the 2D array
    background_data = bkg_df[[var1, var2]].values

    # Combine signals data for rotation angle calculation
    combined_data = background_data
    for signals_df in signals_df_list:
        combined_data = np.vstack((combined_data, signals_df[[var1, var2]].values))

    if scale:
        # Standardize the data
        scaler = StandardScaler()
        data_scaled = scaler.fit_transform(combined_data)
    else:
        data_scaled = combined_data

    # Perform PCA to find principal axes and rotation angle
    pca = PCA(n_components=2)
    pca.fit(data_scaled)
    rotation_angle = np.degrees(np.arctan2(*pca.components_[0][::-1]))

    # Rotate the data points
    rotation_matrix = np.array([[np.cos(np.radians(rotation_angle)), -np.sin(np.radians(rotation_angle))],
                                [np.sin(np.radians(rotation_angle)), np.cos(np.radians(rotation_angle))]])
    rotated_data = np.dot(data_scaled, rotation_matrix)

    # Separate rotated data back into background
    background_rotated_data = rotated_data[:len(background_data)]

    # Create DataFrame with rotated data for background
    background_rotated_df = pd.DataFrame(background_rotated_data, columns=['var_x', 'var_y'])
    background_rotated_df['tag'] = bkg_df['tag'].values


    # Rotate each signal data
    signals_rotated_df_list = []
    for signals_df in signals_df_list:
        signals_data = signals_df[[var1, var2]].values
        signals_rotated_data = np.dot(signals_data, rotation_matrix)
        signals_rotated_df = pd.DataFrame(signals_rotated_data, columns=['var_x', 'var_y'])
        signals_rotated_df['tag'] = signals_df['tag'].values
        signals_rotated_df_list.append(signals_rotated_df)

    return background_rotated_df, signals_rotated_df_list

# %%
def custom_rotation(background_df, signals_df_list, var1, var2):
    # Extract the relevant variables for background
    background_data = background_df[[var1, var2]].values

    # Combine signals data for rotation angle calculation
    combined_data = background_data
    for signals_df in signals_df_list:
        combined_data = np.vstack((combined_data, signals_df[[var1, var2]].values))

    # Calculate the means of each variable for combined data
    mean_var1 = np.mean(combined_data[:, 0])
    mean_var2 = np.mean(combined_data[:, 1])

    # Compute the covariance matrix for combined data
    cov_matrix = np.cov(combined_data, rowvar=False)

    # Eigen decomposition of the covariance matrix
    eigenvalues, eigenvectors = np.linalg.eig(cov_matrix)

    # Sort eigenvectors by eigenvalues
    sorted_indices = np.argsort(eigenvalues)[::-1]
    sorted_eigenvectors = eigenvectors[:, sorted_indices]

    # Rotate the combined data
    rotated_data = np.dot(combined_data - [mean_var1, mean_var2], sorted_eigenvectors) + [mean_var1, mean_var2]

    # Separate rotated data back into background
    background_rotated_data = rotated_data[:len(background_data)]

    # Create DataFrame with rotated data for background
    background_rotated_df = pd.DataFrame(background_rotated_data, columns=['var_x', 'var_y'])
    background_rotated_df['tag'] = background_df['tag'].values

    # Rotate each signal data
    signals_rotated_df_list = []
    for signals_df in signals_df_list:
        signals_data = signals_df[[var1, var2]].values
        signals_rotated_data = np.dot(signals_data - [mean_var1, mean_var2], sorted_eigenvectors) + [mean_var1, mean_var2]
        signals_rotated_df = pd.DataFrame(signals_rotated_data, columns=['var_x', 'var_y'])
        signals_rotated_df['tag'] = signals_df['tag'].values
        signals_rotated_df_list.append(signals_rotated_df)

    return background_rotated_df, signals_rotated_df_list

# %%
def whitining_PCA(background_df, signals_df_list, var1, var2):
    # Extract the relevant variables for background
    background_data = background_df[[var1, var2]].values

    # Combine signals data for rotation angle calculation
    combined_data = background_data
    for signals_df in signals_df_list:
        combined_data = np.vstack((combined_data, signals_df[[var1, var2]].values))

    # Calculate the means of each variable for combined data
    mean_var1 = np.mean(combined_data[:, 0])
    mean_var2 = np.mean(combined_data[:, 1])

    # Compute the covariance matrix for combined data
    cov_matrix = np.cov(combined_data, rowvar=False)

    # Eigen decomposition of the covariance matrix
    eigenvalues, eigenvectors = np.linalg.eig(cov_matrix)

    # Sort eigenvectors by eigenvalues
    sorted_indices = np.argsort(eigenvalues)[::-1]
    sorted_eigenvectors = eigenvectors[:, sorted_indices]

    # Whitening transformation
    whitening_matrix = np.diag(1.0 / np.sqrt(eigenvalues[sorted_indices]))
    whitened_data = np.dot(combined_data - [mean_var1, mean_var2], np.dot(sorted_eigenvectors, whitening_matrix))

    # Rotate the whitened data
    rotated_data = np.dot(whitened_data, sorted_eigenvectors.T) + [mean_var1, mean_var2]

    # Separate rotated data back into background
    background_rotated_data = rotated_data[:len(background_data)]

    # Create DataFrame with rotated data for background
    background_rotated_df = pd.DataFrame(background_rotated_data, columns=['var_x', 'var_y'])
    background_rotated_df['tag'] = background_df['tag'].values

    # Rotate each signal data
    signals_rotated_df_list = []
    for signals_df in signals_df_list:
        signals_data = signals_df[[var1, var2]].values
        signals_rotated_data = np.dot(signals_data - [mean_var1, mean_var2], np.dot(sorted_eigenvectors, whitening_matrix)) + [mean_var1, mean_var2]
        signals_rotated_df = pd.DataFrame(signals_rotated_data, columns=['var_x', 'var_y'])
        signals_rotated_df['tag'] = signals_df['tag'].values
        signals_rotated_df_list.append(signals_rotated_df)

    return background_rotated_df, signals_rotated_df_list

# %%
bkgSemi_rot_df, signals_rot_df_list = PCA_Converter_rot(bkgSemi_df, 
                                                        [SemilepTag_m00_df, SemilepTag_m05_df, SemilepTag_m10_df, 
                                                         SemilepTag_m15_df, SemilepTag_m20_df, SemilepTag_m25_df, 
                                                         SemilepTag_m30_df, SemilepTag_m35_df, SemilepTag_m40_df, 
                                                         SemilepTag_m50_df], 
                                                         'Mmin2', 'Mmax2', scale=False)

# %%
bkgSemi_rot_preserve_df, signals_rot_preserve_df_list = custom_rotation(bkgSemi_df, 
                                                                        [SemilepTag_m00_df, SemilepTag_m05_df, SemilepTag_m10_df, 
                                                                         SemilepTag_m15_df, SemilepTag_m20_df, SemilepTag_m25_df, 
                                                                         SemilepTag_m30_df, SemilepTag_m35_df, SemilepTag_m40_df, 
                                                                         SemilepTag_m50_df], 
                                                                        'Mmin2', 'Mmax2')

# %%
bkgSemi_rot_WPCA_df, signals_rot_WPCA_df_list = whitining_PCA(bkgSemi_df, 
                                                                        [SemilepTag_m00_df, SemilepTag_m05_df, SemilepTag_m10_df, 
                                                                         SemilepTag_m15_df, SemilepTag_m20_df, SemilepTag_m25_df, 
                                                                         SemilepTag_m30_df, SemilepTag_m35_df, SemilepTag_m40_df, 
                                                                         SemilepTag_m50_df], 
                                                                        'Mmin2', 'Mmax2')

# %%
bkgSemi_rot_preserve_df
# Out:
#            var_x     var_y  tag
# 0       7.686368  8.035525    1
# 1      -3.572863  8.395757    1
# 2      10.116624  7.582698    1
# 3       9.874846  7.782425    1
# 4      13.409063  7.729467    1
# ...          ...       ...  ...
# 55498  11.915155  8.240785    3
# 55499  19.052464  8.039254    3
# 55500   9.274368  8.355867    3
# 55501  13.279736  7.237191    3
# 55502  11.326366  7.766201    3
#
# [55503 rows x 3 columns]

# %%
bkgSemi_rot_WPCA_df
# Out:
#           var_x     var_y  tag
# 0      5.940751  8.285358    1
# 1      4.531607  8.040990    1
# 2      6.789429  7.745181    1
# 3      6.480442  8.043436    1
# 4      6.835488  8.215178    1
# ...         ...       ...  ...
# 55498  5.975590  8.915498    3
# 55499  6.829917  9.112805    3
# 55500  5.600672  8.906543    3
# 55501  7.539983  7.427629    3
# 55502  6.618239  8.122707    3
#
# [55503 rows x 3 columns]

# %%
semilepTag_m00_rot_df = signals_rot_df_list[0]
semilepTag_m05_rot_df = signals_rot_df_list[1]
semilepTag_m10_rot_df = signals_rot_df_list[2]
semilepTag_m15_rot_df = signals_rot_df_list[3]
semilepTag_m20_rot_df = signals_rot_df_list[4]
semilepTag_m25_rot_df = signals_rot_df_list[5]
semilepTag_m30_rot_df = signals_rot_df_list[6]
semilepTag_m35_rot_df = signals_rot_df_list[7]
semilepTag_m40_rot_df = signals_rot_df_list[8]
semilepTag_m50_rot_df = signals_rot_df_list[9]

# %%
semilepTag_m00_rot_preserve_df = signals_rot_preserve_df_list[0]
semilepTag_m05_rot_preserve_df = signals_rot_preserve_df_list[1]
semilepTag_m10_rot_preserve_df = signals_rot_preserve_df_list[2]
semilepTag_m15_rot_preserve_df = signals_rot_preserve_df_list[3]
semilepTag_m20_rot_preserve_df = signals_rot_preserve_df_list[4]
semilepTag_m25_rot_preserve_df = signals_rot_preserve_df_list[5]
semilepTag_m30_rot_preserve_df = signals_rot_preserve_df_list[6]
semilepTag_m35_rot_preserve_df = signals_rot_preserve_df_list[7]
semilepTag_m40_rot_preserve_df = signals_rot_preserve_df_list[8]
semilepTag_m50_rot_preserve_df = signals_rot_preserve_df_list[9]

# %%
semilepTag_m00_rot_WPCA_df = signals_rot_WPCA_df_list[0]
semilepTag_m05_rot_WPCA_df = signals_rot_WPCA_df_list[1]
semilepTag_m10_rot_WPCA_df = signals_rot_WPCA_df_list[2]
semilepTag_m15_rot_WPCA_df = signals_rot_WPCA_df_list[3]
semilepTag_m20_rot_WPCA_df = signals_rot_WPCA_df_list[4]
semilepTag_m25_rot_WPCA_df = signals_rot_WPCA_df_list[5]
semilepTag_m30_rot_WPCA_df = signals_rot_WPCA_df_list[6]
semilepTag_m35_rot_WPCA_df = signals_rot_WPCA_df_list[7]
semilepTag_m40_rot_WPCA_df = signals_rot_WPCA_df_list[8]
semilepTag_m50_rot_WPCA_df = signals_rot_WPCA_df_list[9]

# %%
semilepTag_m00_rot_preserve_df
# Out:
#            var_x     var_y  tag
# 0      -3.243695  8.487497    1
# 1      -4.079596  7.216152    1
# 2      -1.365100  8.408409    1
# 3      -2.028080  7.797683    1
# 4      -4.635287  7.345251    1
# ...          ...       ...  ...
# 163770 -3.396850  6.334429    3
# 163771 -3.154548  7.453946    3
# 163772 -3.252247  7.005911    3
# 163773 -4.394217  7.712645    3
# 163774 -4.979704  7.199954    3
#
# [163775 rows x 3 columns]

# %%
semilepTag_m45_rot_preserve_df
# Out:
#             var_x     var_y  tag
# 0       25.041443  7.507525    1
# 1       25.006834  7.814533    1
# 2       24.942660  7.579565    1
# 3       24.925432  7.575863    1
# 4       24.764230  7.657841    1
# ...           ...       ...  ...
# 145179  25.206151  7.907965    3
# 145180  25.229971  7.751597    3
# 145181  25.272472  7.785085    3
# 145182  25.057814  7.952932    3
# 145183  25.003491  7.591274    3
#
# [145184 rows x 3 columns]

# %% [markdown]
# def PCA_Converter_test(df, var1, var2):
#     # Create the 2D array
#     data = df[[var1,var2]].to_numpy()
#
#
#     # Standardize the data for the background
#     scaler = StandardScaler()
#     data_scaled = scaler.fit_transform(data)
#
#
#
#     # Perform PCA to find principal axes and rotation angle
#     pca = PCA(n_components=2)
#     pca.fit(data_scaled)
#     rotation_angle = np.degrees(np.arctan2(*pca.components_[0][::-1]))
#
#     # Rotate the data points
#     rotation_matrix = np.array([[np.cos(np.radians(rotation_angle)), -np.sin(np.radians(rotation_angle))],
#                                 [np.sin(np.radians(rotation_angle)), np.cos(np.radians(rotation_angle))]])
#     rotated = np.dot(data_scaled, rotation_matrix)
#
#
#     data_rot_df = pd.DataFrame(rotated, columns=['var_x', 'var_y'])
#
#
#     return data_rot_df

# %%
def Construct_Ellipse(rotated_df, var1, var2, confidence_level):
    
    # To numpy array
    rotated_data = rotated_df[[var1, var2]].to_numpy()
    
    # Calculate covariance matrix of rotated data
    covariance_rotated = np.cov(rotated_data, rowvar=False)

    # Calculate eigenvalues and eigenvectors of the covariance matrix
    eigenvalues, eigenvectors = np.linalg.eig(covariance_rotated)

    # Sort eigenvalues and eigenvectors
    sorted_indices = np.argsort(eigenvalues)[::-1]
    eigenvalues = eigenvalues[sorted_indices]
    eigenvectors = eigenvectors[:, sorted_indices]

    # Determine rotation angle and scale factors for the ellipse
    scale_factor = np.sqrt(-2 * np.log(1 - confidence_level))
    ellipse_width = scale_factor * np.sqrt(eigenvalues[0])
    ellipse_height = scale_factor * np.sqrt(eigenvalues[1])
    ellipse_angle = np.degrees(np.arctan2(*eigenvectors[:, 0][::-1]))

    center_x = np.mean(rotated_data[:, 0])
    center_y = np.mean(rotated_data[:, 1])

    # Define the equation of the ellipse
    def ellipse_equation(x, y):
        return (((x - center_x) * np.cos(np.radians(ellipse_angle)) - (y - center_y) * np.sin(np.radians(ellipse_angle))) / ellipse_width)**2 + \
               (((x - center_x) * np.sin(np.radians(ellipse_angle)) + (y - center_y) * np.cos(np.radians(ellipse_angle))) / ellipse_height)**2

    return center_x, center_y, ellipse_width, ellipse_height, ellipse_angle

# %%
def Label_Data_Inside_Ellipse(df, var1, var2, center_x, center_y, ellipse_width, ellipse_height, ellipse_angle):
    # Define the equation of the ellipse
    def ellipse_equation(x, y):
        return (((x - center_x) * np.cos(np.radians(ellipse_angle)) - (y - center_y) * np.sin(np.radians(ellipse_angle))) / ellipse_width)**2 + \
               (((x - center_x) * np.sin(np.radians(ellipse_angle)) + (y - center_y) * np.cos(np.radians(ellipse_angle))) / ellipse_height)**2

    # Calculate the ellipse equation for each data point in the new DataFrame
    ellipse_values = ellipse_equation(df[var1], df[var2])

    # Determine the label for each data point
    inside_ellipse = ellipse_values <= 1
    inside_ellipse = inside_ellipse.astype(int)

    # Add labels to the new DataFrame
    df['Inside_Ellipse'] = inside_ellipse

    return df

# %%
center_x, center_y, ellipse_width, ellipse_height, ellipse_angle = Construct_Ellipse(bkgSemi_rot_df, 'var_x', 'var_y', confidence_level=0.95)

# %%
center_x_pre, center_y_pre, ellipse_width_pre, ellipse_height_pre, ellipse_angle_pre = Construct_Ellipse(bkgSemi_rot_preserve_df, 'var_x', 'var_y', confidence_level=0.95)

# %%
center_x_WPCA, center_y_WPCA, ellipse_width_WPCA, ellipse_height_WPCA, ellipse_angle_WPCA= Construct_Ellipse(bkgSemi_rot_WPCA_df, 'var_x', 'var_y', confidence_level=0.95)

# %%
center_x_or, center_y_or, ellipse_width_or, ellipse_height_or, ellipse_angle_or = Construct_Ellipse(bkgSemi_df, 'Mmin2', 'Mmax2', confidence_level=0.999)

# %% [markdown]
# def PCA_Converter(dfs, dfb, var1, var2, confidence_level):
#     # Create the 2D array
#     data_s = dfs[[var1,var2]].to_numpy()
#     data_b = dfb[[var1,var2]].to_numpy()
#
#     # Standardize the data for the background
#     scaler = StandardScaler()
#     data_scaled_b = scaler.fit_transform(data_b)
#     data_scaled_s = scaler.fit_transform(data_s)
#
#
#     # Perform PCA to find principal axes and rotation angle
#     pca = PCA(n_components=2)
#     pca.fit(data_scaled_b)
#     rotation_angle = np.degrees(np.arctan2(*pca.components_[0][::-1]))
#
#     # Rotate the data points
#     rotation_matrix = np.array([[np.cos(np.radians(rotation_angle)), -np.sin(np.radians(rotation_angle))],
#                                 [np.sin(np.radians(rotation_angle)), np.cos(np.radians(rotation_angle))]])
#     rotated_data_b = np.dot(data_scaled_b, rotation_matrix)
#     rotated_data_s = np.dot(data_scaled_s, rotation_matrix)
#
#     sig_rot_df = pd.DataFrame(rotated_data_s, columns=['var_x', 'var_y'])
#     bkg_rot_df = pd.DataFrame(rotated_data_b, columns=['var_x', 'var_y'])
#
#     # Calculate covariance matrix of rotated data
#     covariance_rotated = np.cov(rotated_data_b, rowvar=False)
#
#     # Calculate eigenvalues and eigenvectors of the covariance matrix
#     eigenvalues, eigenvectors = np.linalg.eig(covariance_rotated)
#
#     # Sort eigenvalues and eigenvectors
#     sorted_indices = np.argsort(eigenvalues)[::-1]
#     eigenvalues = eigenvalues[sorted_indices]
#     eigenvectors = eigenvectors[:, sorted_indices]
#
#     # Determine rotation angle and scale factors for the ellipse
#     scale_factor = np.sqrt(-2 * np.log(1 - confidence_level))
#     ellipse_width = scale_factor * np.sqrt(eigenvalues[0])
#     ellipse_height = scale_factor * np.sqrt(eigenvalues[1])
#     ellipse_angle = np.degrees(np.arctan2(*eigenvectors[:, 0][::-1]))
#
#     center_x = np.mean(rotated_data_b[:, 0])
#     center_y = np.mean(rotated_data_b[:, 1])
#
#     return sig_rot_df, bkg_rot_df, center_x, center_y, ellipse_width, ellipse_height, ellipse_angle

# %%
bkgSemi_rot_df = Label_Data_Inside_Ellipse(bkgSemi_rot_df,'var_x', 'var_y', center_x, center_y, ellipse_width, ellipse_height, ellipse_angle)

semilepTag_m00_rot_df = Label_Data_Inside_Ellipse(semilepTag_m00_rot_df,'var_x', 'var_y', center_x, center_y, ellipse_width, ellipse_height, ellipse_angle)
semilepTag_m05_rot_df = Label_Data_Inside_Ellipse(semilepTag_m05_rot_df,'var_x', 'var_y', center_x, center_y, ellipse_width, ellipse_height, ellipse_angle)
semilepTag_m10_rot_df = Label_Data_Inside_Ellipse(semilepTag_m10_rot_df,'var_x', 'var_y', center_x, center_y, ellipse_width, ellipse_height, ellipse_angle)
semilepTag_m15_rot_df = Label_Data_Inside_Ellipse(semilepTag_m15_rot_df,'var_x', 'var_y', center_x, center_y, ellipse_width, ellipse_height, ellipse_angle)
semilepTag_m20_rot_df = Label_Data_Inside_Ellipse(semilepTag_m20_rot_df,'var_x', 'var_y', center_x, center_y, ellipse_width, ellipse_height, ellipse_angle)
semilepTag_m2t_rot_df = Label_Data_Inside_Ellipse(semilepTag_m25_rot_df,'var_x', 'var_y', center_x, center_y, ellipse_width, ellipse_height, ellipse_angle)
semilepTag_m30_rot_df = Label_Data_Inside_Ellipse(semilepTag_m30_rot_df,'var_x', 'var_y', center_x, center_y, ellipse_width, ellipse_height, ellipse_angle)
semilepTag_m35_rot_df = Label_Data_Inside_Ellipse(semilepTag_m35_rot_df,'var_x', 'var_y', center_x, center_y, ellipse_width, ellipse_height, ellipse_angle)
semilepTag_m40_rot_df = Label_Data_Inside_Ellipse(semilepTag_m40_rot_df,'var_x', 'var_y', center_x, center_y, ellipse_width, ellipse_height, ellipse_angle)
semilepTag_m50_rot_df = Label_Data_Inside_Ellipse(semilepTag_m50_rot_df,'var_x', 'var_y', center_x, center_y, ellipse_width, ellipse_height, ellipse_angle)

# %%
bkgSemi_rot_df
# Out:
#            var_x     var_y  tag  Inside_Ellipse
# 0      11.331827  1.806938    1               1
# 1       0.072597  2.167170    1               1
# 2      13.762083  1.354111    1               1
# 3      13.520306  1.553838    1               1
# 4      17.054523  1.500881    1               1
# ...          ...       ...  ...             ...
# 55498  15.560614  2.012198    3               1
# 55499  22.697923  1.810667    3               1
# 55500  12.919828  2.127280    3               1
# 55501  16.925195  1.008605    3               1
# 55502  14.971825  1.537614    3               1
#
# [55503 rows x 4 columns]

# %%
semilepTag_m00_rot_df
# Out:
#            var_x     var_y  tag  Inside_Ellipse
# 0       0.401764  2.258910    1               1
# 1      -0.434137  0.987565    1               1
# 2       2.280360  2.179822    1               1
# 3       1.617379  1.569096    1               1
# 4      -0.989828  1.116664    1               1
# ...          ...       ...  ...             ...
# 163770  0.248609  0.105842    3               0
# 163771  0.490911  1.225359    3               1
# 163772  0.393212  0.777324    3               0
# 163773 -0.748758  1.484058    3               1
# 163774 -1.334245  0.971367    3               0
#
# [163775 rows x 4 columns]

# %%
print(len(bkgSemi_rot_df[bkgSemi_rot_df["Inside_Ellipse"]==0]))
# Out:
# 2276

# %%
print(len(semilepTag_m00_rot_df[semilepTag_m00_rot_df["Inside_Ellipse"]==0]))
# Out:
# 50863

# %%
print("The ellipse center: ({}, {})".format(center_x, center_y))
print("Ellipse width: {}".format(ellipse_width))
print("Ellipse hieght: {}".format(ellipse_height))
print("Ellipse inclination angle: {}".format(ellipse_angle))
# Out:
# The ellipse center: (13.043160254320464, 1.5735658560518488)
# Ellipse width: 17.849120804919746
# Ellipse hieght: 0.999622685359045
# Ellipse inclination angle: -0.012507487593706729

# %%
print("The ellipse center: ({}, {})".format(center_x_pre, center_y_pre))
print("Ellipse width: {}".format(ellipse_width_pre))
print("Ellipse hieght: {}".format(ellipse_height_pre))
print("Ellipse inclination angle: {}".format(ellipse_angle_pre))
# Out:
# The ellipse center: (9.397700958704737, 7.802152813413973)
# Ellipse width: 17.84912080491974
# Ellipse hieght: 0.9996226853590451
# Ellipse inclination angle: -0.012507487593753253

# %%
print("The ellipse center: ({}, {})".format(center_x_WPCA, center_y_WPCA))
print("Ellipse width: {}".format(ellipse_width_WPCA))
print("Ellipse hieght: {}".format(ellipse_height_WPCA))
print("Ellipse inclination angle: {}".format(ellipse_angle_WPCA))
# Out:
# The ellipse center: (6.414246786310978, 8.040134756215021)
# Ellipse width: 2.1455770209004803
# Ellipse hieght: 1.9072984075611956
# Ellipse inclination angle: -46.49306275294996

# %%
print("The ellipse center: ({}, {})".format(center_x_or, center_y_or))
print("Ellipse width: {}".format(ellipse_width_or))
print("Ellipse hieght: {}".format(ellipse_height_or))
print("Ellipse inclination angle: {}".format(ellipse_angle_or))
# Out:
# The ellipse center: (8.542308879590326, 9.98143766843682)
# Ellipse width: 27.104025767572782
# Ellipse hieght: 1.5179346544820214
# Ellipse inclination angle: 42.55084814068665

# %%
# Create a canvas
canvas = ROOT.TCanvas("canvas", "2D Distribution Plot", 800, 600)


# Create histograms for signal and background
hist_signal = ROOT.TH2F("hist_signal", "Signal Distribution", 250, -6, 25, 550, -3, 25)
hist_background = ROOT.TH2F("hist_background", "Background Distribution",250, -6, 35, 550, -3, 25)

# Fill histograms with data

SemilepTag_m00_arr = SemilepTag_m00_df[['Mmin2','Mmax2']].to_numpy()
bkgSemi_arr = bkgSemi_df[["Mmin2","Mmax2"]].to_numpy()

for point in SemilepTag_m00_arr:
    hist_signal.Fill(point[0], point[1])

for point in bkgSemi_arr:
    hist_background.Fill(point[0], point[1])

# Set fill colors
hist_signal.SetFillColor(ROOT.kBlue)
hist_background.SetFillColor(ROOT.kRed)

# Draw histograms
hist_signal.Draw("box")
hist_background.Draw("box same")

# Draw legend
legend = ROOT.TLegend(0.7, -0.7, 0.9, -0.9)
legend.AddEntry(hist_signal, "Signal", "f")
legend.AddEntry(hist_background, "Background", "f")
legend.Draw()

# Set labels and titles
hist_signal.GetXaxis().SetTitle("X")
hist_signal.GetYaxis().SetTitle("Y")
hist_signal.SetTitle("2D Distribution Plot")

# Update canvas
canvas.Update()

# Save or show the plot
#canvas.SaveAs("2D_Distribution_Plot.png")
canvas.Draw()

# %%
# Create a canvas
canvas = ROOT.TCanvas("canvas", "2D Distribution Plot", 800, 600)


# Create histograms for signal and background
hist_signal = ROOT.TH2F("hist_signal", "Signal Distribution", 250, -6, 25, 550, -3, 25)
hist_background = ROOT.TH2F("hist_background", "Background Distribution",250, -6, 35, 550, -3, 25)

# Fill histograms with data

SemilepTag_m50_arr = SemilepTag_m50_df[['Mmin2','Mmax2']].to_numpy()
bkgSemi_arr = bkgSemi_df[["Mmin2","Mmax2"]].to_numpy()

for point in SemilepTag_m50_arr:
    hist_signal.Fill(point[0], point[1])

for point in bkgSemi_arr:
    hist_background.Fill(point[0], point[1])

# Set fill colors
hist_signal.SetFillColor(ROOT.kBlue)
hist_background.SetFillColor(ROOT.kRed)

# Draw histograms
hist_signal.Draw("box")
hist_background.Draw("box same")

# Draw legend
legend = ROOT.TLegend(0.7, -0.7, 0.9, -0.9)
legend.AddEntry(hist_signal, "Signal", "f")
legend.AddEntry(hist_background, "Background", "f")
legend.Draw()

# Set labels and titles
hist_signal.GetXaxis().SetTitle("X")
hist_signal.GetYaxis().SetTitle("Y")
hist_signal.SetTitle("2D Distribution Plot")

# Update canvas
canvas.Update()

# Save or show the plot
#canvas.SaveAs("2D_Distribution_Plot.png")
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Warning in <TROOT::Append>: Replacing existing TH1: hist_signal (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: hist_background (Potential memory leak).

# %%
# Create a canvas
canvas = ROOT.TCanvas("canvas", "2D Distribution Plot", 800, 600)


# Create histograms for signal and background
hist_signal = ROOT.TH2F("hist_signal", "Signal Distribution", 250, -10, 35, 550, -3, 5)
hist_background = ROOT.TH2F("hist_background", "Background Distribution",250, -10, 35, 550, -3, 5)

# Fill histograms with data

SemilepTag_m00_rot_arr = semilepTag_m00_rot_df[['var_x','var_y']].to_numpy()
bkgSemi_rot_arr = bkgSemi_rot_df[['var_x','var_y']].to_numpy()

for point in SemilepTag_m00_rot_arr:
    hist_signal.Fill(point[0], point[1])

for point in bkgSemi_rot_arr:
    hist_background.Fill(point[0], point[1])

# Set fill colors
hist_signal.SetFillColor(ROOT.kBlue)
hist_background.SetFillColor(ROOT.kRed)

# Draw histograms
hist_signal.Draw("box")
hist_background.Draw("box same")

# Draw legend
legend = ROOT.TLegend(0.7, 0.7, 0.9, 0.9)
legend.AddEntry(hist_signal, "Signal", "f")
legend.AddEntry(hist_background, "Background", "f")
legend.Draw()

# Set labels and titles
hist_signal.GetXaxis().SetTitle("X")
hist_signal.GetYaxis().SetTitle("Y")
hist_signal.SetTitle("2D Distribution Plot")

# Update canvas
canvas.Update()

# Save or show the plot
#canvas.SaveAs("2D_Distribution_Plot.png")
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Warning in <TROOT::Append>: Replacing existing TH1: hist_signal (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: hist_background (Potential memory leak).

# %%
# Create a canvas
canvas = ROOT.TCanvas("canvas", "2D Distribution Plot", 800, 600)

# Create histograms for signal and background
hist_signal = ROOT.TH2F("hist_signal", "Signal Distribution", 250, -10, 35, 550, -3, 5)
hist_background = ROOT.TH2F("hist_background", "Background Distribution",250, -10, 35, 550, -3, 5)

# Fill histograms with data

SemilepTag_m30_rot_arr = semilepTag_m30_rot_df[['var_x','var_y']].to_numpy()
bkgSemi_rot_arr = bkgSemi_rot_df[['var_x','var_y']].to_numpy()

for point in SemilepTag_m30_rot_arr:
    hist_signal.Fill(point[0], point[1])

for point in bkgSemi_rot_arr:
    hist_background.Fill(point[0], point[1])

ROOT.gStyle.SetOptStat(0)
# Set fill colors
hist_signal.SetFillColor(ROOT.kBlue)
hist_background.SetFillColor(ROOT.kRed)

# Draw histograms
hist_signal.Draw("box")
hist_background.Draw("box same")

# Draw legend
legend = ROOT.TLegend(0.7, -0.7, 0.9, -0.9)
legend.AddEntry(hist_signal, "Signal", "f")
legend.AddEntry(hist_background, "Background", "f")
legend.Draw()

# Set labels and titles
hist_signal.GetXaxis().SetTitle("X")
hist_signal.GetYaxis().SetTitle("Y")
hist_signal.SetTitle("2D Distribution Plot")

# Update canvas
canvas.Update()

# Save or show the plot
#canvas.SaveAs("2D_Distribution_Plot.png")
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Warning in <TROOT::Append>: Replacing existing TH1: hist_signal (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: hist_background (Potential memory leak).

# %%
# Create a canvas
canvas = ROOT.TCanvas("canvas", "2D Distribution Plot", 800, 600)

# Create histograms for signal and background
hist_signal = ROOT.TH2F("hist_signal", "Signal Distribution", 250, -10, 35, 550, -3, 5)
hist_background = ROOT.TH2F("hist_background", "Background Distribution",250, -10, 35, 550, -3, 5)

# Fill histograms with data

SemilepTag_m50_rot_arr = semilepTag_m50_rot_df[['var_x','var_y']].to_numpy()
bkgSemi_rot_arr = bkgSemi_rot_df[['var_x','var_y']].to_numpy()

for point in SemilepTag_m50_rot_arr:
    hist_signal.Fill(point[0], point[1])

for point in bkgSemi_rot_arr:
    hist_background.Fill(point[0], point[1])

ROOT.gStyle.SetOptStat(0)
# Set fill colors
hist_signal.SetFillColor(ROOT.kBlue)
hist_background.SetFillColor(ROOT.kRed)

# Draw histograms
hist_signal.Draw("box")
hist_background.Draw("box same")

# Draw legend
legend = ROOT.TLegend(0.7, -0.7, 0.9, -0.9)
legend.AddEntry(hist_signal, "Signal", "f")
legend.AddEntry(hist_background, "Background", "f")
legend.Draw()

# Set labels and titles
hist_signal.GetXaxis().SetTitle("X")
hist_signal.GetYaxis().SetTitle("Y")
hist_signal.SetTitle("2D Distribution Plot")

# Update canvas
canvas.Update()

# Save or show the plot
#canvas.SaveAs("2D_Distribution_Plot.png")
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Warning in <TROOT::Append>: Replacing existing TH1: hist_signal (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: hist_background (Potential memory leak).

# %%
# Create a canvas
canvas = ROOT.TCanvas("canvas", "2D Distribution Plot", 800, 600)


# Create histograms for signal and background
hist_signal = ROOT.TH2F("hist_signal", "Signal Distribution", 250, -10, 30, 550, 5, 10)
hist_background = ROOT.TH2F("hist_background", "Background Distribution", 250, -10, 30, 550, 5, 10)

# Fill histograms with data

SemilepTag_m00_preserv_arr = semilepTag_m00_rot_preserve_df[['var_x','var_y']].to_numpy()
bkgSemi_preserv_arr = bkgSemi_rot_preserve_df[['var_x','var_y']].to_numpy()

for point in SemilepTag_m00_preserv_arr:
    hist_signal.Fill(point[0], point[1])

for point in bkgSemi_preserv_arr:
    hist_background.Fill(point[0], point[1])

# Set fill colors
hist_signal.SetFillColor(ROOT.kBlue)
hist_background.SetFillColor(ROOT.kRed)

# Draw histograms
hist_signal.Draw("box")
hist_background.Draw("box same")

# Draw legend
legend = ROOT.TLegend(0.7, -0.7, 0.9, -0.9)
legend.AddEntry(hist_signal, "Signal", "f")
legend.AddEntry(hist_background, "Background", "f")
legend.Draw()

# Set labels and titles
hist_signal.GetXaxis().SetTitle("X")
hist_signal.GetYaxis().SetTitle("Y")
hist_signal.SetTitle("2D Distribution Plot")

# Update canvas
canvas.Update()

# Save or show the plot
#canvas.SaveAs("2D_Distribution_Plot.png")
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Warning in <TROOT::Append>: Replacing existing TH1: hist_signal (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: hist_background (Potential memory leak).

# %%
# Create a canvas
canvas = ROOT.TCanvas("canvas", "2D Distribution Plot", 800, 600)


# Create histograms for signal and background
hist_signal = ROOT.TH2F("hist_signal", "Signal Distribution", 250, -10, 30, 550, 5, 10)
hist_background = ROOT.TH2F("hist_background", "Background Distribution",250, -10, 30, 550, 5, 10)

# Fill histograms with data

SemilepTag_m50_preserv_arr = semilepTag_m50_rot_preserve_df[['var_x','var_y']].to_numpy()
bkgSemi_preserv_arr = bkgSemi_rot_preserve_df[['var_x','var_y']].to_numpy()

for point in SemilepTag_m50_preserv_arr:
    hist_signal.Fill(point[0], point[1])

for point in bkgSemi_preserv_arr:
    hist_background.Fill(point[0], point[1])

# Set fill colors
hist_signal.SetFillColor(ROOT.kBlue)
hist_background.SetFillColor(ROOT.kRed)

# Draw histograms
hist_signal.Draw("box")
hist_background.Draw("box same")

# Draw legend
legend = ROOT.TLegend(0.7, -0.7, 0.9, -0.9)
legend.AddEntry(hist_signal, "Signal", "f")
legend.AddEntry(hist_background, "Background", "f")
legend.Draw()

# Set labels and titles
hist_signal.GetXaxis().SetTitle("X")
hist_signal.GetYaxis().SetTitle("Y")
hist_signal.SetTitle("2D Distribution Plot")

# Update canvas
canvas.Update()

# Save or show the plot
#canvas.SaveAs("2D_Distribution_Plot.png")
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Warning in <TROOT::Append>: Replacing existing TH1: hist_signal (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: hist_background (Potential memory leak).

# %%
# Create a canvas
canvas = ROOT.TCanvas("canvas", "2D Distribution Plot", 800, 600)


# Create histograms for signal and background
hist_signal = ROOT.TH2F("hist_signal", "Signal Distribution", 250, 3, 9, 550, 3, 11)
hist_background = ROOT.TH2F("hist_background", "Background Distribution", 250, 3, 9, 550, 3, 11)

# Fill histograms with data

SemilepTag_m00_WPCA_arr = semilepTag_m00_rot_WPCA_df[['var_x','var_y']].to_numpy()
bkgSemi_WPCA_arr = bkgSemi_rot_WPCA_df[['var_x','var_y']].to_numpy()

for point in SemilepTag_m00_WPCA_arr:
    hist_signal.Fill(point[0], point[1])

for point in bkgSemi_WPCA_arr:
    hist_background.Fill(point[0], point[1])

# Set fill colors
hist_signal.SetFillColor(ROOT.kBlue)
hist_background.SetFillColor(ROOT.kRed)

# Draw histograms
hist_signal.Draw("box")
hist_background.Draw("box same")

# Draw legend
legend = ROOT.TLegend(0.7, -0.7, 0.9, -0.9)
legend.AddEntry(hist_signal, "Signal", "f")
legend.AddEntry(hist_background, "Background", "f")
legend.Draw()

# Set labels and titles
hist_signal.GetXaxis().SetTitle("X")
hist_signal.GetYaxis().SetTitle("Y")
hist_signal.SetTitle("2D Distribution Plot")

# Update canvas
canvas.Update()

# Save or show the plot
#canvas.SaveAs("2D_Distribution_Plot.png")
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Warning in <TROOT::Append>: Replacing existing TH1: hist_signal (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: hist_background (Potential memory leak).

# %%
# Create a canvas
canvas = ROOT.TCanvas("canvas", "2D Distribution Plot", 800, 600)


# Create histograms for signal and background
hist_signal = ROOT.TH2F("hist_signal", "Signal Distribution", 250, 3, 9, 550, 3, 11)
hist_background = ROOT.TH2F("hist_background", "Background Distribution", 250, 3, 9, 550, 3, 11)

# Fill histograms with data

SemilepTag_m30_WPCA_arr = semilepTag_m30_rot_WPCA_df[['var_x','var_y']].to_numpy()
bkgSemi_WPCA_arr = bkgSemi_rot_WPCA_df[['var_x','var_y']].to_numpy()

for point in SemilepTag_m30_WPCA_arr:
    hist_signal.Fill(point[0], point[1])

for point in bkgSemi_WPCA_arr:
    hist_background.Fill(point[0], point[1])

# Set fill colors
hist_signal.SetFillColor(ROOT.kBlue)
hist_background.SetFillColor(ROOT.kRed)

# Draw histograms
hist_signal.Draw("box")
hist_background.Draw("box same")

# Draw legend
legend = ROOT.TLegend(0.7, -0.7, 0.9, -0.9)
legend.AddEntry(hist_signal, "Signal", "f")
legend.AddEntry(hist_background, "Background", "f")
legend.Draw()

# Set labels and titles
hist_signal.GetXaxis().SetTitle("X")
hist_signal.GetYaxis().SetTitle("Y")
hist_signal.SetTitle("2D Distribution Plot")

# Update canvas
canvas.Update()

# Save or show the plot
#canvas.SaveAs("2D_Distribution_Plot.png")
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Warning in <TROOT::Append>: Replacing existing TH1: hist_signal (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: hist_background (Potential memory leak).

# %%
import ROOT
from IPython.display import Image

def PlotInRoot(sig_df, bkg_df, var1, var2):
    # Initialize ROOT
    ROOT.PyConfig.IgnoreCommandLineOptions = True
    ROOT.gROOT.SetBatch(ROOT.kTRUE) # Suppresses the graphical display

    # Create a canvas
    canvas = ROOT.TCanvas("canvas", "2D Distribution Plot", 1000, 600)  # Increase canvas width

    # Define histogram parameters
    nbinsX = 100
    nbinsY = 100
    X_min_sig = -10
    X_max_sig = 35
    Y_min_sig = -1
    Y_max_sig = 3
    
    X_min_bkg = -10
    X_max_bkg = 35
    Y_min_bkg = -1
    Y_max_bkg = 3

    # Create histograms for signal and background
    h_sig = ROOT.TH2F("hist_signal", "Signal Distribution", nbinsX, X_min_sig, X_max_sig, nbinsY, Y_min_sig, Y_max_sig)
    h_bkg = ROOT.TH2F("hist_background", "Background Distribution", nbinsX, X_min_bkg, X_max_bkg, nbinsY, Y_min_bkg, Y_max_bkg)
    # Fill histograms with data
    sig_arr = sig_df[[var1, var2]].to_numpy()
    bkg_arr = bkg_df[[var1, var2]].to_numpy()

    for point in sig_arr:
        h_sig.Fill(point[0], point[1])

    for point in bkg_arr:
        h_bkg.Fill(point[0], point[1])

    # Set fill colors
    # h_sig.SetFillColor(ROOT.kBlue)
    # h_bkg.SetFillColor(ROOT.kRed)

    # Divide canvas into two pads
    canvas.Divide(2)  # Divide canvas into two pads
    canvas.cd(1)

    # ROOT.gStyle.SetPalette(1)
    ROOT.gStyle.SetOptStat(0)

    # Draw histograms
    # Set labels and titles
    h_bkg.GetXaxis().SetTitleOffset(1.2)  # Adjust X-axis label position
    h_bkg.GetYaxis().SetTitleOffset(1.2)  # Adjust Y-axis label position
    h_bkg.GetXaxis().SetTitle(var1)
    h_bkg.GetYaxis().SetTitle(var2)
    h_bkg.SetTitle("2D Background Distribution Plot")

    h_bkg.Draw("CONTZ")  # Use COLZ to display the color bar

    # Draw ellipse
    ellipse = ROOT.TEllipse(center_x, center_y, ellipse_width, ellipse_height)
    ellipse.SetFillColor(0)
    ellipse.SetLineColor(ROOT.kGreen)  # Set ellipse color
    ellipse.SetFillStyle(0)
    ellipse.SetLineWidth(2)
    ellipse.SetTheta(ellipse_angle)  # Set angle of rotation
    ellipse.Draw("same")

    # Draw histograms
    canvas.cd(2)

    # Set labels and titles
    h_sig.GetXaxis().SetTitleOffset(1.2)  # Adjust X-axis label position
    h_sig.GetYaxis().SetTitleOffset(1.2)  # Adjust Y-axis label position
    h_sig.GetXaxis().SetTitle(var1)
    h_sig.GetYaxis().SetTitle(var2)
    h_sig.SetTitle("2D Signal Distribution Plot")

    h_sig.Draw("CONTZ")  # Use CONTZ to overlay signal on top
    ellipse.Draw("same")


    # Update canvas
    canvas.Update()

    # Save the plot as an image file
    canvas.SaveAs("2D_Distribution_Plot.png")

    # Close the canvas to release memory
    canvas.Close()

    # Display the saved image
    return Image(filename="2D_Distribution_Plot.png")

# %%
def PlotInRoot3D(sig_df, bkg_df, var1, var2):
    # Initialize ROOT
    ROOT.PyConfig.IgnoreCommandLineOptions = True
    ROOT.gROOT.SetBatch(ROOT.kTRUE) # Suppresses the graphical display

    # Create a canvas
    canvas = ROOT.TCanvas("canvas", "3D Distribution Plot", 800, 600)

    # Define histogram parameters
    nbinsX = 40
    nbinsY = 40
    X_min_sig = -10
    X_max_sig = 30
    Y_min_sig = 5
    Y_max_sig = 10
    
    X_min_bkg = -10
    X_max_bkg = 30
    Y_min_bkg = 5
    Y_max_bkg = 10
    
    # Create histograms for signal and background
    h_sig = ROOT.TH2F("hist_signal", "Signal Distribution", nbinsX, X_min_sig, X_max_sig, nbinsY, Y_min_sig, Y_max_sig)
    h_bkg = ROOT.TH2F("hist_background", "Background Distribution", nbinsX, X_min_bkg, X_max_bkg, nbinsY, Y_min_bkg, Y_max_bkg)

    # Fill histograms with data
    sig_arr = sig_df[[var1, var2]].to_numpy()
    bkg_arr = bkg_df[[var1, var2]].to_numpy()

    for point in sig_arr:
        h_sig.Fill(point[0], point[1])

    for point in bkg_arr:
        h_bkg.Fill(point[0], point[1])

    # Set fill colors
    h_sig.SetLineColor(ROOT.kBlue)  # Set blue color with some transparency for signal
    h_bkg.SetLineColor(ROOT.kRed)   # Set red color with some transparency for background

    # Draw histograms
    canvas.Divide(2)  # Divide canvas into two pads

    canvas.cd(1)
    h_sig.GetZaxis().SetTitleOffset(1.8)
    h_sig.Draw("LEGO1")
    

    canvas.cd(2)
    h_bkg.GetZaxis().SetTitleOffset(1.8)
    h_bkg.Draw("LEGO1")

    # Draw legend
    legend = ROOT.TLegend(0.7, 0.7, 0.9, 0.9)
    legend.AddEntry(h_sig, "Signal", "f")
    legend.AddEntry(h_bkg, "Background", "f")
    legend.Draw()

    # Set labels and titles
    h_bkg.GetXaxis().SetTitle(var1)
    h_bkg.GetYaxis().SetTitle(var2)
    h_bkg.SetTitle("3D Distribution Plot")

    # Update canvas
    canvas.Update()

    # Save the plot as an image file
    canvas.SaveAs("3D_Distribution_Plot.png")

    # Close the canvas to release memory
    canvas.Close()

    # Display the saved image
    return Image(filename="3D_Distribution_Plot.png")

# %%
semilepTag_m00_rot_df
# Out:
#            var_x     var_y  tag  Inside_Ellipse
# 0       0.401764  2.258910    1               1
# 1      -0.434137  0.987565    1               1
# 2       2.280360  2.179822    1               1
# 3       1.617379  1.569096    1               1
# 4      -0.989828  1.116664    1               1
# ...          ...       ...  ...             ...
# 163770  0.248609  0.105842    3               0
# 163771  0.490911  1.225359    3               1
# 163772  0.393212  0.777324    3               0
# 163773 -0.748758  1.484058    3               1
# 163774 -1.334245  0.971367    3               0
#
# [163775 rows x 4 columns]

# %%
semilepTag_m00_rot_preserve_df
# Out:
#            var_x     var_y  tag
# 0      -3.243695  8.487497    1
# 1      -4.079596  7.216152    1
# 2      -1.365100  8.408409    1
# 3      -2.028080  7.797683    1
# 4      -4.635287  7.345251    1
# ...          ...       ...  ...
# 163770 -3.396850  6.334429    3
# 163771 -3.154548  7.453946    3
# 163772 -3.252247  7.005911    3
# 163773 -4.394217  7.712645    3
# 163774 -4.979704  7.199954    3
#
# [163775 rows x 3 columns]

# %%
PlotInRoot(sig_df = semilepTag_m00_rot_df, bkg_df = bkgSemi_rot_df, var1 = "var_x", var2 ="var_y")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Warning in <TROOT::Append>: Replacing existing TH1: hist_signal (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: hist_background (Potential memory leak).
# Info in <TCanvas::Print>: png file 2D_Distribution_Plot.png has been created

# %%
PlotInRoot(sig_df = semilepTag_m10_rot_df, bkg_df = bkgSemi_rot_df, var1 = "var_x", var2 ="var_y")
# Out:
# Info in <TCanvas::Print>: png file 2D_Distribution_Plot.png has been created

# %%
PlotInRoot(sig_df = semilepTag_m50_rot_df, bkg_df = bkgSemi_rot_df, var1 = "var_x", var2 ="var_y")
# Out:
# Info in <TCanvas::Print>: png file 2D_Distribution_Plot.png has been created

# %%
PlotInRoot(sig_df = semilepTag_m00_rot_df[semilepTag_m00_rot_df["tag"]==1], bkg_df = bkgSemi_rot_df[bkgSemi_rot_df["tag"]==1], var1 = "var_x", var2 ="var_y")
# Out:
# Info in <TCanvas::Print>: png file 2D_Distribution_Plot.png has been created

# %%
PlotInRoot(sig_df = semilepTag_m00_rot_df[semilepTag_m00_rot_df["tag"]==2], bkg_df = bkgSemi_rot_df[bkgSemi_rot_df["tag"]==2], var1 = "var_x", var2 ="var_y")
# Out:
# Info in <TCanvas::Print>: png file 2D_Distribution_Plot.png has been created

# %%
PlotInRoot(sig_df = semilepTag_m00_rot_df[semilepTag_m00_rot_df["tag"]==3], bkg_df = bkgSemi_rot_df[bkgSemi_rot_df["tag"]==3], var1 = "var_x", var2 ="var_y")
# Out:
# Info in <TCanvas::Print>: png file 2D_Distribution_Plot.png has been created

# %%
PlotInRoot(sig_df = semilepTag_m00_rot_df[(semilepTag_m00_rot_df["tag"] == 3) & (semilepTag_m00_rot_df["Inside_Ellipse"] == 1)], bkg_df = bkgSemi_rot_df[(bkgSemi_rot_df["tag"]==3) & (bkgSemi_rot_df["Inside_Ellipse"]==1)], var1 = "var_x", var2 ="var_y")
# Out:
# Info in <TCanvas::Print>: png file 2D_Distribution_Plot.png has been created

# %%
PlotInRoot3D(sig_df = semilepTag_m00_rot_preserve_df, bkg_df = bkgSemi_rot_preserve_df, var1 = "var_x", var2 ="var_y")
# Out:
# Info in <TCanvas::Print>: png file 3D_Distribution_Plot.png has been created

# %%
PlotInRoot3D(sig_df = semilepTag_m50_rot_preserve_df, bkg_df = bkgSemi_rot_preserve_df, var1 = "var_x", var2 ="var_y")
# Out:
# Info in <TCanvas::Print>: png file 3D_Distribution_Plot.png has been created

# %%
# Plot rotated data points
plt.figure(figsize=(6, 6))
plt.scatter(bkgSemi_rot_df['var_x'], bkgSemi_rot_df['var_y'], alpha=0.5)
plt.title('Rotated Distribution with Ellipse')
plt.xlabel('Rotated Variable 1')
plt.ylabel('Rotated Variable 2')

# Add ellipse to the plot
ellipse = Ellipse((np.mean(bkgSemi_rot_df['var_x']), np.mean(bkgSemi_rot_df['var_y'])),
                  width=ellipse_width * 2, height=ellipse_height * 2,
                  angle=ellipse_angle, edgecolor='r', fc='None', lw=2)
plt.gca().add_patch(ellipse)

plt.grid(True)
#plt.axis('equal')
#plt.ylim(-0.5,0.5)
plt.show()

# %%
def ToHist2D(df, var1, var2):
    # Define histogram parameters
    nbinsX = 150
    nbinsY = 150
    X_min = -5.5
    X_max = 33.5
    Y_min = -0.1
    Y_max = 2.6

    #X_min = -10
    #X_max = 33
    #Y_min = -12
    #Y_max = 33

    # Create histograms for signal and background
    h_2d = ROOT.TH2F("2D", "2D", nbinsX, X_min, X_max, nbinsY, Y_min, Y_max)

        # Fill histogram with label values
    #for index, row in df.iterrows():
     #   var_x = row[var1]
      #  var_y = row[var2]
      #  label = row["Inside_Ellipse"]
      #  bin_x = h_2d.GetXaxis().FindBin(var_x)
      #  bin_y = h_2d.GetYaxis().FindBin(var_y)
      #  h_2d.SetBinContent(bin_x, bin_y, label)

    # Fill histograms with data
    df_arr = df[[var1, var2]].to_numpy()
    #df_arr = df[[var1, var2, "Inside_Ellipse"]].to_numpy()

    for point in df_arr:
        #h_2d.Fill(point[0], point[1], point[2])
        h_2d.Fill(point[0], point[1])
    return h_2d

# %%
BkgStag_D_rot_df = bkgSemi_rot_df[bkgSemi_rot_df["tag"]==1]
semiD_m00_rot_df = semilepTag_m00_rot_df[semilepTag_m00_rot_df["tag"]==1]
semiD_m05_rot_df = semilepTag_m05_rot_df[semilepTag_m05_rot_df["tag"]==1]
semiD_m10_rot_df = semilepTag_m10_rot_df[semilepTag_m10_rot_df["tag"]==1]
semiD_m15_rot_df = semilepTag_m15_rot_df[semilepTag_m15_rot_df["tag"]==1]
semiD_m20_rot_df = semilepTag_m20_rot_df[semilepTag_m20_rot_df["tag"]==1]
semiD_m25_rot_df = semilepTag_m25_rot_df[semilepTag_m25_rot_df["tag"]==1]
semiD_m30_rot_df = semilepTag_m30_rot_df[semilepTag_m30_rot_df["tag"]==1]
semiD_m35_rot_df = semilepTag_m35_rot_df[semilepTag_m35_rot_df["tag"]==1]
semiD_m40_rot_df = semilepTag_m40_rot_df[semilepTag_m40_rot_df["tag"]==1]
semiD_m50_rot_df = semilepTag_m50_rot_df[semilepTag_m50_rot_df["tag"]==1]

# %%
BkgStag_D_rot_df
# Out:
#            var_x     var_y  tag  Inside_Ellipse
# 0      11.331827  1.806938    1               1
# 1       0.072597  2.167170    1               1
# 2      13.762083  1.354111    1               1
# 3      13.520306  1.553838    1               1
# 4      17.054523  1.500881    1               1
# ...          ...       ...  ...             ...
# 24172  10.697760  1.693592    1               1
# 24173  29.500373  1.542541    1               1
# 24174   9.515483  1.856059    1               1
# 24175  18.733912  1.932043    1               1
# 24176  18.236186  1.434983    1               1
#
# [24177 rows x 4 columns]

# %%
BkgStag_Dstar_gamma_rot_df = bkgSemi_rot_df[bkgSemi_rot_df["tag"]==2]
semiDstar_gamma_m00_rot_df = semilepTag_m00_rot_df[semilepTag_m00_rot_df["tag"]==2]
semiDstar_gamma_m05_rot_df = semilepTag_m05_rot_df[semilepTag_m05_rot_df["tag"]==2]
semiDstar_gamma_m10_rot_df = semilepTag_m10_rot_df[semilepTag_m10_rot_df["tag"]==2]
semiDstar_gamma_m15_rot_df = semilepTag_m15_rot_df[semilepTag_m15_rot_df["tag"]==2]
semiDstar_gamma_m20_rot_df = semilepTag_m20_rot_df[semilepTag_m20_rot_df["tag"]==2]
semiDstar_gamma_m25_rot_df = semilepTag_m25_rot_df[semilepTag_m25_rot_df["tag"]==2]
semiDstar_gamma_m30_rot_df = semilepTag_m30_rot_df[semilepTag_m30_rot_df["tag"]==2]
semiDstar_gamma_m35_rot_df = semilepTag_m35_rot_df[semilepTag_m35_rot_df["tag"]==2]
semiDstar_gamma_m40_rot_df = semilepTag_m40_rot_df[semilepTag_m40_rot_df["tag"]==2]
semiDstar_gamma_m50_rot_df = semilepTag_m50_rot_df[semilepTag_m50_rot_df["tag"]==2]

# %%
BkgStag_Dstar_pi0_rot_df = bkgSemi_rot_df[bkgSemi_rot_df["tag"]==3]
semiDstar_pi0_m00_rot_df = semilepTag_m00_rot_df[semilepTag_m00_rot_df["tag"]==3]
semiDstar_pi0_m05_rot_df = semilepTag_m05_rot_df[semilepTag_m05_rot_df["tag"]==3]
semiDstar_pi0_m10_rot_df = semilepTag_m10_rot_df[semilepTag_m10_rot_df["tag"]==3]
semiDstar_pi0_m15_rot_df = semilepTag_m15_rot_df[semilepTag_m15_rot_df["tag"]==3]
semiDstar_pi0_m20_rot_df = semilepTag_m20_rot_df[semilepTag_m20_rot_df["tag"]==3]
semiDstar_pi0_m25_rot_df = semilepTag_m25_rot_df[semilepTag_m25_rot_df["tag"]==3]
semiDstar_pi0_m30_rot_df = semilepTag_m30_rot_df[semilepTag_m30_rot_df["tag"]==3]
semiDstar_pi0_m35_rot_df = semilepTag_m35_rot_df[semilepTag_m35_rot_df["tag"]==3]
semiDstar_pi0_m40_rot_df = semilepTag_m40_rot_df[semilepTag_m40_rot_df["tag"]==3]
semiDstar_pi0_m50_rot_df = semilepTag_m50_rot_df[semilepTag_m50_rot_df["tag"]==3]

# %%
hS_m00_2D = ToHist2D(semiD_m00_rot_df, var1 = "var_x", var2 ="var_y")
hS_m05_2D = ToHist2D(semiD_m05_rot_df, var1 = "var_x", var2 ="var_y")
hS_m10_2D = ToHist2D(semiD_m10_rot_df, var1 = "var_x", var2 ="var_y")
hS_m15_2D = ToHist2D(semiD_m15_rot_df, var1 = "var_x", var2 ="var_y")
hS_m20_2D = ToHist2D(semiD_m20_rot_df, var1 = "var_x", var2 ="var_y")
hS_m25_2D = ToHist2D(semiD_m25_rot_df, var1 = "var_x", var2 ="var_y")
hS_m30_2D = ToHist2D(semiD_m30_rot_df, var1 = "var_x", var2 ="var_y")
hS_m35_2D = ToHist2D(semiD_m35_rot_df, var1 = "var_x", var2 ="var_y")
hS_m40_2D = ToHist2D(semiD_m40_rot_df, var1 = "var_x", var2 ="var_y")
hS_m50_2D = ToHist2D(semiD_m50_rot_df, var1 = "var_x", var2 ="var_y")

hS_Dstar_gamma_m00_2D = ToHist2D(semiDstar_gamma_m00_rot_df, var1 = "var_x", var2 ="var_y")
hS_Dstar_gamma_m05_2D = ToHist2D(semiDstar_gamma_m05_rot_df, var1 = "var_x", var2 ="var_y")
hS_Dstar_gamma_m10_2D = ToHist2D(semiDstar_gamma_m10_rot_df, var1 = "var_x", var2 ="var_y")
hS_Dstar_gamma_m15_2D = ToHist2D(semiDstar_gamma_m15_rot_df, var1 = "var_x", var2 ="var_y")
hS_Dstar_gamma_m20_2D = ToHist2D(semiDstar_gamma_m20_rot_df, var1 = "var_x", var2 ="var_y")
hS_Dstar_gamma_m25_2D = ToHist2D(semiDstar_gamma_m25_rot_df, var1 = "var_x", var2 ="var_y")
hS_Dstar_gamma_m30_2D = ToHist2D(semiDstar_gamma_m30_rot_df, var1 = "var_x", var2 ="var_y")
hS_Dstar_gamma_m35_2D = ToHist2D(semiDstar_gamma_m35_rot_df, var1 = "var_x", var2 ="var_y")
hS_Dstar_gamma_m40_2D = ToHist2D(semiDstar_gamma_m40_rot_df, var1 = "var_x", var2 ="var_y")
hS_Dstar_gamma_m50_2D = ToHist2D(semiDstar_gamma_m50_rot_df, var1 = "var_x", var2 ="var_y")

hS_Dstar_pi0_m00_2D = ToHist2D(semiDstar_pi0_m00_rot_df, var1 = "var_x", var2 ="var_y")
hS_Dstar_pi0_m05_2D = ToHist2D(semiDstar_pi0_m05_rot_df, var1 = "var_x", var2 ="var_y")
hS_Dstar_pi0_m10_2D = ToHist2D(semiDstar_pi0_m10_rot_df, var1 = "var_x", var2 ="var_y")
hS_Dstar_pi0_m15_2D = ToHist2D(semiDstar_pi0_m15_rot_df, var1 = "var_x", var2 ="var_y")
hS_Dstar_pi0_m20_2D = ToHist2D(semiDstar_pi0_m20_rot_df, var1 = "var_x", var2 ="var_y")
hS_Dstar_pi0_m25_2D = ToHist2D(semiDstar_pi0_m25_rot_df, var1 = "var_x", var2 ="var_y")
hS_Dstar_pi0_m30_2D = ToHist2D(semiDstar_pi0_m30_rot_df, var1 = "var_x", var2 ="var_y")
hS_Dstar_pi0_m35_2D = ToHist2D(semiDstar_pi0_m35_rot_df, var1 = "var_x", var2 ="var_y")
hS_Dstar_pi0_m40_2D = ToHist2D(semiDstar_pi0_m40_rot_df, var1 = "var_x", var2 ="var_y")
hS_Dstar_pi0_m50_2D = ToHist2D(semiDstar_pi0_m50_rot_df, var1 = "var_x", var2 ="var_y")

hB_2D = ToHist2D(BkgStag_D_rot_df, var1 = "var_x", var2 ="var_y")
hB_Dstar_gamma_2D = ToHist2D(BkgStag_Dstar_gamma_rot_df, var1 = "var_x", var2 ="var_y")
hB_Dstar_pi0_2D = ToHist2D(BkgStag_Dstar_pi0_rot_df, var1 = "var_x", var2 ="var_y")
# Out:
# Warning in <TFile::Append>: Replacing existing TH1: 2D (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: 2D (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: 2D (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: 2D (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: 2D (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: 2D (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: 2D (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: 2D (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: 2D (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: 2D (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: 2D (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: 2D (Potential memory leak).
# ...

# %%
# Print bin contents for demonstration
for ix in range(1, hS_m00_2D.GetNbinsX() + 1):
    for iy in range(1, hS_m00_2D.GetNbinsY() + 1):
        bin_content = hS_m00_2D.GetBinContent(ix, iy)
        print(f"Bin ({ix}, {iy}): Label = {bin_content}")
# Out:
# Bin (1, 1): Label = 0.0
# Bin (1, 2): Label = 0.0
# Bin (1, 3): Label = 0.0
# Bin (1, 4): Label = 0.0
# Bin (1, 5): Label = 0.0
# Bin (1, 6): Label = 0.0
# Bin (1, 7): Label = 0.0
# Bin (1, 8): Label = 0.0
# Bin (1, 9): Label = 0.0
# Bin (1, 10): Label = 0.0
# Bin (1, 11): Label = 0.0
# Bin (1, 12): Label = 0.0
# Bin (1, 13): Label = 0.0
# Bin (1, 14): Label = 0.0
# Bin (1, 15): Label = 0.0
# Bin (1, 16): Label = 0.0
# Bin (1, 17): Label = 0.0
# Bin (1, 18): Label = 0.0
# Bin (1, 19): Label = 0.0
# Bin (1, 20): Label = 0.0
# Bin (1, 21): Label = 0.0
# Bin (1, 22): Label = 0.0
# Bin (1, 23): Label = 0.0
# Bin (1, 24): Label = 0.0
# Bin (1, 25): Label = 0.0
# Bin (1, 26): Label = 0.0
# Bin (1, 27): Label = 0.0
# Bin (1, 28): Label = 0.0
# Bin (1, 29): Label = 0.0
# Bin (1, 30): Label = 0.0
# Bin (1, 31): Label = 0.0
# Bin (1, 32): Label = 0.0
# Bin (1, 33): Label = 0.0
# Bin (1, 34): Label = 0.0
# Bin (1, 35): Label = 0.0
# Bin (1, 36): Label = 0.0
# Bin (1, 37): Label = 0.0
# ...

# %%
# Loop through the bins of the histogram
for ix in range(1, hS_m00_2D.GetNbinsX() + 1):
    for iy in range(1, hS_m00_2D.GetNbinsY() + 1):
        bin_content = hS_m00_2D.GetBinContent(ix, iy)
        if bin_content > 0:
            bin_label = hS_m00_2D.GetXaxis().GetBinLabel(ix)
            if bin_label == "Inside_Ellipse":
                print("Label 'Inside_Ellipse' found in histogram bins.")
            else :
                print("Label 'Inside_Ellipse' not found in histogram bins.")
                break
# Out:
# Label 'Inside_Ellipse' not found in histogram bins.
# Label 'Inside_Ellipse' not found in histogram bins.
# Label 'Inside_Ellipse' not found in histogram bins.
# Label 'Inside_Ellipse' not found in histogram bins.
# Label 'Inside_Ellipse' not found in histogram bins.
# Label 'Inside_Ellipse' not found in histogram bins.
# Label 'Inside_Ellipse' not found in histogram bins.
# Label 'Inside_Ellipse' not found in histogram bins.
# Label 'Inside_Ellipse' not found in histogram bins.
# Label 'Inside_Ellipse' not found in histogram bins.
# Label 'Inside_Ellipse' not found in histogram bins.
# Label 'Inside_Ellipse' not found in histogram bins.
# Label 'Inside_Ellipse' not found in histogram bins.
# Label 'Inside_Ellipse' not found in histogram bins.
# Label 'Inside_Ellipse' not found in histogram bins.
# Label 'Inside_Ellipse' not found in histogram bins.
# Label 'Inside_Ellipse' not found in histogram bins.
# Label 'Inside_Ellipse' not found in histogram bins.
# ...

# %% [markdown]
# hS_m00_2D = ToHist2D(df_SemilepTag_m00, var1 = "Mmin2", var2 ="Mmax2")
# hS_m05_2D = ToHist2D(df_SemilepTag_m05, var1 = "Mmin2", var2 ="Mmax2")
# hS_m10_2D = ToHist2D(df_SemilepTag_m10, var1 = "Mmin2", var2 ="Mmax2")
# hS_m15_2D = ToHist2D(df_SemilepTag_m15, var1 = "Mmin2", var2 ="Mmax2")
# hS_m20_2D = ToHist2D(df_SemilepTag_m20, var1 = "Mmin2", var2 ="Mmax2")
# hS_m25_2D = ToHist2D(df_SemilepTag_m25, var1 = "Mmin2", var2 ="Mmax2")
# hS_m30_2D = ToHist2D(df_SemilepTag_m30, var1 = "Mmin2", var2 ="Mmax2")
# hS_m35_2D = ToHist2D(df_SemilepTag_m35, var1 = "Mmin2", var2 ="Mmax2")
# hS_m40_2D = ToHist2D(df_SemilepTag_m40, var1 = "Mmin2", var2 ="Mmax2")
# hS_m45_2D = ToHist2D(df_SemilepTag_m45, var1 = "Mmin2", var2 ="Mmax2")
#
# hS_Dstar_gamma_m00_2D = ToHist2D(df_SemilepTag_Dstar_gamma_m00, var1 = "Mmin2", var2 ="Mmax2")
# hS_Dstar_gamma_m05_2D = ToHist2D(df_SemilepTag_Dstar_gamma_m05, var1 = "Mmin2", var2 ="Mmax2")
# hS_Dstar_gamma_m10_2D = ToHist2D(df_SemilepTag_Dstar_gamma_m10, var1 = "Mmin2", var2 ="Mmax2")
# hS_Dstar_gamma_m15_2D = ToHist2D(df_SemilepTag_Dstar_gamma_m15, var1 = "Mmin2", var2 ="Mmax2")
# hS_Dstar_gamma_m20_2D = ToHist2D(df_SemilepTag_Dstar_gamma_m20, var1 = "Mmin2", var2 ="Mmax2")
# hS_Dstar_gamma_m25_2D = ToHist2D(df_SemilepTag_Dstar_gamma_m25, var1 = "Mmin2", var2 ="Mmax2")
# hS_Dstar_gamma_m30_2D = ToHist2D(df_SemilepTag_Dstar_gamma_m30, var1 = "Mmin2", var2 ="Mmax2")
# hS_Dstar_gamma_m35_2D = ToHist2D(df_SemilepTag_Dstar_gamma_m35, var1 = "Mmin2", var2 ="Mmax2")
# hS_Dstar_gamma_m40_2D = ToHist2D(df_SemilepTag_Dstar_gamma_m40, var1 = "Mmin2", var2 ="Mmax2")
# hS_Dstar_gamma_m45_2D = ToHist2D(df_SemilepTag_Dstar_gamma_m45, var1 = "Mmin2", var2 ="Mmax2")
#
# hS_Dstar_pi0_m00_2D = ToHist2D(df_SemilepTag_Dstar_pi0_m00, var1 = "Mmin2", var2 ="Mmax2")
# hS_Dstar_pi0_m05_2D = ToHist2D(df_SemilepTag_Dstar_pi0_m05, var1 = "Mmin2", var2 ="Mmax2")
# hS_Dstar_pi0_m10_2D = ToHist2D(df_SemilepTag_Dstar_pi0_m10, var1 = "Mmin2", var2 ="Mmax2")
# hS_Dstar_pi0_m15_2D = ToHist2D(df_SemilepTag_Dstar_pi0_m15, var1 = "Mmin2", var2 ="Mmax2")
# hS_Dstar_pi0_m20_2D = ToHist2D(df_SemilepTag_Dstar_pi0_m20, var1 = "Mmin2", var2 ="Mmax2")
# hS_Dstar_pi0_m25_2D = ToHist2D(df_SemilepTag_Dstar_pi0_m25, var1 = "Mmin2", var2 ="Mmax2")
# hS_Dstar_pi0_m30_2D = ToHist2D(df_SemilepTag_Dstar_pi0_m30, var1 = "Mmin2", var2 ="Mmax2")
# hS_Dstar_pi0_m35_2D = ToHist2D(df_SemilepTag_Dstar_pi0_m35, var1 = "Mmin2", var2 ="Mmax2")
# hS_Dstar_pi0_m40_2D = ToHist2D(df_SemilepTag_Dstar_pi0_m40, var1 = "Mmin2", var2 ="Mmax2")
# hS_Dstar_pi0_m45_2D = ToHist2D(df_SemilepTag_Dstar_pi0_m45, var1 = "Mmin2", var2 ="Mmax2")
#
# hB_2D = ToHist2D(df_BkgStag_D, var1 = "Mmin2", var2 ="Mmax2")
# hB_Dstar_gamma_2D = ToHist2D(df_BkgStag_Dstar_gamma, var1 = "Mmin2", var2 ="Mmax2")
# hB_Dstar_pi0_2D = ToHist2D(df_BkgStag_Dstar_pi0, var1 = "Mmin2", var2 ="Mmax2")

# %% [markdown]
# X_min = -3.5
# X_max = 4
# Y_min = -1
# Y_max = 1
#
# nbinsX = 100
# nbinsY = 100
#
# # D tag
# hS_m00_2D = df_SemilepTag_m00_rot_RDF.Histo2D(("2D", "2D", nbinsX, X_min, X_max, nbinsY, Y_min, Y_max), "var_x", "var_y")
# #hS_m05_2D = df_SemilepTag_m05_rot_RDF.Histo2D(("2D", "2D", nbinsX, X_min, X_max, nbinsY, Y_min, Y_max), "var_x", "var_y")
# #hS_m10_2D = df_SemilepTag_m10_rot_RDF.Histo2D(("2D", "2D", nbinsX, X_min, X_max, nbinsY, Y_min, Y_max), "var_x", "var_y")
# #hS_m15_2D = df_SemilepTag_m15_rot_RDF.Histo2D((("2D", "2D", nbinsX, X_min, X_max, nbinsY, Y_min, Y_max), "var_x", "var_y")
# #hS_m20_2D = df_SemilepTag_m20_rot_RDF.Histo2D((("2D", "2D", nbinsX, X_min, X_max, nbinsY, Y_min, Y_max), "var_x", "var_y")
# #hS_m25_2D = df_SemilepTag_m25_rot_RDF.Histo2D((("2D", "2D", nbinsX, X_min, X_max, nbinsY, Y_min, Y_max), "var_x", "var_y")
# #hS_m30_2D = df_SemilepTag_m30_rot_RDF.Histo2D((("2D", "2D", nbinsX, X_min, X_max, nbinsY, Y_min, Y_max), "var_x", "var_y")
# #hS_m35_2D = df_SemilepTag_m35_rot_RDF.Histo2D((("2D", "2D", nbinsX, X_min, X_max, nbinsY, Y_min, Y_max), "var_x", "var_y")
# #hS_m40_2D = df_SemilepTag_m40_rot_RDF.Histo2D((("2D", "2D", nbinsX, X_min, X_max, nbinsY, Y_min, Y_max), "var_x", "var_y")
# #hS_m45_2D = df_SemilepTag_m45_rot_RDF.Histo2D((("2D", "2D", nbinsX, X_min, X_max, nbinsY, Y_min, Y_max), "var_x", "var_y")
# # D0star gamma tag
# hS_Dstar_gamma_m00_2D = df_SemilepTag_Dstar_gamma_m00_rot_RDF.Histo2D(("2D", "2D", nbinsX, X_min, X_max, nbinsY, Y_min, Y_max), "var_x", "var_y")
# #hS_Dstar_gamma_m10_2D = df_SemilepTag_Dstar_gamma_m10_RDF.Histo2D((("2D", "2D", nbinsX, X_min, X_max, nbinsY, Y_min, Y_max), "var_x", "var_y")
# #hS_Dstar_gamma_m20_2D = df_SemilepTag_Dstar_gamma_m20_RDF.Histo2D((("2D", "2D", nbinsX, X_min, X_max, nbinsY, Y_min, Y_max), "var_x", "var_y")
# #hS_Dstar_gamma_m30_2D = df_SemilepTag_Dstar_gamma_m30_RDF.Histo2D((("2D", "2D", nbinsX, X_min, X_max, nbinsY, Y_min, Y_max), "var_x", "var_y")
# #hS_Dstar_gamma_m40_2D = df_SemilepTag_Dstar_gamma_m40_RDF.Histo2D((("2D", "2D", nbinsX, X_min, X_max, nbinsY, Y_min, Y_max), "var_x", "var_y")
# #hS_Dstar_gamma_m45_2D = df_SemilepTag_Dstar_gamma_m45_RDF.Histo2D((("2D", "2D", nbinsX, X_min, X_max, nbinsY, Y_min, Y_max), "var_x", "var_y")
# # D0star pi0 tag
# hS_Dstar_pi0_m00_2D = df_SemilepTag_Dstar_pi0_m00_rot_RDF.Histo2D(("2D", "2D", nbinsX, X_min, X_max, nbinsY, Y_min, Y_max), "var_x", "var_y")
# #hS_Dstar_pi0_m10_2D = df_SemilepTag_Dstar_pi0_m10_RDF.Histo2D((("2D", "2D", nbinsX, X_min, X_max, nbinsY, Y_min, Y_max), "var_x", "var_y")
# #hS_Dstar_pi0_m20_2D = df_SemilepTag_Dstar_pi0_m20_RDF.Histo2D((("2D", "2D", nbinsX, X_min, X_max, nbinsY, Y_min, Y_max), "var_x", "var_y")
# #hS_Dstar_pi0_m30_2D = df_SemilepTag_Dstar_pi0_m30_RDF.Histo2D((("2D", "2D", nbinsX, X_min, X_max, nbinsY, Y_min, Y_max), "var_x", "var_y")
# #hS_Dstar_pi0_m40_2D = df_SemilepTag_Dstar_pi0_m40_RDF.Histo2D((("2D", "2D", nbinsX, X_min, X_max, nbinsY, Y_min, Y_max), "var_x", "var_y")
# #hS_Dstar_pi0_m50_2D = df_SemilepTag_Dstar_pi0_m45_RDF.Histo2D((("2D", "2D", nbinsX, X_min, X_max, nbinsY, Y_min, Y_max), "var_x", "var_y")
#
# # Background per tag
# hB_2D = df_BkgStag_D_rot_RDF.Histo2D(("2D", "2D", nbinsX, X_min, X_max, nbinsY, Y_min, Y_max), "var_x", "var_y")
#
# hB_Dstar_gamma_2D = df_BkgStag_Dstar_gamma_rot_RDF.Histo2D(("2D", "2D", nbinsX, X_min, X_max, nbinsY, Y_min, Y_max), "var_x", "var_y")
#
# hB_Dstar_pi0_2D = df_BkgStag_Dstar_pi0_rot_RDF.Histo2D(("2D", "2D", nbinsX, X_min, X_max, nbinsY, Y_min, Y_max), "var_x", "var_y")

# %%
# D tag
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m00_2D_ROT_pdf.root', 'RECREATE' )
hS_m00_2D.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m05_2D_ROT_pdf.root', 'RECREATE' )
hS_m05_2D.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m10_2D_ROT_pdf.root', 'RECREATE' )
hS_m10_2D.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m15_2D_ROT_pdf.root', 'RECREATE' )
hS_m15_2D.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m20_2D_ROT_pdf.root', 'RECREATE' )
hS_m20_2D.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m25_2D_ROT_pdf.root', 'RECREATE' )
hS_m25_2D.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m30_2D_ROT_pdf.root', 'RECREATE' )
hS_m30_2D.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m35_2D_ROT_pdf.root', 'RECREATE' )
hS_m35_2D.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m40_2D_ROT_pdf.root', 'RECREATE' )
hS_m40_2D.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m50_2D_ROT_pdf.root', 'RECREATE' )
hS_m50_2D.Write()
myfile.Close()

# %%
# D0star gamma tag
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m00_2D_ROT_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m00_2D.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m05_2D_ROT_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m05_2D.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m10_2D_ROT_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m10_2D.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m15_2D_ROT_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m15_2D.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m20_2D_ROT_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m20_2D.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m25_2D_ROT_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m25_2D.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m30_2D_ROT_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m30_2D.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m35_2D_ROT_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m35_2D.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m40_2D_ROT_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m40_2D.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m50_2D_ROT_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m50_2D.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m00_2D_ROT_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m00_2D.Write()
myfile.Close()

# %%
# D0star gamma tag
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m00_2D_ROT_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m00_2D.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m05_2D_ROT_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m05_2D.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m10_2D_ROT_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m10_2D.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m15_2D_ROT_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m15_2D.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m20_2D_ROT_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m20_2D.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m25_2D_ROT_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m25_2D.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m30_2D_ROT_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m30_2D.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m35_2D_ROT_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m35_2D.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m40_2D_ROT_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m40_2D.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m50_2D_ROT_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m50_2D.Write()
myfile.Close()

# %%
# Background
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgStag_D_2D_ROT_pdf.root', 'RECREATE' )
hB_2D.Write()
myfile.Close()

myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_gamma_2D_ROT_pdf.root', 'RECREATE' )
hB_Dstar_gamma_2D.Write()
myfile.Close()

myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_pi0_2D_ROT_pdf.root', 'RECREATE' )
hB_Dstar_pi0_2D.Write()
myfile.Close()

# %%
fSD_2D_m00 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m00_2D_ROT_pdf.root')

fSDstarGamma_2D_m00 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m00_2D_ROT_pdf.root')

fSDstarPi0_2D_m00 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m00_2D_ROT_pdf.root')

# %%
fBD_2D = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgStag_D_2D_ROT_pdf.root')

fBDstarGamma_2D = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_gamma_2D_ROT_pdf.root')

fBDstarPi0_2D = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_pi0_2D_ROT_pdf.root')

# %%
X_min = -5.5
X_max = 33.5
Y_min = -0.1
Y_max = 2.6

nbinsX = 100
nbinsY = 100

hS_m00_2D_pdf = ROOT.TH2D('hS_m00_2D_pdf','hS_m00_2D_pdf' , nbinsX, X_min, X_max, nbinsY, Y_min, Y_max)
hS_m00_2D_pdf = fSD_2D_m00.Get("2D")

hS_Dstar_gamma_m00_2D_pdf = ROOT.TH2D('hS_Dstar_gamma_m00_2D_pdf','hS_Dstar_gamma_m00_2D_pdf' , nbinsX, X_min, X_max, nbinsY, Y_min, Y_max)
hS_Dstar_gamma_m00_2D_pdf = fSDstarGamma_2D_m00.Get("2D")

hS_Dstar_pi0_m00_2D_pdf = ROOT.TH2D('hS_Dstar_pi0_m00_2D_pdf','hS_Dstar_pi0_m00_2D_pdf' , nbinsX, X_min, X_max, nbinsY, Y_min, Y_max)
hS_Dstar_pi0_m00_2D_pdf = fSDstarPi0_2D_m00.Get("2D")

# %%
hB_2D_pdf = ROOT.TH2D('hB_2D_pdf','hB_2D_pdf' , nbinsX, X_min, X_max, nbinsY, Y_min, Y_max)
hB_2D_pdf = fBD_2D.Get("2D")

hB_Dstar_gamma_2D_pdf = ROOT.TH2D('hB_Dstar_gamma_2D_pdf','hB_Dstar_gamma_2D_pdf' , nbinsX, X_min, X_max, nbinsY, Y_min, Y_max)
hB_Dstar_gamma_2D_pdf = fBDstarGamma_2D.Get("2D")

hB_Dstar_pi0_2D_pdf = ROOT.TH2D('hB_Dstar_pi0_2D_pdf','hB_Dstar_pi0_2D_pdf' , nbinsX, X_min, X_max, nbinsY, Y_min, Y_max)
hB_Dstar_pi0_2D_pdf = fBDstarPi0_2D.Get("2D")

# %%
c1 = ROOT.TCanvas("c1","c1",2000,800)

c1.Divide(4)
c1.cd(1)
hS_m00_2D_pdf.Draw("CONTZ")
c1.cd(2)
hB_2D_pdf.Draw("CONTZ")
c1.cd(3)
hS_Dstar_gamma_m00_2D_pdf.Draw("CONTZ")
c1.cd(4)
hB_Dstar_gamma_2D_pdf.Draw("CONTZ")
c1.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1

# %%
def plot_data_inside_ellipse_with_label(histogram, ellipse_params):
    center_x, center_y, ellipse_width, ellipse_height, ellipse_angle = ellipse_params
    
    # Create a canvas
    c2 = ROOT.TCanvas("c2", "c2", 2000, 800)
    c2.Divide(4)
    
    # Draw each histogram
    histograms = [hS_m00_2D_pdf, hB_2D_pdf, hS_Dstar_gamma_m00_2D_pdf, hB_Dstar_gamma_2D_pdf]
    
    for i, hist in enumerate(histograms, start=1):
        c2.cd(i)
        hist.Draw("COLZ")
    
        # Iterate over each bin and set the content based on the label
        for bin_x in range(1, hist.GetNbinsX() + 1):
            for bin_y in range(1, hist.GetNbinsY() + 1):
                x = hist.GetXaxis().GetBinCenter(bin_x)
                y = hist.GetYaxis().GetBinCenter(bin_y)
                label = get_label(x, y, center_x, center_y, ellipse_width, ellipse_height, ellipse_angle)
                if label == 1:  # Inside the ellipse
                    hist.SetBinContent(bin_x, bin_y, hist.GetBinContent(bin_x, bin_y))
                else:  # Outside the ellipse
                    hist.SetBinContent(bin_x, bin_y, 0)
    
    c2.Draw()

        # Save the plot as an image file
    c2.SaveAs("2D_Distribution_Plot_Inside.png")

    # Close the canvas to release memory
    c2.Close()

    # Display the saved image
    return Image(filename="2D_Distribution_Plot_Inside.png")

# Define a function to check if a point is inside the ellipse
def is_point_inside_ellipse(x, y, center_x, center_y, width, height, angle):
    cos_angle = np.cos(np.radians(angle))
    sin_angle = np.sin(np.radians(angle))
    dx = x - center_x
    dy = y - center_y
    rotated_x = cos_angle * dx + sin_angle * dy
    rotated_y = -sin_angle * dx + cos_angle * dy
    return (rotated_x / width) ** 2 + (rotated_y / height) ** 2 <= 1

# Define a function to get the label for a point based on whether it's inside or outside the ellipse
def get_label(x, y, center_x, center_y, width, height, angle):
    if is_point_inside_ellipse(x, y, center_x, center_y, width, height, angle):
        return 1  # Inside the ellipse
    else:
        return 0  # Outside the ellipse

# Assuming you have the ellipse parameters already calculated
ellipse_params = [center_x, center_y, ellipse_width, ellipse_height, ellipse_angle]

# Plot the histograms with the data inside the ellipse
plot_data_inside_ellipse_with_label(hS_m00_2D_pdf, ellipse_params)
# Out:
# Info in <TCanvas::Print>: png file 2D_Distribution_Plot_Inside.png has been created

# %%
plot_data_inside_ellipse_with_label(hS_Dstar_gamma_m00_2D_pdf, ellipse_params)
# Out:
# Info in <TCanvas::Print>: png file 2D_Distribution_Plot_Inside.png has been created

# %%
def plot_data_inside_ellipse_with_label(histogram1,histogram2,histogram3,histogram4):
    # Create a canvas
    c2 = ROOT.TCanvas("c2", "c2", 2000, 800)
    c2.Divide(4)
    
    # Draw each histogram
    histograms = [histogram1, histogram2, histogram3, histogram4]
    
    for i, hist in enumerate(histograms, start=2):
        c2.cd(i)
        hist.Draw("COLZ")
    
        # Iterate over each bin and set the content based on the label
        for bin_x in range(2, hist.GetNbinsX() + 2):
            for bin_y in range(2, hist.GetNbinsY() + 2):
                label = hist.GetBinContent(bin_x, bin_y)
                if label == 0:  # Outside the ellipse
                    hist.SetBinContent(bin_x, bin_y, 0)
    
    c2.Draw()

    # Save the plot as an image file
    c2.SaveAs("2D_Distribution_Plot_Inside.png")

    # Close the canvas to release memory
    c2.Close()

    # Display the saved image
    return Image(filename="2D_Distribution_Plot_Inside.png")

# Plot the histograms with the data inside the ellipse
plot_data_inside_ellipse_with_label(hS_m00_2D_pdf, hB_2D_pdf, hS_Dstar_gamma_m00_2D_pdf, hB_Dstar_gamma_2D_pdf)
# Out:
# Info in <TCanvas::Print>: png file 2D_Distribution_Plot_Inside.png has been created
