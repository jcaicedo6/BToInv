# %%
import ROOT
import numpy as np
import pandas as pd
import random
from functions.loadRDataFrame import RDF_to_pandas

import matplotlib.pyplot as plt
import time
import math, copy

# %%
df_HadronicTag_m00 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_m00_wc.csv')
df_HadronicTag_m10 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_m10_wc.csv')
df_HadronicTag_m20 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_m20_wc.csv')
df_HadronicTag_m30 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_m30_wc.csv')
df_HadronicTag_m40 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_m40_wc.csv')
df_HadronicTag_m50 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_m50_wc.csv')

df_HadronicTag_Dstar_gamma_m00 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m00_wc.csv')
df_HadronicTag_Dstar_gamma_m10 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m10_wc.csv')
df_HadronicTag_Dstar_gamma_m20 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m20_wc.csv')
df_HadronicTag_Dstar_gamma_m30 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m30_wc.csv')
df_HadronicTag_Dstar_gamma_m40 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m40_wc.csv')
df_HadronicTag_Dstar_gamma_m50 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m50_wc.csv')

df_HadronicTag_Dstar_pi0_m00 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m00_wc.csv')
df_HadronicTag_Dstar_pi0_m10 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m10_wc.csv')
df_HadronicTag_Dstar_pi0_m20 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m20_wc.csv')
df_HadronicTag_Dstar_pi0_m30 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m30_wc.csv')
df_HadronicTag_Dstar_pi0_m40 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m40_wc.csv')
df_HadronicTag_Dstar_pi0_m50 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m50_wc.csv')

df_SemilepTag_m00 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_m00_wc.csv')
df_SemilepTag_m10 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_m10_wc.csv')
df_SemilepTag_m20 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_m20_wc.csv')
df_SemilepTag_m30 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_m30_wc.csv')
df_SemilepTag_m40 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_m40_wc.csv')
df_SemilepTag_m50 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_m50_wc.csv')

df_SemilepTag_Dstar_gamma_m00 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m00_wc.csv')
df_SemilepTag_Dstar_gamma_m10 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m10_wc.csv')
df_SemilepTag_Dstar_gamma_m20 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m20_wc.csv')
df_SemilepTag_Dstar_gamma_m30 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m30_wc.csv')
df_SemilepTag_Dstar_gamma_m40 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m40_wc.csv')
df_SemilepTag_Dstar_gamma_m50 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m50_wc.csv')

df_SemilepTag_Dstar_pi0_m00 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_m00_wc.csv')
df_SemilepTag_Dstar_pi0_m10 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_m10_wc.csv')
df_SemilepTag_Dstar_pi0_m20 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_m20_wc.csv')
df_SemilepTag_Dstar_pi0_m30 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_m30_wc.csv')
df_SemilepTag_Dstar_pi0_m40 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_m40_wc.csv')
df_SemilepTag_Dstar_pi0_m50 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_m50_wc.csv')

df_BkgHtag_D = pd.read_csv('../Analysis/Files/CSV_Files/BkgHtag_D_wc.csv')
df_BkgHtad_Dstar_gamma = pd.read_csv('../Analysis/Files/CSV_Files/BkgHtag_Dstar_gamma_wc.csv')
df_BkgHtad_Dstar_pi0 = pd.read_csv('../Analysis/Files/CSV_Files/BkgHtag_Dstar_pi0_wc.csv')

df_BkgStag_D = pd.read_csv('../Analysis/Files/CSV_Files/BkgStag_D_wc.csv')
df_BkgStag_Dstar_gamma = pd.read_csv('../Analysis/Files/CSV_Files/BkgStag_Dstar_gamma_wc.csv')
df_BkgStag_Dstar_pi0 = pd.read_csv('../Analysis/Files/CSV_Files/BkgStag_Dstar_pi0_wc.csv')

#df_topoana_SemilepTagD = pd.read_csv('../Analysis/Files/CSV_Files/topoana_SemilepTagD_wc.csv')

# %% [markdown]
# # let's resampling the signal data frames, in order to do a comparable comparison
# #fraction = 0.03
# fraction = 1
# df_SemilepTag_m00 = df_SemilepTag_m00_1.sample(frac=fraction, random_state=1)
# df_SemilepTag_m10 = df_SemilepTag_m10_1.sample(frac=fraction, random_state=1)
# df_SemilepTag_m20 = df_SemilepTag_m20_1.sample(frac=fraction, random_state=1)
# df_SemilepTag_m30 = df_SemilepTag_m30_1.sample(frac=fraction, random_state=1)
# df_SemilepTag_m40 = df_SemilepTag_m40_1.sample(frac=fraction, random_state=1)
# df_SemilepTag_m50 = df_SemilepTag_m50_1.sample(frac=fraction, random_state=1)

# %%
print(len(df_SemilepTag_m00))
print(len(df_SemilepTag_m10))
print(len(df_SemilepTag_m20))
print(len(df_SemilepTag_m30))
print(len(df_SemilepTag_m40))
print(len(df_SemilepTag_m50))
print("--------------------")

#print(len(pi_taunu_HadronicTag_wc_df))
print(len(df_BkgStag_D))
#print(len(pi_nunu_HadronicTag_wc_df))
print(len(df_BkgStag_Dstar_pi0))
print("--------------------")
# Out:
# 95883
# 96735
# 96784
# 96164
# 91141
# 88424
# --------------------
# 44571
# 42795
# --------------------

# %%
print(len(df_BkgStag_Dstar_pi0[df_BkgStag_Dstar_pi0["Mmin2"]!=1000]))
print(len(df_BkgStag_D[df_BkgStag_D["Mmin2"]==1000]))
print(len(df_BkgStag_Dstar_gamma[df_BkgStag_Dstar_gamma["Mmax2"]==1000]))
# Out:
# 39403
# 3503
# 1176

# %%
print(len(df_SemilepTag_m00[df_SemilepTag_m00["Mmin2"]!=1000]))
print(len(df_SemilepTag_m00[df_SemilepTag_m00["Mmax2"]==1000]))
# Out:
# 89565
# 6318

# %%
df_BkgStag_D
# Out:
#        Unnamed: 0  nEta  nEtaPrime  nTracks_  track_sig_genMotherPDG  \
# 0           33804   0.0        0.0       4.0                  -521.0
# 1           11256   0.0        0.0       4.0                   -15.0
# 2           33534   0.0        0.0       6.0                 -1114.0
# 3           23461   0.0        0.0       6.0                   521.0
# 4           11581   0.0        0.0       6.0                   323.0
# ...           ...   ...        ...       ...                     ...
# 44566       59590   0.0        0.0       6.0                -10411.0
# 44567       42454   0.0        0.0       6.0                 10411.0
# 44568       55319   0.0        0.0       6.0                 10411.0
# 44569       46849   0.0        0.0       6.0                -10411.0
# 44570       58480   0.0        0.0       6.0                 10411.0
#
#        track_tag_genMotherPDG  pi_tag_genMotherPDG  D_tag_M   B_tag_M  \
# ...

# %%
df_SemilepTag_m00 = pd.concat([df_SemilepTag_m00, df_SemilepTag_Dstar_gamma_m00, df_SemilepTag_Dstar_pi0_m00])
df_SemilepTag_m10 = pd.concat([df_SemilepTag_m10, df_SemilepTag_Dstar_gamma_m10, df_SemilepTag_Dstar_pi0_m10])
df_SemilepTag_m20 = pd.concat([df_SemilepTag_m20, df_SemilepTag_Dstar_gamma_m20, df_SemilepTag_Dstar_pi0_m20])
df_SemilepTag_m30 = pd.concat([df_SemilepTag_m30, df_SemilepTag_Dstar_gamma_m30, df_SemilepTag_Dstar_pi0_m30])
df_SemilepTag_m40 = pd.concat([df_SemilepTag_m40, df_SemilepTag_Dstar_gamma_m40, df_SemilepTag_Dstar_pi0_m40])
df_SemilepTag_m50 = pd.concat([df_SemilepTag_m50, df_SemilepTag_Dstar_gamma_m50, df_SemilepTag_Dstar_pi0_m50])

df_HadronicTag_m00 = pd.concat([df_HadronicTag_m00, df_HadronicTag_Dstar_gamma_m00, df_HadronicTag_Dstar_pi0_m00])
df_HadronicTag_m10 = pd.concat([df_HadronicTag_m10, df_HadronicTag_Dstar_gamma_m10, df_HadronicTag_Dstar_pi0_m00])
df_HadronicTag_m20 = pd.concat([df_HadronicTag_m20, df_HadronicTag_Dstar_gamma_m20, df_HadronicTag_Dstar_pi0_m00])
df_HadronicTag_m30 = pd.concat([df_HadronicTag_m30, df_HadronicTag_Dstar_gamma_m30, df_HadronicTag_Dstar_pi0_m00])
df_HadronicTag_m40 = pd.concat([df_HadronicTag_m40, df_HadronicTag_Dstar_gamma_m40, df_HadronicTag_Dstar_pi0_m00])
df_HadronicTag_m50 = pd.concat([df_HadronicTag_m50, df_HadronicTag_Dstar_gamma_m50, df_HadronicTag_Dstar_pi0_m00])

# %%
plt.figure(figsize=(10, 8.5))
# Datos con pandas
SemilepTag_m00_Mmin = df_SemilepTag_m00["Mmin2"]
SemilepTag_m00_Mmax = df_SemilepTag_m00["Mmax2"]
#hcheeee = df_SemilepTag_m10["Mmin2"]
#hchmumu = df_SemilepTag_m10["MMin2"]
# Dato cargado con ROOT
# Se reescala la señal de ruido ee dado que es muy grande y no se alcanzaría a ver su influencia sobre la señal
# principal
#hchee_w = np.empty(cheeInvMass.shape)
#hchee_w.fill(1/cheeInvMass.shape[0])
# unificamos los ruidos eeee y mumu en uno solo dado que su influencia es similar
#hchotrosbkg = np.concatenate((hcheeee, hchmumu)) 
# se aplican los histogramas con distintas modificaciones para poder analizar diferencias
plt.hist(SemilepTag_m00_Mmin, 80 , label = "Mmin", range = (-20, 10.0), linestyle = 'dashed', histtype = 'step', linewidth = 2, facecolor = '#2CBDFE', lw = 2, edgecolor = 'b')
plt.hist(SemilepTag_m00_Mmax, 80,  label = 'Mmax', range = (-20., 10.0), histtype = 'step', hatch = '\\', facecolor = 'k', linewidth = 2)
#plt.hist(hchtaupair, 80, label = 'taupair background', range = (0., 2.0), histtype = 'step', linewidth = 2, hatch= '////', lw = 2)
#plt.hist(cheeInvMass, 80, weights = hchee_w*260000, label = r'e$\bar{e}$ background', range = (0., 2.0), histtype = 'step', linewidth = 2, lw = 2, linestyle = 'dashed')


plt.xlabel("$M_{min}^2$ and $M_{max}^2$ $[GeV/\mathrm{c}^2]^2$",fontsize = 20)
plt.ylabel(r"N. Events / (0.025 GeV/$\mathrm{c}^2$)",fontsize = 20)
plt.title(r"$M_{min}^2$ and $M_{max}^2$ distribution - $M_{\chi}=0.0$")
plt.legend(loc='upper right')
plt.grid()
#plt.savefig('SignalofMass.png')
plt.show()

# %%
plt.figure(figsize=(10, 8.5))
# Datos con pandas
SemilepTag_m10_Mmin = df_SemilepTag_m10["Mmin2"]
SemilepTag_m10_Mmax = df_SemilepTag_m10["Mmax2"]
#hcheeee = df_SemilepTag_m10["Mmin2"]
#hchmumu = df_SemilepTag_m10["MMin2"]
# Dato cargado con ROOT
# Se reescala la señal de ruido ee dado que es muy grande y no se alcanzaría a ver su influencia sobre la señal
# principal
#hchee_w = np.empty(cheeInvMass.shape)
#hchee_w.fill(1/cheeInvMass.shape[0])
# unificamos los ruidos eeee y mumu en uno solo dado que su influencia es similar
#hchotrosbkg = np.concatenate((hcheeee, hchmumu)) 
# se aplican los histogramas con distintas modificaciones para poder analizar diferencias
plt.hist(SemilepTag_m10_Mmin, 80 , label = "Mmin", range = (-20, 10.0), linestyle = 'dashed', histtype = 'step', linewidth = 2, facecolor = '#2CBDFE', lw = 2, edgecolor = 'b')
plt.hist(SemilepTag_m10_Mmax, 80,  label = 'Mmax', range = (-20., 10.0), histtype = 'step', hatch = '\\', facecolor = 'k', linewidth = 2)
#plt.hist(hchtaupair, 80, label = 'taupair background', range = (0., 2.0), histtype = 'step', linewidth = 2, hatch= '////', lw = 2)
#plt.hist(cheeInvMass, 80, weights = hchee_w*260000, label = r'e$\bar{e}$ background', range = (0., 2.0), histtype = 'step', linewidth = 2, lw = 2, linestyle = 'dashed')


plt.xlabel("$M_{min}^2$ and $M_{max}^2$ $[GeV/\mathrm{c}^2]^2$",fontsize = 20)
plt.ylabel(r"N. Events / (0.025 GeV/$\mathrm{c}^2$)",fontsize = 20)
plt.title(r"$M_{min}^2$ and $M_{max}^2$ distribution - $M_{\chi}=1.0$")
plt.legend(loc='upper right')
plt.grid()
#plt.savefig('SignalofMass.png')
plt.show()

# %%
plt.figure(figsize=(10, 8.5))
# Datos con pandas
SemilepTag_m20_Mmin = df_SemilepTag_m20["Mmin2"]
SemilepTag_m20_Mmax = df_SemilepTag_m20["Mmax2"]
#hcheeee = df_SemilepTag_m10["Mmin2"]
#hchmumu = df_SemilepTag_m10["MMin2"]
# Dato cargado con ROOT
# Se reescala la señal de ruido ee dado que es muy grande y no se alcanzaría a ver su influencia sobre la señal
# principal
#hchee_w = np.empty(cheeInvMass.shape)
#hchee_w.fill(1/cheeInvMass.shape[0])
# unificamos los ruidos eeee y mumu en uno solo dado que su influencia es similar
#hchotrosbkg = np.concatenate((hcheeee, hchmumu)) 
# se aplican los histogramas con distintas modificaciones para poder analizar diferencias
plt.hist(SemilepTag_m20_Mmin, 80 , label = "Mmin", range = (-20, 15.0), linestyle = 'dashed', histtype = 'step', linewidth = 2, facecolor = '#2CBDFE', lw = 2, edgecolor = 'b')
plt.hist(SemilepTag_m20_Mmax, 80,  label = 'Mmax', range = (-20., 15.0), histtype = 'step', hatch = '\\', facecolor = 'k', linewidth = 2)
#plt.hist(hchtaupair, 80, label = 'taupair background', range = (0., 2.0), histtype = 'step', linewidth = 2, hatch= '////', lw = 2)
#plt.hist(cheeInvMass, 80, weights = hchee_w*260000, label = r'e$\bar{e}$ background', range = (0., 2.0), histtype = 'step', linewidth = 2, lw = 2, linestyle = 'dashed')


plt.xlabel("$M_{min}^2$ and $M_{max}^2$ $[GeV/\mathrm{c}^2]^2$",fontsize = 20)
plt.ylabel(r"N. Events / (0.025 GeV/$\mathrm{c}^2$)",fontsize = 20)
plt.title(r"$M_{min}^2$ and $M_{max}^2$ distribution - $M_{\chi}=2.0$")
plt.legend(loc='upper right')
plt.grid()
#plt.savefig('SignalofMass.png')
plt.show()

# %%
plt.figure(figsize=(10, 8.5))
# Datos con pandas
SemilepTag_m30_Mmin = df_SemilepTag_m30["Mmin2"]
SemilepTag_m30_Mmax = df_SemilepTag_m30["Mmax2"]
#hcheeee = df_SemilepTag_m10["Mmin2"]
#hchmumu = df_SemilepTag_m10["MMin2"]
# Dato cargado con ROOT
# Se reescala la señal de ruido ee dado que es muy grande y no se alcanzaría a ver su influencia sobre la señal
# principal
#hchee_w = np.empty(cheeInvMass.shape)
#hchee_w.fill(1/cheeInvMass.shape[0])
# unificamos los ruidos eeee y mumu en uno solo dado que su influencia es similar
#hchotrosbkg = np.concatenate((hcheeee, hchmumu)) 
# se aplican los histogramas con distintas modificaciones para poder analizar diferencias
plt.hist(SemilepTag_m30_Mmin, 80 , label = "Mmin", range = (-20, 18.0), linestyle = 'dashed', histtype = 'step', linewidth = 2, facecolor = '#2CBDFE', lw = 2, edgecolor = 'b')
plt.hist(SemilepTag_m30_Mmax, 80,  label = 'Mmax', range = (-20., 18.0), histtype = 'step', hatch = '\\', facecolor = 'k', linewidth = 2)
#plt.hist(hchtaupair, 80, label = 'taupair background', range = (0., 2.0), histtype = 'step', linewidth = 2, hatch= '////', lw = 2)
#plt.hist(cheeInvMass, 80, weights = hchee_w*260000, label = r'e$\bar{e}$ background', range = (0., 2.0), histtype = 'step', linewidth = 2, lw = 2, linestyle = 'dashed')


plt.xlabel("$M_{min}^2$ and $M_{max}^2$ $[GeV/\mathrm{c}^2]^2$",fontsize = 20)
plt.ylabel(r"N. Events / (0.025 GeV/$\mathrm{c}^2$)",fontsize = 20)
plt.title(r"$M_{min}^2$ and $M_{max}^2$ distribution - $M_{\chi}=3.0$")
plt.legend(loc='upper right')
plt.grid()
#plt.savefig('SignalofMass.png')
plt.show()

# %%
plt.figure(figsize=(10, 8.5))
# Datos con pandas
SemilepTag_m40_Mmin = df_SemilepTag_m40["Mmin2"]
SemilepTag_m40_Mmax = df_SemilepTag_m40["Mmax2"]
#hcheeee = df_SemilepTag_m10["Mmin2"]
#hchmumu = df_SemilepTag_m10["MMin2"]
# Dato cargado con ROOT
# Se reescala la señal de ruido ee dado que es muy grande y no se alcanzaría a ver su influencia sobre la señal
# principal
#hchee_w = np.empty(cheeInvMass.shape)
#hchee_w.fill(1/cheeInvMass.shape[0])
# unificamos los ruidos eeee y mumu en uno solo dado que su influencia es similar
#hchotrosbkg = np.concatenate((hcheeee, hchmumu)) 
# se aplican los histogramas con distintas modificaciones para poder analizar diferencias
plt.hist(SemilepTag_m40_Mmin, 80 , label = "Mmin", range = (-20, 20.0), linestyle = 'dashed', histtype = 'step', linewidth = 2, facecolor = '#2CBDFE', lw = 2, edgecolor = 'b')
plt.hist(SemilepTag_m40_Mmax, 80,  label = 'Mmax', range = (-20, 20.0), histtype = 'step', hatch = '\\', facecolor = 'k', linewidth = 2)
#plt.hist(hchtaupair, 80, label = 'taupair background', range = (0., 2.0), histtype = 'step', linewidth = 2, hatch= '////', lw = 2)
#plt.hist(cheeInvMass, 80, weights = hchee_w*260000, label = r'e$\bar{e}$ background', range = (0., 2.0), histtype = 'step', linewidth = 2, lw = 2, linestyle = 'dashed')


plt.xlabel("$M_{min}^2$ and $M_{max}^2$ $[GeV/\mathrm{c}^2]^2$",fontsize = 20)
plt.ylabel(r"N. Events / (0.025 GeV/$\mathrm{c}^2$)",fontsize = 20)
plt.title(r"$M_{min}^2$ and $M_{max}^2$ distribution - $M_{\chi}=4.0$")
plt.legend(loc='upper right')
plt.grid()
#plt.savefig('SignalofMass.png')
plt.show()

# %%
plt.figure(figsize=(10, 8.5))
# Datos con pandas
SemilepTag_m50_Mmin = df_SemilepTag_m50["Mmin2"]
SemilepTag_m50_Mmax = df_SemilepTag_m50["Mmax2"]
#hcheeee = df_SemilepTag_m10["Mmin2"]
#hchmumu = df_SemilepTag_m10["MMin2"]
# Dato cargado con ROOT
# Se reescala la señal de ruido ee dado que es muy grande y no se alcanzaría a ver su influencia sobre la señal
# principal
#hchee_w = np.empty(cheeInvMass.shape)
#hchee_w.fill(1/cheeInvMass.shape[0])
# unificamos los ruidos eeee y mumu en uno solo dado que su influencia es similar
#hchotrosbkg = np.concatenate((hcheeee, hchmumu)) 
# se aplican los histogramas con distintas modificaciones para poder analizar diferencias
plt.hist(SemilepTag_m50_Mmin, 80 , label = "Mmin", range = (-20, 26.0), linestyle = 'dashed', histtype = 'step', linewidth = 2, facecolor = '#2CBDFE', lw = 2, edgecolor = 'b')
plt.hist(SemilepTag_m50_Mmax, 80,  label = 'Mmax', range = (-20, 26.0), histtype = 'step', hatch = '\\', facecolor = 'k', linewidth = 2)
#plt.hist(hchtaupair, 80, label = 'taupair background', range = (0., 2.0), histtype = 'step', linewidth = 2, hatch= '////', lw = 2)
#plt.hist(cheeInvMass, 80, weights = hchee_w*260000, label = r'e$\bar{e}$ background', range = (0., 2.0), histtype = 'step', linewidth = 2, lw = 2, linestyle = 'dashed')


plt.xlabel("$M_{min}^2$ and $M_{max}^2$ $[GeV/\mathrm{c}^2]^2$",fontsize = 20)
plt.ylabel(r"N. Events / (0.025 GeV/$\mathrm{c}^2$)",fontsize = 20)
plt.title(r"$M_{min}^2$ and $M_{max}^2$ distribution - $M_{\chi}=5.0$")
plt.legend(loc='upper right')
plt.grid()
#plt.savefig('SignalofMass.png')
plt.show()

# %%
plt.figure(figsize=(10, 8.5))
plt.rcParams['text.usetex'] = True
# Datos con pandas
SemilepTag_m00_Mmin = df_SemilepTag_m00["Mmin2"]
SemilepTag_m10_Mmin = df_SemilepTag_m10["Mmin2"]
SemilepTag_m20_Mmin = df_SemilepTag_m20["Mmin2"]
SemilepTag_m30_Mmin = df_SemilepTag_m30["Mmin2"]
SemilepTag_m40_Mmin = df_SemilepTag_m40["Mmin2"]
SemilepTag_m50_Mmin = df_SemilepTag_m50["Mmin2"]
BkgStag_D = df_BkgStag_D["Mmin2"]
#BkgStag_Dstar_gamma = df_BkgStag_Dstar_gamma["Mmin2"]
#BkgStag_Dstar_pi0 = df_BkgStag_Dstar_pi0["Mmin2"]

# Dato cargado con ROOT
# Se reescala la señal de ruido ee dado que es muy grande y no se alcanzaría a ver su influencia sobre la señal
# principal
#hchee_w = np.empty(cheeInvMass.shape)
#hchee_w.fill(1/cheeInvMass.shape[0])
# unificamos los ruidos eeee y mumu en uno solo dado que su influencia es similar
#hchotrosbkg = np.concatenate((hcheeee, hchmumu)) 
# se aplican los histogramas con distintas modificaciones para poder analizar diferencias
plt.hist(SemilepTag_m00_Mmin, 100 , label = r'$B \to \pi \chi (M_{\chi} = 0.0)$', range = (-6, 27), 
         histtype = 'step', facecolor = '#2CBDFE', lw = 1.5, edgecolor = 'b', hatch= '////', linestyle = 'dashed')
plt.hist(SemilepTag_m10_Mmin, 100 , label = r'$B \to \pi \chi (M_{\chi} = 1.0)$', range = (-6, 27), 
         histtype = 'step', facecolor = '#2CBDFE', lw = 1.5, edgecolor = 'darkorange', hatch = '\\', linestyle = 'dashed')
plt.hist(SemilepTag_m20_Mmin, 100,  label = r'$B \to \pi \chi (M_{\chi} = 2.0)$', range = (-6, 27), histtype = 'step', 
         facecolor = 'k', linewidth = 1.5,  hatch= '////', linestyle = 'dashed')
plt.hist(SemilepTag_m30_Mmin, 100,  label = r'$B \to \pi \chi (M_{\chi} = 3.0)$', range = (-6, 27), histtype = 'step', 
         facecolor = 'k', linewidth = 1.5,  hatch = '\\', linestyle = 'dashed')
plt.hist(SemilepTag_m40_Mmin, 100,  label = r'$B \to \pi \chi (M_{\chi} = 4.0)$', range = (-6, 27), histtype = 'step', 
         facecolor = 'k', linewidth = 1.5, hatch= '////', linestyle = 'dashed')
plt.hist(SemilepTag_m50_Mmin, 100,  label = r'$B \to \pi \chi (M_{\chi} = 5.0)$', range = (-6, 27), histtype = 'step', 
         facecolor = 'k', linewidth = 1.5, hatch = '\\', linestyle = 'dashed')
plt.hist(BkgStag_D, 100, label = r'$Bkg$', range = (-5, 27), 
         histtype = 'step', linewidth = 1.5)
#plt.hist(pi_nunu, 100,  label = r'$B \to \pi\nu\nu$', range = (-5, 27), 
 #        histtype = 'step', linewidth = 1.5, facecolor = 'k')


plt.xlabel(r"$M_{min}^2$  $[GeV/\mathrm{c}^2]^2$",fontsize = 20)
plt.ylabel("Counts",fontsize = 20)
plt.title(r"$M_{min}^2$ distribution")
plt.legend(loc='upper right')
#plt.grid()
#plt.savefig('SignalofMass.png')
plt.show()

# %%
plt.figure(figsize=(10, 8.5))
# Datos con pandas
SemilepTag_m00_Mmin = df_SemilepTag_m00["Mmax2"]
SemilepTag_m10_Mmin = df_SemilepTag_m10["Mmax2"]
SemilepTag_m20_Mmin = df_SemilepTag_m20["Mmax2"]
SemilepTag_m30_Mmin = df_SemilepTag_m30["Mmax2"]
SemilepTag_m40_Mmin = df_SemilepTag_m40["Mmax2"]
SemilepTag_m50_Mmin = df_SemilepTag_m50["Mmax2"]
BkgStag_D = df_BkgStag_D["Mmax2"]
# Dato cargado con ROOT
# Se reescala la señal de ruido ee dado que es muy grande y no se alcanzaría a ver su influencia sobre la señal
# principal
#hchee_w = np.empty(cheeInvMass.shape)
#hchee_w.fill(1/cheeInvMass.shape[0])
# unificamos los ruidos eeee y mumu en uno solo dado que su influencia es similar
#hchotrosbkg = np.concatenate((hcheeee, hchmumu)) 
# se aplican los histogramas con distintas modificaciones para poder analizar diferencias
plt.hist(SemilepTag_m00_Mmin, 100 , label = r'$B \to \pi \chi (M_{\chi} = 0.0)$', range = (-6, 27), 
         histtype = 'step', linewidth = 1.5, facecolor = '#2CBDFE', edgecolor = 'b', hatch= '////', linestyle = 'dashed')
plt.hist(SemilepTag_m10_Mmin, 100 , label = r'$B \to \pi \chi (M_{\chi} = 1.0)$', range = (-6, 27), 
         histtype = 'step', linewidth = 1.5, facecolor = '#2CBDFE', edgecolor = 'darkorange', hatch = '\\', linestyle = 'dashed')
plt.hist(SemilepTag_m20_Mmin, 100,  label = r'$B \to \pi \chi (M_{\chi} = 2.0)$', range = (-6, 27), histtype = 'step', 
         facecolor = 'k', linewidth = 1.5,  hatch= '////', linestyle = 'dashed')
plt.hist(SemilepTag_m30_Mmin, 100,  label = r'$B \to \pi \chi (M_{\chi} = 3.0)$', range = (-6, 27), histtype = 'step', 
         facecolor = 'k', linewidth = 1.5,  hatch = '\\', linestyle = 'dashed')
plt.hist(SemilepTag_m40_Mmin, 100,  label = r'$B \to \pi \chi (M_{\chi} = 4.0)$', range = (-6, 27), histtype = 'step', 
         facecolor = 'k', linewidth = 1.5, hatch= '////', linestyle = 'dashed')
plt.hist(SemilepTag_m50_Mmin, 100,  label = r'$B \to \pi \chi (M_{\chi} = 5.0)$', range = (-6, 27), histtype = 'step', 
         facecolor = 'k', linewidth = 1.5, hatch = '\\', linestyle = 'dashed')
plt.hist(BkgStag_D, 100, label = r'$Bkg$', range = (-1, 27), 
         histtype = 'step', linewidth = 1.5)
#plt.hist(pi_nunu, 100,  label = r'$B \to \pi\nu\nu$', range = (-1, 27), 
 #        histtype = 'step', linewidth = 1.5, facecolor = 'k')


plt.xlabel("$M_{max}^2$ $[GeV/\mathrm{c}^2]^2$",fontsize = 20)
plt.ylabel("Counts",fontsize = 20)
plt.title(r"$M_{max}^2$ distribution")
plt.legend(loc='upper right')
#plt.grid()
#plt.savefig('SignalofMass.png')
plt.show()

# %%
bkg_df = pd.concat([df_BkgStag_D, df_BkgStag_Dstar_gamma, df_BkgStag_Dstar_pi0])

# %%
plt.figure(figsize=(10, 8.5))
# Datos con pandas
SemilepTag_m00_Mmin2 = df_SemilepTag_m00["Mmin2"]
SemilepTag_m10_Mmin2 = df_SemilepTag_m10["Mmin2"]
SemilepTag_m20_Mmin2 = df_SemilepTag_m20["Mmin2"]
SemilepTag_m30_Mmin2 = df_SemilepTag_m30["Mmin2"]
SemilepTag_m40_Mmin2 = df_SemilepTag_m40["Mmin2"]
SemilepTag_m50_Mmin2 = df_SemilepTag_m50["Mmin2"]
bkg = bkg_df["Mmin2"]

factor = 0.05
# Dato cargado con ROOT
# Se reescala la señal de ruido ee dado que es muy grande y no se alcanzaría a ver su influencia sobre la señal
# principal
#hchee_w = np.empty(cheeInvMass.shape)
#hchee_w.fill(1/cheeInvMass.shape[0])
# unificamos los ruidos eeee y mumu en uno solo dado que su influencia es similar
#hchotrosbkg = np.concatenate((hcheeee, hchmumu)) 
# se aplican los histogramas con distintas modificaciones para poder analizar diferencias
plt.hist(SemilepTag_m00_Mmin2, 100 , label = r'$B \to \pi \chi (M_{\chi} = 0.0)$', range = (-6, 27), 
         histtype = 'step', linewidth = 1.5, facecolor = '#2CBDFE', edgecolor = 'b', hatch= '////', linestyle = 'dashed', weights=factor*np.ones_like(SemilepTag_m00_Mmin2))
plt.hist(SemilepTag_m10_Mmin2, 100 , label = r'$B \to \pi \chi (M_{\chi} = 1.0)$', range = (-6, 27), 
         histtype = 'step', linewidth = 1.5, facecolor = '#2CBDFE', edgecolor = 'darkorange', hatch = '\\', linestyle = 'dashed', weights=factor*np.ones_like(SemilepTag_m10_Mmin2))
plt.hist(SemilepTag_m20_Mmin2, 100,  label = r'$B \to \pi \chi (M_{\chi} = 2.0)$', range = (-6, 27), histtype = 'step', 
         facecolor = 'k', linewidth = 1.5,  hatch= '////', linestyle = 'dashed', weights=factor*np.ones_like(SemilepTag_m20_Mmin2))
plt.hist(SemilepTag_m30_Mmin2, 100,  label = r'$B \to \pi \chi (M_{\chi} = 3.0)$', range = (-6, 27), histtype = 'step', 
         facecolor = 'k', linewidth = 1.5,  hatch = '\\', linestyle = 'dashed', weights=factor*np.ones_like(SemilepTag_m30_Mmin2))
plt.hist(SemilepTag_m40_Mmin2, 100,  label = r'$B \to \pi \chi (M_{\chi} = 4.0)$', range = (-6, 27), histtype = 'step', 
         facecolor = 'k', linewidth = 1.5, hatch= '////', linestyle = 'dashed', weights=factor*np.ones_like(SemilepTag_m40_Mmin2))
plt.hist(SemilepTag_m50_Mmin2, 100,  label = r'$B \to \pi \chi (M_{\chi} = 5.0)$', range = (-6, 27), histtype = 'step', 
         facecolor = 'k', linewidth = 1.5, hatch = '\\', linestyle = 'dashed', weights=factor*np.ones_like(SemilepTag_m50_Mmin2))
plt.hist(bkg, 100, label = 'semilep bkg', range = (-6, 27), histtype = 'step', linewidth = 1.5)


plt.xlabel(r"$M_{min}^2$ $[GeV/\mathrm{c}^2]^2$",fontsize = 20)
plt.ylabel("Counts",fontsize = 20)
plt.title(r"$M_{min}^2$ "+"  distribution")
plt.legend(loc='upper right')
#plt.grid()
#plt.savefig('SignalofMass.png')
plt.show()

# %%
plt.figure(figsize=(10, 8.5))
# Datos con pandas
SemilepTag_m00_Mmax2 = df_SemilepTag_m00["Mmax2"]
SemilepTag_m10_Mmax2 = df_SemilepTag_m10["Mmax2"]
SemilepTag_m20_Mmax2 = df_SemilepTag_m20["Mmax2"]
SemilepTag_m30_Mmax2 = df_SemilepTag_m30["Mmax2"]
SemilepTag_m40_Mmax2 = df_SemilepTag_m40["Mmax2"]
SemilepTag_m50_Mmax2 = df_SemilepTag_m50["Mmax2"]
bkg = bkg_df["Mmax2"]

factor = 0.05
# Dato cargado con ROOT
# Se reescala la señal de ruido ee dado que es muy grande y no se alcanzaría a ver su influencia sobre la señal
# principal
#hchee_w = np.empty(cheeInvMass.shape)
#hchee_w.fill(1/cheeInvMass.shape[0])
# unificamos los ruidos eeee y mumu en uno solo dado que su influencia es similar
#hchotrosbkg = np.concatenate((hcheeee, hchmumu)) 
# se aplican los histogramas con distintas modificaciones para poder analizar diferencias
plt.hist(SemilepTag_m00_Mmax2, 100 , label = r'$B \to \pi \chi (M_{\chi} = 0.0)$', range = (-3, 27), 
         histtype = 'step', linewidth = 1.5, facecolor = '#2CBDFE', edgecolor = 'b', hatch= '////', linestyle = 'dashed', weights=factor*np.ones_like(SemilepTag_m00_Mmax2))
plt.hist(SemilepTag_m10_Mmax2, 100 , label = r'$B \to \pi \chi (M_{\chi} = 1.0)$', range = (-3, 27), 
         histtype = 'step', linewidth = 1.5, facecolor = '#2CBDFE', edgecolor = 'darkorange', hatch = '\\', linestyle = 'dashed', weights=factor*np.ones_like(SemilepTag_m10_Mmax2))
plt.hist(SemilepTag_m20_Mmax2, 100,  label = r'$B \to \pi \chi (M_{\chi} = 2.0)$', range = (-3, 27), histtype = 'step', 
         facecolor = 'k', linewidth = 1.5,  hatch= '////', linestyle = 'dashed', weights=factor*np.ones_like(SemilepTag_m20_Mmax2))
plt.hist(SemilepTag_m30_Mmax2, 100,  label = r'$B \to \pi \chi (M_{\chi} = 3.0)$', range = (-3, 27), histtype = 'step', 
         facecolor = 'k', linewidth = 1.5,  hatch = '\\', linestyle = 'dashed', weights=factor*np.ones_like(SemilepTag_m30_Mmax2))
plt.hist(SemilepTag_m40_Mmax2, 100,  label = r'$B \to \pi \chi (M_{\chi} = 4.0)$', range = (-3, 27), histtype = 'step', 
         facecolor = 'k', linewidth = 1.5, hatch= '////', linestyle = 'dashed', weights=factor*np.ones_like(SemilepTag_m40_Mmax2))
plt.hist(SemilepTag_m50_Mmax2, 100,  label = r'$B \to \pi \chi (M_{\chi} = 5.0)$', range = (-3, 27), histtype = 'step', 
         facecolor = 'k', linewidth = 1.5, hatch = '\\', linestyle = 'dashed', weights=factor*np.ones_like(SemilepTag_m50_Mmax2))
plt.hist(bkg, 100, label = 'semilep bkg', range = (-3, 27), histtype = 'step', linewidth = 1.5)


plt.xlabel(r"$M_{max}^2$ $[GeV/\mathrm{c}^2]^2$",fontsize = 20)
plt.ylabel("Counts",fontsize = 20)
plt.title(r"$M_{max}^2$ "+"  distribution")
plt.legend(loc='upper right')
#plt.grid()
#plt.savefig('SignalofMass.png')
plt.show()

# %%
plt.figure(figsize=(10, 8.5))
# Datos con pandas

BkgStag_D_1 = df_BkgStag_D["Mmin2"]
BkgStag_Dstar_gamma_1 = df_BkgStag_Dstar_gamma["Mmin2"]
BkgStag_Dstar_pi0_1 = df_BkgStag_Dstar_pi0["Mmin2"]
#BkgStag_D_2 = df_BkgStag_D["Mmax2"]
#BkgStag_Dstar_gamma_2 = df_BkgStag_Dstar_gamma["Mmax2"]
#BkgStag_Dstar_pi0_2 = df_BkgStag_Dstar_pi0["Mmax2"]
# Dato cargado con ROOT
# Se reescala la señal de ruido ee dado que es muy grande y no se alcanzaría a ver su influencia sobre la señal
# principal
#hchee_w = np.empty(cheeInvMass.shape)
#hchee_w.fill(1/cheeInvMass.shape[0])
# unificamos los ruidos eeee y mumu en uno solo dado que su influencia es similar
#hchotrosbkg = np.concatenate((hcheeee, hchmumu)) 
# se aplican los histogramas con distintas modificaciones para poder analizar diferencias
plt.hist(BkgStag_D_1, 100 , label = r'$Bkg_{D} (M_{min})$', range = (-5, 27), 
         histtype = 'step', linewidth = 2, facecolor = '#2CBDFE', lw = 2, edgecolor = 'b')#, hatch= '////', linestyle = 'dashed')
plt.hist(BkgStag_Dstar_gamma_1, 100 , label = r'$Bkg_{D^*\gamma} (M_{min})$', range = (-5, 27), 
         histtype = 'step', linewidth = 2, facecolor = '#2CBDFE', lw = 2, edgecolor = 'k')#, hatch = '\\', linestyle = 'dashed')
plt.hist(BkgStag_Dstar_pi0_1, 100,  label = r'$Bkg_{D^*\pi^0} (M_{min})$', range = (-5, 27), histtype = 'step', 
         facecolor = 'k', linewidth = 2)#,  hatch= '////', linestyle = 'dashed')
#plt.hist(BkgStag_D_2, 100,  label = r'$Bkg_{D} (M_{max})$', range = (-5, 27), histtype = 'step', 
 #        facecolor = 'k', linewidth = 2)#,  hatch = '\\', linestyle = 'dashed')
#plt.hist(BkgStag_Dstar_gamma_2, 100,  label = r'$Bkg_{D^*\gamma} (M_{max})$', range = (-5, 27), histtype = 'step', 
 #        facecolor = 'k', linewidth = 2)
#plt.hist(BkgStag_Dstar_pi0_2, 100,  label = r'$Bkg_{D^*\pi^0} (M_{max})$', range = (-5, 27), histtype = 'step', 
 #        facecolor = 'k', linewidth = 2)


plt.xlabel("$M_{min}^2$ $[GeV/\mathrm{c}^2]^2$",fontsize = 20)
plt.ylabel(r"N. Events / (0.025 GeV/$\mathrm{c}^2$)",fontsize = 20)
plt.title(r"$M_{min}^2$ distribution - $M_{\chi}=0.0$")
plt.legend(loc='upper right')
#plt.grid()
#plt.savefig('SignalofMass.png')
plt.show()

# %%
plt.figure(figsize=(10, 8.5))
# Datos con pandas

BkgStag_D_2 = df_BkgStag_D["Mmax2"]
BkgStag_Dstar_gamma_2 = df_BkgStag_Dstar_gamma["Mmax2"]
BkgStag_Dstar_pi0_2 = df_BkgStag_Dstar_pi0["Mmax2"]
#BkgStag_D_2 = df_BkgStag_D["Mmax2"]
#BkgStag_Dstar_gamma_2 = df_BkgStag_Dstar_gamma["Mmax2"]
#BkgStag_Dstar_pi0_2 = df_BkgStag_Dstar_pi0["Mmax2"]
# Dato cargado con ROOT
# Se reescala la señal de ruido ee dado que es muy grande y no se alcanzaría a ver su influencia sobre la señal
# principal
#hchee_w = np.empty(cheeInvMass.shape)
#hchee_w.fill(1/cheeInvMass.shape[0])
# unificamos los ruidos eeee y mumu en uno solo dado que su influencia es similar
#hchotrosbkg = np.concatenate((hcheeee, hchmumu)) 
# se aplican los histogramas con distintas modificaciones para poder analizar diferencias
#plt.hist(BkgStag_D_1, 100 , label = r'$Bkg_{D} (M_{min}$', range = (-5, 27), 
 #        histtype = 'step', linewidth = 2, facecolor = '#2CBDFE', lw = 2, edgecolor = 'b')#, hatch= '////', linestyle = 'dashed')
#plt.hist(BkgStag_Dstar_gamma_1, 100 , label = r'$Bkg_{D^*\gamma} (M_{min})$', range = (-5, 27), 
 #        histtype = 'step', linewidth = 2, facecolor = '#2CBDFE', lw = 2, edgecolor = 'k')#, hatch = '\\', linestyle = 'dashed')
#plt.hist(BkgStag_Dstar_pi0_1, 100,  label = r'$Bkg_{D^*\pi^0} (M_{min})$', range = (-5, 27), histtype = 'step', 
    #     facecolor = 'k', linewidth = 2)#,  hatch= '////', linestyle = 'dashed')
plt.hist(BkgStag_D_2, 100,  label = r'$Bkg_{D}$ $(M_{max})$', range = (-5, 27), histtype = 'step', 
         facecolor = 'k', linewidth = 2)#,  hatch = '\\', linestyle = 'dashed')
plt.hist(BkgStag_Dstar_gamma_2, 100,  label = r'$Bkg_{D^*\gamma}$ $(M_{max})$', range = (-5, 27), histtype = 'step', 
         facecolor = 'k', linewidth = 2)
plt.hist(BkgStag_Dstar_pi0_2, 100,  label = r'$Bkg_{D^*\pi^0}$ $(M_{max})$', range = (-5, 27), histtype = 'step', 
         facecolor = 'k', linewidth = 2)


plt.xlabel("$M_{max}^2$ $[GeV/\mathrm{c}^2]^2$",fontsize = 20)
plt.ylabel(r"N. Events / (0.025 GeV/$\mathrm{c}^2$)",fontsize = 20)
plt.title(r"$M_{max}^2$ distribution - $M_{\chi}=0.0$")
plt.legend(loc='upper right')
#plt.grid()
#plt.savefig('SignalofMass.png')
plt.show()

# %%
plt.figure(figsize=(10, 8.5))
# Datos con pandas

BkgStag_D_1 = df_BkgStag_D["Xps"]
BkgStag_Dstar_gamma_1 = df_BkgStag_Dstar_gamma["Xps"]
BkgStag_Dstar_pi0_1 = df_BkgStag_Dstar_pi0["Xps"]
#pi_taununu2 = df_pi_taunu_SemilepTag["Mmax2"]
#pi_nunu2 = df_pi_nunu_SemilepTag["Mmax2"]

# Dato cargado con ROOT
# Se reescala la señal de ruido ee dado que es muy grande y no se alcanzaría a ver su influencia sobre la señal
# principal
#hchee_w = np.empty(cheeInvMass.shape)
#hchee_w.fill(1/cheeInvMass.shape[0])
# unificamos los ruidos eeee y mumu en uno solo dado que su influencia es similar
#hchotrosbkg = np.concatenate((hcheeee, hchmumu)) 
# se aplican los histogramas con distintas modificaciones para poder analizar diferencias
plt.hist(BkgStag_D_1, 100 , label = r'$Bkg_{D}$ $(X_{ps})$', range = (0, 1.2), 
         histtype = 'step', linewidth = 2, facecolor = '#2CBDFE', lw = 2, edgecolor = 'b', hatch= '////', linestyle = 'dashed')
plt.hist(BkgStag_Dstar_gamma_1, 100 , label = r'$Bkg_{D^*\gamma}$ $ (X_{ps})$', range = (0, 1.2), 
         histtype = 'step', linewidth = 2, facecolor = '#2CBDFE', lw = 2, edgecolor = 'k', hatch = '\\', linestyle = 'dashed')
plt.hist(BkgStag_Dstar_pi0_1, 100 , label = r'$Bkg_{D^*\pi^0}$ $(X_{ps})$', range = (0, 1.2), 
         histtype = 'step', linewidth = 2, facecolor = 'g', lw = 2, edgecolor = 'g')#, hatch = '\\', linestyle = 'dashed')



plt.xlabel("$X_{ps}$ $[GeV/\mathrm{c}^2]$",fontsize = 20)
plt.ylabel(r"N. Events / (0.025 GeV/$\mathrm{c}^2$)",fontsize = 20)
plt.title(r"$X_{ps}'$ distribution")
plt.legend(loc='upper left')
#plt.grid()
#plt.savefig('SignalofMass.png')
plt.show()

# %%
# Set plot size and use LaTeX for text rendering
plt.figure(figsize=(10, 8.5))
plt.rcParams['text.usetex'] = True
plt.rcParams.update({"font.size": 16, "font.family": "serif"})

# Extract data from pandas DataFrame
SemilepTag_m00_Xps = df_SemilepTag_m00["Xps"]
SemilepTag_m10_Xps = df_SemilepTag_m10["Xps"]
SemilepTag_m20_Xps = df_SemilepTag_m20["Xps"]
SemilepTag_m30_Xps = df_SemilepTag_m30["Xps"]
SemilepTag_m40_Xps = df_SemilepTag_m40["Xps"]
SemilepTag_m50_Xps = df_SemilepTag_m50["Xps"]
bkg = bkg_df["Xps"]

# Define luminosity and scaling factors
Limunosity = 8.20e5
Lumi = 50000
factor = 0.0015
factorbkg = Lumi / Limunosity

# Set histogram parameters
nbins = 50
range_limit = (0, 1.2)

# Plot background and signal components
plt.hist(
    bkg,
    nbins,
    label='Background',
    range=range_limit,
    color='lightgray',
    alpha=0.8,
    weights=factorbkg * np.ones_like(bkg),
)
# Customize each signal component
for mass, data in [
    (0.0, SemilepTag_m00_Xps),
    (1.0, SemilepTag_m10_Xps),
    (2.0, SemilepTag_m20_Xps),
    (3.0, SemilepTag_m30_Xps),
    (4.0, SemilepTag_m40_Xps),
    (5.0, SemilepTag_m50_Xps),
]:
    plt.hist(
        data,
        nbins,
        label=f'$B \\to \\pi \\chi$ $(M_\\chi = {mass})$',
        range=range_limit,
        histtype='step',
        linewidth=1.5,
        hatch='////',
        linestyle='dashed',
        weights=factor * np.ones_like(data),
    )

# Customize plot appearance
plt.xlabel("$X_{ps}$", fontsize=20)
plt.ylabel("Counts", fontsize=20)
plt.title("Background and signal components (semileptonic tag)")
plt.legend(loc='upper left', fontsize=14)
#plt.grid(True, linestyle='--', alpha=0.5)

# Display the plot
plt.show()

# %%
df_BkgHtag_D
# Out:
#       Unnamed: 0  nEta  nEtaPrime  nTracks_  track_sig_genMotherPDG  \
# 0          28392   0.0        0.0       6.0                  -323.0
# 1          10937   0.0        0.0       6.0                  -323.0
# 2          47601   0.0        0.0       6.0                   323.0
# 3           7942   0.0        0.0       4.0                    15.0
# 4          36609   0.0        0.0       6.0                   521.0
# ...          ...   ...        ...       ...                     ...
# 4253       44591   0.0        0.0       6.0                  -521.0
# 4254       41451   0.0        0.0       6.0                   521.0
# 4255       46371   0.0        0.0       6.0                   521.0
# 4256       27937   0.0        0.0       6.0                  -521.0
# 4257       55544   0.0        0.0       6.0                   521.0
#
#       track_tag_genMotherPDG  pi_tag_genMotherPDG   D_tag_M   B_tag_M  \
# 0                      521.0               -421.0  1.864830  5.279340
# ...

# %%
plt.figure(figsize=(10, 8.5))
# Datos con pandas

BkgStag_D_1 = df_BkgHtag_D["Xps"]
BkgStag_Dstar_gamma_1 = df_BkgHtad_Dstar_gamma["Xps"]
BkgStag_Dstar_pi0_1 = df_BkgHtad_Dstar_pi0["Xps"]
#pi_taununu2 = df_pi_taunu_SemilepTag["Mmax2"]
#pi_nunu2 = df_pi_nunu_SemilepTag["Mmax2"]

# Dato cargado con ROOT
# Se reescala la señal de ruido ee dado que es muy grande y no se alcanzaría a ver su influencia sobre la señal
# principal
#hchee_w = np.empty(cheeInvMass.shape)
#hchee_w.fill(1/cheeInvMass.shape[0])
# unificamos los ruidos eeee y mumu en uno solo dado que su influencia es similar
#hchotrosbkg = np.concatenate((hcheeee, hchmumu)) 
# se aplican los histogramas con distintas modificaciones para poder analizar diferencias
plt.hist(BkgStag_D_1, 100 , label = r'$Bkg_{D}$ $(X_{ps})$', range = (0, 1.2), 
         histtype = 'step', linewidth = 2, facecolor = '#2CBDFE', lw = 2, edgecolor = 'b', hatch= '////', linestyle = 'dashed')
plt.hist(BkgStag_Dstar_gamma_1, 100 , label = r'$Bkg_{D^*\gamma}$ $ (X_{ps})$', range = (0, 1.2), 
         histtype = 'step', linewidth = 2, facecolor = '#2CBDFE', lw = 2, edgecolor = 'k', hatch = '\\', linestyle = 'dashed')
plt.hist(BkgStag_Dstar_pi0_1, 100 , label = r'$Bkg_{D^*\pi^0}$ $(X_{ps})$', range = (0, 1.2), 
         histtype = 'step', linewidth = 2, facecolor = 'g', lw = 2, edgecolor = 'g')#, hatch = '\\', linestyle = 'dashed')



plt.xlabel("$X_{ps}$ $[GeV/\mathrm{c}^2]$",fontsize = 20)
plt.ylabel(r"N. Events / (0.025 GeV/$\mathrm{c}^2$)",fontsize = 20)
plt.title(r"$X_{ps}'$ distribution")
plt.legend(loc='upper right')
#plt.grid()
#plt.savefig('SignalofMass.png')
plt.show()

# %%
bkgHad = pd.concat([df_BkgHtag_D, df_BkgHtad_Dstar_gamma, df_BkgHtad_Dstar_pi0])

# %%
plt.figure(figsize=(10, 8.5))
# Extract data from pandas DataFrame
HadronicTag_m00_xps = df_HadronicTag_m00["Xps"]
HadronicTag_m10_xps = df_HadronicTag_m10["Xps"]
HadronicTag_m20_xps = df_HadronicTag_m20["Xps"]
HadronicTag_m30_xps = df_HadronicTag_m30["Xps"]
HadronicTag_m40_xps = df_HadronicTag_m40["Xps"]
HadronicTag_m50_xps = df_HadronicTag_m50["Xps"]
bkg = bkgHad["Xps"]

# Define luminosity and scaling factors
Limunosity = 8.20e5
Lumi = 50000
factor = 0.00015
factorbkg = Lumi / Limunosity

# Set histogram parameters
nbins = 50
range_limit = (0, 1.1)

# Plot background and signal components
plt.hist(
    bkg,
    nbins,
    label='Background',
    range=range_limit,
    color='lightgray',
    alpha=0.8,
    weights=factorbkg * np.ones_like(bkg),
)
# Customize each signal component
for mass, data in [
    (0.0, HadronicTag_m00_xps),
    (1.0, HadronicTag_m10_xps),
    (2.0, HadronicTag_m20_xps),
    (3.0, HadronicTag_m30_xps),
    (4.0, HadronicTag_m40_xps),
    (5.0, HadronicTag_m50_xps),
]:
    plt.hist(
        data,
        nbins,
        label=f'$B \\to \\pi \\chi$ $(M_\\chi = {mass})$',
        range=range_limit,
        histtype='step',
        linewidth=1.5,
        hatch='////',
        linestyle='dashed',
        weights=factor * np.ones_like(data),
    )

# Customize plot appearance
plt.xlabel("$X_{ps}$", fontsize=20)
plt.ylabel("Counts", fontsize=20)
plt.title("Background and signal components (hadronic tag)")
plt.legend(loc='upper left', fontsize=14)
#plt.grid(True, linestyle='--', alpha=0.5)

# Display the plot
plt.show()

# %%
plt.figure(figsize=(10, 8.5))
# Extract data from pandas DataFrame
SemilepTag_m00_q2 = df_SemilepTag_m00["q2"]
SemilepTag_m10_q2 = df_SemilepTag_m10["q2"]
SemilepTag_m20_q2 = df_SemilepTag_m20["q2"]
SemilepTag_m30_q2 = df_SemilepTag_m30["q2"]
SemilepTag_m40_q2 = df_SemilepTag_m40["q2"]
SemilepTag_m50_q2 = df_SemilepTag_m50["q2"]
bkg = bkg_df["q2"]

# Define luminosity and scaling factors
Limunosity = 8.20e5
Lumi = 50000
factor = 0.0015
factorbkg = Lumi / Limunosity

# Set histogram parameters
nbins = 50
range_limit = (-3, 27)

# Plot background and signal components
plt.hist(
    bkg,
    nbins,
    label='Background',
    range=range_limit,
    color='lightgray',
    alpha=0.8,
    weights=factorbkg * np.ones_like(bkg),
)
# Customize each signal component
for mass, data in [
    (0.0, SemilepTag_m00_q2),
    (1.0, SemilepTag_m10_q2),
    (2.0, SemilepTag_m20_q2),
    (3.0, SemilepTag_m30_q2),
    (4.0, SemilepTag_m40_q2),
    (5.0, SemilepTag_m50_q2),
]:
    plt.hist(
        data,
        nbins,
        label=f'$B \\to \\pi \\chi$ $(M_\\chi = {mass})$',
        range=range_limit,
        histtype='step',
        linewidth=1.5,
        hatch='////',
        linestyle='dashed',
        weights=factor * np.ones_like(data),
    )

# Customize plot appearance
plt.xlabel("$q^2$ $[GeV^2/c^4]$", fontsize=20)
plt.ylabel("Counts", fontsize=20)
plt.title("Background and signal components (semileptonic tag)")
plt.legend(loc='upper right', fontsize=14)
#plt.grid(True, linestyle='--', alpha=0.5)

# Display the plot
plt.show()

# %%
plt.figure(figsize=(10, 8.5))
# Extract data from pandas DataFrame
HadronicTag_m00_q2 = df_HadronicTag_m00["q2"]
HadronicTag_m10_q2 = df_HadronicTag_m10["q2"]
HadronicTag_m20_q2 = df_HadronicTag_m20["q2"]
HadronicTag_m30_q2 = df_HadronicTag_m30["q2"]
HadronicTag_m40_q2 = df_HadronicTag_m40["q2"]
HadronicTag_m50_q2 = df_HadronicTag_m50["q2"]
bkg = bkgHad["q2"]

# Define luminosity and scaling factors
Limunosity = 8.20e5
Lumi = 50000
factor = 0.00015
factorbkg = Lumi / Limunosity

# Set histogram parameters
nbins = 50
range_limit = (-3, 27)

# Plot background and signal components
plt.hist(
    bkg,
    nbins,
    label='Background',
    range=range_limit,
    color='lightgray',
    alpha=0.8,
    weights=factorbkg * np.ones_like(bkg),
)
# Customize each signal component
for mass, data in [
    (0.0, HadronicTag_m00_q2),
    (1.0, HadronicTag_m10_q2),
    (2.0, HadronicTag_m20_q2),
    (3.0, HadronicTag_m30_q2),
    (4.0, HadronicTag_m40_q2),
    (5.0, HadronicTag_m50_q2),
]:
    plt.hist(
        data,
        nbins,
        label=f'$B \\to \\pi \\chi$ $(M_\\chi = {mass})$',
        range=range_limit,
        histtype='step',
        linewidth=1.5,
        hatch='////',
        linestyle='dashed',
        weights=factor * np.ones_like(data),
    )

# Customize plot appearance
plt.xlabel("$q^2$ $[GeV^2/c^4]$", fontsize=20)
plt.ylabel("Counts", fontsize=20)
plt.title("Background and signal components (hadronic tag)")
plt.legend(loc='upper right', fontsize=14)
#plt.grid(True, linestyle='--', alpha=0.5)

# Display the plot
plt.show()

# %%
def Bidim_wc_wlimits(name, nbins, X1, X2, x1_min, x1_max, x2_min, x2_max):
    
    #X1=sig_wc_df[name]
    #X2=tau_wc_bkg_df[name]
    #X3=bkg_wc_df[name]
    plt.rcParams.update({"font.size": 14, "font.family": "serif"})
    
    fig, ax = plt.subplots()
    fig.set_size_inches((9.5,6))
    plt.tight_layout()
    
    #ax.set_title(name)
    
    ax.hist2d(X1, X2, 
            label = r"$ B \to \tau(\pi\nu)\nu + B \to \pi\nu\nu$", bins=nbins, range = [[x1_min, x1_max],[x2_min, x2_max]])
    
    
    
    ax.set_ylabel("A.U")#, loc="top")
    
    if (name == "Mmin2"):
        name = r"$M_{min}^2 (GeV^2)$ "
        ax.set_xlabel(f"{name}")
    
    if (name == "Mmax2"):
        name = r"$M_{max}^2 (GeV^2)$ "
        ax.set_xlabel(f"{name}")

    if (name == "Xps"):
        name = r"$X_{ps}^2 (GeV)$ "
        ax.set_xlabel(f"{name}")
    
    #ax.set_xlabel(f"{name}")
    ax.tick_params(which="both", direction="in", length=6, width=1)
    
    bottom, top = plt.ylim()
    n_step_y = (top-bottom)/4
    left, right = plt.xlim()
    n_step_x = (right-left)/6
    
    #n_step_x = (X1.max() - X1.min())/nbins
    
    #ax.text(x_min, top+n_step_y/1.5, "Belle II", weight="bold", style='italic', fontsize= 16)
    #ax.text(x_min+n_step_x, top+n_step_y/1.5, "Preliminar")
    #ax.text(x_min, top+n_step_y/3.5, "Simulation:" + r" $\int$"+r"$Ldt =$" + "10 fb" + r"$^{-1}$")
    #bottom, top = plt.ylim()
    ax.set_ylim(0, top+n_step_y)
    ax.legend(frameon=False, fontsize=12, loc = 'upper left', ncol=1);
    #plt.colorbar()
    #plt.savefig(f'Plots_eChannel/MC_plots/{name}_wc.png', dpi=300)
    #return fig
#sig_df.hist(column=['thrust'], ax=ax)
#tau_bkg_df.hist(column=['thrust'], ax=ax)
#bkg_df.hist(column=['thrust'], ax=ax)

# %%
import mpl_scatter_density # adds projection='scatter_density'
from matplotlib.colors import LinearSegmentedColormap

# "Viridis-like" colormap with white background
white_viridis = LinearSegmentedColormap.from_list('white_viridis', [
    (0, '#ffffff'),
    (1e-20, '#0343df'),
    #(1e-20, '#440053'),
    (0.2, '#069af3'),
    #(0.2, '#404388'),
    (0.4, '#06c2ac'),
    #(0.4, '#2a788e'),
    (0.6, '#daa520'),
    #(0.6, '#21a784'),
    (0.8, '#ffd700'),
    #(0.8, '#78d151'),
    (1, '#ffff14'),
    #(1, '#fde624'),
], N=256)

def using_mpl_scatter_density(type1, type2, namex, namey, x, y, x_min, x_max, y_min, y_max):
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1, projection='scatter_density')
    fig.set_size_inches((9.5,6))
    density = ax.scatter_density(x, y, cmap=white_viridis)
    ax.set_xlim(x_min, x_max)
    ax.set_ylim(y_min, y_max)
    
    if (namex == "Mmin2"):
        namex = r"$M_{min}^2 (GeV^2)$ "
        ax.set_xlabel(f"{namex}")
    
    if (namex == "Mmax2"):
        namex = r"$M_{max}^2 (GeV^2)$ "
        ax.set_xlabel(f"{namex}")
    
    if (namey == "Mmin2"):
        namey = r"$M_{min}^2 (GeV^2)$ "
        ax.set_ylabel(f"{namey}")
    
    if (namey == "Mmax2"):
        namey = r"$M_{max}^2 (GeV^2)$ "
        ax.set_ylabel(f"{namey}")

    if (namex == "Xps"):
        namex = r"$X_{ps} (GeV)$ "
        ax.set_xlabel(f"{namex}")

    if (namey == "Xps"):
        namey = r"$X_{ps} (GeV)$ "
        ax.set_ylabel(f"{namey}")
        
        
    fig.colorbar(density, label='Number of points per pixel')
    '''if (type1 == "standard" and type2 == "signal"):
        #plt.savefig(f'Plots_eChannel/2D_Plots/{namex}{namey}{type1}{type2}_wc.png', dpi=300, bbox_inches = 'tight')
    else:
        #plt.savefig(f'Plots_eChannel/2D_Plots/{namex}{namey}{type1}{type2}_wc.png', dpi=300, bbox_inches = 'tight')
    if (type1 == "purity" and type2 == "signal"):
        #plt.savefig(f'Plots_eChannel/2D_Plots/{namex}{namey}{type1}{type2}_wc.png', dpi=300, bbox_inches = 'tight')
    else:
        #plt.savefig(f'Plots_eChannel/2D_Plots/{namex}{namey}{type1}{type2}_wc.png', dpi=300, bbox_inches = 'tight')'''
    plt.show()

# %%
Mmin2_min = -5.0
Mmin2_max = 27.0

Mmax2_min = -1.0
Mmax2_max = 27.0

Mmin2_min_bkg = -5.0
Mmin2_max_bkg = 27.0

Mmax2_min_bkg = -1.0
Mmax2_max_bkg = 27.0

x = df_SemilepTag_m00["Mmin2"]
y = df_SemilepTag_m00["Mmax2"]

x_sm = bkg_df["Mmin2"]
y_sm = bkg_df["Mmax2"]

using_mpl_scatter_density("standard", "signal","Mmin2", "Mmax2", x, y, Mmin2_min, Mmin2_max, Mmax2_min, Mmax2_max)
using_mpl_scatter_density("standard", "SM", "Mmin2", "Mmax2", x_sm, y_sm, Mmin2_min_bkg, Mmin2_max_bkg, Mmax2_min_bkg, Mmax2_max_bkg)
# Out:
# /home/belle2/johancol/anaconda3/envs/RootPyEnv/lib/python3.10/site-packages/mpl_scatter_density/generic_density_artist.py:77: RuntimeWarning: All-NaN slice encountered
#   vmin = self._density_vmin(array)
# /home/belle2/johancol/anaconda3/envs/RootPyEnv/lib/python3.10/site-packages/mpl_scatter_density/generic_density_artist.py:82: RuntimeWarning: All-NaN slice encountered
#   vmax = self._density_vmax(array)

# %%
Mmin2_min = 24.5
Mmin2_max = 25.2

Mmax2_min = 24.8
Mmax2_max = 25.5

Mmin2_min_bkg = -5.0
Mmin2_max_bkg = 27.0

Mmax2_min_bkg = -1.0
Mmax2_max_bkg = 27.0

x = df_SemilepTag_m50["Mmin2"]
y = df_SemilepTag_m50["Mmax2"]

x_sm = bkg_df["Mmin2"]
y_sm = bkg_df["Mmax2"]

using_mpl_scatter_density("standard", "signal","Mmin2", "Mmax2", x, y, Mmin2_min, Mmin2_max, Mmax2_min, Mmax2_max)
using_mpl_scatter_density("standard", "SM", "Mmin2", "Mmax2", x_sm, y_sm, Mmin2_min_bkg, Mmin2_max_bkg, Mmax2_min_bkg, Mmax2_max_bkg)

# %%
x_sig_min = 0.1
x_sig_max = 1.2

y_sig_min = -5
y_sig_max = 22

x_min_bkg = 0.0
x_max_bkg = 1.2

y_min_bkg = -5
y_max_bkg = 27

x = df_SemilepTag_m00["Xps"]
y = df_SemilepTag_m00["Mmin2"]

x_sm = bkg_df["Xps"]
y_sm = bkg_df["Mmin2"]

using_mpl_scatter_density("standard", "signal","Xps", "Mmin2", x, y, x_sig_min, x_sig_max, y_sig_min, y_sig_max)
using_mpl_scatter_density("standard", "SM", "Xps", "Mmin2", x_sm, y_sm, x_min_bkg, x_max_bkg, y_min_bkg, y_max_bkg)

# %%
x_sig_min = 0.1
x_sig_max = 1.2

y_sig_min = -2
y_sig_max = 22

x_min_bkg = 0.0
x_max_bkg = 1.2

y_min_bkg = -2
y_max_bkg = 27

x = df_SemilepTag_m00["Xps"]
y = df_SemilepTag_m00["Mmax2"]

x_sm = bkg_df["Xps"]
y_sm = bkg_df["Mmax2"]

using_mpl_scatter_density("standard", "signal","Xps", "Mmax2", x, y, x_sig_min, x_sig_max, y_sig_min, y_sig_max)
using_mpl_scatter_density("standard", "SM", "Xps", "Mmax2", x_sm, y_sm, x_min_bkg, x_max_bkg, y_min_bkg, y_max_bkg)

# %%
df_topoana_SemilepTagD[['iDcyBrP_50_0', 'iDcyBrCcP_50_0']].value_counts().reset_index(name='count').head(30)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/belle2/johancol/BToInv/PiChannel/Analysis/EDA_Plots.ipynb Cell 36 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bkekcc/home/belle2/johancol/BToInv/PiChannel/Analysis/EDA_Plots.ipynb#X46sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> df_topoana_SemilepTagD[['iDcyBrP_50_0', 'iDcyBrCcP_50_0']].value_counts().reset_index(name='count').head(30)
#
# NameError: name 'df_topoana_SemilepTagD' is not defined
