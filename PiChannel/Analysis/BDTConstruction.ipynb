# %%
import numpy as np
import pandas as pd
import ROOT

import matplotlib.pyplot as plt
import seaborn as sns

import xgboost as xgb
from sklearn.model_selection import GridSearchCV
from matplotlib import pyplot
from numpy import mean
from numpy import std
from array import array

import time

# %%
df_HadronicTag_m00 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_m00_wc.csv')
df_HadronicTag_m10 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_m10_wc.csv')
df_HadronicTag_m20 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_m20_wc.csv')
df_HadronicTag_m30 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_m30_wc.csv')
df_HadronicTag_m40 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_m40_wc.csv')
df_HadronicTag_m50 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_m50_wc.csv')

df_HadronicTag_Dstar_gamma_m00 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m00_wc.csv')
df_HadronicTag_Dstar_gamma_m10 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m10_wc.csv')
df_HadronicTag_Dstar_gamma_m20 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m20_wc.csv')
df_HadronicTag_Dstar_gamma_m30 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m30_wc.csv')
df_HadronicTag_Dstar_gamma_m40 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m40_wc.csv')
df_HadronicTag_Dstar_gamma_m50 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m50_wc.csv')

df_HadronicTag_Dstar_pi0_m00 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m00_wc.csv')
df_HadronicTag_Dstar_pi0_m10 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m10_wc.csv')
df_HadronicTag_Dstar_pi0_m20 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m20_wc.csv')
df_HadronicTag_Dstar_pi0_m30 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m30_wc.csv')
df_HadronicTag_Dstar_pi0_m40 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m40_wc.csv')
df_HadronicTag_Dstar_pi0_m50 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m50_wc.csv')

df_SemilepTag_m00 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_m00_wc.csv')
df_SemilepTag_m10 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_m10_wc.csv')
df_SemilepTag_m20 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_m20_wc.csv')
df_SemilepTag_m30 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_m30_wc.csv')
df_SemilepTag_m40 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_m40_wc.csv')
df_SemilepTag_m50 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_m50_wc.csv')

df_SemilepTag_Dstar_gamma_m00 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m00_wc.csv')
df_SemilepTag_Dstar_gamma_m10 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m10_wc.csv')
df_SemilepTag_Dstar_gamma_m20 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m20_wc.csv')
df_SemilepTag_Dstar_gamma_m30 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m30_wc.csv')
df_SemilepTag_Dstar_gamma_m40 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m40_wc.csv')
df_SemilepTag_Dstar_gamma_m50 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m50_wc.csv')

df_SemilepTag_Dstar_pi0_m00 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_pi0_m00_wc.csv')
df_SemilepTag_Dstar_pi0_m10 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_pi0_m10_wc.csv')
df_SemilepTag_Dstar_pi0_m20 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_pi0_m20_wc.csv')
df_SemilepTag_Dstar_pi0_m30 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_pi0_m30_wc.csv')
df_SemilepTag_Dstar_pi0_m40 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_pi0_m40_wc.csv')
df_SemilepTag_Dstar_pi0_m50 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_pi0_m50_wc.csv')

df_BkgHtag_D = pd.read_csv('../Analysis/Files/CSV_Files/BkgHtag_D_wc.csv')
df_BkgHtag_Dstar_gamma = pd.read_csv('../Analysis/Files/CSV_Files/BkgHtag_Dstar_gamma_wc.csv')
df_BkgHtag_Dstar_pi0 = pd.read_csv('../Analysis/Files/CSV_Files/BkgHtag_Dstar_pi0_wc.csv')

df_BkgStag_D = pd.read_csv('../Analysis/Files/CSV_Files/BkgStag_D_wc.csv')
df_BkgStag_Dstar_gamma = pd.read_csv('../Analysis/Files/CSV_Files/BkgStag_Dstar_gamma_wc.csv')
df_BkgStag_Dstar_pi0 = pd.read_csv('../Analysis/Files/CSV_Files/BkgStag_Dstar_pi0_wc.csv')

# %%
def splitDataFrame(df, fraction):
    # Shuffle the DataFrame rows
    shuffled_df = df.sample(frac=1, random_state=1)
    
    # Calculate the number of rows for the training set
    train_size = int(fraction * len(shuffled_df))
    
    # Split the DataFrame into training and other parts
    train_df = shuffled_df.iloc[:train_size]
    other_df = shuffled_df.iloc[train_size:]
    
    return train_df, other_df

# %%
def getSample(df, fraction):
    data = df.sample(frac=fraction, random_state=1)
    return data

# %%
train_fraction = 0.5

df_SemilepTag_m00_train, df_SemilepTag_m00_eval = splitDataFrame(df_SemilepTag_m00, train_fraction)
df_SemilepTag_Dstar_gamma_m00_train, df_SemilepTag_Dstar_gamma_m00_eval = splitDataFrame(df_SemilepTag_Dstar_gamma_m00, train_fraction)
df_SemilepTag_Dstar_pi0_m00_train, df_SemilepTag_Dstar_pi0_m00_eval = splitDataFrame(df_SemilepTag_Dstar_pi0_m00, train_fraction)

df_SemilepTag_m10_train, df_SemilepTag_m10_eval = splitDataFrame(df_SemilepTag_m10, train_fraction)
df_SemilepTag_Dstar_gamma_m10_train, df_SemilepTag_Dstar_gamma_m10_eval = splitDataFrame(df_SemilepTag_Dstar_gamma_m10, train_fraction)
df_SemilepTag_Dstar_pi0_m10_train, df_SemilepTag_Dstar_pi0_m10_eval = splitDataFrame(df_SemilepTag_Dstar_pi0_m10, train_fraction)

df_SemilepTag_m20_train, df_SemilepTag_m20_eval = splitDataFrame(df_SemilepTag_m20, train_fraction)
df_SemilepTag_Dstar_gamma_m20_train, df_SemilepTag_Dstar_gamma_m20_eval = splitDataFrame(df_SemilepTag_Dstar_gamma_m20, train_fraction)
df_SemilepTag_Dstar_pi0_m20_train, df_SemilepTag_Dstar_pi0_m20_eval = splitDataFrame(df_SemilepTag_Dstar_pi0_m20, train_fraction)

df_SemilepTag_m30_train, df_SemilepTag_m30_eval = splitDataFrame(df_SemilepTag_m30, train_fraction)
df_SemilepTag_Dstar_gamma_m30_train, df_SemilepTag_Dstar_gamma_m30_eval = splitDataFrame(df_SemilepTag_Dstar_gamma_m30, train_fraction)
df_SemilepTag_Dstar_pi0_m30_train, df_SemilepTag_Dstar_pi0_m30_eval = splitDataFrame(df_SemilepTag_Dstar_pi0_m30, train_fraction)

df_SemilepTag_m40_train, df_SemilepTag_m40_eval = splitDataFrame(df_SemilepTag_m40, train_fraction)
df_SemilepTag_Dstar_gamma_m40_train, df_SemilepTag_Dstar_gamma_m40_eval = splitDataFrame(df_SemilepTag_Dstar_gamma_m40, train_fraction)
df_SemilepTag_Dstar_pi0_m40_train, df_SemilepTag_Dstar_pi0_m40_eval = splitDataFrame(df_SemilepTag_Dstar_pi0_m40, train_fraction)

df_SemilepTag_m50_train, df_SemilepTag_m50_eval = splitDataFrame(df_SemilepTag_m50, train_fraction)
df_SemilepTag_Dstar_gamma_m50_train, df_SemilepTag_Dstar_gamma_m50_eval = splitDataFrame(df_SemilepTag_Dstar_gamma_m50, train_fraction)
df_SemilepTag_Dstar_pi0_m50_train, df_SemilepTag_Dstar_pi0_m50_eval = splitDataFrame(df_SemilepTag_Dstar_pi0_m50, train_fraction)


df_BkgStag_D_train, df_BkgStag_D_eval = splitDataFrame(df_BkgStag_D, train_fraction)
df_BkgStag_Dstar_gamma_train, df_BkgStag_Dstar_gamma_eval = splitDataFrame(df_BkgStag_Dstar_gamma, train_fraction)
df_BkgStag_Dstar_pi0_train, df_BkgStag_Dstar_pi0_eval = splitDataFrame(df_BkgStag_Dstar_pi0, train_fraction)

# %%
train_fraction = 0.5

df_HadronicTag_m00_train, df_HadronicTag_m00_eval = splitDataFrame(df_HadronicTag_m00, train_fraction)
df_HadronicTag_Dstar_gamma_m00_train, df_HadronicTag_Dstar_gamma_m00_eval = splitDataFrame(df_HadronicTag_Dstar_gamma_m00, train_fraction)
df_HadronicTag_Dstar_pi0_m00_train, df_HadronicTag_Dstar_pi0_m00_eval = splitDataFrame(df_HadronicTag_Dstar_pi0_m00, train_fraction)

df_HadronicTag_m10_train, df_HadronicTag_m10_eval = splitDataFrame(df_HadronicTag_m10, train_fraction)
df_HadronicTag_Dstar_gamma_m10_train, df_HadronicTag_Dstar_gamma_m10_eval = splitDataFrame(df_HadronicTag_Dstar_gamma_m10, train_fraction)
df_HadronicTag_Dstar_pi0_m10_train, df_HadronicTag_Dstar_pi0_m10_eval = splitDataFrame(df_HadronicTag_Dstar_pi0_m10, train_fraction)

df_HadronicTag_m20_train, df_HadronicTag_m20_eval = splitDataFrame(df_HadronicTag_m20, train_fraction)
df_HadronicTag_Dstar_gamma_m20_train, df_HadronicTag_Dstar_gamma_m20_eval = splitDataFrame(df_HadronicTag_Dstar_gamma_m20, train_fraction)
df_HadronicTag_Dstar_pi0_m20_train, df_HadronicTag_Dstar_pi0_m20_eval = splitDataFrame(df_HadronicTag_Dstar_pi0_m20, train_fraction)

df_HadronicTag_m30_train, df_HadronicTag_m30_eval = splitDataFrame(df_HadronicTag_m30, train_fraction)
df_HadronicTag_Dstar_gamma_m30_train, df_HadronicTag_Dstar_gamma_m30_eval = splitDataFrame(df_HadronicTag_Dstar_gamma_m30, train_fraction)
df_HadronicTag_Dstar_pi0_m30_train, df_HadronicTag_Dstar_pi0_m30_eval = splitDataFrame(df_HadronicTag_Dstar_pi0_m30, train_fraction)

df_HadronicTag_m40_train, df_HadronicTag_m40_eval = splitDataFrame(df_HadronicTag_m40, train_fraction)
df_HadronicTag_Dstar_gamma_m40_train, df_HadronicTag_Dstar_gamma_m40_eval = splitDataFrame(df_HadronicTag_Dstar_gamma_m40, train_fraction)
df_HadronicTag_Dstar_pi0_m40_train, df_HadronicTag_Dstar_pi0_m40_eval = splitDataFrame(df_HadronicTag_Dstar_pi0_m40, train_fraction)

df_HadronicTag_m50_train, df_HadronicTag_m50_eval = splitDataFrame(df_HadronicTag_m50, train_fraction)
df_HadronicTag_Dstar_gamma_m50_train, df_HadronicTag_Dstar_gamma_m50_eval = splitDataFrame(df_HadronicTag_Dstar_gamma_m50, train_fraction)
df_HadronicTag_Dstar_pi0_m50_train, df_HadronicTag_Dstar_pi0_m50_eval = splitDataFrame(df_HadronicTag_Dstar_pi0_m50, train_fraction)


df_BkgHtag_D_train, df_BkgHtag_D_eval = splitDataFrame(df_BkgHtag_D, train_fraction)
df_BkgHtag_Dstar_gamma_train, df_BkgHtag_Dstar_gamma_eval = splitDataFrame(df_BkgHtag_Dstar_gamma, train_fraction)
df_BkgHtag_Dstar_pi0_train, df_BkgHtag_Dstar_pi0_eval = splitDataFrame(df_BkgHtag_Dstar_pi0, train_fraction)

# %%
HadronicTag_m00_df = pd.concat([df_HadronicTag_m00_train, df_HadronicTag_Dstar_gamma_m00_train, df_HadronicTag_Dstar_pi0_m00_train])
HadronicTag_m10_df = pd.concat([df_HadronicTag_m10_train, df_HadronicTag_Dstar_gamma_m10_train, df_HadronicTag_Dstar_pi0_m10_train])
HadronicTag_m20_df = pd.concat([df_HadronicTag_m20_train, df_HadronicTag_Dstar_gamma_m20_train, df_HadronicTag_Dstar_pi0_m20_train])
HadronicTag_m30_df = pd.concat([df_HadronicTag_m30_train, df_HadronicTag_Dstar_gamma_m30_train, df_HadronicTag_Dstar_pi0_m30_train])
HadronicTag_m40_df = pd.concat([df_HadronicTag_m40_train, df_HadronicTag_Dstar_gamma_m40_train, df_HadronicTag_Dstar_pi0_m40_train])
HadronicTag_m50_df = pd.concat([df_HadronicTag_m50_train, df_HadronicTag_Dstar_gamma_m50_train, df_HadronicTag_Dstar_pi0_m50_train])


SemilepTag_m00_df = pd.concat([df_SemilepTag_m00_train, df_SemilepTag_Dstar_gamma_m00_train, df_SemilepTag_Dstar_pi0_m00_train])
SemilepTag_m10_df = pd.concat([df_SemilepTag_m10_train, df_SemilepTag_Dstar_gamma_m10_train, df_SemilepTag_Dstar_pi0_m10_train])
SemilepTag_m20_df = pd.concat([df_SemilepTag_m20_train, df_SemilepTag_Dstar_gamma_m20_train, df_SemilepTag_Dstar_pi0_m20_train])
SemilepTag_m30_df = pd.concat([df_SemilepTag_m30_train, df_SemilepTag_Dstar_gamma_m30_train, df_SemilepTag_Dstar_pi0_m30_train])
SemilepTag_m40_df = pd.concat([df_SemilepTag_m40_train, df_SemilepTag_Dstar_gamma_m40_train, df_SemilepTag_Dstar_pi0_m40_train])
SemilepTag_m50_df = pd.concat([df_SemilepTag_m50_train, df_SemilepTag_Dstar_gamma_m50_train, df_SemilepTag_Dstar_pi0_m50_train])

# %% [markdown]
# SemilepTag_m00_df = pd.concat([df_SemilepTag_m00, df_SemilepTag_Dstar_gamma_m00, df_SemilepTag_Dstar_pi0_m00])
# SemilepTag_m10_df = pd.concat([df_SemilepTag_m10, df_SemilepTag_Dstar_gamma_m10, df_SemilepTag_Dstar_pi0_m10])
# SemilepTag_m20_df = pd.concat([df_SemilepTag_m20, df_SemilepTag_Dstar_gamma_m20, df_SemilepTag_Dstar_pi0_m20])
# SemilepTag_m30_df = pd.concat([df_SemilepTag_m30, df_SemilepTag_Dstar_gamma_m30, df_SemilepTag_Dstar_pi0_m30])
# SemilepTag_m40_df = pd.concat([df_SemilepTag_m40, df_SemilepTag_Dstar_gamma_m40, df_SemilepTag_Dstar_pi0_m40])
# SemilepTag_m45_df = pd.concat([df_SemilepTag_m45, df_SemilepTag_Dstar_gamma_m45, df_SemilepTag_Dstar_pi0_m45])
#
# HadronicTag_m00_df = pd.concat([df_HadronicTag_m00, df_HadronicTag_Dstar_gamma_m00, df_HadronicTag_Dstar_pi0_m00])
# HadronicTag_m10_df = pd.concat([df_HadronicTag_m10, df_HadronicTag_Dstar_gamma_m10, df_HadronicTag_Dstar_pi0_m10])
# HadronicTag_m20_df = pd.concat([df_HadronicTag_m20, df_HadronicTag_Dstar_gamma_m20, df_HadronicTag_Dstar_pi0_m20])
# HadronicTag_m30_df = pd.concat([df_HadronicTag_m30, df_HadronicTag_Dstar_gamma_m30, df_HadronicTag_Dstar_pi0_m30])
# HadronicTag_m40_df = pd.concat([df_HadronicTag_m40, df_HadronicTag_Dstar_gamma_m40, df_HadronicTag_Dstar_pi0_m40])
# HadronicTag_m45_df = pd.concat([df_HadronicTag_m45, df_HadronicTag_Dstar_gamma_m45, df_HadronicTag_Dstar_pi0_m45])

# %%
df_bkg_train = pd.concat([df_BkgStag_D_train, df_BkgStag_Dstar_gamma_train, df_BkgStag_Dstar_pi0_train])
df_bkgHad = pd.concat([df_BkgHtag_D_train, df_BkgHtag_Dstar_gamma_train, df_BkgHtag_Dstar_pi0_train])

# %%
df_bkgHad
# Out:
#       Unnamed: 0  nEta  nEtaPrime  nTracks_  track_sig_genMotherPDG  \
# 1937       24234   0.0        0.0       6.0                  -521.0
# 1856       28074   0.0        0.0       4.0                  -521.0
# 219        37343   0.0        0.0       6.0                  -521.0
# 368        17977   0.0        0.0       4.0                    15.0
# 719        22501   0.0        0.0       4.0                    15.0
# ...          ...   ...        ...       ...                     ...
# 9          17832   0.0        0.0       4.0                    15.0
# 1767       34453   0.0        0.0       6.0                 -1114.0
# 543        19024   0.0        0.0       4.0                   -15.0
# 1885       10261   0.0        0.0       4.0                    15.0
# 10         35971   0.0        0.0       6.0                  -521.0
#
#       track_tag_genMotherPDG  pi_tag_genMotherPDG   D_tag_M   B_tag_M  \
# 1937                   521.0               -421.0  1.864830  5.279340
# ...

# %%
SemilepTag_m50_df
# Out:
#        Unnamed: 0  nEta  nEtaPrime  nTracks_  track_sig_genMotherPDG  \
# 21065       21065   0.0        0.0       4.0                   521.0
# 36435       36435   0.0        0.0       4.0                   521.0
# 40304       40304   0.0        0.0       4.0                  -521.0
# 76335       76335   0.0        0.0       4.0                  -521.0
# 30949       30949   0.0        0.0       4.0                   521.0
# ...           ...   ...        ...       ...                     ...
# 9860         9860   0.0        0.0       4.0                  -521.0
# 7996         7996   0.0        0.0       4.0                  -521.0
# 16883       16883   0.0        0.0       4.0                   521.0
# 11373       11373   0.0        0.0       4.0                  -521.0
# 2633         2633   0.0        0.0       4.0                   521.0
#
#        track_tag_genMotherPDG  pi_tag_genMotherPDG  D_tag_M   B_tag_M  \
# ...

# %%
cols = ['Mmin2', 'Mmax2', 'Xps', 'q2']
#cols = ['Mmin2', 'Mmax2']

df_sig_train = SemilepTag_m50_df.filter(cols, axis=1)

df_bkg_train = df_bkg_train.filter(cols, axis=1)

df_SemilepTag_m00_eval = df_SemilepTag_m00_eval.filter(cols, axis=1)
df_SemilepTag_Dstar_gamma_m00_eval = df_SemilepTag_Dstar_gamma_m00_eval.filter(cols, axis=1)
df_SemilepTag_Dstar_pi0_m00_eval = df_SemilepTag_Dstar_pi0_m00_eval.filter(cols, axis=1)

df_SemilepTag_m10_eval = df_SemilepTag_m10_eval.filter(cols, axis=1)
df_SemilepTag_Dstar_gamma_m10_eval = df_SemilepTag_Dstar_gamma_m10_eval.filter(cols, axis=1)
df_SemilepTag_Dstar_pi0_m10_eval = df_SemilepTag_Dstar_pi0_m10_eval.filter(cols, axis=1)

df_SemilepTag_m20_eval = df_SemilepTag_m20_eval.filter(cols, axis=1)
df_SemilepTag_Dstar_gamma_m20_eval = df_SemilepTag_Dstar_gamma_m20_eval.filter(cols, axis=1)
df_SemilepTag_Dstar_pi0_m20_eval = df_SemilepTag_Dstar_pi0_m20_eval.filter(cols, axis=1)

df_SemilepTag_m30_eval = df_SemilepTag_m30_eval.filter(cols, axis=1)
df_SemilepTag_Dstar_gamma_m30_eval = df_SemilepTag_Dstar_gamma_m30_eval.filter(cols, axis=1)
df_SemilepTag_Dstar_pi0_m30_eval = df_SemilepTag_Dstar_pi0_m30_eval.filter(cols, axis=1)


df_SemilepTag_m40_eval = df_SemilepTag_m40_eval.filter(cols, axis=1)
df_SemilepTag_Dstar_gamma_m40_eval = df_SemilepTag_Dstar_gamma_m40_eval.filter(cols, axis=1)
df_SemilepTag_Dstar_pi0_m40_eval = df_SemilepTag_Dstar_pi0_m40_eval.filter(cols, axis=1)

df_SemilepTag_m50_eval = df_SemilepTag_m50_eval.filter(cols, axis=1)
df_SemilepTag_Dstar_gamma_m50_eval = df_SemilepTag_Dstar_gamma_m50_eval.filter(cols, axis=1)
df_SemilepTag_Dstar_pi0_m50_eval = df_SemilepTag_Dstar_pi0_m50_eval.filter(cols, axis=1)

df_BkgStag_D_eval = df_BkgStag_D_eval.filter(cols, axis=1)
df_BkgStag_Dstar_gamma_eval = df_BkgStag_Dstar_gamma_eval.filter(cols, axis=1)
df_BkgStag_Dstar_pi0_eval = df_BkgStag_Dstar_pi0_eval.filter(cols, axis=1)

# %%
cols_Had = ['Xps', 'q2']
#df_sig_train = HadronicTag_m00_df.filter(cols_Had, axis=1)

#df_bkg_train = df_bkgHad.filter(cols_Had, axis=1)

df_HadronicTag_m00_eval = df_HadronicTag_m00_eval.filter(cols_Had, axis=1)
df_HadronicTag_Dstar_gamma_m00_eval = df_HadronicTag_Dstar_gamma_m00_eval.filter(cols_Had, axis=1)
df_HadronicTag_Dstar_pi0_m00_eval = df_HadronicTag_Dstar_pi0_m00_eval.filter(cols_Had, axis=1)

df_HadronicTag_m10_eval = df_HadronicTag_m10_eval.filter(cols_Had, axis=1)
df_HadronicTag_Dstar_gamma_m10_eval = df_HadronicTag_Dstar_gamma_m10_eval.filter(cols_Had, axis=1)
df_HadronicTag_Dstar_pi0_m10_eval = df_HadronicTag_Dstar_pi0_m10_eval.filter(cols_Had, axis=1)

df_HadronicTag_m20_eval = df_HadronicTag_m20_eval.filter(cols_Had, axis=1)
df_HadronicTag_Dstar_gamma_m20_eval = df_HadronicTag_Dstar_gamma_m20_eval.filter(cols_Had, axis=1)
df_HadronicTag_Dstar_pi0_m20_eval = df_HadronicTag_Dstar_pi0_m20_eval.filter(cols_Had, axis=1)

df_HadronicTag_m30_eval = df_HadronicTag_m30_eval.filter(cols_Had, axis=1)
df_HadronicTag_Dstar_gamma_m30_eval = df_HadronicTag_Dstar_gamma_m30_eval.filter(cols_Had, axis=1)
df_HadronicTag_Dstar_pi0_m30_eval = df_HadronicTag_Dstar_pi0_m30_eval.filter(cols_Had, axis=1)


df_HadronicTag_m40_eval = df_HadronicTag_m40_eval.filter(cols_Had, axis=1)
df_HadronicTag_Dstar_gamma_m40_eval = df_HadronicTag_Dstar_gamma_m40_eval.filter(cols_Had, axis=1)
df_HadronicTag_Dstar_pi0_m40_eval = df_HadronicTag_Dstar_pi0_m40_eval.filter(cols_Had, axis=1)

df_HadronicTag_m50_eval = df_HadronicTag_m50_eval.filter(cols_Had, axis=1)
df_HadronicTag_Dstar_gamma_m50_eval = df_HadronicTag_Dstar_gamma_m50_eval.filter(cols_Had, axis=1)
df_HadronicTag_Dstar_pi0_m50_eval = df_HadronicTag_Dstar_pi0_m50_eval.filter(cols_Had, axis=1)

df_BkgHtag_D_eval = df_BkgHtag_D_eval.filter(cols_Had, axis=1)
df_BkgHtag_Dstar_gamma_eval = df_BkgHtag_Dstar_gamma_eval.filter(cols_Had, axis=1)
df_BkgHtag_Dstar_pi0_eval = df_BkgHtag_Dstar_pi0_eval.filter(cols_Had, axis=1)

# %%
df_sig_train
# Out:
#            Mmin2      Mmax2       Xps         q2
# 21065  24.972723  25.206740  0.101386  25.229744
# 36435  24.930454  25.122222  0.101252  25.077032
# 40304  24.973605  25.213956  0.099597  25.176193
# 76335  25.023542  25.293926  0.099497  25.260924
# 30949  24.862586  25.064932  0.105455  25.075174
# ...          ...        ...       ...        ...
# 9860   24.752018  25.068589  0.105857  25.021483
# 7996   25.001876  25.176857  0.099970  25.148646
# 16883  24.998056  25.237075  0.097225  25.248408
# 11373  24.998309  25.092579  0.102982  25.250170
# 2633   24.698091  25.015105  0.110669  24.964779
#
# [80780 rows x 4 columns]

# %%
#print('Rows: ', df_SemilepTag_m45_eval.shape[0])
#print('Columns: ', df_SemilepTag_m45_eval.shape[1])

# %%
print('Rows: ', df_sig_train.shape[0])
print('Columns: ', df_sig_train.shape[1])
# Out:
# Rows:  80780
# Columns:  4

# %%
print('Rows: ', df_bkg_train.shape[0])
print('Columns: ', df_bkg_train.shape[1])
# Out:
# Rows:  50227
# Columns:  4

# %% [markdown]
# train_fraction = 0.5
#
# df_sig_train, df_sig = splitDataFrame(df_sig, train_fraction)
# df_bkg_train, df_bkg = splitDataFrame(df_bkg, train_fraction)
# df_sigHad_train, df_sigHad = splitDataFrame(df_sigHad, train_fraction)
# df_bkgHad_train, df_bkgHad = splitDataFrame(df_bkgHad, train_fraction)

# %%
# Create a 2D numpy array for signal and bkg
sig = df_sig_train.to_numpy()
bkg = df_bkg_train.to_numpy()



# for sklearn data is usually organised
# into one 2D array of shape (n_samples x n_features)
# containing all the data and one array of categories
# of length n_samples
# We assign a 0 value to background and 1 to signal 
Combied_array = np.concatenate((sig, bkg), axis=0)
labels_array = np.concatenate((np.ones(sig.shape[0]),
                    np.zeros(bkg.shape[0])))

# %%
Combied_array.shape
# Out:
# (131007, 4)

# %%
labels_array.shape
# Out:
# (131007,)

# %%
# After to create a function, we need to join in a dataframe called "df" the above arrays
# called "X" and "y"

# Create a pandas DataFrame for our data
# this provides many convenience functions
# for exploring our dataset
# need to reshape y so it is a 2D array with one column

df = pd.DataFrame(np.hstack((Combied_array, labels_array.reshape(labels_array.shape[0], -1))), 
        columns=cols+['y'])


df.head()
# Out:
#        Mmin2      Mmax2       Xps         q2    y
# 0  24.972723  25.206740  0.101386  25.229744  1.0
# 1  24.930454  25.122222  0.101252  25.077032  1.0
# 2  24.973605  25.213956  0.099597  25.176193  1.0
# 3  25.023542  25.293926  0.099497  25.260924  1.0
# 4  24.862586  25.064932  0.105455  25.075174  1.0

# %%
print('Rows: ', df.shape[0])
print('Columns: ', df.shape[1])
# Out:
# Rows:  131007
# Columns:  5

# %%
print('Number of null data: ', df.isnull().sum().max())
# Out:
# Number of null data:  0

# %%
plt.title("Unbalanced Classes")
ax= sns.countplot(x=df["y"]);
for p in ax.patches:
    ax.annotate(int(p.get_height()), (p.get_x()+0.25, p.get_height()+1), 
    va = 'bottom', color = 'black')

# %%
shuffled_df = df.sample(frac=1,random_state=4)

# Put all the signal class in a separate dataset.
#signal_df = shuffled_df.loc[shuffled_df['y'] == 1]
#bkg_df = shuffled_df.loc[shuffled_df['y'] == 0]
# Number of events
nevnts = shuffled_df.y.count()/2

# Randomly select 159086 observations from the background (majority class)
bkg_df = shuffled_df.loc[shuffled_df['y'] == 0].sample(n=int(nevnts), replace=True, random_state=42)
sig_df = shuffled_df.loc[shuffled_df['y'] == 1].sample(n=int(nevnts), replace=True, random_state=42)

# Concatenate both dataframes again
normalized_df = pd.concat([sig_df, bkg_df])

# Plot the dataser after dataframe again
plt.figure(figsize=(8, 8))
plt.title('Balanced Classes')
ax = sns.countplot(x=normalized_df["y"])
for p in ax.patches:
    ax.annotate(int(p.get_height()), (p.get_x()+0.25, p.get_height()+1), 
    va = 'bottom', color = 'black')
#plt.show()

# %%
# Split the signal and Background using the dummy variables y
# To make this, we split in the half of the range bkg if y < 0.5 and bkg if y > 0.5

Sig = df.y > 0.5
Bkg = df.y < 0.5

def correlation_M(data, name, **kwds):
    """Calculate pairwise correlation between features.
    
    Extra arguments are passed on to DataFrame.corr()
    """
    # simply call df.corr() to get a table of
    # correlation values if you do not need
    # the fancy plotting
    corrmat = data.corr(**kwds)
    
    fig, axes = plt.subplots(ncols=1, figsize=(8,6), dpi = 120)
    
    axes.set_title('Correlation between variables, {}'.format(name))
    
    annot_kws = {'fontsize': 9}
    
    sns.heatmap(corrmat, annot=True, annot_kws = annot_kws, cmap='coolwarm', vmin=-1.0, linewidths = .5);ze=(15,8)
    plt.tight_layout()
    
# remove the y column from the correlation matrix
# after using it to select background and signal
correlation_M(df[Sig].drop('y', 1), "independient of BDT target - Signal")
correlation_M(df[Bkg].drop('y', 1), "independient of BDT target - Noise")
# %%time
# Out:
# /tmp/ipykernel_111996/742204321.py:28: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   correlation_M(df[Sig].drop('y', 1), "independient of BDT target - Signal")
# /tmp/ipykernel_111996/742204321.py:29: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   correlation_M(df[Bkg].drop('y', 1), "independient of BDT target - Noise")
# UsageError: Line magic function `%%time` not found.

# %%
Sig = normalized_df.y > 0.5
Bkg = normalized_df.y < 0.5

# remove the y column from the correlation matrix
# after using it to select background and signal

correlation_M(normalized_df[Sig].drop('y', 1), "independient of BDT target - Signal")
correlation_M(normalized_df[Bkg].drop('y', 1), "independient of BDT target - Noise")
# Out:
# /tmp/ipykernel_111996/1944933348.py:7: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   correlation_M(normalized_df[Sig].drop('y', 1), "independient of BDT target - Signal")
# /tmp/ipykernel_111996/1944933348.py:8: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   correlation_M(normalized_df[Bkg].drop('y', 1), "independient of BDT target - Noise")

# %%
correlation_M(normalized_df, "with the target")

# %%
correlation_M(normalized_df[Sig], "with the target")

# %%
correlation_M(normalized_df[Bkg], "with the target")

# %%
X = normalized_df.drop(['y'], axis=1)
y = normalized_df['y']

#X = normalized_df.drop(['y', 'Mmin2', 'Mmax2'], axis=1)
#y = normalized_df['y']

#X = df.drop(['y'], axis=1)
#y = df['y']

# %%
from sklearn.model_selection import train_test_split


#X_dev,X_eval, y_dev,y_eval = train_test_split(X, y,
 #                                             test_size=0.3, random_state=42)
X_train,X_test, y_train,y_test = train_test_split(X, y,
                                                  test_size=0.3, random_state=492)

# %%
print('Number of events of X_train: {}'.format(len(X_train)))
print('Number of events of X_test: {}'.format(len(X_test)))
print('Number of events of y_train: {}'.format(len(y_train)))
print('Number of events of y_test: {}'.format(len(y_test)))
#print('Number of events of X_dev: {}'.format(len(X_dev)))
#print('Number of events of X_eval: {}'.format(len(X_eval)))
#print('Number of events of y_dev: {}'.format(len(X_dev)))
#print('Number of events of y_eval: {}'.format(len(X_eval)))
# Out:
# Number of events of X_train: 91704
# Number of events of X_test: 39302
# Number of events of y_train: 91704
# Number of events of y_test: 39302

# %% [markdown]
# ### Using XGBoost
# Let's estimatethe best parameters in our BDT

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold

# Function to evaluate the models
def evaluate_model(model, X, y):
	# define the evaluation procedure
	cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
	# evaluate the model and collect the results
	scores = cross_val_score(model, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
	return scores

# %%
# get a list of models to evaluate
def get_models_xgb_learning_rate():
	models = dict()
	# explore learning rates from 0.1 to 2 in 0.1 increments
	for i in np.arange(0.0001, 0.1, 0.005):
		key = '%.3f' % i
		models[key] = xgb.XGBClassifier(learning_rate=i, tree_method="hist")
	return models

# %%
models = get_models_xgb_learning_rate()
# evaluate the models and store results
results, names = list(), list()
for name, model in models.items():
	# evaluate the model
	scores = evaluate_model(model, X_train, y_train)
	# store the results
	results.append(scores)
	names.append(name)
	# summarize the performance along the way
	print('>%s %.4f (+/-%.5f)' % (name, mean(scores), std(scores)))
# plot model performance for comparison
pyplot.boxplot(results, labels=names, showmeans=True)
pyplot.show()
# Out:
# >0.000 0.9936 (+/-0.00086)
# >0.005 0.9936 (+/-0.00088)
# >0.010 0.9936 (+/-0.00088)
# >0.015 0.9936 (+/-0.00090)
# >0.020 0.9937 (+/-0.00085)
# >0.025 0.9938 (+/-0.00083)
# >0.030 0.9938 (+/-0.00085)
# >0.035 0.9938 (+/-0.00084)
# >0.040 0.9938 (+/-0.00084)
# >0.045 0.9938 (+/-0.00083)
# >0.050 0.9938 (+/-0.00083)
# >0.055 0.9939 (+/-0.00081)
# >0.060 0.9938 (+/-0.00085)
# >0.065 0.9939 (+/-0.00084)
# >0.070 0.9939 (+/-0.00086)
# >0.075 0.9939 (+/-0.00084)
# >0.080 0.9939 (+/-0.00085)
# >0.085 0.9939 (+/-0.00085)
# >0.090 0.9939 (+/-0.00085)
# >0.095 0.9939 (+/-0.00086)

# %%
# get a list of models to evaluate
def get_models_xgb_max_depth():
	models = dict()
	# explore learning rates from 0.1 to 2 in 0.1 increments
	for i in np.arange(1, 21, 1):
		key = '%.3f' % i
		models[key] = xgb.XGBClassifier(max_depth=i, tree_method="hist")
	return models

# %%
models = get_models_xgb_max_depth()
# evaluate the models and store results
results, names = list(), list()
for name, model in models.items():
	# evaluate the model
	scores = evaluate_model(model, X_train, y_train)
	# store the results
	results.append(scores)
	names.append(name)
	# summarize the performance along the way
	print('>%s %.4f (+/-%.5f)' % (name, mean(scores), std(scores)))
# plot model performance for comparison
pyplot.boxplot(results, labels=names, showmeans=True)
pyplot.show()
# Out:
# >1.000 0.9933 (+/-0.00072)
# >2.000 0.9935 (+/-0.00085)
# >3.000 0.9936 (+/-0.00084)
# >4.000 0.9938 (+/-0.00083)
# >5.000 0.9941 (+/-0.00090)
# >6.000 0.9943 (+/-0.00085)
# >7.000 0.9946 (+/-0.00087)
# >8.000 0.9949 (+/-0.00083)
# >9.000 0.9951 (+/-0.00084)
# >10.000 0.9952 (+/-0.00077)
# >11.000 0.9953 (+/-0.00080)
# >12.000 0.9955 (+/-0.00080)
# >13.000 0.9956 (+/-0.00074)
# >14.000 0.9957 (+/-0.00080)
# >15.000 0.9958 (+/-0.00079)
# >16.000 0.9959 (+/-0.00073)
# >17.000 0.9959 (+/-0.00072)
# >18.000 0.9960 (+/-0.00072)
# >19.000 0.9960 (+/-0.00080)
# >20.000 0.9960 (+/-0.00074)

# %%
# get a list of models to evaluate
def get_models_xgb_n_estimators():
	models = dict()
	# explore learning rates from 0.1 to 2 in 0.1 increments
	for i in np.arange(10, 310, 10):
		key = '%.3f' % i
		models[key] = xgb.XGBClassifier(n_estimators=i, tree_method="hist")
	return models

# %%
models = get_models_xgb_n_estimators()
# evaluate the models and store results
results, names = list(), list()
for name, model in models.items():
	# evaluate the model
	scores = evaluate_model(model, X_train, y_train)
	# store the results
	results.append(scores)
	names.append(name)
	# summarize the performance along the way
	print('>%s %.4f (+/-%.5f)' % (name, mean(scores), std(scores)))
# plot model performance for comparison
pyplot.boxplot(results, labels=names, showmeans=True)
pyplot.show()
# Out:
# >10.000 0.9938 (+/-0.00086)
# >20.000 0.9939 (+/-0.00084)
# >30.000 0.9939 (+/-0.00086)
# >40.000 0.9939 (+/-0.00087)
# >50.000 0.9940 (+/-0.00083)
# >60.000 0.9941 (+/-0.00086)
# >70.000 0.9941 (+/-0.00088)
# >80.000 0.9942 (+/-0.00088)
# >90.000 0.9943 (+/-0.00085)
# >100.000 0.9943 (+/-0.00085)
# >110.000 0.9944 (+/-0.00083)
# >120.000 0.9945 (+/-0.00083)
# >130.000 0.9945 (+/-0.00085)
# >140.000 0.9946 (+/-0.00083)
# >150.000 0.9946 (+/-0.00084)
# >160.000 0.9947 (+/-0.00082)
# >170.000 0.9947 (+/-0.00081)
# >180.000 0.9948 (+/-0.00081)
# >190.000 0.9948 (+/-0.00080)
# >200.000 0.9949 (+/-0.00081)
# >210.000 0.9950 (+/-0.00082)
# >220.000 0.9950 (+/-0.00081)
# >230.000 0.9951 (+/-0.00080)
# >240.000 0.9951 (+/-0.00080)
# >250.000 0.9952 (+/-0.00081)
# >260.000 0.9952 (+/-0.00080)
# >270.000 0.9953 (+/-0.00079)
# >280.000 0.9953 (+/-0.00081)
# >290.000 0.9954 (+/-0.00082)
# >300.000 0.9954 (+/-0.00082)

# %%
# get a list of models to evaluate
def get_models_xgb_subsample():
	models = dict()
	# explore learning rates from 0.1 to 2 in 0.1 increments
	for i in np.arange(0, 1.1, 0.1):
		key = '%.3f' % i
		models[key] = xgb.XGBClassifier(subsample=i, tree_method="hist")
		
	return models

# %%
models = get_models_xgb_subsample()
# evaluate the models and store results
results, names = list(), list()
for name, model in models.items():
	# evaluate the model
	scores = evaluate_model(model, X_train, y_train)
	# store the results
	results.append(scores)
	names.append(name)
	# summarize the performance along the way
	print('>%s %.4f (+/-%.5f)' % (name, mean(scores), std(scores)))
# plot model performance for comparison
pyplot.boxplot(results, labels=names, showmeans=True)
pyplot.show()
# Out:
# >0.000 0.4984 (+/-0.00003)
# >0.100 0.9935 (+/-0.00078)
# >0.200 0.9938 (+/-0.00085)
# >0.300 0.9940 (+/-0.00078)
# >0.400 0.9940 (+/-0.00082)
# >0.500 0.9941 (+/-0.00087)
# >0.600 0.9942 (+/-0.00088)
# >0.700 0.9943 (+/-0.00079)
# >0.800 0.9944 (+/-0.00082)
# >0.900 0.9943 (+/-0.00087)
# >1.000 0.9943 (+/-0.00085)

# %%
# bests HP for mass point (ST)
# m00
#max_depth = 10
#learning_rate = 0.070
#n_estimators = 230
#subsample = 0.900
# m10
#max_depth = 10
#learning_rate = 0.070
#n_estimators = 220
#subsample = 0.900
# m20
#max_depth = 10
#learning_rate = 0.075
#n_estimators = 300
#subsample = 0.900
# m30
#max_depth = 14
#learning_rate = 0.075
#n_estimators = 270
#subsample = 0.900
# m40
#max_depth = 10
#learning_rate = 0.070
#n_estimators = 220
#subsample = 0.900
# m45
max_depth = 10
learning_rate = 0.070
n_estimators = 220
subsample = 0.900

# %%
# bests HP for mass point (HT)
# m00
#max_depth = 8
#learning_rate = 0.045
#n_estimators = 100
#subsample = 0.400
# m10
#max_depth = 10
#learning_rate = 0.070
#n_estimators = 220
#subsample = 0.900
# m20
#max_depth = 10
#learning_rate = 0.075
#n_estimators = 300
#subsample = 0.900
# m30
#max_depth = 14
#learning_rate = 0.075
#n_estimators = 270
#subsample = 0.900
# m40
#max_depth = 10
#learning_rate = 0.070
#n_estimators = 220
#subsample = 0.900
# m45
#max_depth = 10
#learning_rate = 0.070
#n_estimators = 220
#subsample = 0.900

# %%
# Setting the best hyper-params found in our optimization

num_trees =100
xgb_model = xgb.XGBClassifier(
                    max_depth=max_depth,
                    learning_rate=learning_rate,
                    n_estimators=n_estimators,
                    #objective="binary:logistic",
                    subsample=subsample,
                    nthread=8,
                    tree_method="hist"  # 'gpu_hist' this enables GPU.
)

evalset = [( X_train, y_train), ( X_test, y_test)]

import time
print('Lets GO!')
start = time.ctime()
# fit the model
xgb_model.fit(X_train, y_train, eval_metric='auc', eval_set=evalset)

end = time.ctime()
print('all done!')
print('started', start)

print('finished', end)
# Out:
# Lets GO!
# /home/belle2/johancol/anaconda3/envs/RootPyEnv/lib/python3.10/site-packages/xgboost/sklearn.py:835: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# [0]	validation_0-auc:0.99549	validation_1-auc:0.99530
# [1]	validation_0-auc:0.99549	validation_1-auc:0.99530
# [2]	validation_0-auc:0.99549	validation_1-auc:0.99530
# [3]	validation_0-auc:0.99551	validation_1-auc:0.99535
# [4]	validation_0-auc:0.99571	validation_1-auc:0.99549
# [5]	validation_0-auc:0.99571	validation_1-auc:0.99549
# [6]	validation_0-auc:0.99624	validation_1-auc:0.99593
# [7]	validation_0-auc:0.99624	validation_1-auc:0.99593
# [8]	validation_0-auc:0.99624	validation_1-auc:0.99593
# [9]	validation_0-auc:0.99624	validation_1-auc:0.99594
# [10]	validation_0-auc:0.99625	validation_1-auc:0.99594
# [11]	validation_0-auc:0.99626	validation_1-auc:0.99595
# ...

# %%
from sklearn.metrics import classification_report, roc_auc_score

xgb_y_test_predicted = xgb_model.predict(X_test)
xgb_y__test_predicted_proba = xgb_model.predict_proba(X_test)[:,1]
print(classification_report(y_test, xgb_y_test_predicted, target_names=["background", "signal"]))
print("Area under ROC curve: %.4f"%(roc_auc_score(y_test, xgb_y__test_predicted_proba)))
# Out:
#               precision    recall  f1-score   support
#
#   background       1.00      0.99      1.00     19800
#       signal       0.99      1.00      1.00     19502
#
#     accuracy                           1.00     39302
#    macro avg       1.00      1.00      1.00     39302
# weighted avg       1.00      1.00      1.00     39302
#
# Area under ROC curve: 0.9986

# %%
xgb_y_train_predicted = xgb_model.predict(X_train)
xgb_y_train_predicted_proba = xgb_model.predict_proba(X_train)[:,1]
print(classification_report(y_train, xgb_y_train_predicted,
                            target_names=["background", "signal"]))
print("Area under ROC curve: %.4f"%(roc_auc_score(y_train,
                                                  xgb_y_train_predicted_proba)))
# %time
# Out:
#               precision    recall  f1-score   support
#
#   background       1.00      0.99      1.00     45703
#       signal       0.99      1.00      1.00     46001
#
#     accuracy                           1.00     91704
#    macro avg       1.00      1.00      1.00     91704
# weighted avg       1.00      1.00      1.00     91704
#
# Area under ROC curve: 0.9999
# CPU times: user 7 µs, sys: 0 ns, total: 7 µs
# Wall time: 14.1 µs

# %%
print("Importancia de los predictores en el modelo")
print("-------------------------------------------")
importancia_predictores = pd.DataFrame(
                            {'predictor': X.columns,
                             'importancia': xgb_model.feature_importances_}
                            )
importancia_predictores.sort_values('importancia', ascending=False)
# Out:
# Importancia de los predictores en el modelo
# -------------------------------------------
#   predictor  importancia
# 3        q2     0.501732
# 2       Xps     0.473565
# 1     Mmax2     0.014240
# 0     Mmin2     0.010463

# %%
def plot_xgboost_response(clf, X_train, y_train, X_test, y_test, bins=30):
    decisions = []
    
    for X, y in [(X_train, y_train), (X_test, y_test)]:
        d1 = clf.predict_proba(X[y > 0.5])[:, 1].ravel()
        d2 = clf.predict_proba(X[y < 0.5])[:, 1].ravel()
        decisions += [d1, d2]

    low = min(np.min(d) for d in decisions)
    high = max(np.max(d) for d in decisions)
    low_high = (low, high)

    plt.hist(decisions[0],
             color='r', alpha=0.5, range=low_high, bins=bins,
             histtype='stepfilled', density=True,
             label='S (train)')
    plt.hist(decisions[1],
             color='b', alpha=0.5, range=low_high, bins=bins,
             histtype='stepfilled', density=True,
             label='B (train)')

    hist, bins = np.histogram(decisions[2],
                              bins=bins, range=low_high, density=True)
    scale = len(decisions[2]) / sum(hist)
    err = np.sqrt(hist * scale) / scale

    width = (bins[1] - bins[0])
    center = (bins[:-1] + bins[1:]) / 2
    plt.errorbar(center, hist, yerr=err, fmt='o', c='r', label='S (test)')

    hist, bins = np.histogram(decisions[3],
                              bins=bins, range=low_high, density=True)
    scale = len(decisions[2]) / sum(hist)
    err = np.sqrt(hist * scale) / scale

    plt.errorbar(center, hist, yerr=err, fmt='o', c='b', label='B (test)')

    plt.xlabel("XGBoost output")
    plt.ylabel("Arbitrary units")
    plt.legend(loc='best')
    plt.show()

# Example usage:
# Replace X_train, y_train, X_test, y_test with your actual training and testing data
# clf is your trained XGBoost classifier
# plot_xgboost_response(clf, X_train, y_train, X_test, y_test)

# %%
plot_xgboost_response(xgb_model, X_train, y_train, X_test, y_test, bins=30)

# %%
from sklearn.metrics import roc_curve, auc


# Assuming xgb_model is your trained XGBoost classifier
decisions = xgb_model.predict_proba(X_test)[:, 1]

# Compute ROC curve and area under the curve
fpr, tpr, thresholds = roc_curve(y_test, decisions)
roc_auc = auc(fpr, tpr)

plt.plot(fpr, tpr, lw=1, label='ROC (area = %0.2f)' % (roc_auc))

plt.plot([0, 1], [0, 1], '--', color=(0.6, 0.6, 0.6), label='Luck')
plt.xlim([-0.05, 1.05])
plt.ylim([-0.05, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.grid()

plt.show()

# %% [markdown]
# ## BDT variable construction
# dataS = np.asarray(df_sig.drop(['Mmin2', 'Mmax2'], axis=1))
# dataB = np.asarray(df_bkg.drop(['Mmin2', 'Mmax2'], axis=1))
# # Here, we construct the data from the data used in the training
# #dataS = np.asarray(Sig)
# #dataB = np.asarray(Bkg)
#
# # Here the data from the other half
# dataS_D = np.asarray(df_SemilepTag_m30.drop(['Mmin2', 'Mmax2'], axis=1))
# dataS_Dstar_gamma = np.asarray(df_SemilepTag_Dstar_gamma_m30.drop(['Mmin2', 'Mmax2'], axis=1))
# dataS_Dstar_pi0 = np.asarray(df_SemilepTag_Dstar_pi0_m30.drop(['Mmin2', 'Mmax2'], axis=1))
#
# dataB_D = np.asarray(df_BkgStag_D.drop(['Mmin2', 'Mmax2'], axis=1))
# dataB_Dstar_gamma = np.asarray(df_BkgStag_Dstar_gamma.drop(['Mmin2', 'Mmax2'], axis=1))
# dataB_Dstar_pi0 = np.asarray(df_BkgStag_Dstar_pi0.drop(['Mmin2', 'Mmax2'], axis=1))

# %%
dataS = np.asarray(df_sig_train)
dataB = np.asarray(df_bkg_train)
# Here, we construct the data from the data used in the training
#dataS = np.asarray(Sig)
#dataB = np.asarray(Bkg)

# Here the data from the other half
'''dataS_D = np.asarray(df_SemilepTag_m00_eval)
dataS_Dstar_gamma = np.asarray(df_SemilepTag_Dstar_gamma_m00_eval)
dataS_Dstar_pi0 = np.asarray(df_SemilepTag_Dstar_pi0_m00_eval)

dataS_D = np.asarray(df_SemilepTag_m10_eval)
dataS_Dstar_gamma = np.asarray(df_SemilepTag_Dstar_gamma_m10_eval)
dataS_Dstar_pi0 = np.asarray(df_SemilepTag_Dstar_pi0_m10_eval)

dataS_D = np.asarray(df_SemilepTag_m20_eval)
dataS_Dstar_gamma = np.asarray(df_SemilepTag_Dstar_gamma_m20_eval)
dataS_Dstar_pi0 = np.asarray(df_SemilepTag_Dstar_pi0_m20_eval)

dataS_D = np.asarray(df_SemilepTag_m30_eval)
dataS_Dstar_gamma = np.asarray(df_SemilepTag_Dstar_gamma_m30_eval)
dataS_Dstar_pi0 = np.asarray(df_SemilepTag_Dstar_pi0_m30_eval)

dataS_D = np.asarray(df_SemilepTag_m40_eval)
dataS_Dstar_gamma = np.asarray(df_SemilepTag_Dstar_gamma_m40_eval)
dataS_Dstar_pi0 = np.asarray(df_SemilepTag_Dstar_pi0_m40_eval)'''

dataS_D = np.asarray(df_SemilepTag_m50_eval)
dataS_Dstar_gamma = np.asarray(df_SemilepTag_Dstar_gamma_m50_eval)
dataS_Dstar_pi0 = np.asarray(df_SemilepTag_Dstar_pi0_m50_eval)

dataB_D = np.asarray(df_BkgStag_D_eval)
dataB_Dstar_gamma = np.asarray(df_BkgStag_Dstar_gamma_eval)
dataB_Dstar_pi0 = np.asarray(df_BkgStag_Dstar_pi0_eval)

# %% [markdown]
# dataS = np.asarray(df_sig_train)
# dataB = np.asarray(df_bkg_train)
# # Here, we construct the data from the data used in the training
# #dataS = np.asarray(Sig)
# #dataB = np.asarray(Bkg)
#
# # Here the data from the other half
# dataS_D = np.asarray(df_HadronicTag_m00_eval)
# dataS_Dstar_gamma = np.asarray(df_HadronicTag_Dstar_gamma_m00_eval)
# dataS_Dstar_pi0 = np.asarray(df_HadronicTag_Dstar_pi0_m00_eval)
#
# '''dataS_D = np.asarray(df_HadronicTag_m10_eval)
# dataS_Dstar_gamma = np.asarray(df_HadronicTag_Dstar_gamma_m10_eval)
# dataS_Dstar_pi0 = np.asarray(df_HadronicTag_Dstar_pi0_m10_eval)
#
# dataS_D = np.asarray(df_HadronicTag_m20_eval)
# dataS_Dstar_gamma = np.asarray(df_HadronicTag_Dstar_gamma_m20_eval)
# dataS_Dstar_pi0 = np.asarray(df_HadronicTag_Dstar_pi0_m20_eval)
#
# dataS_D = np.asarray(df_HadronicTag_m30_eval)
# dataS_Dstar_gamma = np.asarray(df_HadronicTag_Dstar_gamma_m30_eval)
# dataS_Dstar_pi0 = np.asarray(df_HadronicTag_Dstar_pi0_m30_eval)
#
# dataS_D = np.asarray(df_HadronicTag_m40_eval)
# dataS_Dstar_gamma = np.asarray(df_HadronicTag_Dstar_gamma_m40_eval)
# dataS_Dstar_pi0 = np.asarray(df_HadronicTag_Dstar_pi0_m40_eval)
#
# dataS_D = np.asarray(df_HadronicTag_m50_eval)
# dataS_Dstar_gamma = np.asarray(df_HadronicTag_Dstar_gamma_m50_eval)
# dataS_Dstar_pi0 = np.asarray(df_HadronicTag_Dstar_pi0_m50_eval)'''
#
# dataB_D = np.asarray(df_BkgHtag_D_eval)
# dataB_Dstar_gamma = np.asarray(df_BkgHtag_Dstar_gamma_eval)
# dataB_Dstar_pi0 = np.asarray(df_BkgHtag_Dstar_pi0_eval)

# %%
# Creation of the BDT variable
bdtS = xgb_model.predict_proba(dataS)[:,1]
bdtB = xgb_model.predict_proba(dataB)[:,1]

bdtS_D = xgb_model.predict_proba(dataS_D)[:,1] # Toma todos los datos de las 4 entradas de leaf
bdtS_Dstar_gamma = xgb_model.predict_proba(dataS_Dstar_gamma)[:,1]
bdtS_Dstar_pi0 = xgb_model.predict_proba(dataS_Dstar_pi0)[:,1]

bdtB_D = xgb_model.predict_proba(dataB_D)[:,1]
bdtB_Dstar_gamma = xgb_model.predict_proba(dataB_Dstar_gamma)[:,1]
bdtB_Dstar_pi0 = xgb_model.predict_proba(dataB_Dstar_pi0)[:,1]

# %%
from array import array
# Significancia de Punzi
#m00
bdtmax = 1.5
bdtmin = -0.05

#bdtmax = 2.5
#bdtmin = -2.5
# m45
#bdtmax = 1.0
#bdtmin = -0.05

nbins = 50
binsize = (bdtmax - bdtmin)/nbins        # Ancho de los bines del histograma

psampling = [bdtmin+i*binsize for i in range(nbins)]

dSigBdt = np.reshape(dataS,(len(dataS),-1)) # Reordena a 'dataS' con numero de filas 'len(dataS)' y columns '-1' 
dBkgBdt = np.reshape(dataB,(len(dataB),-1)) 

#dBkgBdt2 = np.reshape(dataB2,(len(dataB2),-1))
#print(dBkgBdt1)
#dBkgBdt = np.concatenate((dBkgBdt1,dBkgBdt2))

bdtSC = np.reshape(bdtS,(len(bdtS),-1)) # Reordena bdtS con número de filas 'len(bdtS)' y columnas '-1'
bdtBC = np.reshape(bdtB,(len(bdtB),-1))

dSigBdt = np.append(dSigBdt,bdtSC,axis=1)  # Añade a 'dSigBdt' los datos del eje 1 de 'bdtSC'
dBkgBdt = np.append(dBkgBdt,bdtBC,axis=1)

ngenSig = len(df_sig_train.index)#500000  # la mitad de los datos son tomados, la otra mitad fue en entrenamiento

apar = 5        # Desviación estándar de 5 sigma con un nivel de confianza del 99,9999426697 % 
Amp = 10000   

x ,y = array('d'),array('d')

for i in range(len(psampling)):
    nbkg = len([x for x in dBkgBdt if x[2]>psampling[i]])
    nsig = len([x for x in dSigBdt if x[2]>psampling[i]])
    eff = nsig/ngenSig
    punzi =eff/( apar/2 + np.sqrt(nbkg))
    x.append(psampling[i])
    y.append(Amp*punzi)
    #print(psampling[i]," ",nbkg," ", nsig," ",eff," ",punzi)

#Let's find the maximum
ymaxval = np.amax(y)
x_at_max_array = np.where(y==np.amax(y))
x_at_max = x[int(x_at_max_array[0])]
print("maximum at x = ",x_at_max)


point = ROOT.TMarker(x_at_max,ymaxval, 21)
#point.SetMakerColor(ROOT.kFullSquare)
point.SetMarkerColor(ROOT.kBlack)
#point.SetMarkerStyle(21)

gFOM = ROOT.TGraph(len(psampling),x,y)

gFOM.SetLineColor(ROOT.kBlue)
gFOM.SetLineWidth(2)

labelgFOM = ROOT.TLegend(.2, .9, .5, .8);
labelgFOM.AddEntry(gFOM, "criterio de Punzi", "l")
labelgFOM.AddEntry("", f"Mejor corte BDT en: {round(x_at_max, 2)}")

cP = ROOT.TCanvas("cP", "", 800, 600)
#cP.DrawFrame(-0.3, 70, 0.7, 160)
cP.SetGrid()
cP.cd()

gFOM.SetTitle("Criterio de Punzi; Corte en BDT; Eficiencia ")
#gFOM.GetYaxis.SetTitle("Eficiencia")

gFOM.Draw("ACP")
point.Draw()
#gFOM.GetYaxis().SetRangeUser(70, 150)
labelgFOM.Draw()
cP.Draw()
# Out:
# maximum at x =  0.074
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: cP

# %%
def plot_BDT_cut(x_at_max, ngenSig, bdtS, bdtB, dataS, dataB, Variable):
    # Extract the variable indices for 'Mmin', 'Mmax', 'Xps', and 'q2'
    #var_indices = {'Mmin': 0, 'Mmax': 1, 'Xps': 2, 'q2': 3}
    #var_indices = {'Xps': 0, 'q2': 1}
    var_indices = {'Mmin2': 0, 'Mmax2': 1}
    var_index = var_indices[Variable]

    # Filter data based on BDT cut and variable
    VarSig = [dataS[i][var_index] for i in range(len(bdtS)) if bdtS[i] > x_at_max]
    VarBkg = [dataB[i][var_index] for i in range(len(bdtB)) if bdtB[i] > x_at_max]

    finalSig = len(VarSig)
    finalBkg = len(VarBkg)

    print(f"Signal efficiency epsilon: {100 * finalSig / ngenSig:.2f}%")

    VarSig_w = np.full_like(VarSig, 1 / finalSig) if finalSig != 0 else []
    VarBkg_w = np.full_like(VarBkg, 1 / finalSig) if finalSig != 0 else []

    plt.figure(figsize=(10, 8))

    # Plot histograms
    plt.hist([VarSig, VarBkg], weights=[VarSig_w, VarBkg_w], bins=80, range=get_hist_range(Variable),
             label=['Signal', 'Background'], hatch='//', histtype='step', lw=2)

    # Set x-axis label based on the variable
    plt.xlabel(get_x_label(Variable), fontsize=27)

    plt.ylabel("N. Events/ (0.032 GeV/$\mathrm{c}^2$)", fontsize=27)
    plt.legend(loc='upper right')
    plt.grid()
    plt.show()

def get_hist_range(variable):
    if variable == 'Mmin2':
        return (-5.0, 25.0)
    elif variable == 'Mmax2':
        return (-1.0, 24.0)
    elif variable == 'Xps':
        return (0.15, 1.2)
    elif variable == 'q2':
        return (-4.0, 24.0)

def get_x_label(variable):
    if variable == 'Mmin':
        return r"$M_{min}^2$ [GeV/$\mathrm{c}^2$]"
    elif variable == 'Mmax':
        return r"$M_{max}^2$ [GeV/$\mathrm{c}^2$]"
    elif variable == 'Xps':
        return r"$X_{ps}$"
    elif variable == 'q2':
        return r"$q^2_{rec}$"

# Example usage
# plot_BDT_cut(x_at_max, ngenSig, bdtS, bdtB, dataS, dataB, 'Mmin')

# %%
plot_BDT_cut(x_at_max, ngenSig, bdtS_D, bdtB_D, dataS_D, dataB_D, 'Mmin2')
plot_BDT_cut(x_at_max, ngenSig, bdtS_D, bdtB_D, dataS_D, dataB_D, 'Mmax2')
#plot_BDT_cut(x_at_max, ngenSig, bdtS_D, bdtB_D, dataS_D, dataB_D, 'Xps')
#plot_BDT_cut(x_at_max, ngenSig, bdtS_D, bdtB_D, dataS_D, dataB_D, 'q2')
# Out:
# Signal efficiency epsilon: 54.69%
# Signal efficiency epsilon: 54.69%

# %%
'''df_SemilepTag_m00_eval['BDT'] = bdtS_D
df_SemilepTag_Dstar_gamma_m00_eval['BDT'] = bdtS_Dstar_gamma
df_SemilepTag_Dstar_pi0_m00_eval['BDT'] = bdtS_Dstar_pi0

df_SemilepTag_m10_eval['BDT'] = bdtS_D
df_SemilepTag_Dstar_gamma_m10_eval['BDT'] = bdtS_Dstar_gamma
df_SemilepTag_Dstar_pi0_m10_eval['BDT'] = bdtS_Dstar_pi0

df_SemilepTag_m20_eval['BDT'] = bdtS_D
df_SemilepTag_Dstar_gamma_m20_eval['BDT'] = bdtS_Dstar_gamma
df_SemilepTag_Dstar_pi0_m20_eval['BDT'] = bdtS_Dstar_pi0

df_SemilepTag_m30_eval['BDT'] = bdtS_D
df_SemilepTag_Dstar_gamma_m30_eval['BDT'] = bdtS_Dstar_gamma
df_SemilepTag_Dstar_pi0_m30_eval['BDT'] = bdtS_Dstar_pi0

df_SemilepTag_m40_eval['BDT'] = bdtS_D
df_SemilepTag_Dstar_gamma_m40_eval['BDT'] = bdtS_Dstar_gamma
df_SemilepTag_Dstar_pi0_m40_eval['BDT'] = bdtS_Dstar_pi0'''

df_SemilepTag_m50_eval['BDT'] = bdtS_D
df_SemilepTag_Dstar_gamma_m50_eval['BDT'] = bdtS_Dstar_gamma
df_SemilepTag_Dstar_pi0_m50_eval['BDT'] = bdtS_Dstar_pi0

df_BkgStag_D_eval['BDT'] = bdtB_D
df_BkgStag_Dstar_gamma_eval['BDT'] = bdtB_Dstar_gamma
df_BkgStag_Dstar_pi0_eval['BDT'] = bdtB_Dstar_pi0

# %% [markdown]
# df_HadronicTag_m00_eval['BDT'] = bdtS_D
# df_HadronicTag_Dstar_gamma_m00_eval['BDT'] = bdtS_Dstar_gamma
# df_HadronicTag_Dstar_pi0_m00_eval['BDT'] = bdtS_Dstar_pi0
#
# '''df_HadronicTag_m10_eval['BDT'] = bdtS_D
# df_HadronicTag_Dstar_gamma_m10_eval['BDT'] = bdtS_Dstar_gamma
# df_HadronicTag_Dstar_pi0_m10_eval['BDT'] = bdtS_Dstar_pi0
#
# df_HadronicTag_m20_eval['BDT'] = bdtS_D
# df_HadronicTag_Dstar_gamma_m20_eval['BDT'] = bdtS_Dstar_gamma
# df_HadronicTag_Dstar_pi0_m20_eval['BDT'] = bdtS_Dstar_pi0
#
# df_HadronicTag_m30_eval['BDT'] = bdtS_D
# df_HadronicTag_Dstar_gamma_m30_eval['BDT'] = bdtS_Dstar_gamma
# df_HadronicTag_Dstar_pi0_m30_eval['BDT'] = bdtS_Dstar_pi0
#
# df_HadronicTag_m40_eval['BDT'] = bdtS_D
# df_HadronicTag_Dstar_gamma_m40_eval['BDT'] = bdtS_Dstar_gamma
# df_HadronicTag_Dstar_pi0_m40_eval['BDT'] = bdtS_Dstar_pi0
#
# df_HadronicTag_m50_eval['BDT'] = bdtS_D
# df_HadronicTag_Dstar_gamma_m50_eval['BDT'] = bdtS_Dstar_gamma
# df_HadronicTag_Dstar_pi0_m50_eval['BDT'] = bdtS_Dstar_pi0'''
#
# df_BkgHtag_D_eval['BDT'] = bdtB_D
# df_BkgHtag_Dstar_gamma_eval['BDT'] = bdtB_Dstar_gamma
# df_BkgHtag_Dstar_pi0_eval['BDT'] = bdtB_Dstar_pi0

# %% [markdown]
# # Create 'BDT' column and assign predicted values
# df_SemilepTag_m30['BDT'] = xgb_model.predict_proba(np.asarray(df_SemilepTag_m30))[:, 1]
# df_SemilepTag_Dstar_gamma_m30['BDT'] = xgb_model.predict_proba(np.asarray(df_SemilepTag_Dstar_gamma_m30))[:, 1]
# df_SemilepTag_Dstar_pi0_m30['BDT'] = xgb_model.predict_proba(np.asarray(df_SemilepTag_Dstar_pi0_m30))[:, 1]
#
# df_BkgStag_D['BDT'] = xgb_model.predict_proba(np.asarray(df_BkgStag_D))[:, 1]
# df_BkgStag_Dstar_gamma['BDT'] = xgb_model.predict_proba(np.asarray(df_BkgStag_Dstar_gamma))[:, 1]
# df_BkgStag_Dstar_pi0['BDT'] = xgb_model.predict_proba(np.asarray(df_BkgStag_Dstar_pi0))[:, 1]

# %%
#df_SemilepTag_m45_eval

# %%
#df_SemilepTag_Dstar_gamma_m45_eval

# %%
#df_SemilepTag_Dstar_pi0_m45_eval

# %%
#df_BkgStag_D_eval

# %%
#df_BkgStag_Dstar_gamma_eval

# %%
#df_BkgStag_Dstar_pi0_eval

# %%
'''df_SemilepTag_m00_eval.to_csv('../Analysis/Files/CSV_Files/SemilepTag_D_m00_bdt.csv')
df_SemilepTag_Dstar_gamma_m00_eval.to_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m00_bdt.csv')
df_SemilepTag_Dstar_pi0_m00_eval.to_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_pi0_m00_bdt.csv')

df_SemilepTag_m10_eval.to_csv('../Analysis/Files/CSV_Files/SemilepTag_D_m10_bdt.csv')
df_SemilepTag_Dstar_gamma_m10_eval.to_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m10_bdt.csv')
df_SemilepTag_Dstar_pi0_m10_eval.to_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_pi0_m10_bdt.csv')

df_SemilepTag_m20_eval.to_csv('../Analysis/Files/CSV_Files/SemilepTag_D_m20_bdt.csv')
df_SemilepTag_Dstar_gamma_m20_eval.to_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m20_bdt.csv')
df_SemilepTag_Dstar_pi0_m20_eval.to_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_pi0_m20_bdt.csv')

df_SemilepTag_m30_eval.to_csv('../Analysis/Files/CSV_Files/SemilepTag_D_m30_bdt.csv')
df_SemilepTag_Dstar_gamma_m30_eval.to_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m30_bdt.csv')
df_SemilepTag_Dstar_pi0_m30_eval.to_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_pi0_m30_bdt.csv')

df_SemilepTag_m40_eval.to_csv('../Analysis/Files/CSV_Files/SemilepTag_D_m40_bdt.csv')
df_SemilepTag_Dstar_gamma_m40_eval.to_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m40_bdt.csv')
df_SemilepTag_Dstar_pi0_m40_eval.to_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_pi0_m40_bdt.csv')'''

df_SemilepTag_m50_eval.to_csv('../Analysis/Files/CSV_Files/SemilepTag_D_m50_bdt.csv')
df_SemilepTag_Dstar_gamma_m50_eval.to_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m50_bdt.csv')
df_SemilepTag_Dstar_pi0_m50_eval.to_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_pi0_m50_bdt.csv')

# %%
'''df_BkgStag_D_eval.to_csv('../Analysis/Files/CSV_Files/BkgStag_D_m00_bdt.csv')
df_BkgStag_Dstar_gamma_eval.to_csv('../Analysis/Files/CSV_Files/BkgStag_Dstar_gamma_m00_bdt.csv')
df_BkgStag_Dstar_pi0_eval.to_csv('../Analysis/Files/CSV_Files/BkgStag_Dstar_pi0_m00_bdt.csv')

df_BkgStag_D_eval.to_csv('../Analysis/Files/CSV_Files/BkgStag_D_m10_bdt.csv')
df_BkgStag_Dstar_gamma_eval.to_csv('../Analysis/Files/CSV_Files/BkgStag_Dstar_gamma_m10_bdt.csv')
df_BkgStag_Dstar_pi0_eval.to_csv('../Analysis/Files/CSV_Files/BkgStag_Dstar_pi0_m10_bdt.csv')

df_BkgStag_D_eval.to_csv('../Analysis/Files/CSV_Files/BkgStag_D_m20_bdt.csv')
df_BkgStag_Dstar_gamma_eval.to_csv('../Analysis/Files/CSV_Files/BkgStag_Dstar_gamma_m20_bdt.csv')
df_BkgStag_Dstar_pi0_eval.to_csv('../Analysis/Files/CSV_Files/BkgStag_Dstar_pi0_m20_bdt.csv')

df_BkgStag_D_eval.to_csv('../Analysis/Files/CSV_Files/BkgStag_D_m30_bdt.csv')
df_BkgStag_Dstar_gamma_eval.to_csv('../Analysis/Files/CSV_Files/BkgStag_Dstar_gamma_m30_bdt.csv')
df_BkgStag_Dstar_pi0_eval.to_csv('../Analysis/Files/CSV_Files/BkgStag_Dstar_pi0_m30_bdt.csv')

df_BkgStag_D_eval.to_csv('../Analysis/Files/CSV_Files/BkgStag_D_m40_bdt.csv')
df_BkgStag_Dstar_gamma_eval.to_csv('../Analysis/Files/CSV_Files/BkgStag_Dstar_gamma_m40_bdt.csv')
df_BkgStag_Dstar_pi0_eval.to_csv('../Analysis/Files/CSV_Files/BkgStag_Dstar_pi0_m40_bdt.csv')'''

df_BkgStag_D_eval.to_csv('../Analysis/Files/CSV_Files/BkgStag_D_m50_bdt.csv')
df_BkgStag_Dstar_gamma_eval.to_csv('../Analysis/Files/CSV_Files/BkgStag_Dstar_gamma_m50_bdt.csv')
df_BkgStag_Dstar_pi0_eval.to_csv('../Analysis/Files/CSV_Files/BkgStag_Dstar_pi0_m50_bdt.csv')

# %% [markdown]
# df_HadronicTag_m00_eval.to_csv('../Analysis/Files/CSV_Files/HadronicTag_D_m00_bdt.csv')
# df_HadronicTag_Dstar_gamma_m00_eval.to_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m00_bdt.csv')
# df_HadronicTag_Dstar_pi0_m00_eval.to_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m00_bdt.csv')
#
# '''df_HadronicTag_m10_eval.to_csv('../Analysis/Files/CSV_Files/HadronicTag_D_m10_bdt.csv')
# df_HadronicTag_Dstar_gamma_m10_eval.to_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m10_bdt.csv')
# df_HadronicTag_Dstar_pi0_m10_eval.to_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m10_bdt.csv')
#
# df_HadronicTag_m20_eval.to_csv('../Analysis/Files/CSV_Files/HadronicTag_D_m20_bdt.csv')
# df_HadronicTag_Dstar_gamma_m20_eval.to_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m20_bdt.csv')
# df_HadronicTag_Dstar_pi0_m20_eval.to_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m20_bdt.csv')
#
# df_HadronicTag_m30_eval.to_csv('../Analysis/Files/CSV_Files/HadronicTag_D_m30_bdt.csv')
# df_HadronicTag_Dstar_gamma_m30_eval.to_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m30_bdt.csv')
# df_HadronicTag_Dstar_pi0_m30_eval.to_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m30_bdt.csv')
#
# df_HadronicTag_m40_eval.to_csv('../Analysis/Files/CSV_Files/HadronicTag_D_m40_bdt.csv')
# df_HadronicTag_Dstar_gamma_m40_eval.to_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m40_bdt.csv')
# df_HadronicTag_Dstar_pi0_m40_eval.to_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m40_bdt.csv')
#
# df_HadronicTag_m50_eval.to_csv('../Analysis/Files/CSV_Files/HadronicTag_D_m50_bdt.csv')
# df_HadronicTag_Dstar_gamma_m50_eval.to_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m50_bdt.csv')
# df_HadronicTag_Dstar_pi0_m50_eval.to_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m50_bdt.csv')'''

# %% [markdown]
# df_BkgHtag_D_eval.to_csv('../Analysis/Files/CSV_Files/BkgHtag_D_m00_bdt.csv')
# df_BkgHtag_Dstar_gamma_eval.to_csv('../Analysis/Files/CSV_Files/BkgHtag_Dstar_gamma_m00_bdt.csv')
# df_BkgHtag_Dstar_pi0_eval.to_csv('../Analysis/Files/CSV_Files/BkgHtag_Dstar_pi0_m00_bdt.csv')
#
# '''df_BkgHtag_D_eval.to_csv('../Analysis/Files/CSV_Files/BkgHtag_D_m10_bdt.csv')
# df_BkgHtag_Dstar_gamma_eval.to_csv('../Analysis/Files/CSV_Files/BkgHtag_Dstar_gamma_m10_bdt.csv')
# df_BkgHtag_Dstar_pi0_eval.to_csv('../Analysis/Files/CSV_Files/BkgHtag_Dstar_pi0_m10_bdt.csv')
#
# df_BkgHtag_D_eval.to_csv('../Analysis/Files/CSV_Files/BkgHtag_D_m20_bdt.csv')
# df_BkgHtag_Dstar_gamma_eval.to_csv('../Analysis/Files/CSV_Files/BkgHtag_Dstar_gamma_m20_bdt.csv')
# df_BkgHtag_Dstar_pi0_eval.to_csv('../Analysis/Files/CSV_Files/BkgHtag_Dstar_pi0_m20_bdt.csv')
#
# df_BkgHtag_D_eval.to_csv('../Analysis/Files/CSV_Files/BkgHtag_D_m30_bdt.csv')
# df_BkgHtag_Dstar_gamma_eval.to_csv('../Analysis/Files/CSV_Files/BkgHtag_Dstar_gamma_m30_bdt.csv')
# df_BkgHtag_Dstar_pi0_eval.to_csv('../Analysis/Files/CSV_Files/BkgHtag_Dstar_pi0_m30_bdt.csv')
#
# df_BkgHtag_D_eval.to_csv('../Analysis/Files/CSV_Files/BkgHtag_D_m40_bdt.csv')
# df_BkgHtag_Dstar_gamma_eval.to_csv('../Analysis/Files/CSV_Files/BkgHtag_Dstar_gamma_m40_bdt.csv')
# df_BkgHtag_Dstar_pi0_eval.to_csv('../Analysis/Files/CSV_Files/BkgHtag_Dstar_pi0_m40_bdt.csv')
#
# df_BkgHtag_D_eval.to_csv('../Analysis/Files/CSV_Files/BkgHtag_D_m50_bdt.csv')
# df_BkgHtag_Dstar_gamma_eval.to_csv('../Analysis/Files/CSV_Files/BkgHtag_Dstar_gamma_m50_bdt.csv')
# df_BkgHtag_Dstar_pi0_eval.to_csv('../Analysis/Files/CSV_Files/BkgHtag_Dstar_pi0_m50_bdt.csv')'''

# %%
df_HadronicTag_m40_eval
# Out:
#             Xps         q2
# 29081  0.423420  16.276942
# 36053  0.426571  16.385092
# 86215  0.423934  16.887547
# 20319  0.424374  15.366223
# 72246  0.426303  15.140285
# ...         ...        ...
# 21440  0.427381  15.449894
# 73349  0.422979  15.808599
# 50057  0.428969  16.550010
# 5192   0.428414  16.356759
# 77708  0.426939  15.650989
#
# [45138 rows x 2 columns]
