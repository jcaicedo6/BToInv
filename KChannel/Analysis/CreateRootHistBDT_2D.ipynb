# %%
import ROOT
import numpy as np
import pandas as pd
import random

import matplotlib.pyplot as plt
import time
import math, copy
# Out:
# Welcome to JupyROOT 6.26/06

# %%
df_SemilepTag_m00 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_D_m00_bdt.csv')
df_SemilepTag_Dstar_gamma_m00 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m00_bdt.csv')
df_SemilepTag_Dstar_pi0_m00 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_pi0_m00_bdt.csv')

df_SemilepTag_m10 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_D_m10_bdt.csv')
df_SemilepTag_Dstar_gamma_m10 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m10_bdt.csv')
df_SemilepTag_Dstar_pi0_m10 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_pi0_m10_bdt.csv')

df_SemilepTag_m20 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_D_m20_bdt.csv')
df_SemilepTag_Dstar_gamma_m20 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m20_bdt.csv')
df_SemilepTag_Dstar_pi0_m20 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_pi0_m20_bdt.csv')

df_SemilepTag_m30 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_D_m30_bdt.csv')
df_SemilepTag_Dstar_gamma_m30 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m30_bdt.csv')
df_SemilepTag_Dstar_pi0_m30 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_pi0_m30_bdt.csv')

df_SemilepTag_m40 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_D_m40_bdt.csv')
df_SemilepTag_Dstar_gamma_m40 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m40_bdt.csv')
df_SemilepTag_Dstar_pi0_m40 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_pi0_m40_bdt.csv')

df_SemilepTag_m45 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_D_m45_bdt.csv')
df_SemilepTag_Dstar_gamma_m45 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m45_bdt.csv')
df_SemilepTag_Dstar_pi0_m45 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_pi0_m45_bdt.csv')


df_BkgStag_D_m00 = pd.read_csv('../Analysis/Files/CSV_Files/BkgStag_D_m00_bdt.csv')
df_BkgStag_Dstar_gamma_m00 = pd.read_csv('../Analysis/Files/CSV_Files/BkgStag_Dstar_gamma_m00_bdt.csv')
df_BkgStag_Dstar_pi0_m00 = pd.read_csv('../Analysis/Files/CSV_Files/BkgStag_Dstar_pi0_m00_bdt.csv')

df_BkgStag_D_m10 = pd.read_csv('../Analysis/Files/CSV_Files/BkgStag_D_m10_bdt.csv')
df_BkgStag_Dstar_gamma_m10 = pd.read_csv('../Analysis/Files/CSV_Files/BkgStag_Dstar_gamma_m10_bdt.csv')
df_BkgStag_Dstar_pi0_m10 = pd.read_csv('../Analysis/Files/CSV_Files/BkgStag_Dstar_pi0_m10_bdt.csv')

df_BkgStag_D_m20 = pd.read_csv('../Analysis/Files/CSV_Files/BkgStag_D_m20_bdt.csv')
df_BkgStag_Dstar_gamma_m20 = pd.read_csv('../Analysis/Files/CSV_Files/BkgStag_Dstar_gamma_m20_bdt.csv')
df_BkgStag_Dstar_pi0_m20 = pd.read_csv('../Analysis/Files/CSV_Files/BkgStag_Dstar_pi0_m20_bdt.csv')

df_BkgStag_D_m30 = pd.read_csv('../Analysis/Files/CSV_Files/BkgStag_D_m30_bdt.csv')
df_BkgStag_Dstar_gamma_m30 = pd.read_csv('../Analysis/Files/CSV_Files/BkgStag_Dstar_gamma_m30_bdt.csv')
df_BkgStag_Dstar_pi0_m30 = pd.read_csv('../Analysis/Files/CSV_Files/BkgStag_Dstar_pi0_m30_bdt.csv')

df_BkgStag_D_m40 = pd.read_csv('../Analysis/Files/CSV_Files/BkgStag_D_m40_bdt.csv')
df_BkgStag_Dstar_gamma_m40 = pd.read_csv('../Analysis/Files/CSV_Files/BkgStag_Dstar_gamma_m40_bdt.csv')
df_BkgStag_Dstar_pi0_m40 = pd.read_csv('../Analysis/Files/CSV_Files/BkgStag_Dstar_pi0_m40_bdt.csv')

df_BkgStag_D_m45 = pd.read_csv('../Analysis/Files/CSV_Files/BkgStag_D_m45_bdt.csv')
df_BkgStag_Dstar_gamma_m45 = pd.read_csv('../Analysis/Files/CSV_Files/BkgStag_Dstar_gamma_m45_bdt.csv')
df_BkgStag_Dstar_pi0_m45 = pd.read_csv('../Analysis/Files/CSV_Files/BkgStag_Dstar_pi0_m45_bdt.csv')

# %%
df_HadronicTag_m00 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_D_m00_bdt.csv')
df_HadronicTag_Dstar_gamma_m00 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m00_bdt.csv')
df_HadronicTag_Dstar_pi0_m00 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m00_bdt.csv')

df_HadronicTag_m10 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_D_m10_bdt.csv')
df_HadronicTag_Dstar_gamma_m10 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m10_bdt.csv')
df_HadronicTag_Dstar_pi0_m10 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m10_bdt.csv')

df_HadronicTag_m20 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_D_m20_bdt.csv')
df_HadronicTag_Dstar_gamma_m20 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m20_bdt.csv')
df_HadronicTag_Dstar_pi0_m20 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m20_bdt.csv')

df_HadronicTag_m30 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_D_m30_bdt.csv')
df_HadronicTag_Dstar_gamma_m30 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m30_bdt.csv')
df_HadronicTag_Dstar_pi0_m30 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m30_bdt.csv')

df_HadronicTag_m40 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_D_m40_bdt.csv')
df_HadronicTag_Dstar_gamma_m40 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m40_bdt.csv')
df_HadronicTag_Dstar_pi0_m40 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m40_bdt.csv')

df_HadronicTag_m45 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_D_m45_bdt.csv')
df_HadronicTag_Dstar_gamma_m45 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m45_bdt.csv')
df_HadronicTag_Dstar_pi0_m45 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m45_bdt.csv')


df_BkgHtag_D_m00 = pd.read_csv('../Analysis/Files/CSV_Files/BkgHtag_D_m00_bdt.csv')
df_BkgHtag_Dstar_gamma_m00 = pd.read_csv('../Analysis/Files/CSV_Files/BkgHtag_Dstar_gamma_m00_bdt.csv')
df_BkgHtag_Dstar_pi0_m00 = pd.read_csv('../Analysis/Files/CSV_Files/BkgHtag_Dstar_pi0_m00_bdt.csv')

df_BkgHtag_D_m10 = pd.read_csv('../Analysis/Files/CSV_Files/BkgHtag_D_m10_bdt.csv')
df_BkgHtag_Dstar_gamma_m10 = pd.read_csv('../Analysis/Files/CSV_Files/BkgHtag_Dstar_gamma_m10_bdt.csv')
df_BkgHtag_Dstar_pi0_m10 = pd.read_csv('../Analysis/Files/CSV_Files/BkgHtag_Dstar_pi0_m10_bdt.csv')

df_BkgHtag_D_m20 = pd.read_csv('../Analysis/Files/CSV_Files/BkgHtag_D_m20_bdt.csv')
df_BkgHtag_Dstar_gamma_m20 = pd.read_csv('../Analysis/Files/CSV_Files/BkgHtag_Dstar_gamma_m20_bdt.csv')
df_BkgHtag_Dstar_pi0_m20 = pd.read_csv('../Analysis/Files/CSV_Files/BkgHtag_Dstar_pi0_m20_bdt.csv')

df_BkgHtag_D_m30 = pd.read_csv('../Analysis/Files/CSV_Files/BkgHtag_D_m30_bdt.csv')
df_BkgHtag_Dstar_gamma_m30 = pd.read_csv('../Analysis/Files/CSV_Files/BkgHtag_Dstar_gamma_m30_bdt.csv')
df_BkgHtag_Dstar_pi0_m30 = pd.read_csv('../Analysis/Files/CSV_Files/BkgHtag_Dstar_pi0_m30_bdt.csv')

df_BkgHtag_D_m40 = pd.read_csv('../Analysis/Files/CSV_Files/BkgHtag_D_m40_bdt.csv')
df_BkgHtag_Dstar_gamma_m40 = pd.read_csv('../Analysis/Files/CSV_Files/BkgHtag_Dstar_gamma_m40_bdt.csv')
df_BkgHtag_Dstar_pi0_m40 = pd.read_csv('../Analysis/Files/CSV_Files/BkgHtag_Dstar_pi0_m40_bdt.csv')

df_BkgHtag_D_m45 = pd.read_csv('../Analysis/Files/CSV_Files/BkgHtag_D_m45_bdt.csv')
df_BkgHtag_Dstar_gamma_m45 = pd.read_csv('../Analysis/Files/CSV_Files/BkgHtag_Dstar_gamma_m45_bdt.csv')
df_BkgHtag_Dstar_pi0_m45 = pd.read_csv('../Analysis/Files/CSV_Files/BkgHtag_Dstar_pi0_m45_bdt.csv')

# %%
# Loading the files without the split for the BDT
df_HadronicTag_2D_m00 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_m00_wc.csv')
df_HadronicTag_2D_m10 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_m10_wc.csv')
df_HadronicTag_2D_m20 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_m20_wc.csv')
df_HadronicTag_2D_m30 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_m30_wc.csv')
df_HadronicTag_2D_m40 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_m40_wc.csv')
df_HadronicTag_2D_m45 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_m45_wc.csv')

df_HadronicTag_2D_Dstar_gamma_m00 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m00_wc.csv')
df_HadronicTag_2D_Dstar_gamma_m10 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m10_wc.csv')
df_HadronicTag_2D_Dstar_gamma_m20 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m20_wc.csv')
df_HadronicTag_2D_Dstar_gamma_m30 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m30_wc.csv')
df_HadronicTag_2D_Dstar_gamma_m40 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m40_wc.csv')
df_HadronicTag_2D_Dstar_gamma_m45 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_gamma_m45_wc.csv')

df_HadronicTag_2D_Dstar_pi0_m00 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m00_wc.csv')
df_HadronicTag_2D_Dstar_pi0_m10 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m10_wc.csv')
df_HadronicTag_2D_Dstar_pi0_m20 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m20_wc.csv')
df_HadronicTag_2D_Dstar_pi0_m30 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m30_wc.csv')
df_HadronicTag_2D_Dstar_pi0_m40 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m40_wc.csv')
df_HadronicTag_2D_Dstar_pi0_m45 = pd.read_csv('../Analysis/Files/CSV_Files/HadronicTag_Dstar_pi0_m45_wc.csv')

df_SemilepTag_2D_m00 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_m00_wc.csv')
df_SemilepTag_2D_m10 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_m10_wc.csv')
df_SemilepTag_2D_m20 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_m20_wc.csv')
df_SemilepTag_2D_m30 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_m30_wc.csv')
df_SemilepTag_2D_m40 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_m40_wc.csv')
df_SemilepTag_2D_m45 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_m45_wc.csv')

df_SemilepTag_2D_Dstar_gamma_m00 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m00_wc.csv')
df_SemilepTag_2D_Dstar_gamma_m10 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m10_wc.csv')
df_SemilepTag_2D_Dstar_gamma_m20 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m20_wc.csv')
df_SemilepTag_2D_Dstar_gamma_m30 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m30_wc.csv')
df_SemilepTag_2D_Dstar_gamma_m40 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m40_wc.csv')
df_SemilepTag_2D_Dstar_gamma_m45 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_gamma_m45_wc.csv')

df_SemilepTag_2D_Dstar_pi0_m00 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_pi0_m00_wc.csv')
df_SemilepTag_2D_Dstar_pi0_m10 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_pi0_m10_wc.csv')
df_SemilepTag_2D_Dstar_pi0_m20 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_pi0_m20_wc.csv')
df_SemilepTag_2D_Dstar_pi0_m30 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_pi0_m30_wc.csv')
df_SemilepTag_2D_Dstar_pi0_m40 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_pi0_m40_wc.csv')
df_SemilepTag_2D_Dstar_pi0_m45 = pd.read_csv('../Analysis/Files/CSV_Files/SemilepTag_Dstar_pi0_m45_wc.csv')

df_BkgHtag_2D_D = pd.read_csv('../Analysis/Files/CSV_Files/BkgHtag_D_wc.csv')
df_BkgHtag_2D_Dstar_gamma = pd.read_csv('../Analysis/Files/CSV_Files/BkgHtag_Dstar_gamma_wc.csv')
df_BkgHtag_2D_Dstar_pi0 = pd.read_csv('../Analysis/Files/CSV_Files/BkgHtag_Dstar_pi0_wc.csv')

df_BkgStag_2D_D = pd.read_csv('../Analysis/Files/CSV_Files/BkgStag_D_wc.csv')
df_BkgStag_2D_Dstar_gamma = pd.read_csv('../Analysis/Files/CSV_Files/BkgStag_Dstar_gamma_wc.csv')
df_BkgStag_2D_Dstar_pi0 = pd.read_csv('../Analysis/Files/CSV_Files/BkgStag_Dstar_pi0_wc.csv')

# %%
df_BkgStag_D_m30
# Out:
#        Unnamed: 0        Mmin2        Mmax2       Xps         q2       BDT
# 0           18210     9.557691    11.001431  0.644160  10.435016  0.090389
# 1           27413     8.589726    10.107959  0.690002   9.673659  0.944171
# 2           10497     8.222341     9.789544  0.688929   9.250618  0.927714
# 3           11775     1.112960     1.725569  1.009479   0.647579  0.000006
# 4           23656  1000.000000  1000.000000  0.522437  13.410685  0.001505
# ...           ...          ...          ...       ...        ...       ...
# 14250       10955     7.880217     8.163028  0.722818   8.369810  0.042094
# 14251       17289    16.078371    17.176783  0.420889  16.794460  0.015895
# 14252        5192    16.212444    16.954651  0.425376  16.885920  0.000875
# 14253       12172     0.753255     3.469913  0.904510   2.471180  0.000006
# 14254         235    13.525283    14.203589  0.521774  14.265747  0.029171
#
# [14255 rows x 6 columns]

# %%
def PandasToRD(df, flag):
    # Extract the leafs from pandas df
    #leafs = df.columns.values.tolist()
    if flag == 1:
        leafs = ['Xps', 'q2', 'BDT']
    elif flag == 2: 
        leafs = ['Mmin2', 'Mmax2', 'Xps', 'q2', 'BDT']
    elif flag == 3:
        leafs = ['Xps', 'q2']
    else: leafs = ['Mmin2', 'Mmax2', 'Xps', 'q2']
    # Read the pandas dataframe in form of dictionary
    df_dic = {key: df[key].values for key in leafs}
    # write the dictionary with numpy arrays to a RDataframe
    RD_df = ROOT.RDF.MakeNumpyDataFrame(df_dic)
    #RD_df = ROOT.RDF.FromCSV("myfile.csv")
    return RD_df

# %%
sig_SemiTag_D_m00_df = PandasToRD(df_SemilepTag_m00, flag=2)
sig_SemiTag_Dstar_gamma_m00_df = PandasToRD(df_SemilepTag_Dstar_gamma_m00, flag=2)
sig_SemiTag_Dstar_pi0_m00_df = PandasToRD(df_SemilepTag_Dstar_pi0_m00, flag=2)

sig_SemiTag_D_m10_df = PandasToRD(df_SemilepTag_m10, flag=2)
sig_SemiTag_Dstar_gamma_m10_df = PandasToRD(df_SemilepTag_Dstar_gamma_m10, flag=2)
sig_SemiTag_Dstar_pi0_m10_df = PandasToRD(df_SemilepTag_Dstar_pi0_m10, flag=2)

sig_SemiTag_D_m20_df = PandasToRD(df_SemilepTag_m20, flag=2)
sig_SemiTag_Dstar_gamma_m20_df = PandasToRD(df_SemilepTag_Dstar_gamma_m20, flag=2)
sig_SemiTag_Dstar_pi0_m20_df = PandasToRD(df_SemilepTag_Dstar_pi0_m20, flag=2)

sig_SemiTag_D_m30_df = PandasToRD(df_SemilepTag_m30, flag=2)
sig_SemiTag_Dstar_gamma_m30_df = PandasToRD(df_SemilepTag_Dstar_gamma_m30, flag=2)
sig_SemiTag_Dstar_pi0_m30_df = PandasToRD(df_SemilepTag_Dstar_pi0_m30, flag=2)

sig_SemiTag_D_m40_df = PandasToRD(df_SemilepTag_m40, flag=2)
sig_SemiTag_Dstar_gamma_m40_df = PandasToRD(df_SemilepTag_Dstar_gamma_m40, flag=2)
sig_SemiTag_Dstar_pi0_m40_df = PandasToRD(df_SemilepTag_Dstar_pi0_m40, flag=2)

sig_SemiTag_D_m45_df = PandasToRD(df_SemilepTag_m45, flag=2)
sig_SemiTag_Dstar_gamma_m45_df = PandasToRD(df_SemilepTag_Dstar_gamma_m45, flag=2)
sig_SemiTag_Dstar_pi0_m45_df = PandasToRD(df_SemilepTag_Dstar_pi0_m45, flag=2)


BkgStag_D_m00_df = PandasToRD(df_BkgStag_D_m00, flag=2)
BkgStag_Dstar_gamma_m00_df = PandasToRD(df_BkgStag_Dstar_gamma_m00, flag=2)
BkgStag_Dstar_pi0_m00_df = PandasToRD(df_BkgStag_Dstar_pi0_m00, flag=2)

BkgStag_D_m10_df = PandasToRD(df_BkgStag_D_m10, flag=2)
BkgStag_Dstar_gamma_m10_df = PandasToRD(df_BkgStag_Dstar_gamma_m10, flag=2)
BkgStag_Dstar_pi0_m10_df = PandasToRD(df_BkgStag_Dstar_pi0_m10, flag=2)

BkgStag_D_m20_df = PandasToRD(df_BkgStag_D_m20, flag=2)
BkgStag_Dstar_gamma_m20_df = PandasToRD(df_BkgStag_Dstar_gamma_m20, flag=2)
BkgStag_Dstar_pi0_m20_df = PandasToRD(df_BkgStag_Dstar_pi0_m20, flag=2)

BkgStag_D_m30_df = PandasToRD(df_BkgStag_D_m30, flag=2)
BkgStag_Dstar_gamma_m30_df = PandasToRD(df_BkgStag_Dstar_gamma_m30, flag=2)
BkgStag_Dstar_pi0_m30_df = PandasToRD(df_BkgStag_Dstar_pi0_m30, flag=2)

BkgStag_D_m40_df = PandasToRD(df_BkgStag_D_m40, flag=2)
BkgStag_Dstar_gamma_m40_df = PandasToRD(df_BkgStag_Dstar_gamma_m40, flag=2)
BkgStag_Dstar_pi0_m40_df = PandasToRD(df_BkgStag_Dstar_pi0_m40, flag=2)

BkgStag_D_m45_df = PandasToRD(df_BkgStag_D_m45, flag=2)
BkgStag_Dstar_gamma_m45_df = PandasToRD(df_BkgStag_Dstar_gamma_m45, flag=2)
BkgStag_Dstar_pi0_m45_df = PandasToRD(df_BkgStag_Dstar_pi0_m45, flag=2)

# %%
sig_HadTag_D_m00_df = PandasToRD(df_HadronicTag_m00, flag=1)
sig_HadTag_Dstar_gamma_m00_df = PandasToRD(df_HadronicTag_Dstar_gamma_m00, flag=1)
sig_HadTag_Dstar_pi0_m00_df = PandasToRD(df_HadronicTag_Dstar_pi0_m00, flag=1)

sig_HadTag_D_m10_df = PandasToRD(df_HadronicTag_m10, flag=1)
sig_HadTag_Dstar_gamma_m10_df = PandasToRD(df_HadronicTag_Dstar_gamma_m10, flag=1)
sig_HadTag_Dstar_pi0_m10_df = PandasToRD(df_HadronicTag_Dstar_pi0_m10, flag=1)

sig_HadTag_D_m20_df = PandasToRD(df_HadronicTag_m20, flag=1)
sig_HadTag_Dstar_gamma_m20_df = PandasToRD(df_HadronicTag_Dstar_gamma_m20, flag=1)
sig_HadTag_Dstar_pi0_m20_df = PandasToRD(df_HadronicTag_Dstar_pi0_m20, flag=1)

sig_HadTag_D_m30_df = PandasToRD(df_HadronicTag_m30, flag=1)
sig_HadTag_Dstar_gamma_m30_df = PandasToRD(df_HadronicTag_Dstar_gamma_m30, flag=1)
sig_HadTag_Dstar_pi0_m30_df = PandasToRD(df_HadronicTag_Dstar_pi0_m30, flag=1)

sig_HadTag_D_m40_df = PandasToRD(df_HadronicTag_m40, flag=1)
sig_HadTag_Dstar_gamma_m40_df = PandasToRD(df_HadronicTag_Dstar_gamma_m40, flag=1)
sig_HadTag_Dstar_pi0_m40_df = PandasToRD(df_HadronicTag_Dstar_pi0_m40, flag=1)

sig_HadTag_D_m45_df = PandasToRD(df_HadronicTag_m45, flag=1)
sig_HadTag_Dstar_gamma_m45_df = PandasToRD(df_HadronicTag_Dstar_gamma_m45, flag=1)
sig_HadTag_Dstar_pi0_m45_df = PandasToRD(df_HadronicTag_Dstar_pi0_m45, flag=1)


BkgHtag_D_m00_df = PandasToRD(df_BkgHtag_D_m00, flag=1)
BkgHtag_Dstar_gamma_m00_df = PandasToRD(df_BkgHtag_Dstar_gamma_m00, flag=1)
BkgHtag_Dstar_pi0_m00_df = PandasToRD(df_BkgHtag_Dstar_pi0_m00, flag=1)

BkgHtag_D_m10_df = PandasToRD(df_BkgHtag_D_m10, flag=1)
BkgHtag_Dstar_gamma_m10_df = PandasToRD(df_BkgHtag_Dstar_gamma_m10, flag=1)
BkgHtag_Dstar_pi0_m10_df = PandasToRD(df_BkgHtag_Dstar_pi0_m10, flag=1)

BkgHtag_D_m20_df = PandasToRD(df_BkgHtag_D_m20, flag=1)
BkgHtag_Dstar_gamma_m20_df = PandasToRD(df_BkgHtag_Dstar_gamma_m20, flag=1)
BkgHtag_Dstar_pi0_m20_df = PandasToRD(df_BkgHtag_Dstar_pi0_m20, flag=1)

BkgHtag_D_m30_df = PandasToRD(df_BkgHtag_D_m30, flag=1)
BkgHtag_Dstar_gamma_m30_df = PandasToRD(df_BkgHtag_Dstar_gamma_m30, flag=1)
BkgHtag_Dstar_pi0_m30_df = PandasToRD(df_BkgHtag_Dstar_pi0_m30, flag=1)

BkgHtag_D_m40_df = PandasToRD(df_BkgHtag_D_m40, flag=1)
BkgHtag_Dstar_gamma_m40_df = PandasToRD(df_BkgHtag_Dstar_gamma_m40, flag=1)
BkgHtag_Dstar_pi0_m40_df = PandasToRD(df_BkgHtag_Dstar_pi0_m40, flag=1)

BkgHtag_D_m45_df = PandasToRD(df_BkgHtag_D_m45, flag=1)
BkgHtag_Dstar_gamma_m45_df = PandasToRD(df_BkgHtag_Dstar_gamma_m45, flag=1)
BkgHtag_Dstar_pi0_m45_df = PandasToRD(df_BkgHtag_Dstar_pi0_m45, flag=1)

# %%
sig_SemiTag_2D_D_m00_df = PandasToRD(df_SemilepTag_2D_m00, flag=4)
sig_SemiTag_2D_Dstar_gamma_m00_df = PandasToRD(df_SemilepTag_2D_Dstar_gamma_m00, flag=4)
sig_SemiTag_2D_Dstar_pi0_m00_df = PandasToRD(df_SemilepTag_2D_Dstar_pi0_m00, flag=4)

sig_SemiTag_2D_D_m10_df = PandasToRD(df_SemilepTag_2D_m10, flag=4)
sig_SemiTag_2D_Dstar_gamma_m10_df = PandasToRD(df_SemilepTag_2D_Dstar_gamma_m10, flag=4)
sig_SemiTag_2D_Dstar_pi0_m10_df = PandasToRD(df_SemilepTag_2D_Dstar_pi0_m10, flag=4)

sig_SemiTag_2D_D_m20_df = PandasToRD(df_SemilepTag_2D_m20, flag=4)
sig_SemiTag_2D_Dstar_gamma_m20_df = PandasToRD(df_SemilepTag_2D_Dstar_gamma_m20, flag=4)
sig_SemiTag_2D_Dstar_pi0_m20_df = PandasToRD(df_SemilepTag_2D_Dstar_pi0_m20, flag=4)

sig_SemiTag_2D_D_m30_df = PandasToRD(df_SemilepTag_2D_m30, flag=4)
sig_SemiTag_2D_Dstar_gamma_m30_df = PandasToRD(df_SemilepTag_2D_Dstar_gamma_m30, flag=4)
sig_SemiTag_2D_Dstar_pi0_m30_df = PandasToRD(df_SemilepTag_2D_Dstar_pi0_m30, flag=4)

sig_SemiTag_2D_D_m40_df = PandasToRD(df_SemilepTag_2D_m40, flag=4)
sig_SemiTag_2D_Dstar_gamma_m40_df = PandasToRD(df_SemilepTag_2D_Dstar_gamma_m40, flag=4)
sig_SemiTag_2D_Dstar_pi0_m40_df = PandasToRD(df_SemilepTag_2D_Dstar_pi0_m40, flag=4)

sig_SemiTag_2D_D_m45_df = PandasToRD(df_SemilepTag_2D_m45, flag=4)
sig_SemiTag_2D_Dstar_gamma_m45_df = PandasToRD(df_SemilepTag_2D_Dstar_gamma_m45, flag=4)
sig_SemiTag_2D_Dstar_pi0_m45_df = PandasToRD(df_SemilepTag_2D_Dstar_pi0_m45, flag=4)


BkgStag_2D_D_df = PandasToRD(df_BkgStag_2D_D, flag=4)
BkgStag_2D_Dstar_gamma_df = PandasToRD(df_BkgStag_2D_Dstar_gamma, flag=4)
BkgStag_2D_Dstar_pi0_df = PandasToRD(df_BkgStag_2D_Dstar_pi0, flag=4)

# %%
sig_SemiTag_D_m30_df.Display().Print()
# Out:
# +-----+------------+-----------+-----------+------------+-----------+
# | Row | BDT        | Mmax2     | Mmin2     | Xps        | q2        |
# +-----+------------+-----------+-----------+------------+-----------+
# | 0   | 0.92349890 | 9.6950415 | 8.2748946 | 0.68384882 | 8.9605184 |
# +-----+------------+-----------+-----------+------------+-----------+
# | 1   | 0.88267540 | 10.421917 | 8.8165189 | 0.64849385 | 9.5003101 |
# +-----+------------+-----------+-----------+------------+-----------+
# | 2   | 0.96771127 | 9.2154288 | 6.9783212 | 0.71565893 | 8.2505446 |
# +-----+------------+-----------+-----------+------------+-----------+
# | 3   | 0.89707613 | 9.5553575 | 9.0381262 | 0.61682857 | 10.167290 |
# +-----+------------+-----------+-----------+------------+-----------+
# | 4   | 0.86826026 | 9.5208928 | 7.1912441 | 0.71817183 | 8.4322247 |
# +-----+------------+-----------+-----------+------------+-----------+

# %%
bins = 250
bdt_min = -0.05
bdt_max = 1.05

# ------------  BDT variable

# D tag
hS_D_m00_BDT = sig_SemiTag_D_m00_df.Histo1D(("BDT", "BDT", bins, bdt_min, bdt_max), "BDT")
hS_D_m10_BDT = sig_SemiTag_D_m10_df.Histo1D(("BDT", "BDT", bins, bdt_min, bdt_max), "BDT")
hS_D_m20_BDT = sig_SemiTag_D_m20_df.Histo1D(("BDT", "BDT", bins, bdt_min, bdt_max), "BDT")
hS_D_m30_BDT = sig_SemiTag_D_m30_df.Histo1D(("BDT", "BDT", bins, bdt_min, bdt_max), "BDT")
hS_D_m40_BDT = sig_SemiTag_D_m40_df.Histo1D(("BDT", "BDT", bins, bdt_min, bdt_max), "BDT")
hS_D_m45_BDT = sig_SemiTag_D_m45_df.Histo1D(("BDT", "BDT", bins, bdt_min, bdt_max), "BDT")


# D0star gamma tag
hS_Dstar_gamma_m00_BDT = sig_SemiTag_Dstar_gamma_m00_df.Histo1D(("BDT", "BDT", bins, bdt_min, bdt_max), "BDT")
hS_Dstar_gamma_m10_BDT = sig_SemiTag_Dstar_gamma_m10_df.Histo1D(("BDT", "BDT", bins, bdt_min, bdt_max), "BDT")
hS_Dstar_gamma_m20_BDT = sig_SemiTag_Dstar_gamma_m20_df.Histo1D(("BDT", "BDT", bins, bdt_min, bdt_max), "BDT")
hS_Dstar_gamma_m30_BDT = sig_SemiTag_Dstar_gamma_m30_df.Histo1D(("BDT", "BDT", bins, bdt_min, bdt_max), "BDT")
hS_Dstar_gamma_m40_BDT = sig_SemiTag_Dstar_gamma_m40_df.Histo1D(("BDT", "BDT", bins, bdt_min, bdt_max), "BDT")
hS_Dstar_gamma_m45_BDT = sig_SemiTag_Dstar_gamma_m45_df.Histo1D(("BDT", "BDT", bins, bdt_min, bdt_max), "BDT")

# D0star pi0 tag
hS_Dstar_pi0_m00_BDT = sig_SemiTag_Dstar_pi0_m00_df.Histo1D(("BDT", "BDT", bins, bdt_min, bdt_max), "BDT")
hS_Dstar_pi0_m10_BDT = sig_SemiTag_Dstar_pi0_m10_df.Histo1D(("BDT", "BDT", bins, bdt_min, bdt_max), "BDT")
hS_Dstar_pi0_m20_BDT = sig_SemiTag_Dstar_pi0_m20_df.Histo1D(("BDT", "BDT", bins, bdt_min, bdt_max), "BDT")
hS_Dstar_pi0_m30_BDT = sig_SemiTag_Dstar_pi0_m30_df.Histo1D(("BDT", "BDT", bins, bdt_min, bdt_max), "BDT")
hS_Dstar_pi0_m40_BDT = sig_SemiTag_Dstar_pi0_m40_df.Histo1D(("BDT", "BDT", bins, bdt_min, bdt_max), "BDT")
hS_Dstar_pi0_m45_BDT = sig_SemiTag_Dstar_pi0_m45_df.Histo1D(("BDT", "BDT", bins, bdt_min, bdt_max), "BDT")

# Background per tag
hB_D_m00_BDT = BkgStag_D_m00_df.Histo1D(("BDT", "BDT", bins, bdt_min, bdt_max), "BDT")
hB_D_m10_BDT = BkgStag_D_m10_df.Histo1D(("BDT", "BDT", bins, bdt_min, bdt_max), "BDT")
hB_D_m20_BDT = BkgStag_D_m20_df.Histo1D(("BDT", "BDT", bins, bdt_min, bdt_max), "BDT")
hB_D_m30_BDT = BkgStag_D_m30_df.Histo1D(("BDT", "BDT", bins, bdt_min, bdt_max), "BDT")
hB_D_m40_BDT = BkgStag_D_m40_df.Histo1D(("BDT", "BDT", bins, bdt_min, bdt_max), "BDT")
hB_D_m45_BDT = BkgStag_D_m45_df.Histo1D(("BDT", "BDT", bins, bdt_min, bdt_max), "BDT")

hB_Dstar_gamma_m00_BDT = BkgStag_Dstar_gamma_m00_df.Histo1D(("BDT", "BDT", bins, bdt_min, bdt_max), "BDT")
hB_Dstar_gamma_m10_BDT = BkgStag_Dstar_gamma_m10_df.Histo1D(("BDT", "BDT", bins, bdt_min, bdt_max), "BDT")
hB_Dstar_gamma_m20_BDT = BkgStag_Dstar_gamma_m20_df.Histo1D(("BDT", "BDT", bins, bdt_min, bdt_max), "BDT")
hB_Dstar_gamma_m30_BDT = BkgStag_Dstar_gamma_m30_df.Histo1D(("BDT", "BDT", bins, bdt_min, bdt_max), "BDT")
hB_Dstar_gamma_m40_BDT = BkgStag_Dstar_gamma_m40_df.Histo1D(("BDT", "BDT", bins, bdt_min, bdt_max), "BDT")
hB_Dstar_gamma_m45_BDT = BkgStag_Dstar_gamma_m45_df.Histo1D(("BDT", "BDT", bins, bdt_min, bdt_max), "BDT")

hB_Dstar_pi0_m00_BDT = BkgStag_Dstar_pi0_m00_df.Histo1D(("BDT", "BDT", bins, bdt_min, bdt_max), "BDT")
hB_Dstar_pi0_m10_BDT = BkgStag_Dstar_pi0_m10_df.Histo1D(("BDT", "BDT", bins, bdt_min, bdt_max), "BDT")
hB_Dstar_pi0_m20_BDT = BkgStag_Dstar_pi0_m20_df.Histo1D(("BDT", "BDT", bins, bdt_min, bdt_max), "BDT")
hB_Dstar_pi0_m30_BDT = BkgStag_Dstar_pi0_m30_df.Histo1D(("BDT", "BDT", bins, bdt_min, bdt_max), "BDT")
hB_Dstar_pi0_m40_BDT = BkgStag_Dstar_pi0_m40_df.Histo1D(("BDT", "BDT", bins, bdt_min, bdt_max), "BDT")
hB_Dstar_pi0_m45_BDT = BkgStag_Dstar_pi0_m45_df.Histo1D(("BDT", "BDT", bins, bdt_min, bdt_max), "BDT")

# %%
bins_had = 50
bdt_min = -0.05
bdt_max = 1.05

# ------------  BDT variable

# D tag
hS_Had_D_m00_BDT = sig_HadTag_D_m00_df.Histo1D(("BDT", "BDT", bins_had, bdt_min, bdt_max), "BDT")
hS_Had_D_m10_BDT = sig_HadTag_D_m10_df.Histo1D(("BDT", "BDT", bins_had, bdt_min, bdt_max), "BDT")
hS_Had_D_m20_BDT = sig_HadTag_D_m20_df.Histo1D(("BDT", "BDT", bins_had, bdt_min, bdt_max), "BDT")
hS_Had_D_m30_BDT = sig_HadTag_D_m30_df.Histo1D(("BDT", "BDT", bins_had, bdt_min, bdt_max), "BDT")
hS_Had_D_m40_BDT = sig_HadTag_D_m40_df.Histo1D(("BDT", "BDT", bins_had, bdt_min, bdt_max), "BDT")
hS_Had_D_m45_BDT = sig_HadTag_D_m45_df.Histo1D(("BDT", "BDT", bins_had, bdt_min, bdt_max), "BDT")


# D0star gamma tag
hS_Had_Dstar_gamma_m00_BDT = sig_HadTag_Dstar_gamma_m00_df.Histo1D(("BDT", "BDT", bins_had, bdt_min, bdt_max), "BDT")
hS_Had_Dstar_gamma_m10_BDT = sig_HadTag_Dstar_gamma_m10_df.Histo1D(("BDT", "BDT", bins_had, bdt_min, bdt_max), "BDT")
hS_Had_Dstar_gamma_m20_BDT = sig_HadTag_Dstar_gamma_m20_df.Histo1D(("BDT", "BDT", bins_had, bdt_min, bdt_max), "BDT")
hS_Had_Dstar_gamma_m30_BDT = sig_HadTag_Dstar_gamma_m30_df.Histo1D(("BDT", "BDT", bins_had, bdt_min, bdt_max), "BDT")
hS_Had_Dstar_gamma_m40_BDT = sig_HadTag_Dstar_gamma_m40_df.Histo1D(("BDT", "BDT", bins_had, bdt_min, bdt_max), "BDT")
hS_Had_Dstar_gamma_m45_BDT = sig_HadTag_Dstar_gamma_m45_df.Histo1D(("BDT", "BDT", bins_had, bdt_min, bdt_max), "BDT")

# D0star pi0 tag
hS_Had_Dstar_pi0_m00_BDT = sig_HadTag_Dstar_pi0_m00_df.Histo1D(("BDT", "BDT", bins_had, bdt_min, bdt_max), "BDT")
hS_Had_Dstar_pi0_m10_BDT = sig_HadTag_Dstar_pi0_m10_df.Histo1D(("BDT", "BDT", bins_had, bdt_min, bdt_max), "BDT")
hS_Had_Dstar_pi0_m20_BDT = sig_HadTag_Dstar_pi0_m20_df.Histo1D(("BDT", "BDT", bins_had, bdt_min, bdt_max), "BDT")
hS_Had_Dstar_pi0_m30_BDT = sig_HadTag_Dstar_pi0_m30_df.Histo1D(("BDT", "BDT", bins_had, bdt_min, bdt_max), "BDT")
hS_Had_Dstar_pi0_m40_BDT = sig_HadTag_Dstar_pi0_m40_df.Histo1D(("BDT", "BDT", bins_had, bdt_min, bdt_max), "BDT")
hS_Had_Dstar_pi0_m45_BDT = sig_HadTag_Dstar_pi0_m45_df.Histo1D(("BDT", "BDT", bins_had, bdt_min, bdt_max), "BDT")

# Background per tag
hB_Had_D_m00_BDT = BkgHtag_D_m00_df.Histo1D(("BDT", "BDT", bins_had, bdt_min, bdt_max), "BDT")
hB_Had_D_m10_BDT = BkgHtag_D_m10_df.Histo1D(("BDT", "BDT", bins_had, bdt_min, bdt_max), "BDT")
hB_Had_D_m20_BDT = BkgHtag_D_m20_df.Histo1D(("BDT", "BDT", bins_had, bdt_min, bdt_max), "BDT")
hB_Had_D_m30_BDT = BkgHtag_D_m30_df.Histo1D(("BDT", "BDT", bins_had, bdt_min, bdt_max), "BDT")
hB_Had_D_m40_BDT = BkgHtag_D_m40_df.Histo1D(("BDT", "BDT", bins_had, bdt_min, bdt_max), "BDT")
hB_Had_D_m45_BDT = BkgHtag_D_m45_df.Histo1D(("BDT", "BDT", bins_had, bdt_min, bdt_max), "BDT")

hB_Had_Dstar_gamma_m00_BDT = BkgHtag_Dstar_gamma_m00_df.Histo1D(("BDT", "BDT", bins_had, bdt_min, bdt_max), "BDT")
hB_Had_Dstar_gamma_m10_BDT = BkgHtag_Dstar_gamma_m10_df.Histo1D(("BDT", "BDT", bins_had, bdt_min, bdt_max), "BDT")
hB_Had_Dstar_gamma_m20_BDT = BkgHtag_Dstar_gamma_m20_df.Histo1D(("BDT", "BDT", bins_had, bdt_min, bdt_max), "BDT")
hB_Had_Dstar_gamma_m30_BDT = BkgHtag_Dstar_gamma_m30_df.Histo1D(("BDT", "BDT", bins_had, bdt_min, bdt_max), "BDT")
hB_Had_Dstar_gamma_m40_BDT = BkgHtag_Dstar_gamma_m40_df.Histo1D(("BDT", "BDT", bins_had, bdt_min, bdt_max), "BDT")
hB_Had_Dstar_gamma_m45_BDT = BkgHtag_Dstar_gamma_m45_df.Histo1D(("BDT", "BDT", bins_had, bdt_min, bdt_max), "BDT")

hB_Had_Dstar_pi0_m00_BDT = BkgHtag_Dstar_pi0_m00_df.Histo1D(("BDT", "BDT", bins_had, bdt_min, bdt_max), "BDT")
hB_Had_Dstar_pi0_m10_BDT = BkgHtag_Dstar_pi0_m10_df.Histo1D(("BDT", "BDT", bins_had, bdt_min, bdt_max), "BDT")
hB_Had_Dstar_pi0_m20_BDT = BkgHtag_Dstar_pi0_m20_df.Histo1D(("BDT", "BDT", bins_had, bdt_min, bdt_max), "BDT")
hB_Had_Dstar_pi0_m30_BDT = BkgHtag_Dstar_pi0_m30_df.Histo1D(("BDT", "BDT", bins_had, bdt_min, bdt_max), "BDT")
hB_Had_Dstar_pi0_m40_BDT = BkgHtag_Dstar_pi0_m40_df.Histo1D(("BDT", "BDT", bins_had, bdt_min, bdt_max), "BDT")
hB_Had_Dstar_pi0_m45_BDT = BkgHtag_Dstar_pi0_m45_df.Histo1D(("BDT", "BDT", bins_had, bdt_min, bdt_max), "BDT")

# %%
# 2D Histograms
'''XpsLow = 0.2
XpsUp = 1.2

Mmax2Low = -4.0
Mmax2Up = 22.0'''

'''Mmin2Low = 0.2
Mmin2Up = 1.2

Mmax2Low = -5.0
Mmax2Up = 22.0'''

Mmin2Low = -5.0
Mmin2Up = 23.0

Mmax2Low = -2.0
Mmax2Up = 23.0

nbinsL = 200
nbinsH = 200


# ------------  2D variable (Mmin2,Mmax2)

# D tag
#hS_m00_2D = sig_SemiTag_2D_D_m00_df.Histo2D(("2D", "2D", nbinsL, Mmin2Low, Mmin2Up, nbinsH, Mmax2Low, Mmax2Up), "Mmin2", "Mmax2")
#hS_m10_2D = sig_SemiTag_2D_D_m10_df.Histo2D(("2D", "2D", nbinsL, Mmin2Low, Mmin2Up, nbinsH, Mmax2Low, Mmax2Up), "Mmin2", "Mmax2")
#hS_m20_2D = sig_SemiTag_2D_D_m20_df.Histo2D(("2D", "2D", nbinsL, Mmin2Low, Mmin2Up, nbinsH, Mmax2Low, Mmax2Up), "Mmin2", "Mmax2")
hS_m30_2D = sig_SemiTag_2D_D_m30_df.Histo2D(("2D", "2D", nbinsL, Mmin2Low, Mmin2Up, nbinsH, Mmax2Low, Mmax2Up), "Mmin2", "Mmax2")
#hS_m40_2D = sig_SemiTag_2D_D_m40_df.Histo2D(("2D", "2D", nbinsL, Mmin2Low, Mmin2Up, nbinsH, Mmax2Low, Mmax2Up), "Mmin2", "Mmax2")
#hS_m45_2D = sig_SemiTag_2D_D_m45_df.Histo2D(("2D", "2D", nbinsL, Mmin2Low, Mmin2Up, nbinsH, Mmax2Low, Mmax2Up), "Mmin2", "Mmax2")
# D0star gamma tag
#hS_Dstar_gamma_m00_2D = sig_SemiTag_2D_Dstar_gamma_m00_df.Histo2D(("2D", "2D", nbinsL, Mmin2Low, Mmin2Up, nbinsH, Mmax2Low, Mmax2Up), "Mmin2", "Mmax2")
#hS_Dstar_gamma_m10_2D = sig_SemiTag_2D_Dstar_gamma_m10_df.Histo2D(("2D", "2D", nbinsL, Mmin2Low, Mmin2Up, nbinsH, Mmax2Low, Mmax2Up), "Mmin2", "Mmax2")
#hS_Dstar_gamma_m20_2D = sig_SemiTag_2D_Dstar_gamma_m20_df.Histo2D(("2D", "2D", nbinsL, Mmin2Low, Mmin2Up, nbinsH, Mmax2Low, Mmax2Up), "Mmin2", "Mmax2")
hS_Dstar_gamma_m30_2D = sig_SemiTag_2D_Dstar_gamma_m30_df.Histo2D(("2D", "2D", nbinsL, Mmin2Low, Mmin2Up, nbinsH, Mmax2Low, Mmax2Up), "Mmin2", "Mmax2")
#hS_Dstar_gamma_m40_2D = sig_SemiTag_2D_Dstar_gamma_m40_df.Histo2D(("2D", "2D", nbinsL, Mmin2Low, Mmin2Up, nbinsH, Mmax2Low, Mmax2Up), "Mmin2", "Mmax2")
#hS_Dstar_gamma_m45_2D = sig_SemiTag_2D_Dstar_gamma_m45_df.Histo2D(("2D", "2D", nbinsL, Mmin2Low, Mmin2Up, nbinsH, Mmax2Low, Mmax2Up), "Mmin2", "Mmax2")
# D0star pi0 tag
#hS_Dstar_pi0_m00_2D = sig_SemiTag_2D_Dstar_pi0_m00_df.Histo2D(("2D", "2D", nbinsL, Mmin2Low, Mmin2Up, nbinsH, Mmax2Low, Mmax2Up), "Mmin2", "Mmax2")
#hS_Dstar_pi0_m10_2D = sig_SemiTag_2D_Dstar_pi0_m10_df.Histo2D(("2D", "2D", nbinsL, Mmin2Low, Mmin2Up, nbinsH, Mmax2Low, Mmax2Up), "Mmin2", "Mmax2")
#hS_Dstar_pi0_m20_2D = sig_SemiTag_2D_Dstar_pi0_m20_df.Histo2D(("2D", "2D", nbinsL, Mmin2Low, Mmin2Up, nbinsH, Mmax2Low, Mmax2Up), "Mmin2", "Mmax2")
hS_Dstar_pi0_m30_2D = sig_SemiTag_2D_Dstar_pi0_m30_df.Histo2D(("2D", "2D", nbinsL, Mmin2Low, Mmin2Up, nbinsH, Mmax2Low, Mmax2Up), "Mmin2", "Mmax2")
#hS_Dstar_pi0_m40_2D = sig_SemiTag_2D_Dstar_pi0_m40_df.Histo2D(("2D", "2D", nbinsL, Mmin2Low, Mmin2Up, nbinsH, Mmax2Low, Mmax2Up), "Mmin2", "Mmax2")
#hS_Dstar_pi0_m50_2D = sig_SemiTag_2D_Dstar_pi0_m45_df.Histo2D(("2D", "2D", nbinsL, Mmin2Low, Mmin2Up, nbinsH, Mmax2Low, Mmax2Up), "Mmin2", "Mmax2")

# Background per tag
hB_2D = BkgStag_2D_D_df.Histo2D(("2D", "2D", nbinsL, Mmin2Low, Mmin2Up, nbinsH, Mmax2Low, Mmax2Up), "Mmin2", "Mmax2")

hB_Dstar_gamma_2D = BkgStag_2D_Dstar_gamma_df.Histo2D(("2D", "2D", nbinsL, Mmin2Low, Mmin2Up, nbinsH, Mmax2Low, Mmax2Up), "Mmin2", "Mmax2")

hB_Dstar_pi0_2D = BkgStag_2D_Dstar_pi0_df.Histo2D(("2D", "2D", nbinsL, Mmin2Low, Mmin2Up, nbinsH, Mmax2Low, Mmax2Up), "Mmin2", "Mmax2")

# %%
# Lest's create the root files
# D tag
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m00_BDT_pdf.root', 'RECREATE' )
hS_D_m00_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m10_BDT_pdf.root', 'RECREATE' )
hS_D_m10_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m20_BDT_pdf.root', 'RECREATE' )
hS_D_m20_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m30_BDT_pdf.root', 'RECREATE' )
hS_D_m30_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m40_BDT_pdf.root', 'RECREATE' )
hS_D_m40_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m45_BDT_pdf.root', 'RECREATE' )
hS_D_m45_BDT.Write()
myfile.Close()
# D0star gamma tag
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m00_BDT_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m00_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m10_BDT_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m10_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m20_BDT_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m20_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m30_BDT_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m30_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m40_BDT_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m40_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m45_BDT_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m45_BDT.Write()
myfile.Close()
# D0star pi0 tag
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m00_BDT_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m00_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m10_BDT_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m10_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m20_BDT_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m20_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m30_BDT_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m30_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m40_BDT_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m40_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m45_BDT_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m45_BDT.Write()
myfile.Close()

# %%
# Now for background files
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgStag_D_m00_BDT_pdf.root', 'RECREATE' )
hB_D_m00_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgStag_D_m10_BDT_pdf.root', 'RECREATE' )
hB_D_m10_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgStag_D_m20_BDT_pdf.root', 'RECREATE' )
hB_D_m10_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgStag_D_m30_BDT_pdf.root', 'RECREATE' )
hB_D_m30_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgStag_D_m40_BDT_pdf.root', 'RECREATE' )
hB_D_m40_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgStag_D_m45_BDT_pdf.root', 'RECREATE' )
hB_D_m45_BDT.Write()
myfile.Close()

myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_gamma_m00_BDT_pdf.root', 'RECREATE' )
hB_Dstar_gamma_m00_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_gamma_m10_BDT_pdf.root', 'RECREATE' )
hB_Dstar_gamma_m10_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_gamma_m20_BDT_pdf.root', 'RECREATE' )
hB_Dstar_gamma_m20_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_gamma_m30_BDT_pdf.root', 'RECREATE' )
hB_Dstar_gamma_m30_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_gamma_m40_BDT_pdf.root', 'RECREATE' )
hB_Dstar_gamma_m40_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_gamma_m45_BDT_pdf.root', 'RECREATE' )
hB_Dstar_gamma_m45_BDT.Write()
myfile.Close()

myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_pi0_m00_BDT_pdf.root', 'RECREATE' )
hB_Dstar_pi0_m00_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_pi0_m10_BDT_pdf.root', 'RECREATE' )
hB_Dstar_pi0_m10_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_pi0_m20_BDT_pdf.root', 'RECREATE' )
hB_Dstar_pi0_m20_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_pi0_m30_BDT_pdf.root', 'RECREATE' )
hB_Dstar_pi0_m30_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_pi0_m40_BDT_pdf.root', 'RECREATE' )
hB_Dstar_pi0_m40_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_pi0_m45_BDT_pdf.root', 'RECREATE' )
hB_Dstar_pi0_m45_BDT.Write()
myfile.Close()

# %% [markdown]
# ## Hadronic tags

# %%
# Lest's create the root files
# D tag
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_D_m00_BDT_pdf.root', 'RECREATE' )
hS_Had_D_m00_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_D_m10_BDT_pdf.root', 'RECREATE' )
hS_Had_D_m10_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_D_m20_BDT_pdf.root', 'RECREATE' )
hS_Had_D_m20_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_D_m30_BDT_pdf.root', 'RECREATE' )
hS_Had_D_m30_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_D_m40_BDT_pdf.root', 'RECREATE' )
hS_Had_D_m40_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_D_m45_BDT_pdf.root', 'RECREATE' )
hS_Had_D_m45_BDT.Write()
myfile.Close()
# D0star gamma tag
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m00_BDT_pdf.root', 'RECREATE' )
hS_Had_Dstar_gamma_m00_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m10_BDT_pdf.root', 'RECREATE' )
hS_Had_Dstar_gamma_m10_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m20_BDT_pdf.root', 'RECREATE' )
hS_Had_Dstar_gamma_m20_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m30_BDT_pdf.root', 'RECREATE' )
hS_Had_Dstar_gamma_m30_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m40_BDT_pdf.root', 'RECREATE' )
hS_Had_Dstar_gamma_m40_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m45_BDT_pdf.root', 'RECREATE' )
hS_Had_Dstar_gamma_m45_BDT.Write()
myfile.Close()
# D0star pi0 tag
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m00_BDT_pdf.root', 'RECREATE' )
hS_Had_Dstar_pi0_m00_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m10_BDT_pdf.root', 'RECREATE' )
hS_Had_Dstar_pi0_m10_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m20_BDT_pdf.root', 'RECREATE' )
hS_Had_Dstar_pi0_m20_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m30_BDT_pdf.root', 'RECREATE' )
hS_Had_Dstar_pi0_m30_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m40_BDT_pdf.root', 'RECREATE' )
hS_Had_Dstar_pi0_m40_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m45_BDT_pdf.root', 'RECREATE' )
hS_Had_Dstar_pi0_m45_BDT.Write()
myfile.Close()

# %%
# Now for background files
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgHtag_D_m00_BDT_pdf.root', 'RECREATE' )
hB_Had_D_m00_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgHtag_D_m10_BDT_pdf.root', 'RECREATE' )
hB_Had_D_m10_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgHtag_D_m20_BDT_pdf.root', 'RECREATE' )
hB_Had_D_m10_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgHtag_D_m30_BDT_pdf.root', 'RECREATE' )
hB_Had_D_m30_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgHtag_D_m40_BDT_pdf.root', 'RECREATE' )
hB_Had_D_m40_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgHtag_D_m45_BDT_pdf.root', 'RECREATE' )
hB_Had_D_m45_BDT.Write()
myfile.Close()

myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgHtag_Dstar_gamma_m00_BDT_pdf.root', 'RECREATE' )
hB_Had_Dstar_gamma_m00_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgHtag_Dstar_gamma_m10_BDT_pdf.root', 'RECREATE' )
hB_Had_Dstar_gamma_m10_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgHtag_Dstar_gamma_m20_BDT_pdf.root', 'RECREATE' )
hB_Had_Dstar_gamma_m20_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgHtag_Dstar_gamma_m30_BDT_pdf.root', 'RECREATE' )
hB_Had_Dstar_gamma_m30_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgHtag_Dstar_gamma_m40_BDT_pdf.root', 'RECREATE' )
hB_Had_Dstar_gamma_m40_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgHtag_Dstar_gamma_m45_BDT_pdf.root', 'RECREATE' )
hB_Had_Dstar_gamma_m45_BDT.Write()
myfile.Close()

myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgHtag_Dstar_pi0_m00_BDT_pdf.root', 'RECREATE' )
hB_Had_Dstar_pi0_m00_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgHtag_Dstar_pi0_m10_BDT_pdf.root', 'RECREATE' )
hB_Had_Dstar_pi0_m10_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgHtag_Dstar_pi0_m20_BDT_pdf.root', 'RECREATE' )
hB_Had_Dstar_pi0_m20_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgHtag_Dstar_pi0_m30_BDT_pdf.root', 'RECREATE' )
hB_Had_Dstar_pi0_m30_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgHtag_Dstar_pi0_m40_BDT_pdf.root', 'RECREATE' )
hB_Had_Dstar_pi0_m40_BDT.Write()
myfile.Close()
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgHtag_Dstar_pi0_m45_BDT_pdf.root', 'RECREATE' )
hB_Had_Dstar_pi0_m45_BDT.Write()
myfile.Close()

# %% [markdown]
# ## 2D histograms (ST)

# %%
# D tag
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m30_2D_pdf.root', 'RECREATE' )
hS_m30_2D.Write()
myfile.Close()

# D0star gamma tag
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m30_2D_pdf.root', 'RECREATE' )
hS_Dstar_gamma_m30_2D.Write()
myfile.Close()

# D0star gamma tag
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m30_2D_pdf.root', 'RECREATE' )
hS_Dstar_pi0_m30_2D.Write()
myfile.Close()

# %%
# Background
myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgStag_D_2D_pdf.root', 'RECREATE' )
hB_2D.Write()
myfile.Close()

myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_gamma_2D_pdf.root', 'RECREATE' )
hB_Dstar_gamma_2D.Write()
myfile.Close()

myfile = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_pi0_2D_pdf.root', 'RECREATE' )
hB_Dstar_pi0_2D.Write()
myfile.Close()

# %%
fSD_m00 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m00_BDT_pdf.root')
fSD_m10 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m10_BDT_pdf.root')
fSD_m20 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m20_BDT_pdf.root')
fSD_m30 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m30_BDT_pdf.root')
fSD_m40 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m40_BDT_pdf.root')
fSD_m45 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m45_BDT_pdf.root')

fSDstarGamma_m00 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m00_BDT_pdf.root')
fSDstarGamma_m10 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m10_BDT_pdf.root')
fSDstarGamma_m20 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m20_BDT_pdf.root')
fSDstarGamma_m30 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m30_BDT_pdf.root')
fSDstarGamma_m40 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m40_BDT_pdf.root')
fSDstarGamma_m45 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m45_BDT_pdf.root')

fSDstarPi0_m00 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m00_BDT_pdf.root')
fSDstarPi0_m10 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m10_BDT_pdf.root')
fSDstarPi0_m20 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m20_BDT_pdf.root')
fSDstarPi0_m30 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m30_BDT_pdf.root')
fSDstarPi0_m40 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m40_BDT_pdf.root')
fSDstarPi0_m45 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m45_BDT_pdf.root')

# %%
fBD_m00 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgStag_D_m00_BDT_pdf.root')
fBD_m10 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgStag_D_m10_BDT_pdf.root')
fBD_m20 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgStag_D_m20_BDT_pdf.root')
fBD_m30 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgStag_D_m30_BDT_pdf.root')
fBD_m40 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgStag_D_m40_BDT_pdf.root')
fBD_m45 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgStag_D_m45_BDT_pdf.root')

fBDstarGamma_m00 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_gamma_m00_BDT_pdf.root')
fBDstarGamma_m10 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_gamma_m10_BDT_pdf.root')
fBDstarGamma_m20 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_gamma_m20_BDT_pdf.root')
fBDstarGamma_m30 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_gamma_m30_BDT_pdf.root')
fBDstarGamma_m40 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_gamma_m40_BDT_pdf.root')
fBDstarGamma_m45 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_gamma_m45_BDT_pdf.root')

fBDstarPi0_m00 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_gamma_m00_BDT_pdf.root')
fBDstarPi0_m10 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_gamma_m10_BDT_pdf.root')
fBDstarPi0_m20 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_gamma_m20_BDT_pdf.root')
fBDstarPi0_m30 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_gamma_m30_BDT_pdf.root')
fBDstarPi0_m40 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_gamma_m40_BDT_pdf.root')
fBDstarPi0_m45 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_gamma_m45_BDT_pdf.root')

# %% [markdown]
# ## Hadronic tags

# %%
fSD_Had_m00 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_D_m00_BDT_pdf.root')
fSD_Had_m10 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_D_m10_BDT_pdf.root')
fSD_Had_m20 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_D_m20_BDT_pdf.root')
fSD_Had_m30 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_D_m30_BDT_pdf.root')
fSD_Had_m40 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_D_m40_BDT_pdf.root')
fSD_Had_m45 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_D_m45_BDT_pdf.root')

fSDstarGamma_Had_m00 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m00_BDT_pdf.root')
fSDstarGamma_Had_m10 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m10_BDT_pdf.root')
fSDstarGamma_Had_m20 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m20_BDT_pdf.root')
fSDstarGamma_Had_m30 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m30_BDT_pdf.root')
fSDstarGamma_Had_m40 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m40_BDT_pdf.root')
fSDstarGamma_Had_m45 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_gamma_m45_BDT_pdf.root')

fSDstarPi0_Had_m00 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m00_BDT_pdf.root')
fSDstarPi0_Had_m10 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m10_BDT_pdf.root')
fSDstarPi0_Had_m20 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m20_BDT_pdf.root')
fSDstarPi0_Had_m30 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m30_BDT_pdf.root')
fSDstarPi0_Had_m40 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m40_BDT_pdf.root')
fSDstarPi0_Had_m45 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Had_Dstar_pi0_m45_BDT_pdf.root')

# %%
fBD_Had_m00 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgHtag_D_m00_BDT_pdf.root')
fBD_Had_m10 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgHtag_D_m10_BDT_pdf.root')
fBD_Had_m20 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgHtag_D_m20_BDT_pdf.root')
fBD_Had_m30 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgHtag_D_m30_BDT_pdf.root')
fBD_Had_m40 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgHtag_D_m40_BDT_pdf.root')
fBD_Had_m45 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgHtag_D_m45_BDT_pdf.root')

fBDstarGamma_Had_m00 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgHtag_Dstar_gamma_m00_BDT_pdf.root')
fBDstarGamma_Had_m10 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgHtag_Dstar_gamma_m10_BDT_pdf.root')
fBDstarGamma_Had_m20 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgHtag_Dstar_gamma_m20_BDT_pdf.root')
fBDstarGamma_Had_m30 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgHtag_Dstar_gamma_m30_BDT_pdf.root')
fBDstarGamma_Had_m40 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgHtag_Dstar_gamma_m40_BDT_pdf.root')
fBDstarGamma_Had_m45 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgHtag_Dstar_gamma_m45_BDT_pdf.root')

fBDstarPi0_Had_m00 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgHtag_Dstar_gamma_m00_BDT_pdf.root')
fBDstarPi0_Had_m10 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgHtag_Dstar_gamma_m10_BDT_pdf.root')
fBDstarPi0_Had_m20 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgHtag_Dstar_gamma_m20_BDT_pdf.root')
fBDstarPi0_Had_m30 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgHtag_Dstar_gamma_m30_BDT_pdf.root')
fBDstarPi0_Had_m40 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgHtag_Dstar_gamma_m40_BDT_pdf.root')
fBDstarPi0_Had_m45 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgHtag_Dstar_gamma_m45_BDT_pdf.root')

# %% [markdown]
# ## 2D (ST)

# %%
#fSD_2D_m00 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m00_2D_pdf.root')
#fSD_2D_m05 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m00_2D_pdf.root')
#fSD_2D_m10 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m00_2D_pdf.root')
#fSD_2D_m15 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m00_2D_pdf.root')
#fSD_2D_m20 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m00_2D_pdf.root')
#fSD_2D_m25 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m00_2D_pdf.root')
fSD_2D_m30 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m30_2D_pdf.root')
#fSD_2D_m35 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m00_2D_pdf.root')
#fSD_2D_m40 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m00_2D_pdf.root')
#fSD_2D_m45 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_D_m00_2D_pdf.root')

fSDstarGamma_2D_m30 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_gamma_m30_2D_pdf.root')

fSDstarPi0_2D_m30 = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hS_Dstar_pi0_m30_2D_pdf.root')

# %%
fBD_2D = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgStag_D_2D_pdf.root')

fBDstarGamma_2D = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_gamma_2D_pdf.root')

fBDstarPi0_2D = ROOT.TFile('~/BToInv/KChannel/Analysis/Files/RootFiles/hBkgStag_Dstar_pi0_2D_pdf.root')

# %% [markdown]
# # Charge the ROOT histograms (BDT)

# %%
hS_D_m00_BDT_pdf = ROOT.TH1D('hS_D_m00_BDT','hS_D_m00_BDT' , bins, bdt_min, bdt_max)
hS_D_m00_BDT_pdf = fSD_m00.Get("BDT")
hS_D_m10_BDT_pdf = ROOT.TH1D('hS_D_m10_BDT','hS_D_m10_BDT' , bins, bdt_min, bdt_max)
hS_D_m10_BDT_pdf = fSD_m10.Get("BDT")
hS_D_m20_BDT_pdf = ROOT.TH1D('hS_D_m20_BDT','hS_D_m20_BDT' , bins, bdt_min, bdt_max)
hS_D_m20_BDT_pdf = fSD_m20.Get("BDT")
hS_D_m30_BDT_pdf = ROOT.TH1D('hS_D_m30_BDT','hS_D_m30_BDT' , bins, bdt_min, bdt_max)
hS_D_m30_BDT_pdf = fSD_m30.Get("BDT")
hS_D_m40_BDT_pdf = ROOT.TH1D('hS_D_m40_BDT','hS_D_m40_BDT' , bins, bdt_min, bdt_max)
hS_D_m40_BDT_pdf = fSD_m40.Get("BDT")
hS_D_m45_BDT_pdf = ROOT.TH1D('hS_D_m45_BDT','hS_D_m45_BDT' , bins, bdt_min, bdt_max)
hS_D_m45_BDT_pdf = fSD_m45.Get("BDT")

hS_Dstar_gamma_m00_BDT_pdf = ROOT.TH1D('hS_Dstar_gamma_m00_BDT','hS_Dstar_gamma_m00_BDT' , bins, bdt_min, bdt_max)
hS_Dstar_gamma_m00_BDT_pdf = fSDstarGamma_m00.Get("BDT")
hS_Dstar_gamma_m10_BDT_pdf = ROOT.TH1D('hS_Dstar_gamma_m10_BDT','hS_Dstar_gamma_m10_BDT' , bins, bdt_min, bdt_max)
hS_Dstar_gamma_m10_BDT_pdf = fSDstarGamma_m10.Get("BDT")
hS_Dstar_gamma_m20_BDT_pdf = ROOT.TH1D('hS_Dstar_gamma_m20_BDT','hS_Dstar_gamma_m20_BDT' , bins, bdt_min, bdt_max)
hS_Dstar_gamma_m20_BDT_pdf = fSDstarGamma_m20.Get("BDT")
hS_Dstar_gamma_m30_BDT_pdf = ROOT.TH1D('hS_Dstar_gamma_m30_BDT','hS_Dstar_gamma_m30_BDT' , bins, bdt_min, bdt_max)
hS_Dstar_gamma_m30_BDT_pdf = fSDstarGamma_m30.Get("BDT")
hS_Dstar_gamma_m40_BDT_pdf = ROOT.TH1D('hS_Dstar_gamma_m40_BDT','hS_Dstar_gamma_m40_BDT' , bins, bdt_min, bdt_max)
hS_Dstar_gamma_m40_BDT_pdf = fSDstarGamma_m40.Get("BDT")
hS_Dstar_gamma_m45_BDT_pdf = ROOT.TH1D('hS_Dstar_gamma_m45_BDT','hS_Dstar_gamma_m45_BDT' , bins, bdt_min, bdt_max)
hS_Dstar_gamma_m45_BDT_pdf = fSDstarGamma_m45.Get("BDT")

hS_Dstar_pi0_m00_BDT_pdf = ROOT.TH1D('hS_Dstar_pi0_m00_BDT','hS_Dstar_pi0_m00_BDT' , bins, bdt_min, bdt_max)
hS_Dstar_pi0_m00_BDT_pdf = fSDstarPi0_m00.Get("BDT")
hS_Dstar_pi0_m10_BDT_pdf = ROOT.TH1D('hS_Dstar_pi0_m10_BDT','hS_Dstar_pi0_m10_BDT' , bins, bdt_min, bdt_max)
hS_Dstar_pi0_m10_BDT_pdf = fSDstarPi0_m10.Get("BDT")
hS_Dstar_pi0_m20_BDT_pdf = ROOT.TH1D('hS_Dstar_pi0_m20_BDT','hS_Dstar_pi0_m20_BDT' , bins, bdt_min, bdt_max)
hS_Dstar_pi0_m20_BDT_pdf = fSDstarPi0_m20.Get("BDT")
hS_Dstar_pi0_m30_BDT_pdf = ROOT.TH1D('hS_Dstar_pi0_m30_BDT','hS_Dstar_pi0_m30_BDT' , bins, bdt_min, bdt_max)
hS_Dstar_pi0_m30_BDT_pdf = fSDstarPi0_m30.Get("BDT")
hS_Dstar_pi0_m40_BDT_pdf = ROOT.TH1D('hS_Dstar_pi0_m40_BDT','hS_Dstar_pi0_m40_BDT' , bins, bdt_min, bdt_max)
hS_Dstar_pi0_m40_BDT_pdf = fSDstarPi0_m40.Get("BDT")
hS_Dstar_pi0_m45_BDT_pdf = ROOT.TH1D('hS_Dstar_pi0_m45_BDT','hS_Dstar_pi0_m45_BDT' , bins, bdt_min, bdt_max)
hS_Dstar_pi0_m45_BDT_pdf = fSDstarPi0_m45.Get("BDT")

# %%
hBkgStag_D_m00_BDT_pdf = ROOT.TH1D('hBkgStag_D_m00_BDT','hBkgStag_D_m00_BDT' , bins, bdt_min, bdt_max)
hBkgStag_D_m00_BDT_pdf = fBD_m30.Get("BDT")
hBkgStag_D_m10_BDT_pdf = ROOT.TH1D('hBkgStag_D_m10_BDT','hBkgStag_D_m10_BDT' , bins, bdt_min, bdt_max)
hBkgStag_D_m10_BDT_pdf = fBD_m30.Get("BDT")
hBkgStag_D_m20_BDT_pdf = ROOT.TH1D('hBkgStag_D_m20_BDT','hBkgStag_D_m20_BDT' , bins, bdt_min, bdt_max)
hBkgStag_D_m20_BDT_pdf = fBD_m30.Get("BDT")
hBkgStag_D_m30_BDT_pdf = ROOT.TH1D('hBkgStag_D_m30_BDT','hBkgStag_D_m30_BDT' , bins, bdt_min, bdt_max)
hBkgStag_D_m30_BDT_pdf = fBD_m30.Get("BDT")
hBkgStag_D_m40_BDT_pdf = ROOT.TH1D('hBkgStag_D_m40_BDT','hBkgStag_D_m40_BDT' , bins, bdt_min, bdt_max)
hBkgStag_D_m40_BDT_pdf = fBD_m40.Get("BDT")
hBkgStag_D_m45_BDT_pdf = ROOT.TH1D('hBkgStag_D_m45_BDT','hBkgStag_D_m45_BDT' , bins, bdt_min, bdt_max)
hBkgStag_D_m45_BDT_pdf = fBD_m45.Get("BDT")

hBkgStag_Dstar_gamma_m00_BDT_pdf = ROOT.TH1D('hBkgStag_Dstar_gamma_m00_BDT','hBkgStag_Dstar_gamma_m00_BDT' , bins, bdt_min, bdt_max)
hBkgStag_Dstar_gamma_m00_BDT_pdf = fBDstarGamma_m00.Get("BDT")
hBkgStag_Dstar_gamma_m10_BDT_pdf = ROOT.TH1D('hBkgStag_Dstar_gamma_m10_BDT','hBkgStag_Dstar_gamma_m10_BDT' , bins, bdt_min, bdt_max)
hBkgStag_Dstar_gamma_m10_BDT_pdf = fBDstarGamma_m10.Get("BDT")
hBkgStag_Dstar_gamma_m20_BDT_pdf = ROOT.TH1D('hBkgStag_Dstar_gamma_m20_BDT','hBkgStag_Dstar_gamma_m20_BDT' , bins, bdt_min, bdt_max)
hBkgStag_Dstar_gamma_m20_BDT_pdf = fBDstarGamma_m20.Get("BDT")
hBkgStag_Dstar_gamma_m30_BDT_pdf = ROOT.TH1D('hBkgStag_Dstar_gamma_m30_BDT','hBkgStag_Dstar_gamma_m30_BDT' , bins, bdt_min, bdt_max)
hBkgStag_Dstar_gamma_m30_BDT_pdf = fBDstarGamma_m30.Get("BDT")
hBkgStag_Dstar_gamma_m40_BDT_pdf = ROOT.TH1D('hBkgStag_Dstar_gamma_m40_BDT','hBkgStag_Dstar_gamma_m40_BDT' , bins, bdt_min, bdt_max)
hBkgStag_Dstar_gamma_m40_BDT_pdf = fBDstarGamma_m40.Get("BDT")
hBkgStag_Dstar_gamma_m45_BDT_pdf = ROOT.TH1D('hBkgStag_Dstar_gamma_m45_BDT','hBkgStag_Dstar_gamma_m45_BDT' , bins, bdt_min, bdt_max)
hBkgStag_Dstar_gamma_m45_BDT_pdf = fBDstarGamma_m45.Get("BDT")



hBkgStag_Dstar_pi0_m00_BDT_pdf = ROOT.TH1D('hBkgStag_Dstar_pi0_m00_BDT','hBkgStag_Dstar_pi0_m00_BDT' , bins, bdt_min, bdt_max)
hBkgStag_Dstar_pi0_m00_BDT_pdf = fBDstarPi0_m00.Get("BDT")
hBkgStag_Dstar_pi0_m10_BDT_pdf = ROOT.TH1D('hBkgStag_Dstar_pi0_m10_BDT','hBkgStag_Dstar_pi0_m10_BDT' , bins, bdt_min, bdt_max)
hBkgStag_Dstar_pi0_m10_BDT_pdf = fBDstarPi0_m10.Get("BDT")
hBkgStag_Dstar_pi0_m20_BDT_pdf = ROOT.TH1D('hBkgStag_Dstar_pi0_m20_BDT','hBkgStag_Dstar_pi0_m20_BDT' , bins, bdt_min, bdt_max)
hBkgStag_Dstar_pi0_m20_BDT_pdf = fBDstarPi0_m20.Get("BDT")
hBkgStag_Dstar_pi0_m30_BDT_pdf = ROOT.TH1D('hBkgStag_Dstar_pi0_m30_BDT','hBkgStag_Dstar_pi0_m30_BDT' , bins, bdt_min, bdt_max)
hBkgStag_Dstar_pi0_m30_BDT_pdf = fBDstarPi0_m30.Get("BDT")
hBkgStag_Dstar_pi0_m40_BDT_pdf = ROOT.TH1D('hBkgStag_Dstar_pi0_m40_BDT','hBkgStag_Dstar_pi0_m40_BDT' , bins, bdt_min, bdt_max)
hBkgStag_Dstar_pi0_m40_BDT_pdf = fBDstarPi0_m40.Get("BDT")
hBkgStag_Dstar_pi0_m45_BDT_pdf = ROOT.TH1D('hBkgStag_Dstar_pi0_m45_BDT','hBkgStag_Dstar_pi0_m45_BDT' , bins, bdt_min, bdt_max)
hBkgStag_Dstar_pi0_m45_BDT_pdf = fBDstarPi0_m45.Get("BDT")

# %% [markdown]
# ## Hadronic tags

# %%
hS_Had_D_m00_BDT_pdf = ROOT.TH1D('hS_Had_D_m00_BDT','hS_Had_D_m00_BDT' , bins_had, bdt_min, bdt_max)
hS_Had_D_m00_BDT_pdf = fSD_Had_m00.Get("BDT")
hS_Had_D_m10_BDT_pdf = ROOT.TH1D('hS_Had_D_m10_BDT','hS_Had_D_m10_BDT' , bins_had, bdt_min, bdt_max)
hS_Had_D_m10_BDT_pdf = fSD_Had_m10.Get("BDT")
hS_Had_D_m20_BDT_pdf = ROOT.TH1D('hS_Had_D_m20_BDT','hS_Had_D_m20_BDT' , bins_had, bdt_min, bdt_max)
hS_Had_D_m20_BDT_pdf = fSD_Had_m20.Get("BDT")
hS_Had_D_m30_BDT_pdf = ROOT.TH1D('hS_Had_D_m30_BDT','hS_Had_D_m30_BDT' , bins_had, bdt_min, bdt_max)
hS_Had_D_m30_BDT_pdf = fSD_Had_m30.Get("BDT")
hS_Had_D_m40_BDT_pdf = ROOT.TH1D('hS_Had_D_m40_BDT','hS_Had_D_m40_BDT' , bins_had, bdt_min, bdt_max)
hS_Had_D_m40_BDT_pdf = fSD_Had_m40.Get("BDT")
hS_Had_D_m45_BDT_pdf = ROOT.TH1D('hS_Had_D_m45_BDT','hS_Had_D_m45_BDT' , bins_had, bdt_min, bdt_max)
hS_Had_D_m45_BDT_pdf = fSD_Had_m45.Get("BDT")

hS_Had_Dstar_gamma_m00_BDT_pdf = ROOT.TH1D('hS_Had_Dstar_gamma_m00_BDT','hS_Had_Dstar_gamma_m00_BDT' , bins_had, bdt_min, bdt_max)
hS_Had_Dstar_gamma_m00_BDT_pdf = fSDstarGamma_Had_m00.Get("BDT")
hS_Had_Dstar_gamma_m10_BDT_pdf = ROOT.TH1D('hS_Had_Dstar_gamma_m10_BDT','hS_Had_Dstar_gamma_m10_BDT' , bins_had, bdt_min, bdt_max)
hS_Had_Dstar_gamma_m10_BDT_pdf = fSDstarGamma_Had_m10.Get("BDT")
hS_Had_Dstar_gamma_m20_BDT_pdf = ROOT.TH1D('hS_Had_Dstar_gamma_m20_BDT','hS_Had_Dstar_gamma_m20_BDT' , bins_had, bdt_min, bdt_max)
hS_Had_Dstar_gamma_m20_BDT_pdf = fSDstarGamma_Had_m20.Get("BDT")
hS_Had_Dstar_gamma_m30_BDT_pdf = ROOT.TH1D('hS_Had_Dstar_gamma_m30_BDT','hS_Had_Dstar_gamma_m30_BDT' , bins_had, bdt_min, bdt_max)
hS_Had_Dstar_gamma_m30_BDT_pdf = fSDstarGamma_Had_m30.Get("BDT")
hS_Had_Dstar_gamma_m40_BDT_pdf = ROOT.TH1D('hS_Had_Dstar_gamma_m40_BDT','hS_Had_Dstar_gamma_m40_BDT' , bins_had, bdt_min, bdt_max)
hS_Had_Dstar_gamma_m40_BDT_pdf = fSDstarGamma_Had_m40.Get("BDT")
hS_Had_Dstar_gamma_m45_BDT_pdf = ROOT.TH1D('hS_Had_Dstar_gamma_m45_BDT','hS_Had_Dstar_gamma_m45_BDT' , bins_had, bdt_min, bdt_max)
hS_Had_Dstar_gamma_m45_BDT_pdf = fSDstarGamma_Had_m45.Get("BDT")

hS_Had_Dstar_pi0_m00_BDT_pdf = ROOT.TH1D('hS_Had_Dstar_pi0_m00_BDT','hS_Had_Dstar_pi0_m00_BDT' , bins_had, bdt_min, bdt_max)
hS_Had_Dstar_pi0_m00_BDT_pdf = fSDstarPi0_Had_m00.Get("BDT")
hS_Had_Dstar_pi0_m10_BDT_pdf = ROOT.TH1D('hS_Had_Dstar_pi0_m10_BDT','hS_Had_Dstar_pi0_m10_BDT' , bins_had, bdt_min, bdt_max)
hS_Had_Dstar_pi0_m10_BDT_pdf = fSDstarPi0_Had_m10.Get("BDT")
hS_Had_Dstar_pi0_m20_BDT_pdf = ROOT.TH1D('hS_Had_Dstar_pi0_m20_BDT','hS_Had_Dstar_pi0_m20_BDT' , bins_had, bdt_min, bdt_max)
hS_Had_Dstar_pi0_m20_BDT_pdf = fSDstarPi0_Had_m20.Get("BDT")
hS_Had_Dstar_pi0_m30_BDT_pdf = ROOT.TH1D('hS_Had_Dstar_pi0_m30_BDT','hS_Had_Dstar_pi0_m30_BDT' , bins_had, bdt_min, bdt_max)
hS_Had_Dstar_pi0_m30_BDT_pdf = fSDstarPi0_Had_m30.Get("BDT")
hS_Had_Dstar_pi0_m40_BDT_pdf = ROOT.TH1D('hS_Had_Dstar_pi0_m40_BDT','hS_Had_Dstar_pi0_m40_BDT' , bins_had, bdt_min, bdt_max)
hS_Had_Dstar_pi0_m40_BDT_pdf = fSDstarPi0_Had_m40.Get("BDT")
hS_Had_Dstar_pi0_m45_BDT_pdf = ROOT.TH1D('hS_Had_Dstar_pi0_m45_BDT','hS_Had_Dstar_pi0_m45_BDT' , bins_had, bdt_min, bdt_max)
hS_Had_Dstar_pi0_m45_BDT_pdf = fSDstarPi0_Had_m45.Get("BDT")

# %%
hBkgHtag_D_m00_BDT_pdf = ROOT.TH1D('hBkgHtag_D_m00_BDT','hBkgHtag_D_m00_BDT' , bins_had, bdt_min, bdt_max)
hBkgHtag_D_m00_BDT_pdf = fBD_Had_m30.Get("BDT")
hBkgHtag_D_m10_BDT_pdf = ROOT.TH1D('hBkgHtag_D_m10_BDT','hBkgHtag_D_m10_BDT' , bins_had, bdt_min, bdt_max)
hBkgHtag_D_m10_BDT_pdf = fBD_Had_m30.Get("BDT")
hBkgHtag_D_m20_BDT_pdf = ROOT.TH1D('hBkgHtag_D_m20_BDT','hBkgHtag_D_m20_BDT' , bins_had, bdt_min, bdt_max)
hBkgHtag_D_m20_BDT_pdf = fBD_Had_m30.Get("BDT")
hBkgHtag_D_m30_BDT_pdf = ROOT.TH1D('hBkgHtag_D_m30_BDT','hBkgHtag_D_m30_BDT' , bins_had, bdt_min, bdt_max)
hBkgHtag_D_m30_BDT_pdf = fBD_Had_m30.Get("BDT")
hBkgHtag_D_m40_BDT_pdf = ROOT.TH1D('hBkgHtag_D_m40_BDT','hBkgHtag_D_m40_BDT' , bins_had, bdt_min, bdt_max)
hBkgHtag_D_m40_BDT_pdf = fBD_Had_m40.Get("BDT")
hBkgHtag_D_m45_BDT_pdf = ROOT.TH1D('hBkgHtag_D_m45_BDT','hBkgHtag_D_m45_BDT' , bins_had, bdt_min, bdt_max)
hBkgHtag_D_m45_BDT_pdf = fBD_Had_m45.Get("BDT")

hBkgHtag_Dstar_gamma_m00_BDT_pdf = ROOT.TH1D('hBkgHtag_Dstar_gamma_m00_BDT','hBkgHtag_Dstar_gamma_m00_BDT' , bins_had, bdt_min, bdt_max)
hBkgHtag_Dstar_gamma_m00_BDT_pdf = fBDstarGamma_Had_m00.Get("BDT")
hBkgHtag_Dstar_gamma_m10_BDT_pdf = ROOT.TH1D('hBkgHtag_Dstar_gamma_m10_BDT','hBkgHtag_Dstar_gamma_m10_BDT' , bins_had, bdt_min, bdt_max)
hBkgHtag_Dstar_gamma_m10_BDT_pdf = fBDstarGamma_Had_m10.Get("BDT")
hBkgHtag_Dstar_gamma_m20_BDT_pdf = ROOT.TH1D('hBkgHtag_Dstar_gamma_m20_BDT','hBkgHtag_Dstar_gamma_m20_BDT' , bins_had, bdt_min, bdt_max)
hBkgHtag_Dstar_gamma_m20_BDT_pdf = fBDstarGamma_Had_m20.Get("BDT")
hBkgHtag_Dstar_gamma_m30_BDT_pdf = ROOT.TH1D('hBkgHtag_Dstar_gamma_m30_BDT','hBkgHtag_Dstar_gamma_m30_BDT' , bins_had, bdt_min, bdt_max)
hBkgHtag_Dstar_gamma_m30_BDT_pdf = fBDstarGamma_Had_m30.Get("BDT")
hBkgHtag_Dstar_gamma_m40_BDT_pdf = ROOT.TH1D('hBkgHtag_Dstar_gamma_m40_BDT','hBkgHtag_Dstar_gamma_m40_BDT' , bins_had, bdt_min, bdt_max)
hBkgHtag_Dstar_gamma_m40_BDT_pdf = fBDstarGamma_Had_m40.Get("BDT")
hBkgHtag_Dstar_gamma_m45_BDT_pdf = ROOT.TH1D('hBkgHtag_Dstar_gamma_m45_BDT','hBkgHtag_Dstar_gamma_m45_BDT' , bins_had, bdt_min, bdt_max)
hBkgHtag_Dstar_gamma_m45_BDT_pdf = fBDstarGamma_Had_m45.Get("BDT")



hBkgHtag_Dstar_pi0_m00_BDT_pdf = ROOT.TH1D('hBkgHtag_Dstar_pi0_m00_BDT','hBkgHtag_Dstar_pi0_m00_BDT' , bins_had, bdt_min, bdt_max)
hBkgHtag_Dstar_pi0_m00_BDT_pdf = fBDstarPi0_Had_m00.Get("BDT")
hBkgHtag_Dstar_pi0_m10_BDT_pdf = ROOT.TH1D('hBkgHtag_Dstar_pi0_m10_BDT','hBkgHtag_Dstar_pi0_m10_BDT' , bins_had, bdt_min, bdt_max)
hBkgHtag_Dstar_pi0_m10_BDT_pdf = fBDstarPi0_Had_m10.Get("BDT")
hBkgHtag_Dstar_pi0_m20_BDT_pdf = ROOT.TH1D('hBkgHtag_Dstar_pi0_m20_BDT','hBkgHtag_Dstar_pi0_m20_BDT' , bins_had, bdt_min, bdt_max)
hBkgHtag_Dstar_pi0_m20_BDT_pdf = fBDstarPi0_Had_m20.Get("BDT")
hBkgHtag_Dstar_pi0_m30_BDT_pdf = ROOT.TH1D('hBkgHtag_Dstar_pi0_m30_BDT','hBkgHtag_Dstar_pi0_m30_BDT' , bins_had, bdt_min, bdt_max)
hBkgHtag_Dstar_pi0_m30_BDT_pdf = fBDstarPi0_Had_m30.Get("BDT")
hBkgHtag_Dstar_pi0_m40_BDT_pdf = ROOT.TH1D('hBkgHtag_Dstar_pi0_m40_BDT','hBkgHtag_Dstar_pi0_m40_BDT' , bins_had, bdt_min, bdt_max)
hBkgHtag_Dstar_pi0_m40_BDT_pdf = fBDstarPi0_Had_m40.Get("BDT")
hBkgHtag_Dstar_pi0_m45_BDT_pdf = ROOT.TH1D('hBkgHtag_Dstar_pi0_m45_BDT','hBkgHtag_Dstar_pi0_m45_BDT' , bins_had, bdt_min, bdt_max)
hBkgHtag_Dstar_pi0_m45_BDT_pdf = fBDstarPi0_Had_m45.Get("BDT")

# %% [markdown]
# ## Charge the histograms 2D

# %%
hS_m30_2D_pdf = ROOT.TH2D('hS_m30_2D_pdf','hS_m30_2D_pdf' , nbinsL, Mmin2Low, Mmin2Up, nbinsH, Mmax2Low, Mmax2Up)
hS_m30_2D_pdf = fSD_2D_m30.Get("2D")

hS_Dstar_gamma_m30_2D_pdf = ROOT.TH2D('hS_Dstar_gamma_m30_2D_pdf','hS_Dstar_gamma_m30_2D_pdf' , nbinsL, Mmin2Low, Mmin2Up, nbinsH, Mmax2Low, Mmax2Up)
hS_Dstar_gamma_m30_2D_pdf = fSDstarGamma_2D_m30.Get("2D")

hS_Dstar_pi0_m30_2D_pdf = ROOT.TH2D('hS_Dstar_pi0_m30_2D_pdf','hS_Dstar_pi0_m30_2D_pdf' , nbinsL, Mmin2Low, Mmin2Up, nbinsH, Mmax2Low, Mmax2Up)
hS_Dstar_pi0_m30_2D_pdf = fSDstarPi0_2D_m30.Get("2D")

# %%
hB_2D_pdf = ROOT.TH2D('hB_2D_pdf','hB_2D_pdf' , nbinsL, Mmin2Low, Mmin2Up, nbinsH, Mmax2Low, Mmax2Up)
hB_2D_pdf = fBD_2D.Get("2D")

hB_Dstar_gamma_2D_pdf = ROOT.TH2D('hB_Dstar_gamma_2D_pdf','hB_Dstar_gamma_2D_pdf' , nbinsL, Mmin2Low, Mmin2Up, nbinsH, Mmax2Low, Mmax2Up)
hB_Dstar_gamma_2D_pdf = fBDstarGamma_2D.Get("2D")

hB_Dstar_pi0_2D_pdf = ROOT.TH2D('hB_Dstar_pi0_2D_pdf','hB_Dstar_pi0_2D_pdf' , nbinsL, Mmin2Low, Mmin2Up, nbinsH, Mmax2Low, Mmax2Up)
hB_Dstar_pi0_2D_pdf = fBDstarPi0_2D.Get("2D")

# %%
c1 = ROOT.TCanvas("a","a",800,400)

c1.Divide(3)
c1.cd(1)
hS_D_m00_BDT_pdf.Draw()
hBkgStag_D_m00_BDT_pdf.Draw("SAME")
#hpi_nunu_Mmin2_pdf.Draw("SAME")
c1.cd(2)
hS_Dstar_gamma_m00_BDT_pdf.Draw()
hBkgStag_Dstar_gamma_m30_BDT_pdf.Draw("SAME")

c1.cd(3)
hS_Dstar_pi0_m00_BDT_pdf.Draw()
hBkgStag_Dstar_pi0_m00_BDT_pdf.Draw("SAME")
#hBkgStag_D_Mmax2_pdf.Draw("SAME")
#hpi_nunu_Mmax2_pdf.Draw("SAME")
c1.Draw()

# %%
c2 = ROOT.TCanvas("b","b",800,400)

c2.Divide(3)
c2.cd(1)
hS_D_m45_BDT_pdf.Draw()
hBkgStag_D_m45_BDT_pdf.Draw("SAME")
#hBkgStag_D_Mmin2_pdf.Draw("SAME")
#hpi_nunu_Mmin2_pdf.Draw("SAME")
c2.cd(2)
hS_Dstar_gamma_m45_BDT_pdf.Draw()
hBkgStag_Dstar_gamma_m45_BDT_pdf.Draw("SAME")
#hBkgStag_D_Mmax2_pdf.Draw("SAME")
#hpi_nunu_Mmax2_pdf.Draw("SAME")
c2.Draw()

# %%
c3 = ROOT.TCanvas("c","c",800,400)

c3.Divide(3)
c3.cd(1)
hS_Had_D_m00_BDT_pdf.Draw()
hBkgHtag_D_m00_BDT_pdf.Draw("SAME")
#hpi_nunu_Mmin2_pdf.Draw("SAME")
c3.cd(2)
hS_Had_Dstar_gamma_m00_BDT_pdf.Draw()
hBkgHtag_Dstar_gamma_m00_BDT_pdf.Draw("SAME")

c3.cd(3)
hS_Had_Dstar_pi0_m00_BDT_pdf.Draw()
hBkgHtag_Dstar_pi0_m00_BDT_pdf.Draw("SAME")
#hBkgStag_D_Mmax2_pdf.Draw("SAME")
#hpi_nunu_Mmax2_pdf.Draw("SAME")
c3.Draw()

# %%
c4 = ROOT.TCanvas("c4","c4",800,400)

c4.Divide(4)
c4.cd(1)
hS_m30_2D_pdf.Draw("CONTZ")
c4.cd(2)
hB_2D_pdf.Draw("CONTZ")
c4.cd(3)
hS_Dstar_gamma_m30_2D_pdf.Draw("CONTZ")
c4.cd(4)
hB_Dstar_gamma_2D_pdf.Draw("CONTZ")
c4.Draw()
